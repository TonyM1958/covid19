# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Get the latest json data from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Check data against the world figures at <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>
# <br>Example region codes: UK, FR, IT, DE, ES, US, CN, KR, JP, RU, NZ, AU, BE, IE

# %%
import covid

# %%
# United Kingdom
# lag and dilation set so prediction tracks latest data
covid.Region(geoId='UK', dilation=2.5, d_cases=1).analyse(ylog=0)
# Out:
# UK confirmed data up to end of 2020-04-24:
#   143,464 confirmed cases, 19,506 deaths
#   2,158 cases per million, 293 deaths per million (population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-02 (-53 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-15 ( -9 days)
#   End:         2020-05-28 ( 35 days, 44 days after peak cases)
#   Day Zero:    2020-03-16 (-39 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-12 (-12 days)
#
# Parameters:
#   Totals:      124,743 cases and 16,509 deaths at end of 2020-04-20
#   Smoothed:    124,742 cases and 16,508 deaths at end of 2020-04-20 (9 points)
#   Spread:      Peak infection rate 5.7 (2020-03-16, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-20, compared to 7 days earlier)
#   Growth:      44 days (Start -> Peak Cases)
#   Lag:         -3 days (Peak Cases -> Peak Deaths)
# ...

# %%
# China
covid.Region(geoId='CN', dilation=1).analyse(ylog=1)
# Out:
# CN confirmed data up to end of 2020-04-24:
#   83,899 confirmed cases, 4,636 deaths
#   60 cases per million, 3 deaths per million (population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-01-15 (-100 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-09 (-75 days)
#   End:         2020-03-04 (-50 days, 25 days after peak cases)
#   Day Zero:    2020-01-24 (-91 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-16 (-68 days)
#
# Parameters:
#   Totals:      83,849 cases and 4,636 deaths at end of 2020-04-20
#   Smoothed:    83,848 cases and 4,636 deaths at end of 2020-04-20 (9 points)
#   Spread:      Peak infection rate 15.3 (2020-01-22, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-04-20, compared to 7 days earlier)
#   Growth:      25 days (Start -> Peak Cases)
#   Lag:         7 days (Peak Cases -> Peak Deaths)
# ...

# %%
# Spain
covid.Region(geoId='ES', dilation=3, d_cases=4.5).analyse(ylog=0)
# Out:
# ES confirmed data up to end of 2020-04-24:
#   219,764 confirmed cases, 22,524 deaths
#   4,703 cases per million, 482 deaths per million (population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-28 (-56 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-26 days)
#   End:         2020-04-27 (  4 days, 30 days after peak cases)
#   Day Zero:    2020-03-10 (-45 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-24 days)
#
# Parameters:
#   Totals:      200,210 cases and 20,852 deaths at end of 2020-04-20
#   Smoothed:    200,210 cases and 20,851 deaths at end of 2020-04-20 (9 points)
#   Spread:      Peak infection rate 13.6 (2020-03-10, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-04-20, compared to 7 days earlier)
#   Growth:      30 days (Start -> Peak Cases)
#   Lag:         2 days (Peak Cases -> Peak Deaths)
# ...

# %%
# Italy
covid.Region(geoId='IT', dilation=2, d_cases=3).analyse(ylog=0)
# Out:
# IT confirmed data up to end of 2020-04-24:
#   192,994 confirmed cases, 25,969 deaths
#   3,194 cases per million, 430 deaths per million (population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-20 (-64 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-24 (-31 days)
#   End:         2020-04-25 (  2 days, 33 days after peak cases)
#   Day Zero:    2020-03-01 (-54 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-24 days)
#
# Parameters:
#   Totals:      181,228 cases and 24,114 deaths at end of 2020-04-20
#   Smoothed:    181,227 cases and 24,114 deaths at end of 2020-04-20 (9 points)
#   Spread:      Peak infection rate 13.0 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-04-20, compared to 7 days earlier)
#   Growth:      33 days (Start -> Peak Cases)
#   Lag:         7 days (Peak Cases -> Peak Deaths)
# ...

# %%
# France
covid.Region(geoId='FR', dilation=2).analyse(ylog=0)
# Out:
# FR confirmed data up to end of 2020-04-24:
#   122,577 confirmed cases, 22,245 deaths
#   1,830 cases per million, 332 deaths per million (population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-27 (-57 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-31 (-24 days)
#   End:         2020-05-02 (  9 days, 33 days after peak cases)
#   Day Zero:    2020-03-11 (-44 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-07 (-17 days)
#
# Parameters:
#   Totals:      114,657 cases and 20,265 deaths at end of 2020-04-20
#   Smoothed:    114,656 cases and 20,264 deaths at end of 2020-04-20 (9 points)
#   Spread:      Peak infection rate 8.3 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-04-20, compared to 7 days earlier)
#   Growth:      33 days (Start -> Peak Cases)
#   Lag:         7 days (Peak Cases -> Peak Deaths)
# ...

# %%
# Germany
covid.Region(geoId='DE', dilation=1, d_cases=2).analyse(ylog=0)
# Out:
# DE confirmed data up to end of 2020-04-24:
#   152,438 confirmed cases, 5,500 deaths
#   1,838 cases per million, 66 deaths per million (population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-27 (-57 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-31 (-24 days)
#   End:         2020-05-02 (  9 days, 33 days after peak cases)
#   Day Zero:    2020-03-20 (-35 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 ( -6 days)
#
# Parameters:
#   Totals:      143,457 cases and 4,598 deaths at end of 2020-04-20
#   Smoothed:    143,457 cases and 4,597 deaths at end of 2020-04-20 (9 points)
#   Spread:      Peak infection rate 7.2 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-04-20, compared to 7 days earlier)
#   Growth:      33 days (Start -> Peak Cases)
#   Lag:         18 days (Peak Cases -> Peak Deaths)
# ...

# %%
# United States of America
covid.Region(geoId='US', dilation=1, d_cases=3.2).analyse(ylog=0)
# Out:
# US confirmed data up to end of 2020-04-24:
#   890,524 confirmed cases, 51,017 deaths
#   2,722 cases per million, 156 deaths per million (population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-25 (-59 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-06 (-18 days)
#   End:         2020-05-16 ( 23 days, 41 days after peak cases)
#   Day Zero:    2020-03-13 (-42 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-19 ( -5 days)
#
# Parameters:
#   Totals:      787,752 cases and 42,539 deaths at end of 2020-04-20
#   Smoothed:    787,752 cases and 42,538 deaths at end of 2020-04-20 (9 points)
#   Spread:      Peak infection rate 11.4 (2020-03-07, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-20, compared to 7 days earlier)
#   Growth:      41 days (Start -> Peak Cases)
#   Lag:         13 days (Peak Cases -> Peak Deaths)
# ...

# %%
# Japan
covid.Region(geoId='JP', dilation=10, lag=14).analyse(ylog=1)
# Out:
# JP confirmed data up to end of 2020-04-24:
#   12,892 confirmed cases, 334 deaths
#   102 cases per million, 3 deaths per million (population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-16 (-68 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-14 (-10 days)
#   End:         2020-06-10 ( 48 days, 58 days after peak cases)
#   Day Zero:    2020-03-31 (-24 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-19 ( -5 days)
#
# Parameters:
#   Totals:      11,118 cases and 186 deaths at end of 2020-04-20
#   Smoothed:    11,118 cases and 186 deaths at end of 2020-04-20 (9 points)
#   Spread:      Peak infection rate 2.7 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-04-20, compared to 7 days earlier)
#   Growth:      58 days (Start -> Peak Cases)
#   Lag:         5 days (Peak Cases -> Peak Deaths)
#   Prediction:  Cases L = 2,542 r = 8.0, dilation = 10
# ...

# %%
# Russia
covid.Region(geoId='RU', dilation=7, growth_days=45).analyse(ylog=1)
# Out:
# RU confirmed data up to end of 2020-04-24:
#   68,622 confirmed cases, 615 deaths
#   475 cases per million, 4 deaths per million (population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-14 (-41 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-28 (  4 days)
#   End:         2020-06-11 ( 49 days, 45 days after peak cases)
#   Day Zero:    2020-04-06 (-18 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-02 (  8 days)
#
# Parameters:
#   Totals:      47,121 cases and 405 deaths at end of 2020-04-20
#   Smoothed:    47,120 cases and 405 deaths at end of 2020-04-20 (9 points)
#   Spread:      Peak infection rate 4.4 (2020-03-27, compared to 7 days earlier)
#                Latest infection rate 1.9 (2020-04-20, compared to 7 days earlier)
#   Growth:      45 days (Start -> Peak Cases)
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#   Prediction:  Cases L = 26,546 r = 6.47, dilation = 7
# ...

# %%
# New Zealand
covid.Region(geoId='NZ').analyse(ylog=0)
# Out:
# NZ confirmed data up to end of 2020-04-24:
#   1,117 confirmed cases, 18 deaths
#   229 cases per million, 4 deaths per million (population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-19 (-36 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-26 days)
#   End:         2020-04-07 (-16 days, 10 days after peak cases)
#
# Parameters:
#   Totals:      1,107 cases and 13 deaths at end of 2020-04-20
#   Smoothed:    1,107 cases and 13 deaths at end of 2020-04-20 (9 points)
#   Spread:      Peak infection rate 1.8 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.3 (2020-04-20, compared to 7 days earlier)
#   Growth:      10 days (Start -> Peak Cases)
#               Raw ----------     Total --------     Smoothed ------   Total ---------
# Date          Cases   Deaths     Cases   Deaths     Cases   Deaths     Cases   Deaths
# ...

# %%
# Belgium
covid.Region(geoId='BE', dilation=1, d_cases=1.5).analyse(ylog=0)
# Out:
# BE confirmed data up to end of 2020-04-24:
#   44,293 confirmed cases, 6,679 deaths
#   3,878 cases per million, 585 deaths per million (population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-04 (-51 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-08 (-16 days)
#   End:         2020-05-12 ( 19 days, 35 days after peak cases)
#   Day Zero:    2020-03-21 (-34 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-14 (-10 days)
#
# Parameters:
#   Totals:      39,983 cases and 5,828 deaths at end of 2020-04-20
#   Smoothed:    39,983 cases and 5,827 deaths at end of 2020-04-20 (9 points)
#   Spread:      Peak infection rate 4.1 (2020-03-14, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-04-20, compared to 7 days earlier)
#   Growth:      35 days (Start -> Peak Cases)
#   Lag:         6 days (Peak Cases -> Peak Deaths)
# ...

# %%
# Ireland
covid.Region(geoId='IE', lag=10).analyse()
# Out:
# IE confirmed data up to end of 2020-04-24:
#   18,184 confirmed cases, 829 deaths
#   3,747 cases per million, 171 deaths per million (population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-11 (-44 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-11 days)
#   End:         2020-05-15 ( 22 days, 33 days after peak cases)
#   Day Zero:    2020-03-29 (-26 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 ( -6 days)
#
# Parameters:
#   Totals:      15,652 cases and 687 deaths at end of 2020-04-20
#   Smoothed:    15,652 cases and 687 deaths at end of 2020-04-20 (9 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-20, compared to 7 days earlier)
#   Growth:      33 days (Start -> Peak Cases)
#   Lag:         5 days (Peak Cases -> Peak Deaths)
#   Prediction:  Cases L = 3,433 r = 5.11, dilation = 2
# ...
