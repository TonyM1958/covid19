# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Get the latest json data from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Check data against the world figures at <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>
# <br>Example region codes: UK, FR, IT, DE, ES, US, CN, KR, JP, RU, NZ, AU, BE, IE

# %%
import covid

# %%
# United Kingdom
# lag and dilation set so prediction tracks latest data
covid.Region(geoId='UK', dilation=1.6, d_cases=1).analyse(ylog=1)
# Out:
# UK confirmed data up to end of 2020-04-23:
#   138,078 confirmed cases, 18,738 deaths
#   2,077 cases per million, 282 deaths per million (population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-02 (-52 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-15 ( -8 days)
#   End:         2020-05-28 ( 36 days, 44 days after peak cases)
#   Day Zero:    2020-03-16 (-38 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-12 (-11 days)
#
# Parameters:
#   Totals:      120,067 cases and 16,060 deaths at end of 2020-04-19
#   Smoothed:    120,066 cases and 16,059 deaths at end of 2020-04-19 (9 points)
#   Spread:      Peak infection rate 5.7 (2020-03-16, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-19, compared to 7 days earlier)
#   Growth:      44 days (Start -> Peak Cases)
#   Lag:         -3 days (Peak Cases -> Peak Deaths)
# ...

# %%
# China
covid.Region(geoId='CN', dilation=1).analyse(ylog=1)
# Out:
# CN confirmed data up to end of 2020-04-22:
#   83,876 confirmed cases, 4,636 deaths
#   60 cases per million, 3 deaths per million (population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-01-15 (-98 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-09 (-73 days)
#   End:         2020-03-04 (-48 days, 25 days after peak cases)
#   Day Zero:    2020-01-24 (-89 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-16 (-66 days)
#
# Parameters:
#   Totals:      83,803 cases and 4,636 deaths at end of 2020-04-18
#   Smoothed:    83,802 cases and 4,636 deaths at end of 2020-04-18 (9 points)
#   Spread:      Peak infection rate 15.3 (2020-01-22, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-04-18, compared to 7 days earlier)
#   Growth:      25 days (Start -> Peak Cases)
#   Lag:         7 days (Peak Cases -> Peak Deaths)
# ...

# %%
# Spain
covid.Region(geoId='ES', dilation=2.6, d_cases=3).analyse()
# Out:
# ES confirmed data up to end of 2020-04-22:
#   208,389 confirmed cases, 21,717 deaths
#   4,460 cases per million, 465 deaths per million (population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-28 (-54 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-24 days)
#   End:         2020-04-27 (  6 days, 30 days after peak cases)
#   Day Zero:    2020-03-10 (-43 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-22 days)
#
# Parameters:
#   Totals:      191,726 cases and 20,043 deaths at end of 2020-04-18
#   Smoothed:    191,726 cases and 20,042 deaths at end of 2020-04-18 (9 points)
#   Spread:      Peak infection rate 13.6 (2020-03-10, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-18, compared to 7 days earlier)
#   Growth:      30 days (Start -> Peak Cases)
#   Lag:         2 days (Peak Cases -> Peak Deaths)
# ...

# %%
# Italy
covid.Region(geoId='IT', dilation=1.9, d_cases=2.8).analyse()
# Out:
# IT confirmed data up to end of 2020-04-22:
#   187,327 confirmed cases, 25,085 deaths
#   3,100 cases per million, 415 deaths per million (population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-20 (-62 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-24 (-29 days)
#   End:         2020-04-25 (  4 days, 33 days after peak cases)
#   Day Zero:    2020-03-01 (-52 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-22 days)
#
# Parameters:
#   Totals:      175,925 cases and 23,227 deaths at end of 2020-04-18
#   Smoothed:    175,924 cases and 23,227 deaths at end of 2020-04-18 (9 points)
#   Spread:      Peak infection rate 13.0 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-18, compared to 7 days earlier)
#   Growth:      33 days (Start -> Peak Cases)
#   Lag:         7 days (Peak Cases -> Peak Deaths)
# ...

# %%
# France
covid.Region(geoId='FR', dilation=1.6, d_cases=1.9).analyse()
# Out:
# FR confirmed data up to end of 2020-04-22:
#   119,151 confirmed cases, 21,340 deaths
#   1,779 cases per million, 319 deaths per million (population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-27 (-55 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-31 (-22 days)
#   End:         2020-05-02 ( 11 days, 33 days after peak cases)
#   Day Zero:    2020-03-11 (-42 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-07 (-15 days)
#
# Parameters:
#   Totals:      111,821 cases and 19,323 deaths at end of 2020-04-18
#   Smoothed:    111,820 cases and 19,323 deaths at end of 2020-04-18 (9 points)
#   Spread:      Peak infection rate 8.3 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-18, compared to 7 days earlier)
#   Growth:      33 days (Start -> Peak Cases)
#   Lag:         7 days (Peak Cases -> Peak Deaths)
# ...

# %%
# Germany
covid.Region(geoId='DE', dilation=1, d_cases=2).analyse()
# Out:
# DE confirmed data up to end of 2020-04-22:
#   148,046 confirmed cases, 5,094 deaths
#   1,785 cases per million, 61 deaths per million (population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-27 (-55 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-31 (-22 days)
#   End:         2020-05-02 ( 11 days, 33 days after peak cases)
#   Day Zero:    2020-03-20 (-33 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 ( -4 days)
#
# Parameters:
#   Totals:      139,897 cases and 4,294 deaths at end of 2020-04-18
#   Smoothed:    139,897 cases and 4,294 deaths at end of 2020-04-18 (9 points)
#   Spread:      Peak infection rate 7.2 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-18, compared to 7 days earlier)
#   Growth:      33 days (Start -> Peak Cases)
#   Lag:         18 days (Peak Cases -> Peak Deaths)
# ...

# %%
# United States of America
covid.Region(geoId='US', dilation=1.3, d_cases=3).analyse(ylog=1)
# Out:
# US confirmed data up to end of 2020-04-22:
#   842,629 confirmed cases, 46,784 deaths
#   2,576 cases per million, 143 deaths per million (population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-25 (-57 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-06 (-16 days)
#   End:         2020-05-16 ( 25 days, 41 days after peak cases)
#   Day Zero:    2020-03-13 (-40 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 ( -4 days)
#
# Parameters:
#   Totals:      735,086 cases and 38,910 deaths at end of 2020-04-18
#   Smoothed:    735,085 cases and 38,909 deaths at end of 2020-04-18 (9 points)
#   Spread:      Peak infection rate 11.4 (2020-03-07, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-04-18, compared to 7 days earlier)
#   Growth:      41 days (Start -> Peak Cases)
#   Lag:         12 days (Peak Cases -> Peak Deaths)
# ...

# %%
# Japan
covid.Region(geoId='JP', dilation=2, lag=6).analyse(ylog=1)
# Out:
# JP confirmed data up to end of 2020-04-22:
#   11,772 confirmed cases, 287 deaths
#   93 cases per million, 2 deaths per million (population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-15 (-67 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-14 ( -8 days)
#   End:         2020-06-11 ( 51 days, 59 days after peak cases)
#   Day Zero:    2020-03-30 (-23 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-20 ( -2 days)
#
# Parameters:
#   Totals:      10,361 cases and 161 deaths at end of 2020-04-18
#   Smoothed:    10,361 cases and 161 deaths at end of 2020-04-18 (9 points)
#   Spread:      Peak infection rate 2.7 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-18, compared to 7 days earlier)
#   Growth:      59 days (Start -> Peak Cases)
#   Lag:         6 days (Peak Cases -> Peak Deaths)
#   Prediction:  Cases L = 2,589 r = 8.0, dilation = 2
# ...

# %%
# Russia
covid.Region(geoId='RU', dilation=10, growth_days=47).analyse(ylog=1)
# Out:
# RU confirmed data up to end of 2020-04-22:
#   57,999 confirmed cases, 513 deaths
#   401 cases per million, 4 deaths per million (population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-14 (-39 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-30 (  8 days)
#   End:         2020-06-15 ( 55 days, 47 days after peak cases)
#   Day Zero:    2020-04-06 (-16 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-04 ( 12 days)
#
# Parameters:
#   Totals:      36,793 cases and 313 deaths at end of 2020-04-18
#   Smoothed:    36,793 cases and 313 deaths at end of 2020-04-18 (9 points)
#   Spread:      Peak infection rate 4.4 (2020-03-27, compared to 7 days earlier)
#                Latest infection rate 2.2 (2020-04-18, compared to 7 days earlier)
#   Growth:      47 days (Start -> Peak Cases)
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#   Prediction:  Cases L = 33,017 r = 6.73, dilation = 10
# ...

# %%
# New Zealand
covid.Region(geoId='NZ').analyse(ylog=0)
# Out:
# NZ confirmed data up to end of 2020-04-22:
#   1,112 confirmed cases, 16 deaths
#   228 cases per million, 3 deaths per million (population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-19 (-34 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-24 days)
#   End:         2020-04-07 (-14 days, 10 days after peak cases)
#
# Parameters:
#   Totals:      1,098 cases and 12 deaths at end of 2020-04-18
#   Smoothed:    1,098 cases and 12 deaths at end of 2020-04-18 (9 points)
#   Spread:      Peak infection rate 1.8 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.3 (2020-04-18, compared to 7 days earlier)
#   Growth:      10 days (Start -> Peak Cases)
#               Raw ----------     Total --------     Smoothed ------   Total ---------
# Date          Cases   Deaths     Cases   Deaths     Cases   Deaths     Cases   Deaths
# ...

# %%
# Belgium
covid.Region(geoId='BE', dilation=0.7, d_cases=1.5).analyse()
# Out:
# BE confirmed data up to end of 2020-04-22:
#   41,889 confirmed cases, 6,262 deaths
#   3,667 cases per million, 548 deaths per million (population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-04 (-49 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-08 (-14 days)
#   End:         2020-05-12 ( 21 days, 35 days after peak cases)
#   Day Zero:    2020-03-21 (-32 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-14 ( -8 days)
#
# Parameters:
#   Totals:      37,183 cases and 5,453 deaths at end of 2020-04-18
#   Smoothed:    37,183 cases and 5,453 deaths at end of 2020-04-18 (9 points)
#   Spread:      Peak infection rate 4.1 (2020-03-14, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-18, compared to 7 days earlier)
#   Growth:      35 days (Start -> Peak Cases)
#   Lag:         6 days (Peak Cases -> Peak Deaths)
# ...

# %%
# Ireland
covid.Region(geoId='IE', lag=9, dilation=1).analyse()
# Out:
# IE confirmed data up to end of 2020-04-22:
#   16,671 confirmed cases, 769 deaths
#   3,435 cases per million, 158 deaths per million (population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-11 (-42 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 ( -9 days)
#   End:         2020-05-15 ( 24 days, 33 days after peak cases)
#   Day Zero:    2020-03-30 (-23 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (  0 days)
#
# Parameters:
#   Totals:      14,758 cases and 571 deaths at end of 2020-04-18
#   Smoothed:    14,757 cases and 571 deaths at end of 2020-04-18 (9 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-04-18, compared to 7 days earlier)
#   Growth:      33 days (Start -> Peak Cases)
#   Lag:         9 days (Peak Cases -> Peak Deaths)
#   Prediction:  Cases L = 3,531 r = 5.12, dilation = 1
# ...
