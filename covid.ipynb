# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://coronavirus.data.gov.uk/">coronavirus.data.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# smoothing changed to 7 days instead of 9
covid.data_load('download.json', smooth=7)
# Out:
# 207 region(s) found in download.json

# %%
covid.Region(geoId='UK', dilation=4.4, d_cases=3.7).analyse()
# note: deaths include all settings and revisions for Wales
# Out:
# United Kingdom data to end of 2020-04-30:
#   171,253 cases, 26,771 deaths
#   2,576 cases per million, 403 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-02 (-59 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-19 days)
#   End:         2020-06-29 ( 61 days, 80 days after peak cases)
#   Day Zero:    2020-03-16 (-45 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-19 days)
#
# Parameters:
#   Totals:      157,149 cases and 24,393 deaths at end of 2020-04-27
#   Smoothed:    157,149 cases and 24,393 deaths at end of 2020-04-27 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-27, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
#                L = 22,086, r = 5.89, dilation = 3.7 for cases
# ...

# %%
covid.Region(geoId='CN').analyse(ylog=1)
# Out:
# China data to end of 2020-04-29:
#   83,944 cases, 4,637 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-01-15 (-105 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-79 days)
#   End:         2020-03-06 (-53 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-95 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-74 days)
#
# Parameters:
#   Totals:      83,912 cases and 4,637 deaths at end of 2020-04-26
#   Smoothed:    83,912 cases and 4,637 deaths at end of 2020-04-26 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.1 (2020-04-26, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
#                L = 18,756, r = 5.66, dilation = 1 for cases
#   Lag:         5 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='ES', dilation=5, d_cases=3.5).analyse()
# note: ECDC cases data differs from Worldometer by ~24,000 cases (anti-body tests?)
# Out:
# Spain data to end of 2020-04-29:
#   215,657 cases, 24,543 deaths
#   4,616 cases per million, 525 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-29 (-60 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-28 (-32 days)
#   End:         2020-05-22 ( 24 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-49 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-29 days)
#
# Parameters:
#   Totals:      209,465 cases and 23,190 deaths at end of 2020-04-26
#   Smoothed:    209,465 cases and 23,190 deaths at end of 2020-04-26 (7 points)
#   Spread:      Peak infection rate 14.6 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-04-26, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
#                L = 31,302, r = 8.0, dilation = 3.5 for cases
# ...

# %%
covid.Region(geoId='IT', dilation=2.2, d_cases=3.1).analyse()
# Out:
# Italy data to end of 2020-04-29:
#   203,591 cases, 27,682 deaths
#   3,369 cases per million, 458 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-21 (-68 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-37 days)
#   End:         2020-05-23 ( 25 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-58 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-30 days)
#
# Parameters:
#   Totals:      197,675 cases and 26,644 deaths at end of 2020-04-26
#   Smoothed:    197,674 cases and 26,644 deaths at end of 2020-04-26 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-26, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
#                L = 22,626, r = 5.72, dilation = 3.1 for cases
# ...

# %%
covid.Region(geoId='FR', dilation=3.1).analyse()
# Out:
# France data to end of 2020-04-29:
#   128,442 cases, 24,087 deaths
#   1,917 cases per million, 360 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-27 (-62 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-31 days)
#   End:         2020-05-29 ( 31 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-49 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-23 days)
#
# Parameters:
#   Totals:      124,575 cases and 22,856 deaths at end of 2020-04-26
#   Smoothed:    124,574 cases and 22,856 deaths at end of 2020-04-26 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-26, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
#                L = 18,123, r = 8.0, dilation = 3.1 for cases
# ...

# %%
covid.Region(geoId='DE', dilation=1.3, d_cases=2).analyse()
# Out:
# Germany data to end of 2020-04-29:
#   159,119 cases, 6,288 deaths
#   1,919 cases per million, 76 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-27 (-62 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-28 days)
#   End:         2020-06-07 ( 40 days, 68 days after peak cases)
#   Day Zero:    2020-03-20 (-40 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-12 days)
#
# Parameters:
#   Totals:      155,193 cases and 5,750 deaths at end of 2020-04-26
#   Smoothed:    155,193 cases and 5,750 deaths at end of 2020-04-26 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-04-26, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
#                L = 22,403, r = 6.78, dilation = 2 for cases
#   Lag:         16 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='US', dilation=1.5, d_cases=3.3).analyse()
# Out:
# United States of America data to end of 2020-04-29:
#   1,039,909 cases, 60,966 deaths
#   3,179 cases per million, 186 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-25 (-64 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-22 days)
#   End:         2020-06-29 ( 62 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-47 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-11 days)
#
# Parameters:
#   Totals:      965,910 cases and 54,876 deaths at end of 2020-04-26
#   Smoothed:    965,910 cases and 54,876 deaths at end of 2020-04-26 (7 points)
#   Spread:      Peak infection rate 12.5 (2020-03-07, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-04-26, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
#                L = 128,831, r = 6.64, dilation = 3.3 for cases
# ...

# %%
covid.Region(geoId='JP').analyse()
# Out:
# Japan data to end of 2020-04-29:
#   14,088 cases, 415 deaths
#   111 cases per million, 3 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-16 (-73 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-16 days)
#   End:         2020-06-08 ( 41 days, 57 days after peak cases)
#   Day Zero:    2020-03-29 (-31 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 ( -4 days)
#
# Parameters:
#   Totals:      13,385 cases and 351 deaths at end of 2020-04-26
#   Smoothed:    13,384 cases and 350 deaths at end of 2020-04-26 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-26, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
#                L = 2,584, r = 8.0, dilation = 1 for cases
#   Lag:         12 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='RU', dilation=2, growth_days=47).analyse(ylog=1)
# Out:
# Russia data to end of 2020-04-29:
#   99,399 cases, 972 deaths
#   688 cases per million, 7 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-14 (-46 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-30 (  1 days)
#   End:         2020-08-01 ( 95 days, 94 days after peak cases)
#   Day Zero:    2020-04-06 (-23 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-04 (  5 days)
#
# Parameters:
#   Totals:      80,949 cases and 747 deaths at end of 2020-04-26
#   Smoothed:    80,949 cases and 747 deaths at end of 2020-04-26 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-04-26, compared to 7 days earlier)
#   Growth:      47 days (Start -> Peak Cases)
#                L = 25,190, r = 5.95, dilation = 2 for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='NZ', dilation=3).analyse()
# Out:
# New Zealand data to end of 2020-04-29:
#   1,129 cases, 19 deaths
#   231 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-20 (-40 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-33 days)
#   End:         2020-04-09 (-19 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,122 cases and 19 deaths at end of 2020-04-26
#   Smoothed:    1,121 cases and 19 deaths at end of 2020-04-26 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-04-26, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                L = 288, r = 4.0, dilation = 3 for cases
#
# Outcome: 1,035 cases, 4 deaths at end of 2020-04-10
#   212 cases per million, 1 deaths per million (2018 population = 4,885,500)
# ...

# %%
covid.Region(geoId='BE', dilation=1.4, d_cases=0.8).analyse()
# Out:
# Belgium data to end of 2020-04-29:
#   47,859 cases, 7,501 deaths
#   4,190 cases per million, 657 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-04 (-56 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-17 days)
#   End:         2020-05-20 ( 22 days, 39 days after peak cases)
#   Day Zero:    2020-03-21 (-39 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-16 days)
#
# Parameters:
#   Totals:      46,134 cases and 7,094 deaths at end of 2020-04-26
#   Smoothed:    46,134 cases and 7,094 deaths at end of 2020-04-26 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-26, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
#                L = 5,856, r = 4.0, dilation = 0.8 for cases
#   Lag:         1 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='IE', dilation=1.4).analyse()
# Out:
# Ireland data to end of 2020-04-29:
#   20,253 cases, 1,190 deaths
#   4,173 cases per million, 245 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-11 (-49 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-17 days)
#   End:         2020-05-25 ( 27 days, 44 days after peak cases)
#   Day Zero:    2020-03-29 (-31 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 ( -7 days)
#
# Parameters:
#   Totals:      19,262 cases and 1,087 deaths at end of 2020-04-26
#   Smoothed:    19,262 cases and 1,087 deaths at end of 2020-04-26 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-26, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
#                L = 3,652, r = 5.7, dilation = 1.4 for cases
#   Lag:         10 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='SE').analyse()
# Out:
# Sweden data to end of 2020-04-29:
#   20,302 cases, 2,462 deaths
#   1,994 cases per million, 242 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-04 (-56 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 ( -7 days)
#   End:         2020-06-09 ( 42 days, 49 days after peak cases)
#   Day Zero:    2020-03-25 (-35 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 ( -8 days)
#
# Parameters:
#   Totals:      18,640 cases and 2,194 deaths at end of 2020-04-26
#   Smoothed:    18,640 cases and 2,194 deaths at end of 2020-04-26 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-04-26, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
#                L = 2,497, r = 4.0, dilation = 1 for cases
#   Lag:         -1 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='SG', dilation=2).analyse()
# Out:
# Singapore data to end of 2020-04-29:
#   15,641 cases, 14 deaths
#   2,774 cases per million, 2 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-11 (-78 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 ( -6 days)
#   End:         2020-09-13 (138 days, 144 days after peak cases)
#
# Parameters:
#   Totals:      13,624 cases and 12 deaths at end of 2020-04-26
#   Smoothed:    13,624 cases and 12 deaths at end of 2020-04-26 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-26, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                L = 4,092, r = 8.0, dilation = 2 for cases
#
# Outcome: 34,230 cases, 32 deaths at end of 2020-09-13
#   6,071 cases per million, 6 deaths per million (2018 population = 5,638,676)
# ...

# %%
covid.Region(geoId='BR', growth_days=54).analyse()
# Out:
# Brazil data to end of 2020-04-29:
#   78,162 cases, 5,466 deaths
#   373 cases per million, 26 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-11 (-49 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-04 (  5 days)
#   End:         2020-06-26 ( 59 days, 54 days after peak cases)
#   Day Zero:    2020-03-25 (-35 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-08 (  9 days)
#
# Parameters:
#   Totals:      61,888 cases and 4,205 deaths at end of 2020-04-26
#   Smoothed:    61,887 cases and 4,204 deaths at end of 2020-04-26 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.9 (2020-04-26, compared to 7 days earlier)
#   Growth:      54 days (Start -> Peak Cases)
#                L = 21,751, r = 5.73, dilation = 1 for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
# ...
