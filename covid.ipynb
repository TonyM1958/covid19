# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Get the latest json data from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Check data against the world figures at <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# smoothing changed to 7 days instead of 9
covid.data_load('download.json', smooth=7)
# Out:
# 207 region(s) found in download.json

# %%
covid.Region(geoId='UK', dilation=2.6, d_cases=2.3).analyse()
# note: change in reporting of deaths by Public Health England, using data from https://coronavirus.data.gov.uk/
# Out:
# United Kingdom data to end of 2020-04-29:
#   165,221 cases, 26,097 deaths
#   2,485 cases per million, 393 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-02 (-58 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-18 days)
#   End:         2020-06-29 ( 62 days, 80 days after peak cases)
#   Day Zero:    2020-03-15 (-45 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-18 days)
#
# Parameters:
#   Totals:      152,840 cases and 24,055 deaths at end of 2020-04-26
#   Smoothed:    152,840 cases and 24,055 deaths at end of 2020-04-26 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-26, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
#                L = 22,149, r = 5.88, dilation = 2.3 for cases
# ...

# %%
covid.Region(geoId='CN').analyse(ylog=1)
# Out:
# China data to end of 2020-04-28:
#   83,940 cases, 4,637 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-01-15 (-104 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-78 days)
#   End:         2020-03-06 (-52 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-94 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-73 days)
#
# Parameters:
#   Totals:      83,909 cases and 4,636 deaths at end of 2020-04-25
#   Smoothed:    83,909 cases and 4,635 deaths at end of 2020-04-25 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.1 (2020-04-25, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
#                L = 18,758, r = 5.66, dilation = 1 for cases
#   Lag:         5 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='ES', dilation=2.8).analyse()
# ECDC data is one day out and differs from Worldometer by ~22,000 cases?
# Out:
# Spain data to end of 2020-04-27:
#   210,773 cases, 23,822 deaths
#   4,511 cases per million, 510 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-29 (-58 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-28 (-30 days)
#   End:         2020-05-22 ( 26 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-47 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-27 days)
#
# Parameters:
#   Totals:      205,905 cases and 22,902 deaths at end of 2020-04-24
#   Smoothed:    205,904 cases and 22,902 deaths at end of 2020-04-24 (7 points)
#   Spread:      Peak infection rate 14.6 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-04-24, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
#                L = 31,440, r = 7.06, dilation = 2.8 for cases
# ...

# %%
covid.Region(geoId='IT', dilation=2, d_cases=3).analyse()
# Out:
# Italy data to end of 2020-04-28:
#   201,505 cases, 27,359 deaths
#   3,334 cases per million, 453 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-21 (-67 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-36 days)
#   End:         2020-05-23 ( 26 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-57 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-29 days)
#
# Parameters:
#   Totals:      195,351 cases and 26,384 deaths at end of 2020-04-25
#   Smoothed:    195,350 cases and 26,384 deaths at end of 2020-04-25 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-04-25, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
#                L = 22,626, r = 5.69, dilation = 3 for cases
#   Lag:         7 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='FR', dilation=2.3, d_cases=2).analyse()
# Out:
# France data to end of 2020-04-28:
#   126,835 cases, 23,660 deaths
#   1,893 cases per million, 353 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-27 (-61 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-30 days)
#   End:         2020-05-29 ( 32 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-48 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-22 days)
#
# Parameters:
#   Totals:      124,114 cases and 22,614 deaths at end of 2020-04-25
#   Smoothed:    124,113 cases and 22,614 deaths at end of 2020-04-25 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-25, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
#                L = 18,250, r = 6.05, dilation = 2 for cases
#   Lag:         8 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='DE', dilation=0.9, d_cases=1.5).analyse()
# Out:
# Germany data to end of 2020-04-28:
#   157,641 cases, 6,115 deaths
#   1,901 cases per million, 74 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-27 (-61 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-27 days)
#   End:         2020-05-21 ( 24 days, 51 days after peak cases)
#   Day Zero:    2020-03-20 (-39 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-11 days)
#
# Parameters:
#   Totals:      154,175 cases and 5,640 deaths at end of 2020-04-25
#   Smoothed:    154,174 cases and 5,640 deaths at end of 2020-04-25 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-25, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
#                L = 22,485, r = 5.61, dilation = 1.5 for cases
#   Lag:         16 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='US', dilation=1, d_cases=3).analyse()
# Out:
# United States of America data to end of 2020-04-28:
#   1,012,583 cases, 58,355 deaths
#   3,095 cases per million, 178 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-25 (-63 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-21 days)
#   End:         2020-06-29 ( 63 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-46 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-10 days)
#
# Parameters:
#   Totals:      939,053 cases and 53,189 deaths at end of 2020-04-25
#   Smoothed:    939,052 cases and 53,189 deaths at end of 2020-04-25 (7 points)
#   Spread:      Peak infection rate 12.5 (2020-03-07, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-25, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
#                L = 129,045, r = 6.62, dilation = 3 for cases
# ...

# %%
covid.Region(geoId='JP').analyse()
# Out:
# Japan data to end of 2020-04-28:
#   13,852 cases, 389 deaths
#   109 cases per million, 3 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-16 (-72 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-15 days)
#   End:         2020-06-08 ( 42 days, 57 days after peak cases)
#   Day Zero:    2020-03-28 (-31 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-24 ( -4 days)
#
# Parameters:
#   Totals:      13,182 cases and 348 deaths at end of 2020-04-25
#   Smoothed:    13,182 cases and 347 deaths at end of 2020-04-25 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-25, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
#                L = 2,610, r = 8.0, dilation = 1 for cases
#   Lag:         11 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='RU', dilation=5, growth_days=46).analyse(ylog=1)
# Out:
# Russia data to end of 2020-04-28:
#   93,558 cases, 867 deaths
#   648 cases per million, 6 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-14 (-45 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-29 (  1 days)
#   End:         2020-07-29 ( 93 days, 92 days after peak cases)
#   Day Zero:    2020-04-06 (-22 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-03 (  5 days)
#
# Parameters:
#   Totals:      74,588 cases and 681 deaths at end of 2020-04-25
#   Smoothed:    74,587 cases and 681 deaths at end of 2020-04-25 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-04-25, compared to 7 days earlier)
#   Growth:      46 days (Start -> Peak Cases)
#                L = 24,827, r = 6.11, dilation = 5 for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='NZ', dilation=3).analyse()
# Out:
# New Zealand data to end of 2020-04-28:
#   1,126 cases, 19 deaths
#   230 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-20 (-39 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-32 days)
#   End:         2020-04-09 (-18 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,121 cases and 18 deaths at end of 2020-04-25
#   Smoothed:    1,121 cases and 18 deaths at end of 2020-04-25 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.4 (2020-04-25, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                L = 288, r = 4.0, dilation = 3 for cases
#
# Outcome: 1,035 cases, 4 deaths at end of 2020-04-10
#   212 cases per million, 1 deaths per million (2018 population = 4,885,500)
# ...

# %%
covid.Region(geoId='BE', dilation=1.4, d_cases=1).analyse()
# Out:
# Belgium data to end of 2020-04-28:
#   47,334 cases, 7,331 deaths
#   4,144 cases per million, 642 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-04 (-55 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-16 days)
#   End:         2020-05-20 ( 23 days, 39 days after peak cases)
#   Day Zero:    2020-03-21 (-38 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-15 days)
#
# Parameters:
#   Totals:      45,325 cases and 6,917 deaths at end of 2020-04-25
#   Smoothed:    45,325 cases and 6,916 deaths at end of 2020-04-25 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-04-25, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
#                L = 5,863, r = 4.25, dilation = 1 for cases
#   Lag:         1 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='IE', dilation=2).analyse()
# Out:
# Ireland data to end of 2020-04-28:
#   19,877 cases, 1,159 deaths
#   4,095 cases per million, 239 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-11 (-48 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-16 days)
#   End:         2020-06-14 ( 48 days, 64 days after peak cases)
#   Day Zero:    2020-03-29 (-30 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 ( -6 days)
#
# Parameters:
#   Totals:      18,561 cases and 1,063 deaths at end of 2020-04-25
#   Smoothed:    18,561 cases and 1,062 deaths at end of 2020-04-25 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-04-25, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
#                L = 3,616, r = 7.48, dilation = 2 for cases
#   Lag:         10 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='SE').analyse()
# Out:
# Sweden data to end of 2020-04-28:
#   19,621 cases, 2,355 deaths
#   1,927 cases per million, 231 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-04 (-55 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 ( -6 days)
#   End:         2020-06-09 ( 43 days, 49 days after peak cases)
#   Day Zero:    2020-03-25 (-34 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 ( -7 days)
#
# Parameters:
#   Totals:      18,177 cases and 2,192 deaths at end of 2020-04-25
#   Smoothed:    18,177 cases and 2,192 deaths at end of 2020-04-25 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-04-25, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
#                L = 2,519, r = 4.0, dilation = 1 for cases
#   Lag:         -1 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='SG').analyse()
# Out:
# Singapore data to end of 2020-04-28:
#   14,951 cases, 14 deaths
#   2,652 cases per million, 2 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-11 (-77 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 ( -5 days)
#   End:         2020-07-03 ( 67 days, 72 days after peak cases)
#
# Parameters:
#   Totals:      12,693 cases and 12 deaths at end of 2020-04-25
#   Smoothed:    12,693 cases and 11 deaths at end of 2020-04-25 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-04-25, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                L = 4,050, r = 8.0, dilation = 1 for cases
#
# Outcome: 22,304 cases, 22 deaths at end of 2020-07-03
#   3,956 cases per million, 4 deaths per million (2018 population = 5,638,676)
# ...

# %%
covid.Region(geoId='BR', growth_days=49).analyse()
# Out:
# Brazil data to end of 2020-04-28:
#   71,886 cases, 5,017 deaths
#   343 cases per million, 24 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-11 (-48 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-29 (  1 days)
#   End:         2020-06-16 ( 50 days, 49 days after peak cases)
#   Day Zero:    2020-03-24 (-35 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-03 (  5 days)
#
# Parameters:
#   Totals:      58,509 cases and 4,016 deaths at end of 2020-04-25
#   Smoothed:    58,508 cases and 4,015 deaths at end of 2020-04-25 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.6 (2020-04-25, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
#                L = 17,383, r = 5.41, dilation = 1 for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
# ...
