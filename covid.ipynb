# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Get the latest json data from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Check data against the world figures at <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
ylog=1

# %%
covid.Region(geoId='UK', dilation=2.1, d_cases=1.6).analyse(ylog=ylog)
# Out:
# United Kingdom (UK) to end of 2020-04-26:
#   152,840 cases, 20,732 deaths
#   2,299 cases per million, 312 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-02 (-55 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-15 (-11 days)
#   End:         2020-06-23 ( 59 days, 70 days after peak cases)
#   Day Zero:    2020-03-16 (-41 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-12 (-14 days)
#
# Parameters:
#   Totals:      133,495 cases and 18,100 deaths at end of 2020-04-22
#   Smoothed:    133,494 cases and 18,100 deaths at end of 2020-04-22 (9 points)
#   Spread:      Peak infection rate 5.7 (2020-03-16, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-22, compared to 7 days earlier)
#   Growth:      44 days (Start -> Peak Cases)
#                L = 22,078, r = 5.02, dilation = 1.6 for cases
# ...

# %%
covid.Region(geoId='CN', dilation=1).analyse(ylog=1)
# Out:
# China (CN) to end of 2020-04-26:
#   84,199 cases, 4,639 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-01-15 (-102 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-09 (-77 days)
#   End:         2020-03-04 (-52 days, 25 days after peak cases)
#   Day Zero:    2020-01-24 (-93 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-16 (-70 days)
#
# Parameters:
#   Totals:      83,876 cases and 4,636 deaths at end of 2020-04-22
#   Smoothed:    83,876 cases and 4,636 deaths at end of 2020-04-22 (9 points)
#   Spread:      Peak infection rate 15.3 (2020-01-22, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-04-22, compared to 7 days earlier)
#   Growth:      25 days (Start -> Peak Cases)
#                L = 17,647, r = 5.25, dilation = 1 for cases
#   Lag:         7 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='ES', dilation=2.8).analyse(ylog=ylog)
# Out:
# Spain (ES) to end of 2020-04-25:
#   207,634 cases, 23,190 deaths
#   4,444 cases per million, 496 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-28 (-57 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-27 days)
#   End:         2020-05-27 ( 33 days, 60 days after peak cases)
#   Day Zero:    2020-03-10 (-46 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-25 days)
#
# Parameters:
#   Totals:      197,142 cases and 21,717 deaths at end of 2020-04-21
#   Smoothed:    197,142 cases and 21,717 deaths at end of 2020-04-21 (9 points)
#   Spread:      Peak infection rate 13.6 (2020-03-10, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-04-21, compared to 7 days earlier)
#   Growth:      30 days (Start -> Peak Cases)
#                L = 31,294, r = 8.0, dilation = 2.8 for cases
# ...

# %%
covid.Region(geoId='IT', dilation=2, d_cases=3).analyse(ylog=ylog)
# Out:
# Italy (IT) to end of 2020-04-26:
#   197,675 cases, 26,644 deaths
#   3,271 cases per million, 441 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-20 (-66 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-24 (-33 days)
#   End:         2020-05-28 ( 33 days, 66 days after peak cases)
#   Day Zero:    2020-03-01 (-56 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-26 days)
#
# Parameters:
#   Totals:      187,327 cases and 25,085 deaths at end of 2020-04-22
#   Smoothed:    187,326 cases and 25,085 deaths at end of 2020-04-22 (9 points)
#   Spread:      Peak infection rate 13.0 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-04-22, compared to 7 days earlier)
#   Growth:      33 days (Start -> Peak Cases)
#                L = 22,895, r = 6.0, dilation = 3 for cases
#   Lag:         7 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='FR', dilation=1.8).analyse(ylog=ylog)
# Out:
# France (FR) to end of 2020-04-26:
#   124,575 cases, 22,856 deaths
#   1,860 cases per million, 341 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-27 (-59 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-31 (-26 days)
#   End:         2020-05-28 ( 33 days, 59 days after peak cases)
#   Day Zero:    2020-03-11 (-46 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-07 (-19 days)
#
# Parameters:
#   Totals:      119,151 cases and 21,340 deaths at end of 2020-04-22
#   Smoothed:    119,150 cases and 21,340 deaths at end of 2020-04-22 (9 points)
#   Spread:      Peak infection rate 8.3 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-22, compared to 7 days earlier)
#   Growth:      33 days (Start -> Peak Cases)
#                L = 17,611, r = 5.92, dilation = 1.8 for cases
# ...

# %%
covid.Region(geoId='DE', dilation=0.7, d_cases=2).analyse(ylog=ylog)
# Out:
# Germany (DE) to end of 2020-04-26:
#   155,193 cases, 5,750 deaths
#   1,871 cases per million, 69 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-27 (-59 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-31 (-26 days)
#   End:         2020-06-04 ( 40 days, 66 days after peak cases)
#   Day Zero:    2020-03-20 (-37 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 ( -8 days)
#
# Parameters:
#   Totals:      148,046 cases and 5,094 deaths at end of 2020-04-22
#   Smoothed:    148,046 cases and 5,093 deaths at end of 2020-04-22 (9 points)
#   Spread:      Peak infection rate 7.2 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-22, compared to 7 days earlier)
#   Growth:      33 days (Start -> Peak Cases)
#                L = 21,991, r = 6.36, dilation = 2 for cases
#   Lag:         18 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='US', dilation=0.8, d_cases=10).analyse(ylog=1)
# Out:
# United States (US) to end of 2020-04-26:
#   965,910 cases, 54,876 deaths
#   2,952 cases per million, 168 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-25 (-61 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-06 (-20 days)
#   End:         2020-06-26 ( 62 days, 82 days after peak cases)
#   Day Zero:    2020-03-13 (-44 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-19 ( -7 days)
#
# Parameters:
#   Totals:      842,629 cases and 46,784 deaths at end of 2020-04-22
#   Smoothed:    842,628 cases and 46,784 deaths at end of 2020-04-22 (9 points)
#   Spread:      Peak infection rate 11.4 (2020-03-07, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-04-22, compared to 7 days earlier)
#   Growth:      41 days (Start -> Peak Cases)
#                L = 126,076, r = 7.03, dilation = 10 for cases
# ...

# %%
covid.Region(geoId='JP', dilation=6).analyse(ylog=ylog)
# Out:
# Japan (JP) to end of 2020-04-26:
#   13,385 cases, 351 deaths
#   106 cases per million, 3 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-16 (-70 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-14 (-12 days)
#   End:         2020-08-07 (104 days, 116 days after peak cases)
#   Day Zero:    2020-03-25 (-32 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 ( -5 days)
#
# Parameters:
#   Totals:      11,772 cases and 287 deaths at end of 2020-04-22
#   Smoothed:    11,772 cases and 287 deaths at end of 2020-04-22 (9 points)
#   Spread:      Peak infection rate 2.7 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-22, compared to 7 days earlier)
#   Growth:      58 days (Start -> Peak Cases)
#                L = 2,501, r = 8.0, dilation = 6 for cases
#   Lag:         7 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='RU', dilation=5, growth_days=44).analyse(ylog=1)
# Out:
# Russian Federation (RU) to end of 2020-04-26:
#   80,949 cases, 747 deaths
#   560 cases per million, 5 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-14 (-43 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-27 (  1 days)
#   End:         2020-07-23 ( 89 days, 88 days after peak cases)
#   Day Zero:    2020-04-06 (-20 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-01 (  5 days)
#
# Parameters:
#   Totals:      57,999 cases and 513 deaths at end of 2020-04-22
#   Smoothed:    57,999 cases and 513 deaths at end of 2020-04-22 (9 points)
#   Spread:      Peak infection rate 4.4 (2020-03-27, compared to 7 days earlier)
#                Latest infection rate 1.6 (2020-04-22, compared to 7 days earlier)
#   Growth:      44 days (Start -> Peak Cases)
#                L = 24,692, r = 6.45, dilation = 5 for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='NZ').analyse(ylog=0)
# Out:
# New Zealand (NZ) to end of 2020-04-26:
#   1,122 cases, 19 deaths
#   230 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-19 (-38 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-28 days)
#   End:         2020-04-17 ( -8 days, 20 days after peak cases)
#
# Parameters:
#   Totals:      1,112 cases and 16 deaths at end of 2020-04-22
#   Smoothed:    1,112 cases and 16 deaths at end of 2020-04-22 (9 points)
#   Spread:      Peak infection rate 1.8 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.4 (2020-04-22, compared to 7 days earlier)
#   Growth:      10 days (Start -> Peak Cases)
#                L = 259, r = 4.05, dilation = 2 for cases
#
# Outcome: 1,098 cases, 12 deaths at end of 2020-04-18
#   225 cases per million, 2 deaths per million (2018 population = 4,885,500)
# ...

# %%
covid.Region(geoId='BE', dilation=1.3, d_cases=2).analyse(ylog=ylog)
# Out:
# Belgium (BE) to end of 2020-04-26:
#   46,134 cases, 7,094 deaths
#   4,039 cases per million, 621 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-04 (-53 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-08 (-18 days)
#   End:         2020-06-16 ( 52 days, 70 days after peak cases)
#   Day Zero:    2020-03-21 (-36 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-14 (-12 days)
#
# Parameters:
#   Totals:      41,889 cases and 6,262 deaths at end of 2020-04-22
#   Smoothed:    41,889 cases and 6,261 deaths at end of 2020-04-22 (9 points)
#   Spread:      Peak infection rate 4.1 (2020-03-14, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-04-22, compared to 7 days earlier)
#   Growth:      35 days (Start -> Peak Cases)
#                L = 5,722, r = 4.7, dilation = 2 for cases
#   Lag:         6 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='IE', dilation=3).analyse(ylog=ylog)
# Out:
# Ireland (IE) to end of 2020-04-26:
#   19,262 cases, 1,087 deaths
#   3,969 cases per million, 224 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-11 (-46 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-13 days)
#   End:         2020-06-17 ( 53 days, 66 days after peak cases)
#   Day Zero:    2020-03-30 (-27 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 ( -5 days)
#
# Parameters:
#   Totals:      16,671 cases and 769 deaths at end of 2020-04-22
#   Smoothed:    16,670 cases and 769 deaths at end of 2020-04-22 (9 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-22, compared to 7 days earlier)
#   Growth:      33 days (Start -> Peak Cases)
#                L = 3,402, r = 5.11, dilation = 3 for cases
#   Lag:         8 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='SE', dilation=2).analyse(ylog=ylog)
# Out:
# Sweden (SE) to end of 2020-04-26:
#   18,640 cases, 2,194 deaths
#   1,830 cases per million, 215 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-03 (-54 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-20 ( -6 days)
#   End:         2020-07-24 ( 90 days, 96 days after peak cases)
#   Day Zero:    2020-03-25 (-32 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 ( -8 days)
#
# Parameters:
#   Totals:      16,004 cases and 1,937 deaths at end of 2020-04-22
#   Smoothed:    16,004 cases and 1,937 deaths at end of 2020-04-22 (9 points)
#   Spread:      Peak infection rate 4.7 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-04-22, compared to 7 days earlier)
#   Growth:      48 days (Start -> Peak Cases)
#                L = 2,482, r = 4.0, dilation = 2 for cases
#   Lag:         -2 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='SG').analyse(ylog=ylog)
# Out:
# Singapore (SG) to end of 2020-04-26:
#   13,624 cases, 12 deaths
#   2,416 cases per million, 2 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-11 (-75 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 ( -4 days)
#   End:         2020-09-10 (138 days, 142 days after peak cases)
#
# Parameters:
#   Totals:      10,141 cases and 12 deaths at end of 2020-04-22
#   Smoothed:    10,141 cases and 11 deaths at end of 2020-04-22 (9 points)
#   Spread:      Peak infection rate 3.8 (2020-04-13, compared to 7 days earlier)
#                Latest infection rate 1.8 (2020-04-22, compared to 7 days earlier)
#   Growth:      71 days (Start -> Peak Cases)
#                L = 3,928, r = 8.0, dilation = 2 for cases
#
# Outcome: 29,587 cases, 30 deaths at end of 2020-09-10
#   5,247 cases per million, 5 deaths per million (2018 population = 5,638,676)
# ...
