# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://coronavirus.data.gov.uk/">coronavirus.data.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# include plot of total deaths
covid.setting(totals=4)
# ECDC data was updated to include all settings for UK on 1st May
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=3.6, d_cases=7).analyse()
# Out:
# United Kingdom data to end of 2020-05-01:
#   177,454 cases, 27,510 deaths
#   2,669 cases per million, 414 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-02 (-60 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-20 days, 5,492 cases)
#   End:         2020-06-29 ( 60 days, 80 days after peak cases)
#   Day Zero:    2020-03-16 (-46 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-20 days, 940 deaths)
#
# Parameters:
#   Totals:      161,145 cases and 25,302 deaths at end of 2020-04-28
#   Smoothed:    161,145 cases and 25,302 deaths at end of 2020-04-28 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-04-28, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
#                L = 21,969, r = 5.83, dilation = 7 for cases
# ...

# %%
covid.Region(geoId='CN').analyse(ylog=1)
# Out:
# China data to end of 2020-04-30:
#   83,956 cases, 4,637 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-01-15 (-106 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-80 days, 4,690 cases)
#   End:         2020-03-06 (-54 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-96 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-75 days, 128 deaths)
#
# Parameters:
#   Totals:      83,938 cases and 4,637 deaths at end of 2020-04-27
#   Smoothed:    83,937 cases and 4,636 deaths at end of 2020-04-27 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-04-27, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
#                L = 18,760, r = 5.66, dilation = 1 for cases
# ...

# %%
covid.Region(geoId='ES', dilation=3.8, d_cases=2).analyse()
# note: ECDC cases data differs from Worldometer due to anti-body tests
# Out:
# Spain data to end of 2020-04-30:
#   213,435 cases, 24,543 deaths
#   4,568 cases per million, 525 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-29 (-60 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-28 (-32 days, 7,837 cases)
#   End:         2020-05-23 ( 24 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-49 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-29 days, 857 deaths)
#
# Parameters:
#   Totals:      209,465 cases and 23,190 deaths at end of 2020-04-26
#   Smoothed:    209,465 cases and 23,190 deaths at end of 2020-04-26 (7 points)
#   Spread:      Peak infection rate 14.6 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-26, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
#                L = 31,349, r = 6.05, dilation = 2 for cases
# ...

# %%
covid.Region(geoId='IT', dilation=2.4, d_cases=3.3).analyse()
# Out:
# Italy data to end of 2020-04-30:
#   205,463 cases, 27,967 deaths
#   3,400 cases per million, 463 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-21 (-69 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-38 days, 5,643 cases)
#   End:         2020-05-23 ( 24 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-59 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-31 days, 821 deaths)
#
# Parameters:
#   Totals:      199,414 cases and 26,977 deaths at end of 2020-04-27
#   Smoothed:    199,413 cases and 26,977 deaths at end of 2020-04-27 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-27, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
#                L = 22,572, r = 6.02, dilation = 3.3 for cases
# ...

# %%
covid.Region(geoId='FR', dilation=2.7, d_cases=3.2).analyse()
# Out:
# France data to end of 2020-04-30:
#   129,581 cases, 24,376 deaths
#   1,934 cases per million, 364 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-27 (-63 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-32 days, 4,529 cases)
#   End:         2020-05-29 ( 30 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-50 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-24 days, 1,100 deaths)
#
# Parameters:
#   Totals:      125,770 cases and 23,293 deaths at end of 2020-04-27
#   Smoothed:    125,770 cases and 23,293 deaths at end of 2020-04-27 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-27, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
#                L = 18,115, r = 8.0, dilation = 3.2 for cases
# ...

# %%
covid.Region(geoId='DE', dilation=1, d_cases=1.5).analyse()
# Out:
# Germany data to end of 2020-04-30:
#   159,119 cases, 6,288 deaths
#   1,919 cases per million, 76 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-27 (-63 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-29 days, 5,597 cases)
#   End:         2020-05-21 ( 22 days, 51 days after peak cases)
#   Day Zero:    2020-03-20 (-41 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-13 days, 232 deaths)
#
# Parameters:
#   Totals:      156,337 cases and 5,913 deaths at end of 2020-04-27
#   Smoothed:    156,337 cases and 5,913 deaths at end of 2020-04-27 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-04-27, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
#                L = 22,388, r = 5.42, dilation = 1.5 for cases
# ...

# %%
covid.Region(geoId='US', dilation=2.9, d_cases=4.9).analyse()
# Out:
# United States of America data to end of 2020-04-30:
#   1,069,826 cases, 63,006 deaths
#   3,270 cases per million, 193 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-25 (-65 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-23 days, 32,002 cases)
#   End:         2020-06-29 ( 61 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-48 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-12 days, 2,688 deaths)
#
# Parameters:
#   Totals:      988,451 cases and 56,245 deaths at end of 2020-04-27
#   Smoothed:    988,450 cases and 56,244 deaths at end of 2020-04-27 (7 points)
#   Spread:      Peak infection rate 12.5 (2020-03-07, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-04-27, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP').analyse()
# Out:
# Japan data to end of 2020-04-30:
#   14,281 cases, 432 deaths
#   113 cases per million, 3 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-16 (-74 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-17 days, 641 cases)
#   End:         2020-06-08 ( 40 days, 57 days after peak cases)
#   Day Zero:    2020-03-28 (-33 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 ( -5 days, 29 deaths)
#
# Parameters:
#   Totals:      13,576 cases and 376 deaths at end of 2020-04-27
#   Smoothed:    13,576 cases and 375 deaths at end of 2020-04-27 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-27, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
#                L = 2,565, r = 8.0, dilation = 1 for cases
# ...

# %%
covid.Region(geoId='RU', lag=4).analyse(ylog=1)
# Out:
# Russia data to end of 2020-04-30:
#   106,498 cases, 1,073 deaths
#   737 cases per million, 7 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-14 (-47 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-27 ( -3 days, 6,239 cases)
#   End:         2020-06-09 ( 41 days, 44 days after peak cases)
#   Day Zero:    2020-04-06 (-24 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-01 (  1 days)
#
# Parameters:
#   Totals:      87,147 cases and 795 deaths at end of 2020-04-27
#   Smoothed:    87,147 cases and 795 deaths at end of 2020-04-27 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-04-27, compared to 7 days earlier)
#   Growth:      44 days (Start -> Peak Cases)
#                L = 24,955, r = 6.53, dilation = 1 for cases
# ...

# %%
covid.Region(geoId='NZ', dilation=3).analyse()
# Out:
# New Zealand data to end of 2020-04-30:
#   1,132 cases, 19 deaths
#   232 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-20 (-41 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-34 days, 72 cases)
#   End:         2020-04-09 (-20 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,124 cases and 19 deaths at end of 2020-04-27
#   Smoothed:    1,124 cases and 19 deaths at end of 2020-04-27 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-04-27, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                L = 288, r = 4.0, dilation = 3 for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
#   212 cases per million, 1 deaths per million (2018 population = 4,885,500)
# ...

# %%
covid.Region(geoId='BE', dilation=1.4, d_cases=0.8).analyse()
# Out:
# Belgium data to end of 2020-04-30:
#   48,519 cases, 7,594 deaths
#   4,248 cases per million, 665 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-04 (-57 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-18 days, 1,456 cases)
#   End:         2020-05-20 ( 21 days, 39 days after peak cases)
#   Day Zero:    2020-03-21 (-40 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-17 days, 334 deaths)
#
# Parameters:
#   Totals:      46,687 cases and 7,207 deaths at end of 2020-04-27
#   Smoothed:    46,687 cases and 7,206 deaths at end of 2020-04-27 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-27, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
#                L = 5,823, r = 4.0, dilation = 0.8 for cases
# ...

# %%
covid.Region(geoId='IE', dilation=1.3).analyse()
# Out:
# Ireland data to end of 2020-04-30:
#   20,612 cases, 1,232 deaths
#   4,247 cases per million, 254 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-11 (-50 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-18 days, 911 cases)
#   End:         2020-05-22 ( 23 days, 41 days after peak cases)
#   Day Zero:    2020-03-30 (-31 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 ( -8 days, 71 deaths)
#
# Parameters:
#   Totals:      19,648 cases and 1,102 deaths at end of 2020-04-27
#   Smoothed:    19,648 cases and 1,102 deaths at end of 2020-04-27 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-27, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
#                L = 3,643, r = 5.3, dilation = 1.3 for cases
# ...

# %%
covid.Region(geoId='SE', dilation=3).analyse()
# Out:
# Sweden data to end of 2020-04-30:
#   21,092 cases, 2,586 deaths
#   2,071 cases per million, 254 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-04 (-57 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 ( -8 days, 614 cases)
#   End:         2020-07-28 ( 90 days, 98 days after peak cases)
#   Day Zero:    2020-03-25 (-36 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 ( -9 days, 105 deaths)
#
# Parameters:
#   Totals:      18,926 cases and 2,274 deaths at end of 2020-04-27
#   Smoothed:    18,926 cases and 2,274 deaths at end of 2020-04-27 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-04-27, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
#                L = 2,454, r = 4.0, dilation = 3 for cases
# ...

# %%
covid.Region(geoId='SG', dilation=2).analyse()
# Out:
# Singapore data to end of 2020-04-30:
#   16,169 cases, 15 deaths
#   2,868 cases per million, 3 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-11 (-79 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 ( -7 days, 1,028 cases)
#   End:         2020-09-13 (137 days, 144 days after peak cases)
#
# Parameters:
#   Totals:      14,423 cases and 14 deaths at end of 2020-04-27
#   Smoothed:    14,423 cases and 13 deaths at end of 2020-04-27 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-27, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                L = 4,113, r = 8.0, dilation = 2 for cases
#
# Outcome: 34,644 total cases, 36 total deaths by end of 2020-09-13
#   includes 100.0% of predicted cases and 97.4% of predicted deaths
# ...

# %%
covid.Region(geoId='BR', growth_days=54).analyse()
# Out:
# Brazil data to end of 2020-04-30:
#   85,380 cases, 5,901 deaths
#   408 cases per million, 28 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-11 (-50 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-04 (  4 days, 0 cases)
#   End:         2020-06-26 ( 58 days, 54 days after peak cases)
#   Day Zero:    2020-03-25 (-36 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-08 (  8 days)
#
# Parameters:
#   Totals:      66,501 cases and 4,543 deaths at end of 2020-04-27
#   Smoothed:    66,501 cases and 4,543 deaths at end of 2020-04-27 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.9 (2020-04-27, compared to 7 days earlier)
#   Growth:      54 days (Start -> Peak Cases)
#                L = 23,225, r = 5.95, dilation = 1 for cases
# ...
