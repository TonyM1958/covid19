# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Get the latest json data from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Check data against the world figures at <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# smoothing over 7 days instead of 9
covid.data_load(smooth=7)
# Out:
# 207 region(s) found

# %%
covid.Region(geoId='UK', dilation=1.9, d_cases=2.3).analyse()
# Out:
# United Kingdom data to end of 2020-04-28:
#   161,145 cases, 21,678 deaths
#   2,424 cases per million, 326 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-02 (-57 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-17 days)
#   End:         2020-06-29 ( 63 days, 80 days after peak cases)
#   Day Zero:    2020-03-16 (-43 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-10 (-18 days)
#
# Parameters:
#   Totals:      148,377 cases and 20,319 deaths at end of 2020-04-25
#   Smoothed:    148,377 cases and 20,318 deaths at end of 2020-04-25 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-25, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
#                L = 22,162, r = 5.89, dilation = 2.3 for cases
# ...

# %%
covid.Region(geoId='CN', dilation=1).analyse(ylog=1)
# Out:
# China data to end of 2020-04-27:
#   83,938 cases, 4,637 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-01-15 (-103 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-77 days)
#   End:         2020-03-06 (-51 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-93 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-72 days)
#
# Parameters:
#   Totals:      83,899 cases and 4,636 deaths at end of 2020-04-24
#   Smoothed:    83,898 cases and 4,636 deaths at end of 2020-04-24 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.2 (2020-04-24, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
#                L = 18,758, r = 5.66, dilation = 1 for cases
#   Lag:         5 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='ES', dilation=2.8).analyse()
# ECDC data is one day out and differs from Worldometer by ~20,000 cases?
# Out:
# Spain data to end of 2020-04-26:
#   209,465 cases, 23,521 deaths
#   4,483 cases per million, 503 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-29 (-57 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-28 (-29 days)
#   End:         2020-05-22 ( 27 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-46 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-26 days)
#
# Parameters:
#   Totals:      202,961 cases and 22,524 deaths at end of 2020-04-23
#   Smoothed:    202,960 cases and 22,524 deaths at end of 2020-04-23 (7 points)
#   Spread:      Peak infection rate 14.6 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-23, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
#                L = 31,346, r = 7.16, dilation = 2.8 for cases
# ...

# %%
covid.Region(geoId='IT', dilation=2, d_cases=3).analyse()
# Out:
# Italy data to end of 2020-04-27:
#   199,414 cases, 26,977 deaths
#   3,300 cases per million, 446 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-21 (-66 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-35 days)
#   End:         2020-05-23 ( 27 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-56 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-28 days)
#
# Parameters:
#   Totals:      192,994 cases and 25,969 deaths at end of 2020-04-24
#   Smoothed:    192,993 cases and 25,968 deaths at end of 2020-04-24 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-04-24, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
#                L = 22,645, r = 5.69, dilation = 3 for cases
#   Lag:         7 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='FR', dilation=2, d_cases=3).analyse()
# Out:
# France data to end of 2020-04-27:
#   128,339 cases, 23,293 deaths
#   1,916 cases per million, 348 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-27 (-60 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-29 days)
#   End:         2020-05-29 ( 33 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-47 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-21 days)
#
# Parameters:
#   Totals:      122,577 cases and 22,245 deaths at end of 2020-04-24
#   Smoothed:    122,576 cases and 22,245 deaths at end of 2020-04-24 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-04-24, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
#                L = 18,170, r = 8.0, dilation = 3 for cases
#   Lag:         8 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='DE', dilation=0.8, d_cases=1.7).analyse()
# Out:
# Germany data to end of 2020-04-27:
#   156,337 cases, 5,913 deaths
#   1,885 cases per million, 71 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-27 (-60 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-26 days)
#   End:         2020-05-27 ( 31 days, 57 days after peak cases)
#   Day Zero:    2020-03-20 (-38 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-10 days)
#
# Parameters:
#   Totals:      152,438 cases and 5,500 deaths at end of 2020-04-24
#   Smoothed:    152,438 cases and 5,500 deaths at end of 2020-04-24 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-24, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
#                L = 22,482, r = 6.09, dilation = 1.7 for cases
#   Lag:         16 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='US', dilation=0.9, d_cases=10).analyse()
# Out:
# United States of America data to end of 2020-04-27:
#   988,451 cases, 56,245 deaths
#   3,021 cases per million, 172 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-25 (-62 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-20 days)
#   End:         2020-06-29 ( 64 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-45 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 ( -9 days)
#
# Parameters:
#   Totals:      890,524 cases and 51,017 deaths at end of 2020-04-24
#   Smoothed:    890,523 cases and 51,017 deaths at end of 2020-04-24 (7 points)
#   Spread:      Peak infection rate 11.5 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-04-24, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
#                L = 126,007, r = 6.7, dilation = 10 for cases
# ...

# %%
covid.Region(geoId='JP', dilation=1.3).analyse()
# Out:
# Japan data to end of 2020-04-27:
#   13,576 cases, 376 deaths
#   107 cases per million, 3 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-16 (-71 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-14 days)
#   End:         2020-06-25 ( 60 days, 74 days after peak cases)
#   Day Zero:    2020-03-26 (-32 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 ( -5 days)
#
# Parameters:
#   Totals:      12,892 cases and 334 deaths at end of 2020-04-24
#   Smoothed:    12,892 cases and 334 deaths at end of 2020-04-24 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-24, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
#                L = 2,620, r = 8.0, dilation = 1.3 for cases
#   Lag:         9 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='RU', dilation=5, growth_days=45).analyse(ylog=1)
# Out:
# Russia data to end of 2020-04-27:
#   87,147 cases, 795 deaths
#   603 cases per million, 6 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-14 (-44 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-28 (  1 days)
#   End:         2020-07-26 ( 91 days, 90 days after peak cases)
#   Day Zero:    2020-04-06 (-21 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-02 (  5 days)
#
# Parameters:
#   Totals:      68,622 cases and 615 deaths at end of 2020-04-24
#   Smoothed:    68,622 cases and 615 deaths at end of 2020-04-24 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.4 (2020-04-24, compared to 7 days earlier)
#   Growth:      45 days (Start -> Peak Cases)
#                L = 24,472, r = 6.28, dilation = 5 for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='NZ').analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-04-27:
#   1,124 cases, 19 deaths
#   230 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-20 (-38 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-31 days)
#   End:         2020-04-09 (-17 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,117 cases and 18 deaths at end of 2020-04-24
#   Smoothed:    1,116 cases and 18 deaths at end of 2020-04-24 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-04-24, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                L = 288, r = 4.0, dilation = 2 for cases
#
# Outcome: 1,035 cases, 4 deaths at end of 2020-04-10
#   212 cases per million, 1 deaths per million (2018 population = 4,885,500)
# ...

# %%
covid.Region(geoId='BE', dilation=1.5, d_cases=1).analyse()
# Out:
# Belgium data to end of 2020-04-27:
#   46,687 cases, 7,207 deaths
#   4,087 cases per million, 631 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-04 (-54 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-15 days)
#   End:         2020-05-20 ( 24 days, 39 days after peak cases)
#   Day Zero:    2020-03-21 (-37 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-14 days)
#
# Parameters:
#   Totals:      44,293 cases and 6,679 deaths at end of 2020-04-24
#   Smoothed:    44,293 cases and 6,678 deaths at end of 2020-04-24 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-24, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
#                L = 5,848, r = 4.22, dilation = 1 for cases
#   Lag:         1 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='IE', dilation=3, d_cases=2).analyse()
# Out:
# Ireland data to end of 2020-04-27:
#   19,648 cases, 1,102 deaths
#   4,048 cases per million, 227 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-11 (-47 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-15 days)
#   End:         2020-06-14 ( 49 days, 64 days after peak cases)
#   Day Zero:    2020-03-30 (-28 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 ( -5 days)
#
# Parameters:
#   Totals:      18,184 cases and 829 deaths at end of 2020-04-24
#   Smoothed:    18,183 cases and 828 deaths at end of 2020-04-24 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-04-24, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
#                L = 3,650, r = 7.5, dilation = 2 for cases
#   Lag:         10 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='SE', dilation=1).analyse()
# Out:
# Sweden data to end of 2020-04-27:
#   18,926 cases, 2,274 deaths
#   1,859 cases per million, 223 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-04 (-54 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 ( -5 days)
#   End:         2020-06-09 ( 44 days, 49 days after peak cases)
#   Day Zero:    2020-03-25 (-33 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 ( -6 days)
#
# Parameters:
#   Totals:      17,567 cases and 2,152 deaths at end of 2020-04-24
#   Smoothed:    17,567 cases and 2,152 deaths at end of 2020-04-24 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-04-24, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
#                L = 2,520, r = 4.0, dilation = 1 for cases
#   Lag:         -1 days (Peak Cases -> Peak Deaths)
# ...

# %%
covid.Region(geoId='SG').analyse()
# Out:
# Singapore data to end of 2020-04-27:
#   14,423 cases, 14 deaths
#   2,558 cases per million, 2 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-12 (-75 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 ( -4 days)
#   End:         2020-09-11 (138 days, 142 days after peak cases)
#
# Parameters:
#   Totals:      11,178 cases and 12 deaths at end of 2020-04-24
#   Smoothed:    11,178 cases and 12 deaths at end of 2020-04-24 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-04-24, compared to 7 days earlier)
#   Growth:      71 days (Start -> Peak Cases)
#                L = 3,819, r = 8.0, dilation = 2 for cases
#
# Outcome: 30,919 cases, 29 deaths at end of 2020-09-11
#   5,483 cases per million, 5 deaths per million (2018 population = 5,638,676)
# ...
