# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Get the latest json data from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Check data against the world figures at <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>
# <br>Common region codes: UK, FR, IT, DE, ES, US, CN, KR, JP, NZ

# %%
import covid

# %%
# United Kingdom
# lag adjusted so prediction is similar to actual
covid.Region(geoId='UK', lag=0, dilation=1.5).analyse()
# Out:
# UK confirmed data up to end of 2020-04-17:
#   108,692 confirmed cases, 14,576 deaths
#   1,635 cases per million, 219 deaths per million (population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-02 (-46 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 ( -4 days)
#   End:         2020-05-24 ( 38 days, 42 days after peak cases)
#   Day Zero:    2020-03-16 (-32 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 ( -4 days)
#
# Parameters:
#   Totals:      88,621 cases and 11,329 deaths at end of 2020-04-13
#   Smoothed:    88,620 cases and 11,328 deaths at end of 2020-04-13 (9 adjacent points)
#   Spread:      Peak infection rate 5.7 (2020-03-16, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-04-13, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
#   Lag:         0 days (Peak Cases -> Peak Deaths)
# ...

# %%
# China
covid.Region(geoId='CN', dilation=1).analyse()
# Out:
# CN confirmed data up to end of 2020-04-16:
#   83,754 confirmed cases, 4,636 deaths
#   60 cases per million, 3 deaths per million (population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-01-15 (-92 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-09 (-67 days)
#   End:         2020-03-04 (-42 days, 25 days after peak cases)
#   Day Zero:    2020-01-24 (-83 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-16 (-60 days)
#
# Parameters:
#   Totals:      83,209 cases and 3,345 deaths at end of 2020-04-12
#   Smoothed:    83,209 cases and 3,345 deaths at end of 2020-04-12 (9 adjacent points)
#   Spread:      Peak infection rate 15.3 (2020-01-22, compared to 7 days earlier)
#                Latest infection rate 1.5 (2020-04-12, compared to 7 days earlier)
#   Growth:      25 days (Start -> Peak Cases)
#   Lag:         7 days (Peak Cases -> Peak Deaths)
# ...

# %%
# Spain
covid.Region(geoId='ES').analyse()
# Out:
# ES confirmed data up to end of 2020-04-16:
#   182,816 confirmed cases, 19,130 deaths
#   3,913 cases per million, 409 deaths per million (population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-28 (-48 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-18 days)
#   End:         2020-04-27 ( 12 days, 30 days after peak cases)
#   Day Zero:    2020-03-10 (-37 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-16 days)
#
# Parameters:
#   Totals:      166,019 cases and 16,972 deaths at end of 2020-04-12
#   Smoothed:    166,019 cases and 16,972 deaths at end of 2020-04-12 (9 adjacent points)
#   Spread:      Peak infection rate 13.6 (2020-03-10, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-12, compared to 7 days earlier)
#   Growth:      30 days (Start -> Peak Cases)
#   Lag:         2 days (Peak Cases -> Peak Deaths)
# ...

# %%
# Italy
covid.Region(geoId='IT').analyse()
# Out:
# IT confirmed data up to end of 2020-04-16:
#   168,941 confirmed cases, 22,172 deaths
#   2,796 cases per million, 367 deaths per million (population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-20 (-56 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-24 (-23 days)
#   End:         2020-04-25 ( 10 days, 33 days after peak cases)
#   Day Zero:    2020-03-01 (-46 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-16 days)
#
# Parameters:
#   Totals:      156,363 cases and 19,901 deaths at end of 2020-04-12
#   Smoothed:    156,362 cases and 19,901 deaths at end of 2020-04-12 (9 adjacent points)
#   Spread:      Peak infection rate 13.0 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-12, compared to 7 days earlier)
#   Growth:      33 days (Start -> Peak Cases)
#   Lag:         7 days (Peak Cases -> Peak Deaths)
# ...

# %%
# France
covid.Region(geoId='FR').analyse()
# Out:
# FR confirmed data up to end of 2020-04-16:
#   108,847 confirmed cases, 17,920 deaths
#   1,625 cases per million, 268 deaths per million (population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-27 (-49 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-31 (-16 days)
#   End:         2020-05-02 ( 17 days, 33 days after peak cases)
#   Day Zero:    2020-03-11 (-36 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-07 ( -9 days)
#
# Parameters:
#   Totals:      95,403 cases and 14,393 deaths at end of 2020-04-12
#   Smoothed:    95,402 cases and 14,393 deaths at end of 2020-04-12 (9 adjacent points)
#   Spread:      Peak infection rate 8.3 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-12, compared to 7 days earlier)
#   Growth:      33 days (Start -> Peak Cases)
#   Lag:         7 days (Peak Cases -> Peak Deaths)
# ...

# %%
# Germany
covid.Region(geoId='DE').analyse()
# Out:
# DE confirmed data up to end of 2020-04-16:
#   133,830 confirmed cases, 3,868 deaths
#   1,614 cases per million, 47 deaths per million (population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-27 (-49 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-31 (-16 days)
#   End:         2020-05-02 ( 17 days, 33 days after peak cases)
#   Day Zero:    2020-03-20 (-27 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-12 ( -4 days)
#
# Parameters:
#   Totals:      123,016 cases and 2,799 deaths at end of 2020-04-12
#   Smoothed:    123,016 cases and 2,799 deaths at end of 2020-04-12 (9 adjacent points)
#   Spread:      Peak infection rate 7.2 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-12, compared to 7 days earlier)
#   Growth:      33 days (Start -> Peak Cases)
#   Lag:         12 days (Peak Cases -> Peak Deaths)
# ...

# %%
# United States of America
covid.Region(geoId='US').analyse()
# Out:
# US confirmed data up to end of 2020-04-16:
#   671,331 confirmed cases, 33,284 deaths
#   2,052 cases per million, 102 deaths per million (population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-25 (-51 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-06 (-10 days)
#   End:         2020-05-16 ( 31 days, 41 days after peak cases)
#   Day Zero:    2020-03-13 (-34 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-12 ( -4 days)
#
# Parameters:
#   Totals:      557,571 cases and 22,108 deaths at end of 2020-04-12
#   Smoothed:    557,571 cases and 22,108 deaths at end of 2020-04-12 (9 adjacent points)
#   Spread:      Peak infection rate 11.4 (2020-03-07, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-04-12, compared to 7 days earlier)
#   Growth:      41 days (Start -> Peak Cases)
#   Lag:         6 days (Peak Cases -> Peak Deaths)
# ...

# %%
# Japan
covid.Region(geoId='JP').analyse()
# Out:
# JP confirmed data up to end of 2020-04-16:
#   9,167 confirmed cases, 148 deaths
#   72 cases per million, 1 deaths per million (population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-15 (-61 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 ( -4 days)
#   End:         2020-06-07 ( 53 days, 57 days after peak cases)
#   Day Zero:    2020-03-29 (-18 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-16 (  0 days)
#
# Parameters:
#   Totals:      7,255 cases and 102 deaths at end of 2020-04-12
#   Smoothed:    7,254 cases and 102 deaths at end of 2020-04-12 (9 adjacent points)
#   Spread:      Peak infection rate 2.7 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 1.9 (2020-04-12, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#   Prediction:  Cases L = 14,509 r = 8.24 (over 14 days)
# ...

# %%
# New Zealand
covid.Region(geoId='NZ').analyse()
# Out:
# NZ confirmed data up to end of 2020-04-16:
#   1,086 confirmed cases, 11 deaths
#   222 cases per million, 2 deaths per million (population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-19 (-28 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-18 days)
#   End:         2020-04-07 ( -8 days, 10 days after peak cases)
#
# Parameters:
#   Totals:      1,064 cases and 5 deaths at end of 2020-04-12
#   Smoothed:    1,063 cases and 5 deaths at end of 2020-04-12 (9 adjacent points)
#   Spread:      Peak infection rate 1.8 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.3 (2020-04-12, compared to 7 days earlier)
#   Growth:      10 days (Start -> Peak Cases)
#               Raw ----------     Total --------     Smoothed ------   Total ---------
# Date          Cases   Deaths     Cases   Deaths     Cases   Deaths     Cases   Deaths
# ...
