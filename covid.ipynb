# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://coronavirus.data.gov.uk/">coronavirus.data.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=3.1, d_cases=9).analyse()
# Out:
# United Kingdom data to end of 2020-05-02:
#   182,260 cases, 28,131 deaths
#   2,741 cases per million, 423 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-02 (-61 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-21 days, 5,468 cases)
#   End:         2020-06-29 ( 59 days, 80 days after peak cases)
#   Day Zero:    2020-03-15 (-48 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-21 days, 945 deaths)
#
# Parameters:
#   Totals:      165,221 cases and 26,097 deaths at end of 2020-04-29
#   Smoothed:    165,221 cases and 26,097 deaths at end of 2020-04-29 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-04-29, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
#                L = 21,871, r = 5.83, dilation = 9 for cases
# ...

# %%
covid.Region(geoId='CN').analyse(ylog=1)
# Out:
# China data to end of 2020-05-01:
#   83,959 cases, 4,637 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-01-15 (-107 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-81 days, 4,690 cases)
#   End:         2020-03-06 (-55 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-97 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-76 days, 128 deaths)
#
# Parameters:
#   Totals:      83,940 cases and 4,637 deaths at end of 2020-04-28
#   Smoothed:    83,940 cases and 4,636 deaths at end of 2020-04-28 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-04-28, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
#                L = 18,758, r = 5.66, dilation = 1 for cases
# ...

# %%
covid.Region(geoId='ES', dilation=3.1, d_cases=2.2).analyse()
# note: ECDC cases data differs from Worldometer due to anti-body tests
# Out:
# Spain data to end of 2020-05-01:
#   215,216 cases, 24,824 deaths
#   4,606 cases per million, 531 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-29 (-61 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-28 (-33 days, 7,821 cases)
#   End:         2020-05-23 ( 23 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-50 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-30 days, 868 deaths)
#
# Parameters:
#   Totals:      210,773 cases and 23,822 deaths at end of 2020-04-27
#   Smoothed:    210,772 cases and 23,822 deaths at end of 2020-04-27 (7 points)
#   Spread:      Peak infection rate 14.6 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-27, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
#                L = 31,283, r = 6.25, dilation = 2.2 for cases
# ...

# %%
covid.Region(geoId='IT', dilation=2.4, d_cases=3.6).analyse()
# Out:
# Italy data to end of 2020-05-01:
#   207,428 cases, 28,236 deaths
#   3,432 cases per million, 467 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-21 (-70 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-39 days, 5,644 cases)
#   End:         2020-05-23 ( 23 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-60 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-32 days, 823 deaths)
#
# Parameters:
#   Totals:      201,505 cases and 27,359 deaths at end of 2020-04-28
#   Smoothed:    201,504 cases and 27,358 deaths at end of 2020-04-28 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-28, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
#                L = 22,575, r = 6.59, dilation = 3.6 for cases
# ...

# %%
covid.Region(geoId='FR', dilation=2.6, d_cases=3.1).analyse()
# Out:
# France data to end of 2020-05-01:
#   130,185 cases, 24,594 deaths
#   1,943 cases per million, 367 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-27 (-64 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-33 days, 4,528 cases)
#   End:         2020-05-29 ( 29 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-51 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-25 days, 1,102 deaths)
#
# Parameters:
#   Totals:      126,835 cases and 23,660 deaths at end of 2020-04-28
#   Smoothed:    126,834 cases and 23,659 deaths at end of 2020-04-28 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-04-28, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
#                L = 18,112, r = 8.0, dilation = 3.1 for cases
# ...

# %%
covid.Region(geoId='DE', dilation=1.2, d_cases=2.2).analyse()
# Out:
# Germany data to end of 2020-05-01:
#   161,703 cases, 6,575 deaths
#   1,950 cases per million, 79 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-27 (-64 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-30 days, 5,596 cases)
#   End:         2020-06-07 ( 38 days, 68 days after peak cases)
#   Day Zero:    2020-03-20 (-42 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-14 days, 234 deaths)
#
# Parameters:
#   Totals:      157,641 cases and 6,115 deaths at end of 2020-04-28
#   Smoothed:    157,641 cases and 6,115 deaths at end of 2020-04-28 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-04-28, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
#                L = 22,385, r = 7.48, dilation = 2.2 for cases
# ...

# %%
covid.Region(geoId='US', dilation=2.9, d_cases=6).analyse()
# Out:
# United States of America data to end of 2020-05-01:
#   1,103,781 cases, 65,068 deaths
#   3,374 cases per million, 199 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-25 (-66 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-24 days, 31,801 cases)
#   End:         2020-06-29 ( 60 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-49 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-13 days, 2,694 deaths)
#
# Parameters:
#   Totals:      1,012,583 cases and 58,355 deaths at end of 2020-04-28
#   Smoothed:    1,012,582 cases and 58,355 deaths at end of 2020-04-28 (7 points)
#   Spread:      Peak infection rate 11.5 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-04-28, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP', dilation=1.3).analyse()
# Out:
# Japan data to end of 2020-05-01:
#   14,544 cases, 458 deaths
#   115 cases per million, 4 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-16 (-75 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-18 days, 643 cases)
#   End:         2020-06-25 ( 56 days, 74 days after peak cases)
#   Day Zero:    2020-03-28 (-34 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 ( -6 days, 29 deaths)
#
# Parameters:
#   Totals:      13,852 cases and 389 deaths at end of 2020-04-28
#   Smoothed:    13,851 cases and 388 deaths at end of 2020-04-28 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-04-28, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
#                L = 2,572, r = 8.0, dilation = 1.3 for cases
# ...

# %%
covid.Region(geoId='RU', lag=6).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-01:
#   114,431 cases, 1,169 deaths
#   792 cases per million, 8 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-14 (-48 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-28 ( -3 days, 6,528 cases)
#   End:         2020-06-11 ( 42 days, 45 days after peak cases)
#   Day Zero:    2020-04-06 (-25 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-04 (  3 days)
#
# Parameters:
#   Totals:      93,558 cases and 867 deaths at end of 2020-04-28
#   Smoothed:    93,558 cases and 867 deaths at end of 2020-04-28 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-04-28, compared to 7 days earlier)
#   Growth:      45 days (Start -> Peak Cases)
#                L = 26,110, r = 6.48, dilation = 1 for cases
# ...

# %%
covid.Region(geoId='NZ', dilation=3).analyse()
# Out:
# New Zealand data to end of 2020-05-01:
#   1,134 cases, 20 deaths
#   232 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-20 (-42 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-35 days, 72 cases)
#   End:         2020-04-09 (-21 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,126 cases and 19 deaths at end of 2020-04-28
#   Smoothed:    1,125 cases and 19 deaths at end of 2020-04-28 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-28, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                L = 288, r = 4.0, dilation = 3 for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
#   212 cases per million, 1 deaths per million (2018 population = 4,885,500)
# ...

# %%
covid.Region(geoId='BE', dilation=1.5, d_cases=1).analyse()
# Out:
# Belgium data to end of 2020-05-01:
#   49,032 cases, 7,703 deaths
#   4,293 cases per million, 674 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-04 (-58 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-19 days, 1,455 cases)
#   End:         2020-05-20 ( 20 days, 39 days after peak cases)
#   Day Zero:    2020-03-21 (-41 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-18 days, 333 deaths)
#
# Parameters:
#   Totals:      47,334 cases and 7,331 deaths at end of 2020-04-28
#   Smoothed:    47,334 cases and 7,330 deaths at end of 2020-04-28 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-04-28, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
#                L = 5,819, r = 4.25, dilation = 1 for cases
# ...

# %%
covid.Region(geoId='IE', dilation=1.2).analyse()
# Out:
# Ireland data to end of 2020-05-01:
#   20,833 cases, 1,265 deaths
#   4,292 cases per million, 261 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-11 (-51 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-19 days, 904 cases)
#   End:         2020-05-19 ( 19 days, 38 days after peak cases)
#   Day Zero:    2020-03-30 (-32 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 ( -9 days, 70 deaths)
#
# Parameters:
#   Totals:      19,877 cases and 1,159 deaths at end of 2020-04-28
#   Smoothed:    19,877 cases and 1,159 deaths at end of 2020-04-28 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-04-28, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
#                L = 3,615, r = 5.14, dilation = 1.2 for cases
# ...

# %%
covid.Region(geoId='SE', dilation=3).analyse()
# Out:
# Sweden data to end of 2020-05-01:
#   21,520 cases, 2,653 deaths
#   2,113 cases per million, 261 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-04 (-58 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 ( -9 days, 618 cases)
#   End:         2020-07-28 ( 89 days, 98 days after peak cases)
#   Day Zero:    2020-03-25 (-37 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-10 days, 106 deaths)
#
# Parameters:
#   Totals:      19,621 cases and 2,355 deaths at end of 2020-04-28
#   Smoothed:    19,620 cases and 2,355 deaths at end of 2020-04-28 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-28, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
#                L = 2,471, r = 4.0, dilation = 3 for cases
# ...

# %%
covid.Region(geoId='SG', dilation=4).analyse()
# Out:
# Singapore data to end of 2020-05-01:
#   17,101 cases, 16 deaths
#   3,033 cases per million, 3 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-11 (-80 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 ( -8 days, 1,006 cases)
#   End:         2020-09-13 (136 days, 144 days after peak cases)
#
# Parameters:
#   Totals:      14,951 cases and 14 deaths at end of 2020-04-28
#   Smoothed:    14,950 cases and 14 deaths at end of 2020-04-28 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-04-28, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                L = 4,022, r = 8.0, dilation = 4 for cases
#
# Outcome: 55,633 total cases, 62 total deaths by end of 2020-09-13
#   includes 98.2% of predicted cases and 93.5% of predicted deaths
# ...

# %%
covid.Region(geoId='BR', growth_days=57).analyse()
# Out:
# Brazil data to end of 2020-05-01:
#   91,589 cases, 6,329 deaths
#   437 cases per million, 30 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-11 (-51 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-07 (  6 days, 0 cases)
#   End:         2020-07-02 ( 63 days, 57 days after peak cases)
#   Day Zero:    2020-03-25 (-37 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-11 ( 10 days)
#
# Parameters:
#   Totals:      71,886 cases and 5,017 deaths at end of 2020-04-28
#   Smoothed:    71,886 cases and 5,016 deaths at end of 2020-04-28 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 2.0 (2020-04-28, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
#                L = 26,812, r = 6.0, dilation = 1 for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
# ...
