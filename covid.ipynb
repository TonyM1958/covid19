# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://coronavirus.data.gov.uk/">coronavirus.data.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=3.1, d_cases=9).analyse()
# Out:
# United Kingdom data to end of 2020-05-02:
#   182,260 cases, 28,131 deaths
#   2,741 cases per million, 423 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         48% through outbreak
#   Start:       2020-03-02 (-61 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-21 days, 5,468 cases)
#   End:         2020-06-29 ( 59 days, 80 days after peak cases)
#   Day Zero:    2020-03-15 (-48 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-21 days, 945 deaths)
#
# Parameters:
#   Totals:      165,221 cases and 26,097 deaths at end of 2020-04-29
#   Smoothed:    165,221 cases and 26,097 deaths at end of 2020-04-29 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-04-29, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='CN').analyse(ylog=1)
# Out:
# China data to end of 2020-05-02:
#   83,961 cases, 4,637 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-108 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-82 days, 4,690 cases)
#   End:         2020-03-06 (-56 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-98 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-77 days, 128 deaths)
#
# Parameters:
#   Totals:      83,944 cases and 4,637 deaths at end of 2020-04-29
#   Smoothed:    83,944 cases and 4,637 deaths at end of 2020-04-29 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-04-29, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=2.5, d_cases=2).analyse()
# note: ECDC cases data differs from Worldometer due to anti-body tests
# Out:
# Spain data to end of 2020-05-02:
#   216,582 cases, 25,100 deaths
#   4,635 cases per million, 537 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         70% through outbreak
#   Start:       2020-02-29 (-62 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-28 (-34 days, 7,844 cases)
#   End:         2020-05-23 ( 22 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-51 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-31 days, 873 deaths)
#
# Parameters:
#   Totals:      212,917 cases and 24,275 deaths at end of 2020-04-28
#   Smoothed:    212,916 cases and 24,275 deaths at end of 2020-04-28 (7 points)
#   Spread:      Peak infection rate 14.6 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-28, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=2.8, d_cases=4).analyse()
# Out:
# Italy data to end of 2020-05-02:
#   209,328 cases, 28,710 deaths
#   3,464 cases per million, 475 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         73% through outbreak
#   Start:       2020-02-21 (-71 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-40 days, 5,646 cases)
#   End:         2020-05-23 ( 22 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-61 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-33 days, 823 deaths)
#
# Parameters:
#   Totals:      203,591 cases and 27,682 deaths at end of 2020-04-29
#   Smoothed:    203,590 cases and 27,682 deaths at end of 2020-04-29 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-29, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=2.3, d_cases=2.5).analyse()
# Out:
# France data to end of 2020-05-02:
#   130,979 cases, 24,760 deaths
#   1,955 cases per million, 370 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         67% through outbreak
#   Start:       2020-02-27 (-65 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-34 days, 4,550 cases)
#   End:         2020-05-29 ( 28 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-52 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-26 days, 1,107 deaths)
#
# Parameters:
#   Totals:      128,442 cases and 24,087 deaths at end of 2020-04-29
#   Smoothed:    128,441 cases and 24,087 deaths at end of 2020-04-29 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-04-29, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1, d_cases=2.4).analyse()
# Out:
# Germany data to end of 2020-05-02:
#   162,496 cases, 6,649 deaths
#   1,959 cases per million, 80 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         61% through outbreak
#   Start:       2020-02-27 (-65 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-31 days, 5,606 cases)
#   End:         2020-06-07 ( 37 days, 68 days after peak cases)
#   Day Zero:    2020-03-20 (-43 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-15 days, 235 deaths)
#
# Parameters:
#   Totals:      159,119 cases and 6,288 deaths at end of 2020-04-29
#   Smoothed:    159,119 cases and 6,288 deaths at end of 2020-04-29 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-04-29, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='US', dilation=1.8, d_cases=9).analyse()
# Out:
# United States of America data to end of 2020-05-02:
#   1,133,069 cases, 66,385 deaths
#   3,463 cases per million, 203 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         51% through outbreak
#   Start:       2020-02-25 (-67 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-25 days, 31,793 cases)
#   End:         2020-06-29 ( 59 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-50 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-14 days, 2,727 deaths)
#
# Parameters:
#   Totals:      1,039,909 cases and 60,966 deaths at end of 2020-04-29
#   Smoothed:    1,039,909 cases and 60,966 deaths at end of 2020-04-29 (7 points)
#   Spread:      Peak infection rate 11.5 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-04-29, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP', dilation=1.5).analyse()
# Out:
# Japan data to end of 2020-05-02:
#   14,839 cases, 492 deaths
#   117 cases per million, 4 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         51% through outbreak
#   Start:       2020-02-16 (-76 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-19 days, 643 cases)
#   End:         2020-07-06 ( 66 days, 85 days after peak cases)
#   Day Zero:    2020-03-28 (-35 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 ( -7 days, 29 deaths)
#
# Parameters:
#   Totals:      14,088 cases and 415 deaths at end of 2020-04-29
#   Smoothed:    14,088 cases and 414 deaths at end of 2020-04-29 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-04-29, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
#                L = 2,572, r = 8.0, dilation = 1.5 for cases
# ...

# %%
covid.Region(geoId='RU', growth_days=50, lag=6).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-02:
#   124,054 cases, 1,222 deaths
#   859 cases per million, 8 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         46% through outbreak
#   Start:       2020-03-14 (-49 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-03 (  1 days, --- cases)
#   End:         2020-06-21 ( 51 days, 50 days after peak cases)
#   Day Zero:    2020-04-06 (-26 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-28 ( -4 days, 79 deaths)
#
# Parameters:
#   Totals:      99,399 cases and 972 deaths at end of 2020-04-29
#   Smoothed:    99,399 cases and 972 deaths at end of 2020-04-29 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-04-29, compared to 7 days earlier)
#   Growth:      50 days (Start -> Peak Cases)
#                L = 29,457, r = 5.94, dilation = 1 for cases
# ...

# %%
covid.Region(geoId='NZ', dilation=3).analyse()
# Out:
# New Zealand data to end of 2020-05-02:
#   1,136 cases, 20 deaths
#   233 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-43 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-36 days, 72 cases)
#   End:         2020-04-09 (-22 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,129 cases and 19 deaths at end of 2020-04-29
#   Smoothed:    1,128 cases and 19 deaths at end of 2020-04-29 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-29, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                L = 288, r = 4.0, dilation = 3 for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
# ...

# %%
covid.Region(geoId='BE', dilation=1.3, d_cases=1).analyse()
# Out:
# Belgium data to end of 2020-05-02:
#   49,517 cases, 7,765 deaths
#   4,335 cases per million, 680 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         72% through outbreak
#   Start:       2020-03-04 (-59 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-20 days, 1,453 cases)
#   End:         2020-05-20 ( 19 days, 39 days after peak cases)
#   Day Zero:    2020-03-21 (-42 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-19 days, 335 deaths)
#
# Parameters:
#   Totals:      47,859 cases and 7,501 deaths at end of 2020-04-29
#   Smoothed:    47,859 cases and 7,501 deaths at end of 2020-04-29 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-04-29, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=1, d_cases=2).analyse()
# Out:
# Ireland data to end of 2020-05-02:
#   21,176 cases, 1,265 deaths
#   4,363 cases per million, 261 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         51% through outbreak
#   Start:       2020-03-11 (-52 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-20 days, 904 cases)
#   End:         2020-06-14 ( 44 days, 64 days after peak cases)
#   Day Zero:    2020-03-30 (-33 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-10 days, 71 deaths)
#
# Parameters:
#   Totals:      20,253 cases and 1,190 deaths at end of 2020-04-29
#   Smoothed:    20,253 cases and 1,190 deaths at end of 2020-04-29 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-29, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=1.2, d_cases=3).analyse()
# Out:
# Sweden data to end of 2020-05-02:
#   22,082 cases, 2,669 deaths
#   2,168 cases per million, 262 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         38% through outbreak
#   Start:       2020-03-04 (-59 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 (-10 days, 622 cases)
#   End:         2020-07-28 ( 88 days, 98 days after peak cases)
#   Day Zero:    2020-03-25 (-38 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-11 days, 108 deaths)
#
# Parameters:
#   Totals:      20,302 cases and 2,462 deaths at end of 2020-04-29
#   Smoothed:    20,302 cases and 2,462 deaths at end of 2020-04-29 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-29, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SG', dilation=4).analyse()
# Out:
# Singapore data to end of 2020-05-02:
#   17,548 cases, 17 deaths
#   3,112 cases per million, 3 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         36% through outbreak
#   Start:       2020-02-11 (-81 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 ( -9 days, 1,005 cases)
#   End:         2020-09-13 (135 days, 144 days after peak cases)
#
# Parameters:
#   Totals:      15,641 cases and 14 deaths at end of 2020-04-29
#   Smoothed:    15,640 cases and 14 deaths at end of 2020-04-29 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-29, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                L = 4,021, r = 8.0, dilation = 4 for cases
#
# Outcome: 55,839 total cases, 63 total deaths by end of 2020-09-13
# ...

# %%
covid.Region(geoId='BR', growth_days=59).analyse()
# Out:
# Brazil data to end of 2020-05-02:
#   96,559 cases, 6,750 deaths
#   461 cases per million, 32 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         51% through outbreak
#   Start:       2020-03-11 (-52 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-28 ( -4 days, 5,465 cases)
#   End:         2020-06-14 ( 44 days, 48 days after peak cases)
#   Day Zero:    2020-03-25 (-38 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-02 (  0 days, --- deaths)
#
# Parameters:
#   Totals:      78,162 cases and 5,466 deaths at end of 2020-04-29
#   Smoothed:    78,162 cases and 5,465 deaths at end of 2020-04-29 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.7 (2020-04-29, compared to 7 days earlier)
#   Growth:      48 days (Start -> Peak Cases)
# ...
