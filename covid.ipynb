# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# <p>Region codes: UK, FR, IT, DE, ES, US, CN, KR
# <br>Get the latest json data file and save as download.json from <a href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Check the data against the world figures at <a href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>

# %%
import covid

# %%
covid.Region(geoId='CN').analyse()
# Out:
# CN confirmed data up to end of 2020-04-15:
#   83,402 confirmed cases, 3,346 deaths
#   60 cases per million, 2 deaths per million (based on population of 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-01-15 (-91 days, when 50 or more cases were reported)
#   Day Zero:    2020-01-24 (-82 days, when 50 or more deaths were reported)
#   Peak Cases:  2020-02-09 (-66 days)
#   Peak Deaths: 2020-02-16 (-59 days)
#   End:         2020-03-04 (-41 days, 25 days after peak cases)
#
# Parameters:
#   Totals:      83,097 cases and 3,343 deaths at end of 2020-04-11
#   Smoothing:   83,096 cases and 3,343 deaths at end of 2020-04-11 using 9 adjacent values
#   Growth:      25 days (Start -> Peak Cases)
#   Lag:         7 days (Peak Cases -> Peak Deaths)
#   Spread:      15.3 peak infection rate on 2020-01-22 based on number of new cases compared to 7 days earlier
# ...

# %%
covid.Region(geoId='IT').analyse()
# Out:
# IT confirmed data up to end of 2020-04-15:
#   165,155 confirmed cases, 21,647 deaths
#   2,733 cases per million, 358 deaths per million (based on population of 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-20 (-55 days, when 50 or more cases were reported)
#   Day Zero:    2020-03-01 (-45 days, when 50 or more deaths were reported)
#   Peak Cases:  2020-03-24 (-22 days)
#   Peak Deaths: 2020-03-31 (-15 days)
#   End:         2020-04-25 ( 11 days, 33 days after peak cases)
#
# Parameters:
#   Totals:      152,271 cases and 19,470 deaths at end of 2020-04-11
#   Smoothing:   152,270 cases and 19,470 deaths at end of 2020-04-11 using 9 adjacent values
#   Growth:      33 days (Start -> Peak Cases)
#   Lag:         7 days (Peak Cases -> Peak Deaths)
#   Spread:      13.0 peak infection rate on 2020-02-26 based on number of new cases compared to 7 days earlier
# ...

# %%
covid.Region(geoId='ES').analyse()
# Out:
# ES confirmed data up to end of 2020-04-15:
#   177,633 confirmed cases, 18,579 deaths
#   3,802 cases per million, 398 deaths per million (based on population of 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-28 (-47 days, when 50 or more cases were reported)
#   Day Zero:    2020-03-10 (-36 days, when 50 or more deaths were reported)
#   Peak Cases:  2020-03-29 (-17 days)
#   Peak Deaths: 2020-03-31 (-15 days)
#   End:         2020-04-27 ( 13 days, 30 days after peak cases)
#
# Parameters:
#   Totals:      161,852 cases and 16,353 deaths at end of 2020-04-11
#   Smoothing:   161,852 cases and 16,352 deaths at end of 2020-04-11 using 9 adjacent values
#   Growth:      30 days (Start -> Peak Cases)
#   Lag:         2 days (Peak Cases -> Peak Deaths)
#   Spread:      13.6 peak infection rate on 2020-03-10 based on number of new cases compared to 7 days earlier
# ...

# %%
covid.Region(geoId='FR').analyse()
# Out:
# FR confirmed data up to end of 2020-04-15:
#   106,206 confirmed cases, 17,167 deaths
#   1,585 cases per million, 256 deaths per million (based on population of 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-27 (-48 days, when 50 or more cases were reported)
#   Day Zero:    2020-03-11 (-35 days, when 50 or more deaths were reported)
#   Peak Cases:  2020-03-31 (-15 days)
#   Peak Deaths: 2020-04-07 ( -8 days)
#   End:         2020-05-02 ( 18 days, 33 days after peak cases)
#
# Parameters:
#   Totals:      93,790 cases and 13,832 deaths at end of 2020-04-11
#   Smoothing:   93,789 cases and 13,831 deaths at end of 2020-04-11 using 9 adjacent values
#   Growth:      33 days (Start -> Peak Cases)
#   Lag:         7 days (Peak Cases -> Peak Deaths)
#   Spread:      8.3 peak infection rate on 2020-03-06 based on number of new cases compared to 7 days earlier
# ...

# %%
covid.Region(geoId='UK', lag=1).analyse()
# Out:
# UK confirmed data up to end of 2020-04-15:
#   98,476 confirmed cases, 12,868 deaths
#   1,481 cases per million, 194 deaths per million (based on population of 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-03-02 (-44 days, when 50 or more cases were reported)
#   Day Zero:    2020-03-15 (-31 days, when 50 or more deaths were reported)
#   Peak Cases:  2020-04-11 ( -4 days)
#   Peak Deaths: 2020-04-12 ( -3 days)
#   End:         2020-05-20 ( 36 days, 40 days after peak cases)
#
# Parameters:
#   Totals:      78,991 cases and 9,875 deaths at end of 2020-04-11
#   Smoothing:   78,990 cases and 9,874 deaths at end of 2020-04-11 using 9 adjacent values
#   Growth:      40 days (Start -> Peak Cases)
#   Lag:         1 days (Peak Cases -> Peak Deaths)
#   Spread:      5.7 peak infection rate on 2020-03-16 based on number of new cases compared to 7 days earlier
# ...

# %%
covid.Region(geoId='US', lag=1).analyse()
# Out:
# US confirmed data up to end of 2020-04-15:
#   639,664 confirmed cases, 30,985 deaths
#   1,955 cases per million, 95 deaths per million (based on population of 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Start:       2020-02-25 (-50 days, when 50 or more cases were reported)
#   Day Zero:    2020-03-13 (-33 days, when 50 or more deaths were reported)
#   Peak Cases:  2020-04-06 ( -9 days)
#   Peak Deaths: 2020-04-11 ( -4 days)
#   End:         2020-05-16 ( 32 days, 41 days after peak cases)
#
# Parameters:
#   Totals:      529,951 cases and 20,608 deaths at end of 2020-04-11
#   Smoothing:   529,951 cases and 20,608 deaths at end of 2020-04-11 using 9 adjacent values
#   Growth:      41 days (Start -> Peak Cases)
#   Lag:         5 days (Peak Cases -> Peak Deaths)
#   Spread:      11.4 peak infection rate on 2020-03-07 based on number of new cases compared to 7 days earlier
# ...
