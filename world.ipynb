# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='US', dilation=3, d_cases=6).analyse()
# Out:
# United States of America data to end of 2020-05-26:
#   1,681,212 cases, 98,916 deaths
#   5,139 cases per million, 302 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         70% through outbreak
#   Start:       2020-02-25 (-91 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-49 days, 31,995 cases)
#   End:         2020-06-29 ( 35 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-74 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-38 days, 2,729 deaths)
#
# Parameters:
#   Totals:      1,622,670 cases and 97,087 deaths at end of 2020-05-23
#   Smoothed:    1,622,669 cases and 97,087 deaths at end of 2020-05-23 (7 points)
#   Spread:      Peak infection rate 12.5 (2020-03-07, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-23, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
#                X = 2,344,850, r = 7.33, L = 127,979, dilation = 6, c = 93.2% for cases
#   Lag:         11 days (Peak Cases -> Peak Deaths)
#                X = 114,296, r = 7.64, L = 10,917, dilation = 3, c = 80.6% for deaths
#
# Outcome: 2,157,324 total cases, 112,945 total deaths by end of 2020-06-29
#   71.7% of predicted cases and 86.5% of predicted deaths reported to date
#   92.0% of predicted cases and 98.8% of predicted deaths reported by end date
#   7,167 cases per million (0.72%), 349 deaths per million (0.035%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-13   20,782    1,746   1,390,746   84,133    22,658    1,430   1,397,671   84,575
# 2020-05-14   27,143    1,773   1,417,889   85,906    22,460    1,441   1,420,131   86,016
# 2020-05-15   25,508    1,662   1,443,397   87,568    22,992    1,388   1,443,123   87,404
# 2020-05-16   24,487    1,186   1,467,884   88,754    22,695    1,369   1,465,818   88,773
# 2020-05-17   18,873      808   1,486,757   89,562    23,053    1,336   1,488,871   90,110
# 2020-05-18   21,841      791   1,508,598   90,353    22,809    1,263   1,511,680   91,373
# 2020-05-19   19,970    1,568   1,528,568   91,921    22,614    1,212   1,534,294   92,585
# 2020-05-20   23,285    1,518   1,551,853   93,439    22,149    1,197   1,556,443   93,781
# 2020-05-21   25,434    1,263   1,577,287   94,702    22,391    1,171   1,578,834   94,953
# 2020-05-22   24,147    1,305   1,601,434   96,007    21,994    1,130   1,600,828   96,083
# 2020-05-23   21,236    1,080   1,622,670   97,087    21,842    1,004   1,622,670   97,087
# 2020-05-24   20,568      633   1,643,238   97,720
# 2020-05-25   19,064      500   1,662,302   98,220
# 2020-05-26   18,910      696   1,681,212   98,916
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-23   20,572      999  1,622,670   97,087
# 2020-05-24   20,222      953  1,642,892   98,040
# 2020-05-25   19,873      907  1,662,766   98,947
# 2020-05-26   19,525      864  1,682,291   99,811  <-- latest raw data
# 2020-05-27   19,178      822  1,701,469  100,632
# 2020-05-28   18,832      781  1,720,302  101,413
# 2020-05-29   18,488      742  1,738,790  102,155
# 2020-05-30   18,146      705  1,756,935  102,860
# 2020-05-31   17,805      669  1,774,741  103,530
# 2020-06-01   17,467      635  1,792,207  104,164

# %%
covid.Region(geoId='RU', dilation=3, d_cases=2).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-26:
#   362,342 cases, 3,807 deaths
#   2,508 cases per million, 26 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         42% through outbreak
#   Start:       2020-03-14 (-73 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 (-17 days, 10,993 cases)
#   End:         2020-08-28 ( 95 days, 112 days after peak cases)
#   Day Zero:    2020-04-06 (-50 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-23 ( -3 days, 139 deaths)
#
# Parameters:
#   Totals:      335,882 cases and 3,388 deaths at end of 2020-05-23
#   Smoothed:    335,882 cases and 3,388 deaths at end of 2020-05-23 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-23, compared to 7 days earlier)
#   Growth:      56 days (Start -> Peak Cases)
#                X = 566,214, r = 6.36, L = 43,971, dilation = 2, c = 91.9% for cases
#   Lag:         14 days (Peak Cases -> Peak Deaths)
#                X = 12,828, r = 4.38, L = 554, dilation = 3, c = 83.1% for deaths
#
# Outcome: 565,235 total cases, 11,901 total deaths by end of 2020-08-28
#   64.0% of predicted cases and 29.7% of predicted deaths reported to date
#   99.8% of predicted cases and 92.8% of predicted deaths reported by end date
#   3,919 cases per million (0.39%), 89 deaths per million (0.009%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-13   10,028       96     242,271    2,212    10,491      102     242,051    2,219
# 2020-05-14    9,974       93     252,245    2,305    10,305      102     252,356    2,321
# 2020-05-15   10,598      113     262,843    2,418     9,915      102     262,271    2,423
# 2020-05-16    9,200      119     272,043    2,537     9,681      103     271,952    2,526
# 2020-05-17    9,709       94     281,752    2,631     9,500      109     281,452    2,635
# 2020-05-18    8,926       91     290,678    2,722     9,339      114     290,791    2,748
# 2020-05-19    9,263      115     299,941    2,837     9,095      119     299,887    2,867
# 2020-05-20    8,764      135     308,705    2,972     9,129      122     309,015    2,989
# 2020-05-21    8,849      127     317,554    3,099     8,970      130     317,986    3,119
# 2020-05-22    8,894      150     326,448    3,249     8,973      130     326,959    3,249
# 2020-05-23    9,434      139     335,882    3,388     8,923      139     335,882    3,388
# 2020-05-24    8,599      153     344,481    3,541
# 2020-05-25    8,946       92     353,427    3,633
# 2020-05-26    8,915      174     362,342    3,807
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-23    9,203      131    335,882    3,388
# 2020-05-24    9,002      131    344,884    3,519
# 2020-05-25    8,793      131    353,676    3,650
# 2020-05-26    8,577      131    362,254    3,780  <-- latest raw data
# 2020-05-27    8,356      130    370,610    3,911
# 2020-05-28    8,131      130    378,741    4,041
# 2020-05-29    7,902      130    386,642    4,171
# 2020-05-30    7,670      130    394,313    4,301
# 2020-05-31    7,437      129    401,749    4,430
# 2020-06-01    7,202      129    408,952    4,559

# %%
covid.Region(geoId='JP', dilation=2.2, d_cases=1.3).analyse(ylog=1)
# Out:
# Japan data to end of 2020-05-26:
#   16,651 cases, 858 deaths
#   132 cases per million, 7 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         74% through outbreak
#   Start:       2020-02-16 (-100 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-43 days, 643 cases)
#   End:         2020-06-25 ( 31 days, 74 days after peak cases)
#   Day Zero:    2020-03-28 (-59 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-31 days, 29 deaths)
#
# Parameters:
#   Totals:      16,550 cases and 820 deaths at end of 2020-05-23
#   Smoothed:    16,550 cases and 819 deaths at end of 2020-05-23 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-23, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
#                X = 16,785, r = 8.0, L = 2,570, dilation = 1.3, c = 69.1% for cases
#   Lag:         12 days (Peak Cases -> Peak Deaths)
#                X = 1,006, r = 8.0, L = 116, dilation = 2.2, c = 61.3% for deaths
#
# Outcome: 16,779 total cases, 987 total deaths by end of 2020-06-25
#   99.2% of predicted cases and 85.2% of predicted deaths reported to date
#   100.0% of predicted cases and 98.0% of predicted deaths reported by end date
#   133 cases per million (0.01%), 8 deaths per million (0.001%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-13       55       19      16,079      687        77       19      16,066      686
# 2020-05-14      114       23      16,193      710        72       18      16,139      704
# 2020-05-15       44       15      16,237      725        70       17      16,209      721
# 2020-05-16       48       19      16,285      744        52       15      16,260      736
# 2020-05-17       20        5      16,305      749        49       13      16,309      749
# 2020-05-18       60       14      16,365      763        46       12      16,355      761
# 2020-05-19       20        8      16,385      771        43       12      16,398      773
# 2020-05-20       39        6      16,424      777        38       11      16,436      784
# 2020-05-21       89       19      16,513      796        39       12      16,475      796
# 2020-05-22       23       12      16,536      808        37       12      16,512      808
# 2020-05-23       14       12      16,550      820        38       12      16,550      820
# 2020-05-24       31       10      16,581      830
# 2020-05-25       42       16      16,623      846
# 2020-05-26       28       12      16,651      858
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-23       27       11     16,550      820
# 2020-05-24       24       10     16,574      830
# 2020-05-25       22       10     16,595      840
# 2020-05-26       19       10     16,615      850  <-- latest raw data
# 2020-05-27       17        9     16,632      859
# 2020-05-28       16        9     16,648      868
# 2020-05-29       14        8     16,662      876
# 2020-05-30       13        8     16,675      884
# 2020-05-31       11        7     16,686      891
# 2020-06-01       10        7     16,696      898

# %%
covid.Region(geoId='SG', dilation=3.2).analyse()
# Out:
# Singapore data to end of 2020-05-26:
#   32,343 cases, 23 deaths
#   5,736 cases per million, 4 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         47% through outbreak
#   Start:       2020-02-11 (-105 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-33 days, 1,009 cases)
#   End:         2020-09-13 (111 days, 144 days after peak cases)
#
# Parameters:
#   Totals:      31,068 cases and 23 deaths at end of 2020-05-23
#   Smoothed:    31,067 cases and 23 deaths at end of 2020-05-23 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-23, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                X = 50,944, r = 8.0, L = 4,037, dilation = 3.2, c = 50.5% for cases
#
# Outcome: 50,603 total cases, 48 total deaths by end of 2020-09-13
#   63.5% of predicted cases and 46.1% of predicted deaths reported to date
#   99.3% of predicted cases and 96.2% of predicted deaths reported by end date
#   9,035 cases per million (0.90%), 9 deaths per million (0.001%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-13      675        0      25,346       21       702    < 0.5      25,459       21
# 2020-05-14      752        0      26,098       21       674    < 0.5      26,133       21
# 2020-05-15      793        0      26,891       21       654    < 0.5      26,787       22
# 2020-05-16      465        1      27,356       22       591    < 0.5      27,378       22
# 2020-05-17      682        0      28,038       22       576    < 0.5      27,955       22
# 2020-05-18      305        0      28,343       22       533    < 0.5      28,487       22
# 2020-05-19      451        0      28,794       22       507    < 0.5      28,994       22
# 2020-05-20      570        0      29,364       22       532    < 0.5      29,527       23
# 2020-05-21      448        1      29,812       23       513    < 0.5      30,040       23
# 2020-05-22      614        0      30,426       23       519    < 0.5      30,559       23
# 2020-05-23      642        0      31,068       23       509    < 0.5      31,068       23
# 2020-05-24      548        0      31,616       23
# 2020-05-25      344        0      31,960       23
# 2020-05-26      383        0      32,343       23
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-23      522        1     31,068       23
# 2020-05-24      513        1     31,581       24
# 2020-05-25      504        1     32,085       24
# 2020-05-26      495    < 0.5     32,580       25  <-- latest raw data
# 2020-05-27      486    < 0.5     33,067       25
# 2020-05-28      477    < 0.5     33,544       25
# 2020-05-29      468    < 0.5     34,013       26
# 2020-05-30      459    < 0.5     34,472       26
# 2020-05-31      450    < 0.5     34,922       27
# 2020-06-01      441    < 0.5     35,364       27

# %%
covid.Region(geoId='BR', dilation=2.5).analyse()
# Out:
# Brazil data to end of 2020-05-26:
#   391,222 cases, 24,512 deaths
#   1,868 cases per million, 117 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         34% through outbreak
#   Start:       2020-03-11 (-76 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-21 ( -5 days, 17,610 cases)
#   End:         2020-10-09 (137 days, 142 days after peak cases)
#   Day Zero:    2020-03-24 (-63 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-22 ( -4 days, 964 deaths)
#
# Parameters:
#   Totals:      347,398 cases and 22,013 deaths at end of 2020-05-23
#   Smoothed:    347,397 cases and 22,012 deaths at end of 2020-05-23 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-23, compared to 7 days earlier)
#   Growth:      71 days (Start -> Peak Cases)
#                X = 1,074,400, r = 7.45, L = 70,440, dilation = 2.5, c = 81.2% for cases
#   Lag:         1 days (Peak Cases -> Peak Deaths)
#                X = 72,160, r = 6.31, L = 3,854, dilation = 2.5, c = 89.9% for deaths
#
# Outcome: 1,071,642 total cases, 71,684 total deaths by end of 2020-10-09
#   36.4% of predicted cases and 34.0% of predicted deaths reported to date
#   99.7% of predicted cases and 99.3% of predicted deaths reported by end date
#   5,129 cases per million (0.51%), 344 deaths per million (0.034%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-13   11,385      749     188,974   13,149    11,132      722     194,929   13,361
# 2020-05-14   13,944      844     202,918   13,993    11,302      720     206,231   14,082
# 2020-05-15   15,305      824     218,223   14,817    12,384      761     218,615   14,842
# 2020-05-16   14,919      816     233,142   15,633    13,560      804     232,175   15,646
# 2020-05-17    7,938      485     241,080   16,118    14,795      824     246,969   16,469
# 2020-05-18   13,140      674     254,220   16,792    15,453      873     262,422   17,342
# 2020-05-19   17,408    1,179     271,628   17,971    16,246      899     278,668   18,241
# 2020-05-20   19,951      888     291,579   18,859    16,475      920     295,143   19,161
# 2020-05-21   18,508    1,188     310,087   20,047    17,610      944     312,753   20,106
# 2020-05-22   20,803    1,001     330,890   21,048    17,401      964     330,154   21,070
# 2020-05-23   16,508      965     347,398   22,013    17,244      943     347,398   22,013
# 2020-05-24   15,813      653     363,211   22,666
# 2020-05-25   11,687      807     374,898   23,473
# 2020-05-26   16,324    1,039     391,222   24,512
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-23   16,108      920    347,398   22,013
# 2020-05-24   16,072      919    363,470   22,932
# 2020-05-25   16,023      918    379,493   23,850
# 2020-05-26   15,960      916    395,453   24,765  <-- latest raw data
# 2020-05-27   15,883      913    411,335   25,678
# 2020-05-28   15,793      910    427,128   26,588
# 2020-05-29   15,689      906    442,817   27,494
# 2020-05-30   15,573      902    458,391   28,395
# 2020-05-31   15,445      897    473,836   29,292
# 2020-06-01   15,305      892    489,141   30,184

# %%
covid.Region(geoId='CL', dilation=3).analyse(ylog=1)
# Out:
# Chile data to end of 2020-05-26:
#   77,961 cases, 806 deaths
#   4,163 cases per million, 43 deaths per million (2018 population = 18,729,160)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-13 (-74 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-23 ( -3 days, 4,039 cases)
#   End:         2020-10-11 (139 days, 142 days after peak cases)
#   Day Zero:    2020-04-08 (-48 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-27 (  1 days)
#
# Parameters:
#   Totals:      65,393 cases and 673 deaths at end of 2020-05-23
#   Smoothed:    65,392 cases and 672 deaths at end of 2020-05-23 (7 points)
#   Spread:      Peak infection rate 4.2 (2020-03-22, compared to 7 days earlier)
#                Latest infection rate 1.6 (2020-05-23, compared to 7 days earlier)
#   Growth:      71 days (Start -> Peak Cases)
#                X = 253,872, r = 8.0, L = 16,157, dilation = 3, c = 66.2% for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#                X = 3,334, r = 8.0, L = 178, dilation = 3, c = 60.0% for deaths
#
# Outcome: 252,653 total cases, 3,315 total deaths by end of 2020-10-11
#   30.7% of predicted cases and 24.2% of predicted deaths reported to date
#   99.5% of predicted cases and 99.4% of predicted deaths reported by end date
#   13,555 cases per million (1.36%), 178 deaths per million (0.018%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-13    2,660       11      34,381      346     2,022       17      34,585      355
# 2020-05-14    2,659       12      37,040      358     2,123       20      36,708      374
# 2020-05-15    2,502       36      39,542      394     2,277       22      38,984      397
# 2020-05-16    1,886       27      41,428      421     2,542       25      41,526      421
# 2020-05-17    2,353       29      43,781      450     2,738       28      44,264      450
# 2020-05-18    2,278       28      46,059      478     2,923       33      47,187      483
# 2020-05-19    3,520       31      49,579      509     3,176       34      50,363      516
# 2020-05-20    4,038       35      53,617      544     3,411       36      53,774      552
# 2020-05-21    3,964       45      57,581      589     3,604       38      57,377      590
# 2020-05-22    4,276       41      61,857      630     3,976       40      61,354      631
# 2020-05-23    3,536       43      65,393      673     4,039       42      65,393      673
# 2020-05-24    3,709       45      69,102      718
# 2020-05-25    4,895       43      73,997      761
# 2020-05-26    3,964       45      77,961      806
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-23    3,585       45     65,393      673
# 2020-05-24    3,584       46     68,977      719
# 2020-05-25    3,580       47     72,557      765
# 2020-05-26    3,574       47     76,131      812  <-- latest raw data
# 2020-05-27    3,565       47     79,697      859
# 2020-05-28    3,554       47     83,251      906
# 2020-05-29    3,540       47     86,791      953
# 2020-05-30    3,524       47     90,315    1,000
# 2020-05-31    3,506       47     93,821    1,047
# 2020-06-01    3,485       47     97,306    1,094

# %%
covid.Region(geoId='PE', dilation=2.5, d_cases=3).analyse()
# Out:
# Peru data to end of 2020-05-26:
#   129,751 cases, 3,788 deaths
#   4,056 cases per million, 118 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-15 (-72 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-23 ( -3 days, 4,305 cases)
#   End:         2020-10-07 (135 days, 138 days after peak cases)
#   Day Zero:    2020-04-02 (-54 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-27 (  1 days)
#
# Parameters:
#   Totals:      115,754 cases and 3,373 deaths at end of 2020-05-23
#   Smoothed:    115,754 cases and 3,372 deaths at end of 2020-05-23 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-23, compared to 7 days earlier)
#   Growth:      69 days (Start -> Peak Cases)
#                X = 450,607, r = 4.88, L = 17,219, dilation = 3, c = 88.2% for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#                X = 13,310, r = 4.47, L = 506, dilation = 2.5, c = 88.4% for deaths
#
# Outcome: 433,787 total cases, 12,909 total deaths by end of 2020-10-07
#   28.8% of predicted cases and 28.5% of predicted deaths reported to date
#   96.3% of predicted cases and 97.0% of predicted deaths reported by end date
#   14,086 cases per million (1.41%), 416 deaths per million (0.042%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-13    4,247      112      76,306    2,169     3,346      101      76,528    2,175
# 2020-05-14    4,298       98      80,604    2,267     3,551      108      80,079    2,283
# 2020-05-15    3,891      126      84,495    2,393     3,714      118      83,793    2,401
# 2020-05-16    4,046      130      88,541    2,523     3,900      122      87,693    2,524
# 2020-05-17    3,732      125      92,273    2,648     3,942      122      91,635    2,645
# 2020-05-18    2,660      141      94,933    2,789     4,006      126      95,641    2,771
# 2020-05-19    4,550      125      99,483    2,914     3,869      121      99,510    2,892
# 2020-05-20    4,537      110     104,020    3,024     3,870      121     103,380    3,013
# 2020-05-21    4,749      124     108,769    3,148     3,938      115     107,318    3,129
# 2020-05-22    2,929       96     111,698    3,244     4,131      120     111,449    3,248
# 2020-05-23    4,056      129     115,754    3,373     4,305      125     115,754    3,373
# 2020-05-24    4,205       83     119,959    3,456
# 2020-05-25    4,020      173     123,979    3,629
# 2020-05-26    5,772      159     129,751    3,788
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-23    4,077      123    115,754    3,373
# 2020-05-24    4,076      124    119,830    3,497
# 2020-05-25    4,075      125    123,905    3,622
# 2020-05-26    4,072      125    127,976    3,748  <-- latest raw data
# 2020-05-27    4,068      126    132,044    3,873
# 2020-05-28    4,063      126    136,107    3,999
# 2020-05-29    4,056      125    140,163    4,124
# 2020-05-30    4,049      125    144,212    4,250
# 2020-05-31    4,041      125    148,253    4,375
# 2020-06-01    4,031      125    152,285    4,500

# %%
covid.Region(geoId='MX', dilation=3).analyse()
# Out:
# Mexico data to end of 2020-05-26:
#   74,560 cases, 8,134 deaths
#   591 cases per million, 64 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-15 (-72 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-23 ( -3 days, 2,901 cases)
#   End:         2020-10-07 (135 days, 138 days after peak cases)
#   Day Zero:    2020-04-02 (-54 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-27 (  1 days)
#
# Parameters:
#   Totals:      65,856 cases and 7,179 deaths at end of 2020-05-23
#   Smoothed:    65,856 cases and 7,179 deaths at end of 2020-05-23 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-23, compared to 7 days earlier)
#   Growth:      69 days (Start -> Peak Cases)
#                X = 256,275, r = 5.69, L = 11,605, dilation = 3, c = 88.0% for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#                X = 33,427, r = 5.88, L = 1,460, dilation = 3, c = 89.2% for deaths
#
# Outcome: 250,622 total cases, 32,697 total deaths by end of 2020-10-07
#   29.1% of predicted cases and 24.3% of predicted deaths reported to date
#   97.8% of predicted cases and 97.8% of predicted deaths reported by end date
#   2,031 cases per million (0.20%), 265 deaths per million (0.026%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-13    1,862      294      40,186    4,220     1,964      243      40,853    4,238
# 2020-05-14    2,409      257      42,595    4,477     2,038      246      42,891    4,484
# 2020-05-15    2,437      290      45,032    4,767     2,197      253      45,088    4,737
# 2020-05-16    2,112      278      47,144    5,045     2,300      250      47,387    4,987
# 2020-05-17    2,075      132      49,219    5,177     2,355      269      49,742    5,256
# 2020-05-18    2,414      155      51,633    5,332     2,436      292      52,178    5,548
# 2020-05-19    2,713      334      54,346    5,666     2,511      319      54,689    5,868
# 2020-05-20    2,248      424      56,594    6,090     2,686      307      57,375    6,175
# 2020-05-21    2,973      420      59,567    6,510     2,785      319      60,160    6,493
# 2020-05-22    2,960      479      62,527    6,989     2,795      331      62,955    6,824
# 2020-05-23    3,329      190      65,856    7,179     2,901      355      65,856    7,179
# 2020-05-24    2,764      215      68,620    7,394
# 2020-05-25    2,485      239      71,105    7,633
# 2020-05-26    3,455      501      74,560    8,134
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-23    2,676      350     65,856    7,179
# 2020-05-24    2,676      354     68,532    7,533
# 2020-05-25    2,674      358     71,206    7,891
# 2020-05-26    2,672      360     73,878    8,251  <-- latest raw data
# 2020-05-27    2,668      360     76,546    8,611
# 2020-05-28    2,664      360     79,210    8,971
# 2020-05-29    2,658      360     81,868    9,331
# 2020-05-30    2,652      360     84,520    9,691
# 2020-05-31    2,644      359     87,164   10,050
# 2020-06-01    2,636      358     89,800   10,409

# %%
covid.Region(geoId='CN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2020-05-26:
#   84,103 cases, 4,638 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-132 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-106 days, 4,689 cases)
#   End:         2020-03-06 (-80 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-122 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-101 days, 128 deaths)
#
# Parameters:
#   Totals:      84,084 cases and 4,638 deaths at end of 2020-05-23
#   Smoothed:    84,083 cases and 4,637 deaths at end of 2020-05-23 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-23, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
#                X = 80,828, r = 5.02, L = 18,757, dilation = 0.7, c = 84.1% for cases
#   Lag:         5 days (Peak Cases -> Peak Deaths)
#                X = 3,210, r = 4.05, L = 510, dilation = 1, c = 94.8% for deaths
#
# Outcome: 80,814 total cases, 3,099 total deaths at end of 2020-03-07
#   58 cases per million (0.01%), 2 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-13        6        0      84,024    4,637         8    < 0.5      84,022    4,637
# 2020-05-14        5        0      84,029    4,637         6    < 0.5      84,028    4,637
# 2020-05-15        9        0      84,038    4,637         7    < 0.5      84,035    4,637
# 2020-05-16        6        1      84,044    4,638         7    < 0.5      84,042    4,638
# 2020-05-17       10        0      84,054    4,638         6    < 0.5      84,048    4,638
# 2020-05-18        9        0      84,063    4,638         7    < 0.5      84,055    4,638
# 2020-05-19        2        0      84,065    4,638         6    < 0.5      84,061    4,638
# 2020-05-20        2        0      84,067    4,638         6        0      84,067    4,638
# 2020-05-21       12        0      84,079    4,638         6        0      84,073    4,638
# 2020-05-22        2        0      84,081    4,638         6        0      84,079    4,638
# 2020-05-23        3        0      84,084    4,638         5        0      84,084    4,638
# 2020-05-24       11        0      84,095    4,638
# 2020-05-25        7        0      84,102    4,638
# 2020-05-26        1        0      84,103    4,638
#
#   ** first wave ended **

# %%
covid.Region(geoId='KR', dilation=3, d_cases=1).analyse(ylog=1)
# Out:
# South Korea data to end of 2020-05-26:
#   11,265 cases, 269 deaths
#   218 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-99 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-85 days, 609 cases)
#   End:         2020-03-15 (-71 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-79 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-71 days, 5 deaths)
#
# Parameters:
#   Totals:      11,190 cases and 266 deaths at end of 2020-05-23
#   Smoothed:    11,190 cases and 266 deaths at end of 2020-05-23 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-23, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
#                X = 8,497, r = 4.03, L = 2,435, dilation = 1, c = 93.3% for cases
#   Lag:         14 days (Peak Cases -> Peak Deaths)
#                X = 165, r = 4.0, L = 18, dilation = 3, c = 80.8% for deaths
#
# Outcome: 8,320 total cases, 81 total deaths at end of 2020-03-16
#   161 cases per million (0.02%), 2 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-13       29        1      10,991      260        25        1      10,988      259
# 2020-05-14       27        0      11,018      260        22        1      11,011      260
# 2020-05-15       19        2      11,037      262        20        1      11,031      261
# 2020-05-16       13        0      11,050      262        21        1      11,052      261
# 2020-05-17       15        1      11,065      263        19        1      11,071      262
# 2020-05-18       13        0      11,078      263        18        1      11,088      263
# 2020-05-19       32        0      11,110      263        18        1      11,107      263
# 2020-05-20       12        1      11,122      264        20        1      11,127      264
# 2020-05-21       20        0      11,142      264        20        1      11,147      264
# 2020-05-22       23        2      11,165      266        21        1      11,168      265
# 2020-05-23       25        0      11,190      266        22        1      11,190      266
# 2020-05-24       16        1      11,206      267
# 2020-05-25       19        2      11,225      269
# 2020-05-26       40        0      11,265      269
#
#   ** first wave ended **

# %%
covid.Region(geoId='NZ', dilation=3.1).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-05-26:
#   1,154 cases, 21 deaths
#   236 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-67 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-60 days, 72 cases)
#   End:         2020-04-09 (-46 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,154 cases and 21 deaths at end of 2020-05-23
#   Smoothed:    1,154 cases and 21 deaths at end of 2020-05-23 (7 points)
#   Spread:      Peak infection rate 2.5 (2020-05-21, compared to 7 days earlier)
#                Latest infection rate 0.2 (2020-05-23, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,105, r = 4.0, L = 288, dilation = 3.1, c = 89.2% for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
#   212 cases per million (0.02%), 1 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-13        0        0       1,147       21         1        0       1,148       21
# 2020-05-14        1        0       1,148       21     < 0.5        0       1,148       21
# 2020-05-15        0        0       1,148       21         1        0       1,149       21
# 2020-05-16        1        0       1,149       21         1        0       1,150       21
# 2020-05-17        0        0       1,149       21         1        0       1,151       21
# 2020-05-18        4        0       1,153       21         1        0       1,151       21
# 2020-05-19        0        0       1,153       21         1        0       1,152       21
# 2020-05-20        0        0       1,153       21         1        0       1,153       21
# 2020-05-21        1        0       1,154       21         1        0       1,154       21
# 2020-05-22        0        0       1,154       21     < 0.5        0       1,154       21
# 2020-05-23        0        0       1,154       21     < 0.5        0       1,154       21
# 2020-05-24        0        0       1,154       21
# 2020-05-25        0        0       1,154       21
# 2020-05-26        0        0       1,154       21
#
#   ** first wave ended **

# %%
covid.Region(geoId='AU').analyse(ylog=1)
# Out:
# Australia data to end of 2020-05-26:
#   7,133 cases, 102 deaths
#   285 cases per million, 4 deaths per million (2018 population = 24,992,369)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-04 (-83 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-60 days, 391 cases)
#   End:         2020-04-18 (-37 days, 23 days after peak cases)
#   Day Zero:    2020-04-09 (-47 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-50 days, 4 deaths)
#
# Parameters:
#   Totals:      7,106 cases and 102 deaths at end of 2020-05-23
#   Smoothed:    7,105 cases and 102 deaths at end of 2020-05-23 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-23, compared to 7 days earlier)
#   Growth:      23 days (Start -> Peak Cases)
#                X = 6,623, r = 5.48, L = 1,562, dilation = 1, c = 87.6% for cases
#   Lag:         10 days (Peak Cases -> Peak Deaths)
#                X = 74, r = 5.16, L = 16, dilation = 1, c = 85.5% for deaths
#
# Outcome: 6,612 total cases, 70 total deaths at end of 2020-04-19
#   265 cases per million (0.03%), 3 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-13       11        1       6,975       98        15    < 0.5       6,985       98
# 2020-05-14       14        0       6,989       98        15    < 0.5       7,000       98
# 2020-05-15       30        0       7,019       98        16    < 0.5       7,016       99
# 2020-05-16       17        0       7,036       98        15    < 0.5       7,030       99
# 2020-05-17        9        0       7,045       98        15    < 0.5       7,045       99
# 2020-05-18       15        1       7,060       99        13    < 0.5       7,058      100
# 2020-05-19        8        0       7,068       99        11    < 0.5       7,069      100
# 2020-05-20       11        1       7,079      100        10        1       7,079      101
# 2020-05-21        2        0       7,081      100         9        1       7,088      101
# 2020-05-22       14        1       7,095      101         8    < 0.5       7,097      102
# 2020-05-23       11        1       7,106      102         9    < 0.5       7,106      102
# 2020-05-24        3        0       7,109      102
# 2020-05-25        9        0       7,118      102
# 2020-05-26       15        0       7,133      102
#
#   ** first wave ended **
