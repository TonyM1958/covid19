# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='CN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2020-05-17:
#   84,054 cases, 4,638 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-123 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-97 days, 4,689 cases)
#   End:         2020-03-06 (-71 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-113 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-92 days, 128 deaths)
#
# Parameters:
#   Totals:      84,029 cases and 4,637 deaths at end of 2020-05-14
#   Smoothed:    84,029 cases and 4,637 deaths at end of 2020-05-14 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-14, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
#                X = 80,829, r = 5.02, L = 18,757, dilation = 0.7, c = 84.1% for cases
#   Lag:         5 days (Peak Cases -> Peak Deaths)
#                X = 3,210, r = 4.05, L = 510, dilation = 1, c = 94.8% for deaths
#
# Outcome: 80,814 total cases, 3,099 total deaths at end of 2020-03-07
#   58 cases per million (0.01%), 2 deaths per million (0.000%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-04        2        0      83,966    4,637         3        0      83,964    4,637
# 2020-05-05        2        0      83,968    4,637         2        0      83,967    4,637
# 2020-05-06        2        0      83,970    4,637         4        0      83,971    4,637
# 2020-05-07        6        0      83,976    4,637         7        0      83,977    4,637
# 2020-05-08        0        0      83,976    4,637         6        0      83,984    4,637
# 2020-05-09       15        0      83,991    4,637         7        0      83,991    4,637
# 2020-05-10       19        0      84,010    4,637         8        0      83,999    4,637
# 2020-05-11        1        0      84,011    4,637         8        0      84,006    4,637
# 2020-05-12        7        0      84,018    4,637         9        0      84,015    4,637
# 2020-05-13        6        0      84,024    4,637         8    < 0.5      84,023    4,637
# 2020-05-14        5        0      84,029    4,637         6    < 0.5      84,029    4,637
# 2020-05-15        9        0      84,038    4,637
# 2020-05-16        6        1      84,044    4,638
# 2020-05-17       10        0      84,054    4,638

# %%
covid.Region(geoId='KR', dilation=3, d_cases=1).analyse(ylog=1)
# Out:
# South Korea data to end of 2020-05-17:
#   11,065 cases, 263 deaths
#   214 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-90 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-76 days, 609 cases)
#   End:         2020-03-15 (-62 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-70 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-62 days, 5 deaths)
#
# Parameters:
#   Totals:      11,018 cases and 260 deaths at end of 2020-05-14
#   Smoothed:    11,018 cases and 260 deaths at end of 2020-05-14 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 1.4 (2020-05-14, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
#                X = 8,503, r = 4.03, L = 2,437, dilation = 1, c = 93.2% for cases
#   Lag:         14 days (Peak Cases -> Peak Deaths)
#                X = 165, r = 4.0, L = 18, dilation = 3, c = 80.4% for deaths
#
# Outcome: 8,320 total cases, 81 total deaths at end of 2020-03-16
#   161 cases per million (0.02%), 2 deaths per million (0.000%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-04        3        2      10,804      254         7        1      10,812      253
# 2020-05-05        2        1      10,806      255         9        1      10,820      254
# 2020-05-06        4        1      10,810      256        12        1      10,832      254
# 2020-05-07       12        0      10,822      256        15        1      10,847      255
# 2020-05-08       18        0      10,840      256        19        1      10,866      256
# 2020-05-09       34        0      10,874      256        22        1      10,888      256
# 2020-05-10       35        0      10,909      256        26        1      10,914      257
# 2020-05-11       27        2      10,936      258        28        1      10,942      257
# 2020-05-12       26        1      10,962      259        28        1      10,971      258
# 2020-05-13       29        1      10,991      260        25        1      10,996      259
# 2020-05-14       27        0      11,018      260        22        1      11,018      260
# 2020-05-15       19        2      11,037      262
# 2020-05-16       13        0      11,050      262
# 2020-05-17       15        1      11,065      263

# %%
covid.Region(geoId='NZ', dilation=3.1).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-05-17:
#   1,149 cases, 21 deaths
#   235 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-58 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-51 days, 72 cases)
#   End:         2020-04-09 (-37 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,148 cases and 21 deaths at end of 2020-05-14
#   Smoothed:    1,148 cases and 21 deaths at end of 2020-05-14 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.2 (2020-05-14, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,105, r = 4.0, L = 288, dilation = 3.1, c = 89.1% for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
#   212 cases per million (0.02%), 1 deaths per million (0.000%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-04        0        0       1,137       20         1    < 0.5       1,138       20
# 2020-05-05        1        1       1,138       21         1    < 0.5       1,139       21
# 2020-05-06        1        0       1,139       21         1    < 0.5       1,140       21
# 2020-05-07        2        0       1,141       21         1    < 0.5       1,141       21
# 2020-05-08        1        0       1,142       21         1    < 0.5       1,143       21
# 2020-05-09        2        0       1,144       21         1        0       1,144       21
# 2020-05-10        3        0       1,147       21         1        0       1,145       21
# 2020-05-11        0        0       1,147       21         1        0       1,146       21
# 2020-05-12        0        0       1,147       21         1        0       1,147       21
# 2020-05-13        0        0       1,147       21         1        0       1,148       21
# 2020-05-14        1        0       1,148       21     < 0.5        0       1,148       21
# 2020-05-15        0        0       1,148       21
# 2020-05-16        1        0       1,149       21
# 2020-05-17        0        0       1,149       21

# %%
covid.Region(geoId='US', dilation=2.6, d_cases=6).analyse()
# Out:
# United States of America data to end of 2020-05-17:
#   1,486,757 cases, 89,562 deaths
#   4,544 cases per million, 274 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         63% through outbreak
#   Start:       2020-02-25 (-82 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-40 days, 31,944 cases)
#   End:         2020-06-29 ( 44 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-65 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-29 days, 2,726 deaths)
#
# Parameters:
#   Totals:      1,417,889 cases and 85,906 deaths at end of 2020-05-14
#   Smoothed:    1,417,888 cases and 85,906 deaths at end of 2020-05-14 (7 points)
#   Spread:      Peak infection rate 11.5 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-14, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
#                X = 2,308,597, r = 7.5, L = 127,777, dilation = 6, c = 92.5% for cases
#   Lag:         11 days (Peak Cases -> Peak Deaths)
#                X = 110,594, r = 6.92, L = 10,903, dilation = 2.6, c = 82.4% for deaths
#
# Outcome: 2,133,471 total cases, 109,522 total deaths by end of 2020-06-29
#   64.4% of predicted cases and 81.0% of predicted deaths reported to date
#   92.4% of predicted cases and 99.0% of predicted deaths reported by end date
#   7,056 cases per million (0.71%), 338 deaths per million (0.034%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-04   22,593    1,252   1,180,634   68,934    26,737    1,816   1,180,876   70,023
# 2020-05-05   23,841    2,144   1,204,475   71,078    25,737    1,737   1,206,613   71,760
# 2020-05-06   24,128    2,353   1,228,603   73,431    25,212    1,780   1,231,825   73,540
# 2020-05-07   28,369    2,239   1,256,972   75,670    24,539    1,699   1,256,364   75,239
# 2020-05-08   26,957    1,510   1,283,929   77,180    23,899    1,685   1,280,263   76,924
# 2020-05-09   25,612    1,614   1,309,541   78,794    23,643    1,622   1,303,906   78,546
# 2020-05-10   20,258      734   1,329,799   79,528    23,165    1,535   1,327,071   80,081
# 2020-05-11   18,117    1,156   1,347,916   80,684    22,990    1,468   1,350,060   81,549
# 2020-05-12   22,048    1,703   1,369,964   82,387    22,783    1,490   1,372,843   83,039
# 2020-05-13   20,782    1,746   1,390,746   84,133    22,622    1,428   1,395,465   84,467
# 2020-05-14   27,143    1,773   1,417,889   85,906    22,424    1,439   1,417,889   85,906
# 2020-05-15   25,508    1,662   1,443,397   87,568
# 2020-05-16   24,487    1,186   1,467,884   88,754
# 2020-05-17   18,873      808   1,486,757   89,562
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-14   23,482    1,377  1,417,889   85,906
# 2020-05-15   23,131    1,318  1,441,020   87,224
# 2020-05-16   22,778    1,261  1,463,798   88,486
# 2020-05-17   22,422    1,205  1,486,220   89,691  <-- latest raw data
# 2020-05-18   22,065    1,150  1,508,285   90,841
# 2020-05-19   21,708    1,097  1,529,993   91,938
# 2020-05-20   21,349    1,045  1,551,342   92,983
# 2020-05-21   20,990      995  1,572,332   93,979
# 2020-05-22   20,631      947  1,592,963   94,926
# 2020-05-23   20,272      900  1,613,235   95,826

# %%
covid.Region(geoId='RU', lag=5, dilation=2.5).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-17:
#   281,752 cases, 2,631 deaths
#   1,950 cases per million, 18 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         36% through outbreak
#   Start:       2020-03-14 (-64 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 ( -8 days, 10,988 cases)
#   End:         2020-08-28 (104 days, 112 days after peak cases)
#   Day Zero:    2020-04-06 (-41 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-14 ( -3 days, 102 deaths)
#
# Parameters:
#   Totals:      252,245 cases and 2,305 deaths at end of 2020-05-14
#   Smoothed:    252,245 cases and 2,305 deaths at end of 2020-05-14 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-14, compared to 7 days earlier)
#   Growth:      56 days (Start -> Peak Cases)
#                X = 674,237, r = 6.3, L = 43,951, dilation = 2.5, c = 92.1% for cases
#   Lag:         5 days (Peak Cases -> Peak Deaths)
#                X = 7,859, r = 4.92, L = 406, dilation = 2.5, c = 87.9% for deaths
#
# Outcome: 669,890 total cases, 7,680 total deaths by end of 2020-08-28
#   41.8% of predicted cases and 33.5% of predicted deaths reported to date
#   99.4% of predicted cases and 97.7% of predicted deaths reported by end date
#   4,667 cases per million (0.47%), 54 deaths per million (0.005%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-04   10,581       76     145,268    1,356    10,100       78     145,351    1,369
# 2020-05-05   10,102       95     155,370    1,451    10,496       79     155,847    1,448
# 2020-05-06   10,559       86     165,929    1,537    10,666       86     166,513    1,534
# 2020-05-07   11,231       88     177,160    1,625    10,720       90     177,233    1,624
# 2020-05-08   10,699       98     187,859    1,723    10,874       93     188,107    1,717
# 2020-05-09   10,817      104     198,676    1,827    10,988       94     199,095    1,811
# 2020-05-10   11,012       88     209,688    1,915    10,912       96     210,007    1,907
# 2020-05-11   11,656       94     221,344    2,009    10,732       97     220,740    2,004
# 2020-05-12   10,899      107     232,243    2,116    10,718       99     231,458    2,102
# 2020-05-13   10,028       96     242,271    2,212    10,487      101     241,944    2,203
# 2020-05-14    9,974       93     252,245    2,305    10,301      102     252,245    2,305
# 2020-05-15   10,598      113     262,843    2,418
# 2020-05-16    9,200      119     272,043    2,537
# 2020-05-17    9,709       94     281,752    2,631
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-14   10,738      100    252,245    2,305
# 2020-05-15   10,678      100    262,923    2,405
# 2020-05-16   10,609      100    273,532    2,505
# 2020-05-17   10,529      100    284,062    2,605  <-- latest raw data
# 2020-05-18   10,440       99    294,502    2,704
# 2020-05-19   10,342       99    304,844    2,803
# 2020-05-20   10,235       99    315,079    2,902
# 2020-05-21   10,119       98    325,198    3,001
# 2020-05-22    9,995       98    335,193    3,099
# 2020-05-23    9,863       98    345,056    3,196

# %%
covid.Region(geoId='JP', dilation=2.5, d_cases=1.3).analyse(ylog=1)
# Out:
# Japan data to end of 2020-05-17:
#   16,305 cases, 749 deaths
#   129 cases per million, 6 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         67% through outbreak
#   Start:       2020-02-16 (-91 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-34 days, 645 cases)
#   End:         2020-06-25 ( 40 days, 74 days after peak cases)
#   Day Zero:    2020-03-28 (-50 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-22 days, 29 deaths)
#
# Parameters:
#   Totals:      16,193 cases and 710 deaths at end of 2020-05-14
#   Smoothed:    16,193 cases and 709 deaths at end of 2020-05-14 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-14, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
#                X = 16,804, r = 8.0, L = 2,579, dilation = 1.3, c = 68.7% for cases
#   Lag:         12 days (Peak Cases -> Peak Deaths)
#                X = 1,090, r = 8.0, L = 117, dilation = 2.5, c = 58.4% for deaths
#
# Outcome: 16,799 total cases, 1,057 total deaths by end of 2020-06-25
#   97.0% of predicted cases and 68.7% of predicted deaths reported to date
#   100.0% of predicted cases and 96.9% of predicted deaths reported by end date
#   133 cases per million (0.01%), 9 deaths per million (0.001%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-04      174       11      15,231      521       181       18      15,195      523
# 2020-05-05      123       22      15,354      543       155       21      15,351      544
# 2020-05-06      109        8      15,463      551       130       17      15,481      562
# 2020-05-07       84        6      15,547      557       106       16      15,587      578
# 2020-05-08       81       44      15,628      601        92       18      15,679      595
# 2020-05-09      119       12      15,747      613        96       18      15,775      613
# 2020-05-10       51        8      15,798      621        88       20      15,863      633
# 2020-05-11       76       22      15,874      643        93       22      15,956      655
# 2020-05-12      150       25      16,024      668        87       18      16,043      673
# 2020-05-13       55       19      16,079      687        77       19      16,120      692
# 2020-05-14      114       23      16,193      710        73       18      16,193      710
# 2020-05-15       44       15      16,237      725
# 2020-05-16       48       19      16,285      744
# 2020-05-17       20        5      16,305      749
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-14       67       17     16,193      710
# 2020-05-15       61       16     16,254      726
# 2020-05-16       55       16     16,309      742
# 2020-05-17       50       15     16,359      758  <-- latest raw data
# 2020-05-18       45       15     16,403      773
# 2020-05-19       40       15     16,444      787
# 2020-05-20       36       14     16,480      801
# 2020-05-21       33       14     16,513      815
# 2020-05-22       30       13     16,543      828
# 2020-05-23       27       13     16,569      841

# %%
covid.Region(geoId='SG', dilation=4.5).analyse()
# Out:
# Singapore data to end of 2020-05-17:
#   28,038 cases, 22 deaths
#   4,972 cases per million, 4 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         43% through outbreak
#   Start:       2020-02-11 (-96 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-24 days, 1,008 cases)
#   End:         2020-09-13 (120 days, 144 days after peak cases)
#
# Parameters:
#   Totals:      26,098 cases and 21 deaths at end of 2020-05-14
#   Smoothed:    26,097 cases and 21 deaths at end of 2020-05-14 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-14, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                X = 65,003, r = 8.0, L = 4,031, dilation = 4.5, c = 49.1% for cases
#
# Outcome: 63,197 total cases, 68 total deaths by end of 2020-09-13
#   43.1% of predicted cases and 29.9% of predicted deaths reported to date
#   97.2% of predicted cases and 92.4% of predicted deaths reported by end date
#   11,528 cases per million (1.15%), 13 deaths per million (0.001%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-04      573        0      18,778       18       683        1      18,934       18
# 2020-05-05      632        0      19,410       18       660        1      19,594       18
# 2020-05-06      788        2      20,198       20       704    < 0.5      20,298       19
# 2020-05-07      741        0      20,939       20       735    < 0.5      21,033       19
# 2020-05-08      768        0      21,707       20       718    < 0.5      21,750       20
# 2020-05-09      753        0      22,460       20       754    < 0.5      22,504       20
# 2020-05-10      876        0      23,336       20       737    < 0.5      23,241       20
# 2020-05-11      451        1      23,787       21       739    < 0.5      23,981       20
# 2020-05-12      884        0      24,671       21       743    < 0.5      24,723       20
# 2020-05-13      675        0      25,346       21       701    < 0.5      25,424       21
# 2020-05-14      752        0      26,098       21       674    < 0.5      26,098       21
# 2020-05-15      793        0      26,891       21
# 2020-05-16      465        1      27,356       22
# 2020-05-17      682        0      28,038       22
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-14      626        1     26,098       21
# 2020-05-15      622        1     26,720       22
# 2020-05-16      618        1     27,338       22
# 2020-05-17      614        1     27,952       23  <-- latest raw data
# 2020-05-18      609        1     28,561       23
# 2020-05-19      605        1     29,166       24
# 2020-05-20      600        1     29,766       25
# 2020-05-21      595        1     30,361       25
# 2020-05-22      590        1     30,952       26
# 2020-05-23      585        1     31,537       26

# %%
covid.Region(geoId='BR', growth_days=70, lag=6, dilation=2.5).analyse()
# Out:
# Brazil data to end of 2020-05-17:
#   241,080 cases, 16,118 deaths
#   1,151 cases per million, 77 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         30% through outbreak
#   Start:       2020-03-11 (-67 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-20 (  3 days, --- cases)
#   End:         2020-10-06 (143 days, 140 days after peak cases)
#   Day Zero:    2020-03-24 (-54 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-14 ( -3 days, 716 deaths)
#
# Parameters:
#   Totals:      202,918 cases and 13,993 deaths at end of 2020-05-14
#   Smoothed:    202,917 cases and 13,993 deaths at end of 2020-05-14 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-14, compared to 7 days earlier)
#   Growth:      70 days (Start -> Peak Cases)
#                X = 932,643, r = 6.17, L = 47,666, dilation = 2.5, c = 92.7% for cases
#   Lag:         -6 days (Peak Cases -> Peak Deaths)
#                X = 47,763, r = 7.28, L = 2,863, dilation = 2.5, c = 90.1% for deaths
#
# Outcome: 926,001 total cases, 47,654 total deaths by end of 2020-10-06
#   25.8% of predicted cases and 33.7% of predicted deaths reported to date
#   99.3% of predicted cases and 99.8% of predicted deaths reported by end date
#   4,452 cases per million (0.45%), 228 deaths per million (0.023%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-04    6,633      296     107,780    7,321     7,055      465     109,544    7,600
# 2020-05-05    6,935      600     114,715    7,921     7,624      511     117,168    8,112
# 2020-05-06   10,503      615     125,218    8,536     8,425      556     125,593    8,667
# 2020-05-07    9,888      610     135,106    9,146     8,733      587     134,325    9,255
# 2020-05-08   10,222      751     145,328    9,897     8,591      602     142,916    9,857
# 2020-05-09   10,611      730     155,939   10,627     8,920      642     151,836   10,499
# 2020-05-10    6,760      496     162,699   11,123     9,045      661     160,882   11,160
# 2020-05-11    5,632      396     168,331   11,519     9,621      695     170,502   11,854
# 2020-05-12    9,258      881     177,589   12,400    10,342      705     180,844   12,560
# 2020-05-13   11,385      749     188,974   13,149    10,953      718     191,798   13,277
# 2020-05-14   13,944      844     202,918   13,993    11,120      716     202,918   13,993
# 2020-05-15   15,305      824     218,223   14,817
# 2020-05-16   14,919      816     233,142   15,633
# 2020-05-17    7,938      485     241,080   16,118
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-14   11,011      711    202,918   13,993
# 2020-05-15   11,244      711    214,162   14,704
# 2020-05-16   11,440      710    225,602   15,413
# 2020-05-17   11,595      708    237,197   16,122  <-- latest raw data
# 2020-05-18   11,708      706    248,905   16,828
# 2020-05-19   11,776      703    260,681   17,531
# 2020-05-20   11,799      700    272,480   18,231
# 2020-05-21   11,796      696    284,276   18,927
# 2020-05-22   11,785      692    296,060   19,619
# 2020-05-23   11,766      687    307,827   20,306

# %%
covid.Region(geoId='MX', growth_days=65, lag=5, dilation=3).analyse()
# Out:
# Mexico data to end of 2020-05-17:
#   49,219 cases, 5,177 deaths
#   390 cases per million, 41 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         31% through outbreak
#   Start:       2020-03-15 (-63 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-19 (  2 days, --- cases)
#   End:         2020-09-25 (132 days, 130 days after peak cases)
#   Day Zero:    2020-04-02 (-45 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-14 ( -3 days, 246 deaths)
#
# Parameters:
#   Totals:      42,595 cases and 4,477 deaths at end of 2020-05-14
#   Smoothed:    42,594 cases and 4,477 deaths at end of 2020-05-14 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-05-14, compared to 7 days earlier)
#   Growth:      65 days (Start -> Peak Cases)
#                X = 206,316, r = 5.23, L = 8,427, dilation = 3, c = 95.3% for cases
#   Lag:         -5 days (Peak Cases -> Peak Deaths)
#                X = 17,419, r = 6.67, L = 983, dilation = 3, c = 85.4% for deaths
#
# Outcome: 200,207 total cases, 17,249 total deaths by end of 2020-09-25
#   23.9% of predicted cases and 29.7% of predicted deaths reported to date
#   97.0% of predicted cases and 99.0% of predicted deaths reported by end date
#   1,635 cases per million (0.16%), 138 deaths per million (0.014%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-04    1,434      117      24,905    2,271     1,481      158      24,870    2,387
# 2020-05-05    1,120      236      26,025    2,507     1,537      171      26,407    2,558
# 2020-05-06    1,609      197      27,634    2,704     1,621      185      28,028    2,743
# 2020-05-07    1,982      257      29,616    2,961     1,646      188      29,675    2,932
# 2020-05-08    1,906      199      31,522    3,160     1,628      187      31,303    3,119
# 2020-05-09    1,938      193      33,460    3,353     1,753      204      33,056    3,322
# 2020-05-10    1,562      112      35,022    3,465     1,789      218      34,845    3,540
# 2020-05-11    1,305      108      36,327    3,573     1,850      218      36,695    3,758
# 2020-05-12    1,997      353      38,324    3,926     1,926      231      38,621    3,988
# 2020-05-13    1,862      294      40,186    4,220     1,951      243      40,571    4,231
# 2020-05-14    2,409      257      42,595    4,477     2,024      246      42,595    4,477
# 2020-05-15    2,437      290      45,032    4,767
# 2020-05-16    2,112      278      47,144    5,045
# 2020-05-17    2,075      132      49,219    5,177
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-14    2,032      225     42,595    4,477
# 2020-05-15    2,062      225     44,657    4,702
# 2020-05-16    2,085      225     46,742    4,926
# 2020-05-17    2,102      224     48,845    5,151  <-- latest raw data
# 2020-05-18    2,112      224     50,957    5,375
# 2020-05-19    2,116      223     53,073    5,598
# 2020-05-20    2,116      223     55,188    5,820
# 2020-05-21    2,114      222     57,303    6,042
# 2020-05-22    2,112      221     59,415    6,263
# 2020-05-23    2,110      220     61,525    6,483

# %%
covid.Region(geoId='PE', growth_days=67, lag=6, dilation=2.5, d_cases=3).analyse()
# Out:
# Peru data to end of 2020-05-17:
#   92,273 cases, 2,648 deaths
#   2,884 cases per million, 83 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         30% through outbreak
#   Start:       2020-03-15 (-63 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-21 (  4 days, 5 cases)
#   End:         2020-10-01 (138 days, 134 days after peak cases)
#   Day Zero:    2020-04-02 (-45 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-27 ( 10 days)
#
# Parameters:
#   Totals:      80,604 cases and 2,267 deaths at end of 2020-05-14
#   Smoothed:    80,604 cases and 2,267 deaths at end of 2020-05-14 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-05-14, compared to 7 days earlier)
#   Growth:      67 days (Start -> Peak Cases)
#                X = 411,808, r = 4.62, L = 15,147, dilation = 3, c = 86.4% for cases
#   Lag:         6 days (Peak Cases -> Peak Deaths)
#                X = 13,196, r = 4.48, L = 516, dilation = 2.5, c = 85.4% for deaths
#
# Outcome: 393,771 total cases, 12,781 total deaths by end of 2020-10-01
#   22.4% of predicted cases and 20.1% of predicted deaths reported to date
#   95.6% of predicted cases and 96.9% of predicted deaths reported by end date
#   12,873 cases per million (1.29%), 413 deaths per million (0.041%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-04    1,444       58      47,372    1,344     3,085       82      48,783    1,353
# 2020-05-05    3,817      100      51,189    1,444     3,062       84      51,845    1,436
# 2020-05-06    3,628       89      54,817    1,533     3,218       87      55,063    1,523
# 2020-05-07    3,709       94      58,526    1,627     3,061       85      58,124    1,608
# 2020-05-08    3,321       87      61,847    1,714     3,071       87      61,195    1,696
# 2020-05-09    3,168      100      65,015    1,814     2,988       87      64,183    1,783
# 2020-05-10    2,292       75      67,307    1,889     3,076       90      67,259    1,873
# 2020-05-11    1,515       72      68,822    1,961     3,161       91      70,420    1,963
# 2020-05-12    3,237       96      72,059    2,057     3,242       96      73,662    2,059
# 2020-05-13    4,247      112      76,306    2,169     3,368      100      77,030    2,160
# 2020-05-14    4,298       98      80,604    2,267     3,574      107      80,604    2,267
# 2020-05-15    3,891      126      84,495    2,393
# 2020-05-16    4,046      130      88,541    2,523
# 2020-05-17    3,732      125      92,273    2,648
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-14    3,452      107     80,604    2,267
# 2020-05-15    3,505      110     84,109    2,377
# 2020-05-16    3,551      113     87,660    2,490
# 2020-05-17    3,589      115     91,249    2,605  <-- latest raw data
# 2020-05-18    3,619      118     94,868    2,722
# 2020-05-19    3,641      120     98,509    2,842
# 2020-05-20    3,654      122    102,162    2,964
# 2020-05-21    3,658      124    105,820    3,087
# 2020-05-22    3,657      125    109,478    3,213
# 2020-05-23    3,656      126    113,134    3,339

# %%
covid.Region(geoId='AU').analyse(ylog=1)
# Out:
# Australia data to end of 2020-05-17:
#   7,045 cases, 98 deaths
#   282 cases per million, 4 deaths per million (2018 population = 24,992,369)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-04 (-74 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-51 days, 390 cases)
#   End:         2020-04-18 (-28 days, 23 days after peak cases)
#   Day Zero:    2020-04-09 (-38 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-41 days, 4 deaths)
#
# Parameters:
#   Totals:      6,989 cases and 98 deaths at end of 2020-05-14
#   Smoothed:    6,988 cases and 98 deaths at end of 2020-05-14 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-14, compared to 7 days earlier)
#   Growth:      23 days (Start -> Peak Cases)
#                X = 6,613, r = 5.48, L = 1,560, dilation = 1, c = 87.4% for cases
#   Lag:         10 days (Peak Cases -> Peak Deaths)
#                X = 73, r = 5.16, L = 16, dilation = 1, c = 85.0% for deaths
#
# Outcome: 6,612 total cases, 70 total deaths at end of 2020-04-19
#   265 cases per million (0.03%), 3 deaths per million (0.000%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-04       24        0       6,825       95        19        1       6,821       95
# 2020-05-05       24        1       6,849       96        21        1       6,842       96
# 2020-05-06       26        1       6,875       97        21        1       6,862       97
# 2020-05-07       21        0       6,896       97        20    < 0.5       6,882       97
# 2020-05-08       18        0       6,914       97        18    < 0.5       6,900       97
# 2020-05-09       15        0       6,929       97        16    < 0.5       6,916       97
# 2020-05-10       12        0       6,941       97        14    < 0.5       6,931       97
# 2020-05-11        7        0       6,948       97        13    < 0.5       6,944       98
# 2020-05-12       16        0       6,964       97        15    < 0.5       6,959       98
# 2020-05-13       11        1       6,975       98        15    < 0.5       6,974       98
# 2020-05-14       14        0       6,989       98        15    < 0.5       6,989       98
# 2020-05-15       30        0       7,019       98
# 2020-05-16       17        0       7,036       98
# 2020-05-17        9        0       7,045       98
