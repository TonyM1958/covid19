# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='CN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2020-05-20:
#   84,067 cases, 4,638 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-126 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-100 days, 4,690 cases)
#   End:         2020-03-06 (-74 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-116 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-95 days, 128 deaths)
#
# Parameters:
#   Totals:      84,054 cases and 4,638 deaths at end of 2020-05-17
#   Smoothed:    84,054 cases and 4,637 deaths at end of 2020-05-17 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-17, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='KR', dilation=3, d_cases=1).analyse(ylog=1)
# Out:
# South Korea data to end of 2020-05-20:
#   11,122 cases, 264 deaths
#   215 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-93 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-79 days, 609 cases)
#   End:         2020-03-15 (-65 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-73 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-65 days, 5 deaths)
#
# Parameters:
#   Totals:      11,065 cases and 263 deaths at end of 2020-05-17
#   Smoothed:    11,064 cases and 263 deaths at end of 2020-05-17 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-17, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZ', dilation=3.1).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-05-20:
#   1,153 cases, 21 deaths
#   236 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-61 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-54 days, 72 cases)
#   End:         2020-04-09 (-40 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,149 cases and 21 deaths at end of 2020-05-17
#   Smoothed:    1,149 cases and 21 deaths at end of 2020-05-17 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-17, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,104, r = 4.0, L = 288, dilation = 3.1, c = 89.1% for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
# ...

# %%
covid.Region(geoId='US', dilation=3, d_cases=6).analyse()
# Out:
# United States of America data to end of 2020-05-20:
#   1,551,853 cases, 93,439 deaths
#   4,743 cases per million, 286 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         65% through outbreak
#   Start:       2020-02-25 (-85 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-43 days, 31,949 cases)
#   End:         2020-06-29 ( 41 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-68 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-32 days, 2,713 deaths)
#
# Parameters:
#   Totals:      1,486,757 cases and 89,562 deaths at end of 2020-05-17
#   Smoothed:    1,486,756 cases and 89,562 deaths at end of 2020-05-17 (7 points)
#   Spread:      Peak infection rate 11.5 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-17, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RU', lag=5, dilation=2.5, d_cases=1.4).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-20:
#   308,705 cases, 2,972 deaths
#   2,137 cases per million, 21 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         48% through outbreak
#   Start:       2020-03-14 (-67 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 (-11 days, 11,004 cases)
#   End:         2020-07-25 ( 67 days, 78 days after peak cases)
#   Day Zero:    2020-04-06 (-44 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-17 ( -3 days, 109 deaths)
#
# Parameters:
#   Totals:      281,752 cases and 2,631 deaths at end of 2020-05-17
#   Smoothed:    281,752 cases and 2,631 deaths at end of 2020-05-17 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-17, compared to 7 days earlier)
#   Growth:      56 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP', dilation=2.1, d_cases=1.3).analyse(ylog=1)
# Out:
# Japan data to end of 2020-05-20:
#   16,424 cases, 777 deaths
#   130 cases per million, 6 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         69% through outbreak
#   Start:       2020-02-16 (-94 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-37 days, 643 cases)
#   End:         2020-06-25 ( 37 days, 74 days after peak cases)
#   Day Zero:    2020-03-28 (-53 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-25 days, 29 deaths)
#
# Parameters:
#   Totals:      16,305 cases and 749 deaths at end of 2020-05-17
#   Smoothed:    16,304 cases and 748 deaths at end of 2020-05-17 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-17, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SG', dilation=4).analyse()
# Out:
# Singapore data to end of 2020-05-20:
#   29,364 cases, 22 deaths
#   5,208 cases per million, 4 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         44% through outbreak
#   Start:       2020-02-11 (-99 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-27 days, 1,012 cases)
#   End:         2020-09-13 (117 days, 144 days after peak cases)
#
# Parameters:
#   Totals:      28,038 cases and 22 deaths at end of 2020-05-17
#   Smoothed:    28,038 cases and 22 deaths at end of 2020-05-17 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-17, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                X = 59,981, r = 8.0, L = 4,049, dilation = 4, c = 49.5% for cases
#
# Outcome: 58,902 total cases, 62 total deaths by end of 2020-09-13
# ...

# %%
covid.Region(geoId='BR', growth_days=73, lag=5, dilation=3).analyse()
# Out:
# Brazil data to end of 2020-05-20:
#   291,579 cases, 18,859 deaths
#   1,392 cases per million, 90 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         31% through outbreak
#   Start:       2020-03-11 (-70 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-23 (  3 days, --- cases)
#   End:         2020-10-15 (149 days, 146 days after peak cases)
#   Day Zero:    2020-03-25 (-56 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-28 (  8 days)
#
# Parameters:
#   Totals:      241,080 cases and 16,118 deaths at end of 2020-05-17
#   Smoothed:    241,080 cases and 16,118 deaths at end of 2020-05-17 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.6 (2020-05-17, compared to 7 days earlier)
#   Growth:      73 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MX', growth_days=67, dilation=3).analyse()
# Out:
# Mexico data to end of 2020-05-20:
#   56,594 cases, 6,090 deaths
#   448 cases per million, 48 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         31% through outbreak
#   Start:       2020-03-15 (-66 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-21 (  1 days, --- cases)
#   End:         2020-10-01 (135 days, 134 days after peak cases)
#   Day Zero:    2020-04-02 (-48 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-17 ( -3 days, 265 deaths)
#
# Parameters:
#   Totals:      49,219 cases and 5,177 deaths at end of 2020-05-17
#   Smoothed:    49,219 cases and 5,177 deaths at end of 2020-05-17 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-17, compared to 7 days earlier)
#   Growth:      67 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='PE', growth_days=68, dilation=2.5, d_cases=3).analyse()
# Out:
# Peru data to end of 2020-05-20:
#   104,020 cases, 3,024 deaths
#   3,252 cases per million, 95 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         31% through outbreak
#   Start:       2020-03-15 (-66 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-22 (  2 days, --- cases)
#   End:         2020-10-04 (138 days, 136 days after peak cases)
#   Day Zero:    2020-04-02 (-48 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-26 (  6 days)
#
# Parameters:
#   Totals:      92,273 cases and 2,648 deaths at end of 2020-05-17
#   Smoothed:    92,273 cases and 2,648 deaths at end of 2020-05-17 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-17, compared to 7 days earlier)
#   Growth:      68 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='AU').analyse(ylog=1)
# Out:
# Australia data to end of 2020-05-20:
#   7,079 cases, 100 deaths
#   283 cases per million, 4 deaths per million (2018 population = 24,992,369)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-04 (-77 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-54 days, 391 cases)
#   End:         2020-04-18 (-31 days, 23 days after peak cases)
#   Day Zero:    2020-04-09 (-41 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-44 days, 4 deaths)
#
# Parameters:
#   Totals:      7,045 cases and 98 deaths at end of 2020-05-17
#   Smoothed:    7,044 cases and 98 deaths at end of 2020-05-17 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-17, compared to 7 days earlier)
#   Growth:      23 days (Start -> Peak Cases)
# ...
