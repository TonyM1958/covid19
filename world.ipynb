# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='CN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2020-05-15:
#   84,038 cases, 4,637 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-121 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-95 days, 4,690 cases)
#   End:         2020-03-06 (-69 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-111 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-90 days, 128 deaths)
#
# Parameters:
#   Totals:      84,018 cases and 4,637 deaths at end of 2020-05-12
#   Smoothed:    84,018 cases and 4,637 deaths at end of 2020-05-12 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 3.6 (2020-05-12, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='KR', dilation=3, d_cases=1).analyse(ylog=1)
# Out:
# South Korea data to end of 2020-05-15:
#   11,037 cases, 262 deaths
#   214 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-88 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-74 days, 609 cases)
#   End:         2020-03-15 (-60 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-68 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-60 days, 5 deaths)
#
# Parameters:
#   Totals:      10,962 cases and 259 deaths at end of 2020-05-12
#   Smoothed:    10,962 cases and 259 deaths at end of 2020-05-12 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 3.3 (2020-05-12, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZ', dilation=3.1).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-05-15:
#   1,148 cases, 21 deaths
#   235 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-56 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-49 days, 72 cases)
#   End:         2020-04-09 (-35 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,147 cases and 21 deaths at end of 2020-05-12
#   Smoothed:    1,147 cases and 21 deaths at end of 2020-05-12 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-12, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,105, r = 4.0, L = 288, dilation = 3.1, c = 89.1% for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
# ...

# %%
covid.Region(geoId='US', dilation=3.4, d_cases=6.6).analyse()
# Out:
# United States of America data to end of 2020-05-15:
#   1,443,397 cases, 87,568 deaths
#   4,412 cases per million, 268 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         61% through outbreak
#   Start:       2020-02-25 (-80 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-38 days, 31,877 cases)
#   End:         2020-06-29 ( 46 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-63 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-27 days, 2,704 deaths)
#
# Parameters:
#   Totals:      1,369,964 cases and 82,387 deaths at end of 2020-05-12
#   Smoothed:    1,369,963 cases and 82,387 deaths at end of 2020-05-12 (7 points)
#   Spread:      Peak infection rate 11.5 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-12, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RU', lag=5).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-15:
#   262,843 cases, 2,418 deaths
#   1,819 cases per million, 17 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         53% through outbreak
#   Start:       2020-03-14 (-62 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 ( -6 days, 11,025 cases)
#   End:         2020-07-03 ( 50 days, 56 days after peak cases)
#   Day Zero:    2020-04-06 (-39 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-14 ( -1 days, --- deaths)
#
# Parameters:
#   Totals:      232,243 cases and 2,116 deaths at end of 2020-05-12
#   Smoothed:    232,243 cases and 2,116 deaths at end of 2020-05-12 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-12, compared to 7 days earlier)
#   Growth:      56 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP', dilation=2.5, d_cases=1.3).analyse(ylog=1)
# Out:
# Japan data to end of 2020-05-15:
#   16,237 cases, 725 deaths
#   128 cases per million, 6 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         66% through outbreak
#   Start:       2020-02-16 (-89 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-32 days, 644 cases)
#   End:         2020-06-25 ( 42 days, 74 days after peak cases)
#   Day Zero:    2020-03-28 (-48 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-20 days, 29 deaths)
#
# Parameters:
#   Totals:      16,024 cases and 668 deaths at end of 2020-05-12
#   Smoothed:    16,024 cases and 667 deaths at end of 2020-05-12 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-12, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SG', dilation=4).analyse()
# Out:
# Singapore data to end of 2020-05-15:
#   26,891 cases, 21 deaths
#   4,769 cases per million, 4 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         42% through outbreak
#   Start:       2020-02-11 (-94 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-22 days, 1,006 cases)
#   End:         2020-09-13 (122 days, 144 days after peak cases)
#
# Parameters:
#   Totals:      24,671 cases and 21 deaths at end of 2020-05-12
#   Smoothed:    24,670 cases and 20 deaths at end of 2020-05-12 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-12, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                X = 59,278, r = 8.0, L = 4,023, dilation = 4, c = 48.7% for cases
#
# Outcome: 58,211 total cases, 68 total deaths by end of 2020-09-13
# ...

# %%
covid.Region(geoId='BR', lag=4, dilation=3).analyse()
# Out:
# Brazil data to end of 2020-05-15:
#   218,223 cases, 14,817 deaths
#   1,042 cases per million, 71 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-11 (-65 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-12 ( -3 days, 10,156 cases)
#   End:         2020-09-12 (121 days, 124 days after peak cases)
#   Day Zero:    2020-03-25 (-51 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-16 (  1 days)
#
# Parameters:
#   Totals:      177,589 cases and 12,400 deaths at end of 2020-05-12
#   Smoothed:    177,589 cases and 12,400 deaths at end of 2020-05-12 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.4 (2020-05-12, compared to 7 days earlier)
#   Growth:      62 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MX', lag=5, dilation=3).analyse()
# Out:
# Mexico data to end of 2020-05-15:
#   45,032 cases, 4,767 deaths
#   357 cases per million, 38 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-15 (-61 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-12 ( -3 days, 1,911 cases)
#   End:         2020-09-04 (113 days, 116 days after peak cases)
#   Day Zero:    2020-04-02 (-43 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-17 (  2 days)
#
# Parameters:
#   Totals:      38,324 cases and 3,926 deaths at end of 2020-05-12
#   Smoothed:    38,324 cases and 3,926 deaths at end of 2020-05-12 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-12, compared to 7 days earlier)
#   Growth:      58 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='PE', lag=3, dilation=2.5, d_cases=3).analyse()
# Out:
# Peru data to end of 2020-05-15:
#   84,495 cases, 2,393 deaths
#   2,641 cases per million, 75 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-15 (-61 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-12 ( -3 days, 3,172 cases)
#   End:         2020-09-04 (113 days, 116 days after peak cases)
#   Day Zero:    2020-04-02 (-43 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-15 (  0 days, --- deaths)
#
# Parameters:
#   Totals:      72,059 cases and 2,057 deaths at end of 2020-05-12
#   Smoothed:    72,059 cases and 2,057 deaths at end of 2020-05-12 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-12, compared to 7 days earlier)
#   Growth:      58 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='AU').analyse(ylog=1)
# Out:
# Australia data to end of 2020-05-15:
#   7,019 cases, 98 deaths
#   281 cases per million, 4 deaths per million (2018 population = 24,992,369)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-04 (-72 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-49 days, 390 cases)
#   End:         2020-04-18 (-26 days, 23 days after peak cases)
#   Day Zero:    2020-04-09 (-36 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-39 days, 4 deaths)
#
# Parameters:
#   Totals:      6,964 cases and 97 deaths at end of 2020-05-12
#   Smoothed:    6,963 cases and 96 deaths at end of 2020-05-12 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-12, compared to 7 days earlier)
#   Growth:      23 days (Start -> Peak Cases)
# ...
