# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/data-national-14-day-notification-rate-covid-19">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=0, ylog=1, dilation=1, d_clip=3, smooth=7)
covid.data_load('download.json')

# %%
covid.Region(geoId='USA').analyse()
# Out:
# United States data to end of 2021-03-11:
#   28,006,859 cases, 517,397 deaths
#   84,612 cases per million, 1,563 deaths per million (2019 population = 331,002,647)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         60% through outbreak
#   Start:       2020-03-01 (-375 days, when 50 or more cases were reported)
#   Peak Cases:  2021-01-04 (-66 days, 254,685 cases)
#   End:         2021-11-08 (243 days, 309 days after peak cases)
#   Day Zero:    2020-03-17 (-359 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-02-15 (-24 days, 3,556 deaths)
#
# Parameters:
#   Totals:      27,789,719 cases and 512,819 deaths at end of 2021-03-08
#   Smoothed:    27,789,718 cases and 512,818 deaths at end of 2021-03-08 (7 points)
#   Spread:      Peak infection rate 9.8 (2020-03-23, compared to 7 days earlier)
#                Latest infection rate 1.3 (2021-03-08, compared to 7 days earlier)
#   Growth:      309 days (Start -> Peak Cases)
#                X = 33,160,652, r = 8.0, L = 1,018,738, dilation = 1, c = 49.5% for cases
#   Lag:         42 days (Peak Cases -> Peak Deaths)
#                X = 842,991, r = 6.34, L = 14,223, dilation = 1, c = 52.0% for deaths
#
# Outcome: 33,149,532 total cases, 839,496 total deaths by end of 2021-11-08
#   84.5% of predicted cases and 61.4% of predicted deaths reported to date
#   100.0% of predicted cases and 99.6% of predicted deaths reported by end date
#   100,182 cases per million (10.02%), 2,547 deaths per million (0.255%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-02-26   54,728    1,698  27,171,826  496,525    56,712    1,086  27,169,841  497,137
# 2021-02-27   54,728    1,698  27,226,554  498,223    56,051    1,290  27,225,892  498,427
# 2021-02-28   54,728    1,698  27,281,282  499,921    55,390    1,494  27,281,282  499,921
# 2021-03-01   54,728    1,698  27,336,010  501,619    54,729    1,698  27,336,011  501,619
# 2021-03-02   54,728    1,698  27,390,738  503,317    57,250    1,674  27,393,261  503,293
# 2021-03-03   54,728    1,698  27,445,466  505,015    59,772    1,649  27,453,033  504,942
# 2021-03-04   54,733    1,700  27,500,199  506,715    62,294    1,625  27,515,327  506,567
# 2021-03-05   72,380    1,526  27,572,579  508,241    64,816    1,600  27,580,143  508,167
# 2021-03-06   72,380    1,526  27,644,959  509,767    67,337    1,575  27,647,480  509,742
# 2021-03-07   72,380    1,526  27,717,339  511,293    69,859    1,551  27,717,339  511,293
# 2021-03-08   72,380    1,526  27,789,719  512,819    72,380    1,526  27,789,719  512,819
# 2021-03-09   72,380    1,526  27,862,099  514,345
# 2021-03-10   72,380    1,526  27,934,479  515,871
# 2021-03-11   72,380    1,526  28,006,859  517,397
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-03-08  117,565    4,135 27,789,719  512,819
# 2021-03-09  115,525    4,116 27,905,244  516,935
# 2021-03-10  113,499    4,097 28,018,743  521,033
# 2021-03-11  111,490    4,077 28,130,233  525,110  <-- latest raw data
# 2021-03-12  109,497    4,057 28,239,730  529,167
# 2021-03-13  107,521    4,036 28,347,251  533,203
# 2021-03-14  105,564    4,014 28,452,815  537,217
# 2021-03-15  103,624    3,991 28,556,439  541,208
# 2021-03-16  101,704    3,968 28,658,144  545,176
# 2021-03-17   99,804    3,944 28,757,948  549,120

# %%
covid.Region(geoId='RUS').analyse()
# Out:
# Russia data to end of 2021-03-11:
#   4,208,505 cases, 88,367 deaths
#   28,838 cases per million, 606 deaths per million (2019 population = 145,934,460)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         62% through outbreak
#   Start:       2020-03-17 (-359 days, when 50 or more cases were reported)
#   Peak Cases:  2020-12-28 (-73 days, 45,052 cases)
#   End:         2021-10-09 (213 days, 286 days after peak cases)
#   Day Zero:    2020-04-09 (-336 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-12-28 (-73 days, 873 deaths)
#
# Parameters:
#   Totals:      4,183,826 cases and 87,242 deaths at end of 2021-03-08
#   Smoothed:    4,183,825 cases and 87,241 deaths at end of 2021-03-08 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-03-27, compared to 7 days earlier)
#                Latest infection rate 0.8 (2021-03-08, compared to 7 days earlier)
#   Growth:      286 days (Start -> Peak Cases)
#                X = 4,766,289, r = 8.0, L = 180,209, dilation = 1, c = 28.6% for cases
#   Lag:         0 days (Peak Cases -> Peak Deaths)
#                X = 99,387, r = 8.0, L = 3,493, dilation = 1, c = 45.7% for deaths
#
# Outcome: 4,764,690 total cases, 99,354 total deaths by end of 2021-10-09
#   88.3% of predicted cases and 88.9% of predicted deaths reported to date
#   100.0% of predicted cases and 100.0% of predicted deaths reported by end date
#   32,660 cases per million (3.27%), 681 deaths per million (0.068%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-02-26   10,768      431   4,086,315   83,163    11,071      420   4,086,011   83,173
# 2021-02-27   10,768      431   4,097,083   83,594    10,970      424   4,096,981   83,597
# 2021-02-28   10,768      431   4,107,851   84,025    10,869      428   4,107,850   84,024
# 2021-03-01   10,768      431   4,118,619   84,456    10,768      431   4,118,619   84,455
# 2021-03-02   10,768      431   4,129,387   84,887    10,405      423   4,129,024   84,878
# 2021-03-03   10,768      431   4,140,155   85,318    10,042      415   4,139,066   85,293
# 2021-03-04   10,771      432   4,150,926   85,750     9,679      406   4,148,744   85,699
# 2021-03-05    8,225      373   4,159,151   86,123     9,315      398   4,158,060   86,097
# 2021-03-06    8,225      373   4,167,376   86,496     8,952      390   4,167,012   86,487
# 2021-03-07    8,225      373   4,175,601   86,869     8,589      381   4,175,600   86,868
# 2021-03-08    8,225      373   4,183,826   87,242     8,226      374   4,183,826   87,242
# 2021-03-09    8,225      373   4,192,051   87,615
# 2021-03-10    8,225      373   4,200,276   87,988
# 2021-03-11    8,229      379   4,208,505   88,367
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-03-08   14,455      301  4,183,826   87,242
# 2021-03-09   14,152      295  4,197,978   87,537
# 2021-03-10   13,854      289  4,211,832   87,826
# 2021-03-11   13,560      283  4,225,392   88,109  <-- latest raw data
# 2021-03-12   13,270      277  4,238,662   88,385
# 2021-03-13   12,984      271  4,251,646   88,656
# 2021-03-14   12,702      265  4,264,348   88,921
# 2021-03-15   12,425      259  4,276,773   89,180
# 2021-03-16   12,152      253  4,288,925   89,434
# 2021-03-17   11,883      248  4,300,808   89,681

# %%
covid.Region(geoId='JPN').analyse()
# Out:
# Japan data to end of 2021-03-11:
#   424,295 cases, 8,243 deaths
#   3,355 cases per million, 65 deaths per million (2019 population = 126,476,458)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         60% through outbreak
#   Start:       2020-02-19 (-386 days, when 50 or more cases were reported)
#   Peak Cases:  2021-01-04 (-66 days, 6,129 cases)
#   End:         2021-11-19 (254 days, 320 days after peak cases)
#   Day Zero:    2020-04-02 (-343 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-01-25 (-45 days, 100 deaths)
#
# Parameters:
#   Totals:      420,901 cases and 8,098 deaths at end of 2021-03-08
#   Smoothed:    420,901 cases and 8,098 deaths at end of 2021-03-08 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 1.1 (2021-03-08, compared to 7 days earlier)
#   Growth:      320 days (Start -> Peak Cases)
#                X = 506,979, r = 8.0, L = 24,517, dilation = 1, c = -7.3% for cases
#   Lag:         21 days (Peak Cases -> Peak Deaths)
#                X = 10,897, r = 8.0, L = 401, dilation = 1, c = 29.3% for deaths
#
# Outcome: 506,808 total cases, 10,891 total deaths by end of 2021-11-19
#   83.7% of predicted cases and 75.6% of predicted deaths reported to date
#   100.0% of predicted cases and 99.9% of predicted deaths reported by end date
#   4,008 cases per million (0.40%), 86 deaths per million (0.009%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-02-26    1,031       52     410,193    7,592     1,112       52     410,112    7,591
# 2021-02-27    1,031       52     411,224    7,644     1,085       52     411,196    7,644
# 2021-02-28    1,031       52     412,255    7,696     1,058       52     412,254    7,696
# 2021-03-01    1,031       52     413,286    7,748     1,031       52     413,286    7,748
# 2021-03-02    1,031       52     414,317    7,800     1,045       52     414,331    7,800
# 2021-03-03    1,031       52     415,348    7,852     1,060       51     415,391    7,851
# 2021-03-04    1,033       54     416,381    7,906     1,074       51     416,464    7,902
# 2021-03-05    1,130       48     417,511    7,954     1,088       50     417,552    7,952
# 2021-03-06    1,130       48     418,641    8,002     1,102       49     418,654    8,001
# 2021-03-07    1,130       48     419,771    8,050     1,116       49     419,770    8,050
# 2021-03-08    1,130       48     420,901    8,098     1,131       48     420,901    8,098
# 2021-03-09    1,130       48     422,031    8,146
# 2021-03-10    1,130       48     423,161    8,194
# 2021-03-11    1,134       49     424,295    8,243
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-03-08    1,802       52    420,901    8,098
# 2021-03-09    1,772       52    422,673    8,150
# 2021-03-10    1,743       51    424,416    8,201
# 2021-03-11    1,714       50    426,129    8,251  <-- latest raw data
# 2021-03-12    1,685       50    427,814    8,301
# 2021-03-13    1,656       49    429,470    8,350
# 2021-03-14    1,627       48    431,097    8,399
# 2021-03-15    1,599       48    432,696    8,446
# 2021-03-16    1,571       47    434,268    8,494
# 2021-03-17    1,543       47    435,811    8,540

# %%
covid.Region(geoId='SGP').analyse()
# Out:
# Singapore data to end of 2021-03-11:
#   59,932 cases, 30 deaths
#   10,244 cases per million, 5 deaths per million (2019 population = 5,850,343)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-15 (-390 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-27 (-318 days, 1,005 cases)
#   End:         2020-07-07 (-246 days, 72 days after peak cases)
#
# Parameters:
#   Totals:      59,900 cases and 29 deaths at end of 2021-03-08
#   Smoothed:    59,899 cases and 28 deaths at end of 2021-03-08 (7 points)
#   Spread:      Peak infection rate 3.3 (2020-04-20, compared to 7 days earlier)
#                Latest infection rate 0.7 (2021-03-08, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                X = 44,511, r = 8.0, L = 4,020, dilation = 1, c = 54.8% for cases
#
# Outcome: 44,491 total cases, 26 total deaths at end of 2020-07-08
#   7,605 cases per million (0.76%), 4 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-02-26       13        0      59,776       29        12        0      59,776       29
# 2021-02-27       13        0      59,789       29        12        0      59,789       29
# 2021-02-28       13        0      59,802       29        13        0      59,802       29
# 2021-03-01       13        0      59,815       29        14        0      59,816       29
# 2021-03-02       13        0      59,828       29        13        0      59,829       29
# 2021-03-03       13        0      59,841       29        13        0      59,842       29
# 2021-03-04       19        0      59,860       29        13        0      59,855       29
# 2021-03-05       10        0      59,870       29        12        0      59,867       29
# 2021-03-06       10        0      59,880       29        12        0      59,878       29
# 2021-03-07       10        0      59,890       29        11        0      59,890       29
# 2021-03-08       10        0      59,900       29        10    < 0.5      59,900       29
# 2021-03-09       10        0      59,910       29
# 2021-03-10       10        0      59,920       29
# 2021-03-11       12        1      59,932       30
#
#   ** first wave ended **

# %%
covid.Region(geoId='BRA').analyse()
# Out:
# Brazil data to end of 2021-03-11:
#   11,270,148 cases, 274,407 deaths
#   53,021 cases per million, 1,291 deaths per million (2019 population = 212,559,409)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         50% through outbreak
#   Start:       2020-03-13 (-363 days, when 50 or more cases were reported)
#   Peak Cases:  2021-03-08 ( -3 days, 66,849 cases)
#   End:         2022-03-02 (357 days, 360 days after peak cases)
#   Day Zero:    2020-03-28 (-348 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-03-12 (  1 days)
#
# Parameters:
#   Totals:      11,069,600 cases and 268,883 deaths at end of 2021-03-08
#   Smoothed:    11,069,600 cases and 268,883 deaths at end of 2021-03-08 (7 points)
#   Spread:      Peak infection rate 7.7 (2020-03-23, compared to 7 days earlier)
#                Latest infection rate 1.0 (2021-03-08, compared to 7 days earlier)
#   Growth:      360 days (Start -> Peak Cases)
#                X = 22,415,225, r = 4.16, L = 267,396, dilation = 1, c = 60.5% for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#                X = 559,695, r = 8.0, L = 7,379, dilation = 1, c = 35.6% for deaths
#
# Outcome: 22,069,480 total cases, 559,490 total deaths by end of 2022-03-02
#   50.3% of predicted cases and 49.0% of predicted deaths reported to date
#   98.5% of predicted cases and 100.0% of predicted deaths reported by end date
#   105,454 cases per million (10.55%), 2,633 deaths per million (0.263%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-02-26   66,380    1,525  10,403,920  252,366    61,922    1,397  10,408,378  252,494
# 2021-02-27   66,380    1,525  10,470,300  253,891    63,408    1,440  10,471,786  253,933
# 2021-02-28   66,380    1,525  10,536,680  255,416    64,894    1,482  10,536,680  255,416
# 2021-03-01   66,380    1,525  10,603,060  256,941    66,381    1,525  10,603,060  256,941
# 2021-03-02   66,380    1,525  10,669,440  258,466    66,448    1,571  10,669,508  258,512
# 2021-03-03   66,380    1,525  10,735,820  259,991    66,515    1,616  10,736,023  260,128
# 2021-03-04   66,384    1,528  10,802,204  261,519    66,582    1,661  10,802,604  261,788
# 2021-03-05   66,849    1,841  10,869,053  263,360    66,649    1,706  10,869,253  263,494
# 2021-03-06   66,849    1,841  10,935,902  265,201    66,716    1,751  10,935,968  265,246
# 2021-03-07   66,849    1,841  11,002,751  267,042    66,783    1,796  11,002,751  267,042
# 2021-03-08   66,849    1,841  11,069,600  268,883    66,849    1,841  11,069,600  268,883
# 2021-03-09   66,849    1,841  11,136,449  270,724
# 2021-03-10   66,849    1,841  11,203,298  272,565
# 2021-03-11   66,850    1,842  11,270,148  274,407
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-03-08   65,726    3,104 11,069,600  268,883
# 2021-03-09   65,724    3,107 11,135,324  271,990
# 2021-03-10   65,718    3,109 11,201,042  275,099
# 2021-03-11   65,707    3,110 11,266,749  278,209  <-- latest raw data
# 2021-03-12   65,691    3,110 11,332,440  281,319
# 2021-03-13   65,672    3,110 11,398,112  284,429
# 2021-03-14   65,648    3,109 11,463,759  287,538
# 2021-03-15   65,619    3,107 11,529,379  290,645
# 2021-03-16   65,586    3,104 11,594,965  293,749
# 2021-03-17   65,549    3,101 11,660,514  296,850

# %%
covid.Region(geoId='CHL').analyse()
# Out:
# Chile data to end of 2021-03-11:
#   880,068 cases, 21,448 deaths
#   46,038 cases per million, 1,122 deaths per million (2019 population = 19,116,209)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-17 (-359 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-22 (-262 days, 9,723 cases)
#   End:         2020-09-26 (-165 days, 97 days after peak cases)
#   Day Zero:    2020-04-12 (-333 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-07-20 (-234 days, 218 deaths)
#
# Parameters:
#   Totals:      864,766 cases and 21,187 deaths at end of 2021-03-08
#   Smoothed:    864,765 cases and 21,187 deaths at end of 2021-03-08 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.2 (2021-03-08, compared to 7 days earlier)
#   Growth:      97 days (Start -> Peak Cases)
#                X = 451,465, r = 7.67, L = 38,892, dilation = 1, c = 74.0% for cases
#   Lag:         28 days (Peak Cases -> Peak Deaths)
#                X = 12,693, r = 5.45, L = 870, dilation = 1, c = 69.4% for deaths
#
# Outcome: 451,257 total cases, 12,436 total deaths at end of 2020-09-27
#   23,606 cases per million (2.36%), 651 deaths per million (0.065%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-02-26    4,394       71     818,001   20,407     4,149       73     818,245   20,404
# 2021-02-27    4,394       71     822,395   20,478     4,231       73     822,476   20,477
# 2021-02-28    4,394       71     826,789   20,549     4,312       72     826,788   20,549
# 2021-03-01    4,394       71     831,183   20,620     4,395       72     831,183   20,621
# 2021-03-02    4,394       71     835,577   20,691     4,495       74     835,678   20,695
# 2021-03-03    4,394       71     839,971   20,762     4,596       76     840,275   20,771
# 2021-03-04    4,399       77     844,370   20,839     4,697       79     844,971   20,850
# 2021-03-05    5,099       87     849,469   20,926     4,798       81     849,769   20,931
# 2021-03-06    5,099       87     854,568   21,013     4,898       83     854,667   21,014
# 2021-03-07    5,099       87     859,667   21,100     4,999       86     859,666   21,100
# 2021-03-08    5,099       87     864,766   21,187     5,100       87     864,766   21,187
# 2021-03-09    5,099       87     869,865   21,274
# 2021-03-10    5,099       87     874,964   21,361
# 2021-03-11    5,104       87     880,068   21,448
#
#   ** first wave ended **

# %%
covid.Region(geoId='PER').analyse()
# Out:
# Peru data to end of 2021-03-11:
#   1,406,824 cases, 48,829 deaths
#   42,667 cases per million, 1,481 deaths per million (2019 population = 32,971,846)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-17 (-359 days, when 50 or more cases were reported)
#   Peak Cases:  2020-08-24 (-199 days, 8,340 cases)
#   End:         2021-01-30 (-39 days, 160 days after peak cases)
#   Day Zero:    2020-04-06 (-339 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-08-17 (-206 days, 744 deaths)
#
# Parameters:
#   Totals:      1,387,749 cases and 48,313 deaths at end of 2021-03-08
#   Smoothed:    1,387,748 cases and 48,312 deaths at end of 2021-03-08 (7 points)
#   Spread:      Peak infection rate 3.7 (2020-04-13, compared to 7 days earlier)
#                Latest infection rate 1.1 (2021-03-08, compared to 7 days earlier)
#   Growth:      160 days (Start -> Peak Cases)
#                X = 1,157,159, r = 5.0, L = 33,360, dilation = 1, c = 66.8% for cases
#   Lag:         -7 days (Peak Cases -> Peak Deaths)
#                X = 41,325, r = 8.0, L = 2,976, dilation = 1, c = 20.4% for deaths
#
# Outcome: 1,149,415 total cases, 41,316 total deaths at end of 2021-01-31
#   34,860 cases per million (3.49%), 1,253 deaths per million (0.125%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-02-26    5,932      184   1,326,721   46,521     6,217      192   1,326,435   46,513
# 2021-02-27    5,932      184   1,332,653   46,705     6,122      190   1,332,557   46,702
# 2021-02-28    5,932      184   1,338,585   46,889     6,027      187   1,338,585   46,889
# 2021-03-01    5,932      184   1,344,517   47,073     5,933      184   1,344,517   47,073
# 2021-03-02    5,932      184   1,350,449   47,257     5,993      182   1,350,511   47,255
# 2021-03-03    5,932      184   1,356,381   47,441     6,054      181   1,356,565   47,436
# 2021-03-04    5,936      184   1,362,317   47,625     6,115      179   1,362,680   47,615
# 2021-03-05    6,358      172   1,368,675   47,797     6,176      177   1,368,856   47,792
# 2021-03-06    6,358      172   1,375,033   47,969     6,237      175   1,375,093   47,967
# 2021-03-07    6,358      172   1,381,391   48,141     6,298      174   1,381,391   48,141
# 2021-03-08    6,358      172   1,387,749   48,313     6,358      172   1,387,749   48,313
# 2021-03-09    6,358      172   1,394,107   48,485
# 2021-03-10    6,358      172   1,400,465   48,657
# 2021-03-11    6,359      172   1,406,824   48,829
#
#   ** first wave ended **

# %%
covid.Region(geoId='MEX').analyse()
# Out:
# Mexico data to end of 2021-03-11:
#   2,108,404 cases, 190,586 deaths
#   16,353 cases per million, 1,478 deaths per million (2019 population = 128,932,753)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         58% through outbreak
#   Start:       2020-03-12 (-364 days, when 50 or more cases were reported)
#   Peak Cases:  2021-01-18 (-52 days, 17,463 cases)
#   End:         2021-11-25 (260 days, 312 days after peak cases)
#   Day Zero:    2020-04-06 (-339 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-01-18 (-52 days, 1,289 deaths)
#
# Parameters:
#   Totals:      2,092,436 cases and 188,861 deaths at end of 2021-03-08
#   Smoothed:    2,092,436 cases and 188,861 deaths at end of 2021-03-08 (7 points)
#   Spread:      Peak infection rate 3.3 (2020-03-22, compared to 7 days earlier)
#                Latest infection rate 0.9 (2021-03-08, compared to 7 days earlier)
#   Growth:      312 days (Start -> Peak Cases)
#                X = 2,680,738, r = 8.0, L = 69,850, dilation = 1, c = 39.5% for cases
#   Lag:         0 days (Peak Cases -> Peak Deaths)
#                X = 276,941, r = 4.88, L = 5,157, dilation = 1, c = 46.5% for deaths
#
# Outcome: 2,679,839 total cases, 274,842 total deaths by end of 2021-11-25
#   78.7% of predicted cases and 68.8% of predicted deaths reported to date
#   100.0% of predicted cases and 99.2% of predicted deaths reported by end date
#   20,792 cases per million (2.08%), 2,148 deaths per million (0.215%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-02-26    5,885      681   2,035,841  182,475     6,158      733   2,035,567  182,422
# 2021-02-27    5,885      681   2,041,726  183,156     6,067      716   2,041,634  183,138
# 2021-02-28    5,885      681   2,047,611  183,837     5,976      699   2,047,610  183,837
# 2021-03-01    5,885      681   2,053,496  184,518     5,885      682   2,053,495  184,518
# 2021-03-02    5,885      681   2,059,381  185,199     5,805      666   2,059,300  185,184
# 2021-03-03    5,885      681   2,065,266  185,880     5,724      651   2,065,024  185,835
# 2021-03-04    5,886      685   2,071,152  186,565     5,643      636   2,070,667  186,471
# 2021-03-05    5,321      574   2,076,473  187,139     5,563      620   2,076,230  187,092
# 2021-03-06    5,321      574   2,081,794  187,713     5,482      605   2,081,713  187,697
# 2021-03-07    5,321      574   2,087,115  188,287     5,402      590   2,087,114  188,287
# 2021-03-08    5,321      574   2,092,436  188,861     5,322      574   2,092,436  188,861
# 2021-03-09    5,321      574   2,097,757  189,435
# 2021-03-10    5,321      574   2,103,078  190,009
# 2021-03-11    5,326      577   2,108,404  190,586
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-03-08   11,860      945  2,092,436  188,861
# 2021-03-09   11,691      939  2,104,127  189,800
# 2021-03-10   11,521      934  2,115,648  190,734
# 2021-03-11   11,352      928  2,127,000  191,663  <-- latest raw data
# 2021-03-12   11,182      923  2,138,182  192,585
# 2021-03-13   11,013      917  2,149,195  193,502
# 2021-03-14   10,844      911  2,160,038  194,413
# 2021-03-15   10,675      905  2,170,713  195,319
# 2021-03-16   10,507      900  2,181,220  196,219
# 2021-03-17   10,339      894  2,191,558  197,112

# %%
covid.Region(geoId='IND').analyse()
# Out:
# India data to end of 2021-03-11:
#   11,252,741 cases, 156,977 deaths
#   8,154 cases per million, 114 deaths per million (2019 population = 1,380,004,385)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         98% through outbreak
#   Start:       2020-03-14 (-362 days, when 50 or more cases were reported)
#   Peak Cases:  2020-09-14 (-178 days, 91,688 cases)
#   End:         2021-03-16 (  6 days, 184 days after peak cases)
#   Day Zero:    2020-04-04 (-341 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-09-21 (-171 days, 1,166 deaths)
#
# Parameters:
#   Totals:      11,185,908 cases and 156,601 deaths at end of 2021-03-08
#   Smoothed:    11,185,907 cases and 156,600 deaths at end of 2021-03-08 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-06, compared to 7 days earlier)
#                Latest infection rate 1.3 (2021-03-08, compared to 7 days earlier)
#   Growth:      184 days (Start -> Peak Cases)
#                X = 11,202,290, r = 6.83, L = 366,750, dilation = 1, c = 80.2% for cases
#   Lag:         7 days (Peak Cases -> Peak Deaths)
#                X = 158,061, r = 5.09, L = 4,662, dilation = 1, c = 86.6% for deaths
#
# Outcome: 11,190,172 total cases, 156,893 total deaths by end of 2021-03-16
#   100.5% of predicted cases and 99.3% of predicted deaths reported to date
#   99.9% of predicted cases and 99.3% of predicted deaths reported by end date
#   8,118 cases per million (0.81%), 115 deaths per million (0.011%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-02-26   16,736       99  10,996,379  155,508    16,078      104  10,997,036  155,502
# 2021-02-27   16,736       99  11,013,115  155,607    16,297      102  11,013,334  155,605
# 2021-02-28   16,736       99  11,029,851  155,706    16,517      101  11,029,851  155,705
# 2021-03-01   16,736       99  11,046,587  155,805    16,737       99  11,046,587  155,805
# 2021-03-02   16,736       99  11,063,323  155,904    17,528      103  11,064,116  155,908
# 2021-03-03   16,736       99  11,080,059  156,003    18,320      107  11,082,436  156,014
# 2021-03-04   16,741      102  11,096,800  156,105    19,111      110  11,101,547  156,125
# 2021-03-05   22,277      124  11,119,077  156,229    19,903      114  11,121,450  156,238
# 2021-03-06   22,277      124  11,141,354  156,353    20,695      117  11,142,145  156,356
# 2021-03-07   22,277      124  11,163,631  156,477    21,486      121  11,163,631  156,476
# 2021-03-08   22,277      124  11,185,908  156,601    22,277      125  11,185,908  156,601
# 2021-03-09   22,277      124  11,208,185  156,725
# 2021-03-10   22,277      124  11,230,462  156,849
# 2021-03-11   22,279      128  11,252,741  156,977
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-03-08      627       41 11,185,908  156,601
# 2021-03-09      605       40 11,186,513  156,641
# 2021-03-10      583       39 11,187,095  156,680
# 2021-03-11      562       38 11,187,657  156,718  <-- latest raw data
# 2021-03-12      541       37 11,188,198  156,755
# 2021-03-13      521       36 11,188,719  156,791
# 2021-03-14      503       35 11,189,222  156,826
# 2021-03-15      484       34 11,189,706  156,860
# 2021-03-16      467       33 11,190,173  156,893

# %%
covid.Region(geoId='CHN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2021-03-11:
#   100,455 cases, 4,825 deaths
#   70 cases per million, 3 deaths per million (2019 population = 1,439,323,774)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-16 (-420 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-17 (-388 days, 4,346 cases)
#   End:         2020-03-19 (-356 days, 32 days after peak cases)
#   Day Zero:    2020-01-28 (-408 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-17 (-388 days, 123 deaths)
#
# Parameters:
#   Totals:      100,350 cases and 4,824 deaths at end of 2021-03-08
#   Smoothed:    100,349 cases and 4,824 deaths at end of 2021-03-08 (7 points)
#   Spread:      Peak infection rate 29.4 (2020-12-21, compared to 7 days earlier)
#                Latest infection rate 1.4 (2021-03-08, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
#                X = 81,130, r = 5.52, L = 17,382, dilation = 0.7, c = 81.5% for cases
#   Lag:         0 days (Peak Cases -> Peak Deaths)
#                X = 3,239, r = 5.17, L = 492, dilation = 1, c = 88.8% for deaths
#
# Outcome: 81,086 total cases, 3,224 total deaths at end of 2020-03-20
#   56 cases per million (0.01%), 2 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-02-26       23        0     100,070    4,821        25    < 0.5     100,067    4,820
# 2021-02-27       23        0     100,093    4,821        24    < 0.5     100,092    4,821
# 2021-02-28       23        0     100,116    4,821        24    < 0.5     100,116    4,821
# 2021-03-01       23        0     100,139    4,821        24    < 0.5     100,139    4,821
# 2021-03-02       23        0     100,162    4,821        25    < 0.5     100,165    4,822
# 2021-03-03       23        0     100,185    4,821        27    < 0.5     100,192    4,822
# 2021-03-04       29        3     100,214    4,824        29    < 0.5     100,220    4,823
# 2021-03-05       34        0     100,248    4,824        30    < 0.5     100,251    4,823
# 2021-03-06       34        0     100,282    4,824        32    < 0.5     100,282    4,823
# 2021-03-07       34        0     100,316    4,824        33    < 0.5     100,316    4,824
# 2021-03-08       34        0     100,350    4,824        34    < 0.5     100,350    4,824
# 2021-03-09       34        0     100,384    4,824
# 2021-03-10       34        0     100,418    4,824
# 2021-03-11       37        1     100,455    4,825
#
#   ** first wave ended **

# %%
covid.Region(geoId='KOR').analyse(ylog=1)
# Out:
# South Korea data to end of 2021-03-11:
#   89,433 cases, 1,513 deaths
#   1,744 cases per million, 30 deaths per million (2019 population = 51,269,183)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         63% through outbreak
#   Start:       2020-02-19 (-386 days, when 50 or more cases were reported)
#   Peak Cases:  2020-12-21 (-80 days, 1,015 cases)
#   End:         2021-10-22 (226 days, 306 days after peak cases)
#   Day Zero:    2020-03-13 (-363 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-01-04 (-66 days, 23 deaths)
#
# Parameters:
#   Totals:      88,061 cases and 1,496 deaths at end of 2021-03-08
#   Smoothed:    88,061 cases and 1,495 deaths at end of 2021-03-08 (7 points)
#   Spread:      Peak infection rate 10.5 (2020-02-25, compared to 7 days earlier)
#                Latest infection rate 1.1 (2021-03-08, compared to 7 days earlier)
#   Growth:      306 days (Start -> Peak Cases)
#                X = 99,674, r = 8.0, L = 4,061, dilation = 1, c = 14.9% for cases
#   Lag:         14 days (Peak Cases -> Peak Deaths)
#                X = 1,780, r = 8.0, L = 90, dilation = 1, c = -29.9% for deaths
#
# Outcome: 99,641 total cases, 1,779 total deaths by end of 2021-10-22
#   89.7% of predicted cases and 85.0% of predicted deaths reported to date
#   100.0% of predicted cases and 99.9% of predicted deaths reported by end date
#   1,944 cases per million (0.19%), 35 deaths per million (0.003%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-02-26      398        5      83,843    1,448       393        6      83,847    1,447
# 2021-02-27      398        5      84,241    1,453       395        5      84,242    1,452
# 2021-02-28      398        5      84,639    1,458       397        5      84,639    1,457
# 2021-03-01      398        5      85,037    1,463       398        5      85,037    1,463
# 2021-03-02      398        5      85,435    1,468       407        5      85,444    1,468
# 2021-03-03      398        5      85,833    1,473       415        5      85,859    1,473
# 2021-03-04      400        7      86,233    1,480       424        5      86,283    1,478
# 2021-03-05      457        4      86,690    1,484       432        5      86,715    1,482
# 2021-03-06      457        4      87,147    1,488       440        5      87,155    1,487
# 2021-03-07      457        4      87,604    1,492       449        4      87,604    1,491
# 2021-03-08      457        4      88,061    1,496       457        5      88,061    1,496
# 2021-03-09      457        4      88,518    1,500
# 2021-03-10      457        4      88,975    1,504
# 2021-03-11      458        9      89,433    1,513
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-03-08      271        6     88,061    1,496
# 2021-03-09      266        6     88,327    1,502
# 2021-03-10      260        6     88,587    1,508
# 2021-03-11      255        6     88,842    1,514  <-- latest raw data
# 2021-03-12      250        6     89,092    1,520
# 2021-03-13      245        6     89,337    1,526
# 2021-03-14      240        6     89,576    1,532
# 2021-03-15      235        6     89,811    1,537
# 2021-03-16      230        5     90,041    1,543
# 2021-03-17      225        5     90,266    1,548

# %%
covid.Region(geoId='NZL', d_cases=3).analyse(ylog=0)
# Out:
# New Zealand data to end of 2021-03-11:
#   2,037 cases, 26 deaths
#   422 cases per million, 5 deaths per million (2019 population = 4,822,233)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-23 (-353 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-30 (-346 days, 64 cases)
#   End:         2020-04-19 (-325 days, 21 days after peak cases)
#
# Parameters:
#   Totals:      2,024 cases and 26 deaths at end of 2021-03-08
#   Smoothed:    2,024 cases and 25 deaths at end of 2021-03-08 (7 points)
#   Spread:      Peak infection rate 30.5 (2020-08-17, compared to 7 days earlier)
#                Latest infection rate 0.9 (2021-03-08, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,104, r = 4.0, L = 257, dilation = 3, c = 91.3% for cases
#
# Outcome: 1,084 total cases, 9 total deaths at end of 2020-04-20
#   225 cases per million (0.02%), 2 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-02-26        3        0       1,988       26         3        0       1,987       26
# 2021-02-27        3        0       1,991       26         3        0       1,990       26
# 2021-02-28        3        0       1,994       26         3        0       1,993       26
# 2021-03-01        3        0       1,997       26         4        0       1,997       26
# 2021-03-02        3        0       2,000       26         4        0       2,001       26
# 2021-03-03        3        0       2,003       26         4        0       2,005       26
# 2021-03-04        9        0       2,012       26         4        0       2,009       26
# 2021-03-05        3        0       2,015       26         4        0       2,013       26
# 2021-03-06        3        0       2,018       26         4        0       2,017       26
# 2021-03-07        3        0       2,021       26         4        0       2,020       26
# 2021-03-08        3        0       2,024       26         4        0       2,024       26
# 2021-03-09        3        0       2,027       26
# 2021-03-10        3        0       2,030       26
# 2021-03-11        7        0       2,037       26
#
#   ** first wave ended **

# %%
covid.Region(geoId='AUS').analyse()
# Out:
# Australia data to end of 2021-03-11:
#   28,925 cases, 908 deaths
#   1,134 cases per million, 36 deaths per million (2019 population = 25,499,881)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-09 (-367 days, when 50 or more cases were reported)
#   Peak Cases:  2020-08-03 (-220 days, 503 cases)
#   End:         2020-12-27 (-73 days, 147 days after peak cases)
#   Day Zero:    2020-04-14 (-331 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-09-07 (-185 days, 20 deaths)
#
# Parameters:
#   Totals:      28,889 cases and 908 deaths at end of 2021-03-08
#   Smoothed:    28,889 cases and 907 deaths at end of 2021-03-08 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-23, compared to 7 days earlier)
#                Latest infection rate 1.2 (2021-03-08, compared to 7 days earlier)
#   Growth:      147 days (Start -> Peak Cases)
#                X = 28,271, r = 8.0, L = 2,011, dilation = 1, c = 21.8% for cases
#   Lag:         35 days (Peak Cases -> Peak Deaths)
#                X = 910, r = 8.0, L = 81, dilation = 1, c = 14.9% for deaths
#
# Outcome: 28,262 total cases, 908 total deaths at end of 2020-12-28
#   1,108 cases per million (0.11%), 36 deaths per million (0.004%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-02-26        9        0      28,787      908         8        0      28,787      908
# 2021-02-27        9        0      28,796      908         9        0      28,795      908
# 2021-02-28        9        0      28,805      908         9        0      28,805      908
# 2021-03-01        9        0      28,814      908        10        0      28,814      908
# 2021-03-02        9        0      28,823      908        10        0      28,824      908
# 2021-03-03        9        0      28,832      908        10        0      28,834      908
# 2021-03-04       13        0      28,845      908        10        0      28,845      908
# 2021-03-05       11        0      28,856      908        11        0      28,855      908
# 2021-03-06       11        0      28,867      908        11        0      28,866      908
# 2021-03-07       11        0      28,878      908        11        0      28,878      908
# 2021-03-08       11        0      28,889      908        11        0      28,889      908
# 2021-03-09       11        0      28,900      908
# 2021-03-10       11        0      28,911      908
# 2021-03-11       14        0      28,925      908
#
#   ** first wave ended **
