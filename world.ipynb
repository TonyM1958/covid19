# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=0, ylog=1, dilation=3, d_clip=3)
covid.data_load('download.json')

# %%
covid.Region(geoId='US', dilation=3, d_cases=4).analyse()
# Out:
# United States of America data to end of 2020-07-06:
#   2,938,625 cases, 130,306 deaths
#   8,930 cases per million, 396 deaths per million (2019 population = 329,064,917)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         25% through outbreak
#   Start:       2020-02-25 (-132 days, when 50 or more cases were reported)
#   Peak Cases:  2020-07-03 ( -3 days, 49,822 cases)
#   End:         2021-07-24 (384 days, 387 days after peak cases)
#   Day Zero:    2020-03-13 (-115 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-79 days, 2,723 deaths)
#
# Parameters:
#   Totals:      2,794,321 cases and 129,434 deaths at end of 2020-07-03
#   Smoothed:    2,794,321 cases and 129,434 deaths at end of 2020-07-03 (7 points)
#   Spread:      Peak infection rate 12.5 (2020-03-07, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-07-03, compared to 7 days earlier)
#   Growth:      129 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RU', dilation=2, d_cases=5).analyse()
# Out:
# Russia data to end of 2020-07-06:
#   687,862 cases, 10,296 deaths
#   4,716 cases per million, 71 deaths per million (2019 population = 145,872,260)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         50% through outbreak
#   Start:       2020-03-14 (-114 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 (-58 days, 10,982 cases)
#   End:         2020-10-23 (110 days, 168 days after peak cases)
#   Day Zero:    2020-04-06 (-91 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-15 (-21 days, 180 deaths)
#
# Parameters:
#   Totals:      667,883 cases and 9,859 deaths at end of 2020-07-03
#   Smoothed:    667,882 cases and 9,859 deaths at end of 2020-07-03 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-07-03, compared to 7 days earlier)
#   Growth:      56 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP', dilation=2.4, d_cases=4).analyse()
# Out:
# Japan data to end of 2020-07-06:
#   19,981 cases, 978 deaths
#   158 cases per million, 8 deaths per million (2019 population = 126,860,299)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         61% through outbreak
#   Start:       2020-02-16 (-141 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-84 days, 643 cases)
#   End:         2020-09-30 ( 87 days, 171 days after peak cases)
#   Day Zero:    2020-03-28 (-100 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-72 days, 29 deaths)
#
# Parameters:
#   Totals:      19,282 cases and 977 deaths at end of 2020-07-03
#   Smoothed:    19,282 cases and 977 deaths at end of 2020-07-03 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 2.2 (2020-07-03, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SG').analyse()
# Out:
# Singapore data to end of 2020-07-06:
#   44,983 cases, 26 deaths
#   7,750 cases per million, 4 deaths per million (2019 population = 5,804,343)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         50% through outbreak
#   Start:       2020-02-11 (-146 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-74 days, 1,006 cases)
#   End:         2020-11-24 (142 days, 216 days after peak cases)
#
# Parameters:
#   Totals:      44,479 cases and 26 deaths at end of 2020-07-03
#   Smoothed:    44,479 cases and 26 deaths at end of 2020-07-03 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-07-03, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                X = 49,366, r = 8.0, L = 4,023, dilation = 3, c = 53.1% for cases
#
# Outcome: 49,350 total cases, 30 total deaths by end of 2020-11-24
# ...

# %%
covid.Region(geoId='BR').analyse()
# Out:
# Brazil data to end of 2020-07-06:
#   1,623,284 cases, 65,487 deaths
#   7,691 cases per million, 310 deaths per million (2019 population = 211,049,519)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         26% through outbreak
#   Start:       2020-03-11 (-117 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-29 ( -7 days, 38,692 cases)
#   End:         2021-05-24 (323 days, 330 days after peak cases)
#   Day Zero:    2020-03-24 (-104 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-20 (-16 days, 1,063 deaths)
#
# Parameters:
#   Totals:      1,539,081 cases and 63,174 deaths at end of 2020-07-03
#   Smoothed:    1,539,081 cases and 63,174 deaths at end of 2020-07-03 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-07-03, compared to 7 days earlier)
#   Growth:      110 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='CL').analyse()
# Out:
# Chile data to end of 2020-07-06:
#   298,557 cases, 6,384 deaths
#   15,753 cases per million, 337 deaths per million (2019 population = 18,952,035)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         30% through outbreak
#   Start:       2020-03-13 (-115 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-14 (-22 days, 10,288 cases)
#   End:         2021-03-19 (257 days, 279 days after peak cases)
#   Day Zero:    2020-04-08 (-89 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-10 (-26 days, 223 deaths)
#
# Parameters:
#   Totals:      288,089 cases and 6,051 deaths at end of 2020-07-03
#   Smoothed:    288,089 cases and 6,050 deaths at end of 2020-07-03 (7 points)
#   Spread:      Peak infection rate 4.2 (2020-03-22, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-07-03, compared to 7 days earlier)
#   Growth:      93 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='PE').analyse()
# Out:
# Peru data to end of 2020-07-06:
#   305,703 cases, 10,772 deaths
#   9,403 cases per million, 331 deaths per million (2019 population = 32,510,462)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         37% through outbreak
#   Start:       2020-03-15 (-113 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-29 (-38 days, 6,581 cases)
#   End:         2021-01-08 (187 days, 225 days after peak cases)
#   Day Zero:    2020-04-02 (-95 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-26 (-10 days, 208 deaths)
#
# Parameters:
#   Totals:      295,599 cases and 10,226 deaths at end of 2020-07-03
#   Smoothed:    295,599 cases and 10,226 deaths at end of 2020-07-03 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-07-03, compared to 7 days earlier)
#   Growth:      75 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MX').analyse()
# Out:
# Mexico data to end of 2020-07-06:
#   261,750 cases, 31,119 deaths
#   2,052 cases per million, 244 deaths per million (2019 population = 127,575,529)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         25% through outbreak
#   Start:       2020-03-15 (-113 days, when 50 or more cases were reported)
#   Peak Cases:  2020-07-03 ( -3 days, 5,885 cases)
#   End:         2021-05-28 (327 days, 330 days after peak cases)
#   Day Zero:    2020-04-02 (-95 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-24 (-12 days, 806 deaths)
#
# Parameters:
#   Totals:      245,251 cases and 29,843 deaths at end of 2020-07-03
#   Smoothed:    245,250 cases and 29,843 deaths at end of 2020-07-03 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-07-03, compared to 7 days earlier)
#   Growth:      110 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IN').analyse()
# Out:
# India data to end of 2020-07-06:
#   719,665 cases, 20,160 deaths
#   527 cases per million, 15 deaths per million (2019 population = 1,366,417,756)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         25% through outbreak
#   Start:       2020-03-10 (-118 days, when 50 or more cases were reported)
#   Peak Cases:  2020-07-03 ( -3 days, 21,755 cases)
#   End:         2021-06-12 (342 days, 345 days after peak cases)
#   Day Zero:    2020-04-02 (-95 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-18 (-18 days, 594 deaths)
#
# Parameters:
#   Totals:      648,315 cases and 18,655 deaths at end of 2020-07-03
#   Smoothed:    648,315 cases and 18,654 deaths at end of 2020-07-03 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-02, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-07-03, compared to 7 days earlier)
#   Growth:      115 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='CN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2020-07-06:
#   84,896 cases, 4,641 deaths
#   59 cases per million, 3 deaths per million (2019 population = 1,433,783,692)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-173 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-147 days, 4,689 cases)
#   End:         2020-03-06 (-121 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-163 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-142 days, 128 deaths)
#
# Parameters:
#   Totals:      84,839 cases and 4,641 deaths at end of 2020-07-03
#   Smoothed:    84,839 cases and 4,640 deaths at end of 2020-07-03 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-07-03, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='KR', d_cases=1).analyse(ylog=1)
# Out:
# South Korea data to end of 2020-07-06:
#   13,181 cases, 285 deaths
#   257 cases per million, 6 deaths per million (2019 population = 51,225,321)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-140 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-126 days, 609 cases)
#   End:         2020-03-15 (-112 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-120 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-112 days, 5 deaths)
#
# Parameters:
#   Totals:      13,030 cases and 283 deaths at end of 2020-07-03
#   Smoothed:    13,030 cases and 283 deaths at end of 2020-07-03 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-07-03, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZ', d_cases=3).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-07-06:
#   1,186 cases, 22 deaths
#   248 cases per million, 5 deaths per million (2019 population = 4,783,062)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-108 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-101 days, 72 cases)
#   End:         2020-04-16 (-80 days, 21 days after peak cases)
#
# Parameters:
#   Totals:      1,180 cases and 22 deaths at end of 2020-07-03
#   Smoothed:    1,180 cases and 21 deaths at end of 2020-07-03 (7 points)
#   Spread:      Peak infection rate 5.0 (2020-06-20, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-07-03, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,111, r = 4.0, L = 288, dilation = 3, c = 88.9% for cases
#
# Outcome: 1,094 total cases, 11 total deaths at end of 2020-04-17
# ...

# %%
covid.Region(geoId='AU', dilation=2.2, d_cases=1.5).analyse()
# Out:
# Australia data to end of 2020-07-06:
#   8,586 cases, 106 deaths
#   341 cases per million, 4 deaths per million (2019 population = 25,203,200)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-04 (-124 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-101 days, 393 cases)
#   End:         2020-04-29 (-67 days, 34 days after peak cases)
#   Day Zero:    2020-04-09 (-88 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-91 days, 4 deaths)
#
# Parameters:
#   Totals:      8,255 cases and 104 deaths at end of 2020-07-03
#   Smoothed:    8,254 cases and 104 deaths at end of 2020-07-03 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 2.8 (2020-07-03, compared to 7 days earlier)
#   Growth:      23 days (Start -> Peak Cases)
# ...
