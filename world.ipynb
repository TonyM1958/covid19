# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=0, ylog=1, dilation=3, d_clip=3)
covid.data_load('download.json')

# %%
covid.Region(geoId='US', dilation=3, d_cases=2).analyse()
# Out:
# United States of America data to end of 2020-09-25:
#   7,033,430 cases, 203,774 deaths
#   21,374 cases per million, 619 deaths per million (2019 population = 329,064,917)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         48% through outbreak
#   Start:       2020-02-25 (-213 days, when 50 or more cases were reported)
#   Peak Cases:  2020-07-19 (-68 days, 67,379 cases)
#   End:         2021-05-04 (222 days, 290 days after peak cases)
#   Day Zero:    2020-03-13 (-196 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-160 days, 2,711 deaths)
#
# Parameters:
#   Totals:      6,896,274 cases and 200,807 deaths at end of 2020-09-22
#   Smoothed:    6,896,273 cases and 200,807 deaths at end of 2020-09-22 (7 points)
#   Spread:      Peak infection rate 11.5 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-09-22, compared to 7 days earlier)
#   Growth:      145 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RU', dilation=3, d_cases=8).analyse()
# Out:
# Russia data to end of 2020-09-25:
#   1,136,048 cases, 20,056 deaths
#   7,788 cases per million, 137 deaths per million (2019 population = 145,872,260)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         86% through outbreak
#   Start:       2020-03-14 (-195 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 (-139 days, 10,978 cases)
#   End:         2020-10-23 ( 29 days, 168 days after peak cases)
#   Day Zero:    2020-04-06 (-172 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-15 (-102 days, 180 deaths)
#
# Parameters:
#   Totals:      1,115,810 cases and 19,649 deaths at end of 2020-09-22
#   Smoothed:    1,115,809 cases and 19,648 deaths at end of 2020-09-22 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-09-22, compared to 7 days earlier)
#   Growth:      56 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP', dilation=1, d_cases=2).analyse()
# Out:
# Japan data to end of 2020-09-25:
#   81,055 cases, 1,540 deaths
#   639 cases per million, 12 deaths per million (2019 population = 126,860,299)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         43% through outbreak
#   Start:       2020-02-16 (-222 days, when 50 or more cases were reported)
#   Peak Cases:  2020-08-04 (-52 days, 1,582 cases)
#   End:         2021-07-09 (288 days, 340 days after peak cases)
#   Day Zero:    2020-03-28 (-181 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-153 days, 29 deaths)
#
# Parameters:
#   Totals:      79,768 cases and 1,512 deaths at end of 2020-09-22
#   Smoothed:    79,768 cases and 1,511 deaths at end of 2020-09-22 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-04-04, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-09-22, compared to 7 days earlier)
#   Growth:      170 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SG', d_cases=4).analyse()
# Out:
# Singapore data to end of 2020-09-25:
#   57,665 cases, 27 deaths
#   9,935 cases per million, 5 deaths per million (2019 population = 5,804,343)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         78% through outbreak
#   Start:       2020-02-11 (-227 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-155 days, 1,005 cases)
#   End:         2020-11-24 ( 61 days, 216 days after peak cases)
#
# Parameters:
#   Totals:      57,627 cases and 27 deaths at end of 2020-09-22
#   Smoothed:    57,627 cases and 26 deaths at end of 2020-09-22 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-09-22, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                X = 58,881, r = 8.0, L = 4,021, dilation = 4, c = 38.5% for cases
#
# Outcome: 58,735 total cases, 27 total deaths by end of 2020-11-24
# ...

# %%
covid.Region(geoId='BR').analyse()
# Out:
# Brazil data to end of 2020-09-25:
#   4,689,613 cases, 140,537 deaths
#   22,220 cases per million, 666 deaths per million (2019 population = 211,049,519)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         36% through outbreak
#   Start:       2020-03-11 (-198 days, when 50 or more cases were reported)
#   Peak Cases:  2020-07-26 (-61 days, 46,316 cases)
#   End:         2021-09-09 (350 days, 411 days after peak cases)
#   Day Zero:    2020-03-25 (-184 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-07-22 (-65 days, 1,095 deaths)
#
# Parameters:
#   Totals:      4,591,604 cases and 138,108 deaths at end of 2020-09-22
#   Smoothed:    4,591,604 cases and 138,108 deaths at end of 2020-09-22 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-09-22, compared to 7 days earlier)
#   Growth:      137 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='CL', dilation=2, d_cases=4).analyse()
# Out:
# Chile data to end of 2020-09-25:
#   453,868 cases, 12,527 deaths
#   23,948 cases per million, 661 deaths per million (2019 population = 18,952,035)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         52% through outbreak
#   Start:       2020-03-13 (-196 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-14 (-103 days, 10,296 cases)
#   End:         2021-03-19 (176 days, 279 days after peak cases)
#   Day Zero:    2020-04-08 (-170 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-07-17 (-70 days, 229 deaths)
#
# Parameters:
#   Totals:      448,523 cases and 12,321 deaths at end of 2020-09-22
#   Smoothed:    448,522 cases and 12,321 deaths at end of 2020-09-22 (7 points)
#   Spread:      Peak infection rate 4.2 (2020-03-22, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-09-22, compared to 7 days earlier)
#   Growth:      93 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='PE').analyse()
# Out:
# Peru data to end of 2020-09-25:
#   794,584 cases, 32,037 deaths
#   24,441 cases per million, 985 deaths per million (2019 population = 32,510,462)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         31% through outbreak
#   Start:       2020-03-15 (-194 days, when 50 or more cases were reported)
#   Peak Cases:  2020-08-16 (-40 days, 8,534 cases)
#   End:         2021-11-20 (422 days, 462 days after peak cases)
#   Day Zero:    2020-04-02 (-176 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-08-12 (-44 days, 745 deaths)
#
# Parameters:
#   Totals:      776,546 cases and 31,586 deaths at end of 2020-09-22
#   Smoothed:    776,545 cases and 31,586 deaths at end of 2020-09-22 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-09-22, compared to 7 days earlier)
#   Growth:      154 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MX').analyse()
# Out:
# Mexico data to end of 2020-09-25:
#   720,858 cases, 75,844 deaths
#   5,650 cases per million, 595 deaths per million (2019 population = 127,575,529)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         35% through outbreak
#   Start:       2020-03-15 (-194 days, when 50 or more cases were reported)
#   Peak Cases:  2020-07-29 (-58 days, 7,012 cases)
#   End:         2021-09-09 (350 days, 408 days after peak cases)
#   Day Zero:    2020-04-02 (-176 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-24 (-93 days, 799 deaths)
#
# Parameters:
#   Totals:      705,263 cases and 74,348 deaths at end of 2020-09-22
#   Smoothed:    705,263 cases and 74,347 deaths at end of 2020-09-22 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-09-22, compared to 7 days earlier)
#   Growth:      136 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IN').analyse()
# Out:
# India data to end of 2020-09-25:
#   5,903,932 cases, 93,379 deaths
#   4,321 cases per million, 68 deaths per million (2019 population = 1,366,417,756)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         26% through outbreak
#   Start:       2020-03-10 (-199 days, when 50 or more cases were reported)
#   Peak Cases:  2020-09-13 (-12 days, 93,128 cases)
#   End:         2022-03-27 (549 days, 561 days after peak cases)
#   Day Zero:    2020-04-02 (-176 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-09-12 (-13 days, 1,168 deaths)
#
# Parameters:
#   Totals:      5,646,010 cases and 90,020 deaths at end of 2020-09-22
#   Smoothed:    5,646,010 cases and 90,019 deaths at end of 2020-09-22 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-02, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-09-22, compared to 7 days earlier)
#   Growth:      187 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='CN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2020-09-25:
#   90,441 cases, 4,739 deaths
#   63 cases per million, 3 deaths per million (2019 population = 1,433,783,692)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-254 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-228 days, 4,690 cases)
#   End:         2020-03-06 (-202 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-244 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-223 days, 128 deaths)
#
# Parameters:
#   Totals:      90,399 cases and 4,737 deaths at end of 2020-09-22
#   Smoothed:    90,398 cases and 4,737 deaths at end of 2020-09-22 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-09-22, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='KR', d_cases=1).analyse(ylog=1)
# Out:
# South Korea data to end of 2020-09-25:
#   23,516 cases, 399 deaths
#   459 cases per million, 8 deaths per million (2019 population = 51,225,321)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-221 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-207 days, 608 cases)
#   End:         2020-03-15 (-193 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-201 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-193 days, 5 deaths)
#
# Parameters:
#   Totals:      23,216 cases and 388 deaths at end of 2020-09-22
#   Smoothed:    23,216 cases and 387 deaths at end of 2020-09-22 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-09-22, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZ', d_cases=3).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-09-25:
#   1,475 cases, 25 deaths
#   308 cases per million, 5 deaths per million (2019 population = 4,783,062)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-189 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-182 days, 72 cases)
#   End:         2020-04-16 (-161 days, 21 days after peak cases)
#
# Parameters:
#   Totals:      1,468 cases and 25 deaths at end of 2020-09-22
#   Smoothed:    1,468 cases and 24 deaths at end of 2020-09-22 (7 points)
#   Spread:      Peak infection rate 79.0 (2020-08-15, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-09-22, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,112, r = 4.0, L = 288, dilation = 3, c = 91.1% for cases
#
# Outcome: 1,094 total cases, 11 total deaths at end of 2020-04-17
# ...

# %%
covid.Region(geoId='AU', dilation=2.2, d_cases=1.5).analyse()
# Out:
# Australia data to end of 2020-09-25:
#   27,000 cases, 869 deaths
#   1,071 cases per million, 34 deaths per million (2019 population = 25,203,200)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         54% through outbreak
#   Start:       2020-03-04 (-205 days, when 50 or more cases were reported)
#   Peak Cases:  2020-08-02 (-54 days, 552 cases)
#   End:         2021-03-15 (172 days, 226 days after peak cases)
#   Day Zero:    2020-04-09 (-169 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-09-01 (-24 days, 22 deaths)
#
# Parameters:
#   Totals:      26,942 cases and 854 deaths at end of 2020-09-22
#   Smoothed:    26,942 cases and 854 deaths at end of 2020-09-22 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-09-22, compared to 7 days earlier)
#   Growth:      151 days (Start -> Peak Cases)
# ...
