# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='CN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2020-05-23:
#   84,084 cases, 4,638 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-129 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-103 days, 4,689 cases)
#   End:         2020-03-06 (-77 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-119 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-98 days, 128 deaths)
#
# Parameters:
#   Totals:      84,067 cases and 4,638 deaths at end of 2020-05-20
#   Smoothed:    84,066 cases and 4,637 deaths at end of 2020-05-20 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-20, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='KR', dilation=3, d_cases=1).analyse(ylog=1)
# Out:
# South Korea data to end of 2020-05-23:
#   11,190 cases, 266 deaths
#   217 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-96 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-82 days, 609 cases)
#   End:         2020-03-15 (-68 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-76 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-68 days, 5 deaths)
#
# Parameters:
#   Totals:      11,122 cases and 264 deaths at end of 2020-05-20
#   Smoothed:    11,122 cases and 264 deaths at end of 2020-05-20 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-20, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZ', dilation=3.1).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-05-23:
#   1,154 cases, 21 deaths
#   236 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-64 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-57 days, 72 cases)
#   End:         2020-04-09 (-43 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,153 cases and 21 deaths at end of 2020-05-20
#   Smoothed:    1,152 cases and 21 deaths at end of 2020-05-20 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-20, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,105, r = 4.0, L = 288, dilation = 3.1, c = 89.2% for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
# ...

# %%
covid.Region(geoId='AU').analyse(ylog=1)
# Out:
# Australia data to end of 2020-05-23:
#   7,106 cases, 102 deaths
#   284 cases per million, 4 deaths per million (2018 population = 24,992,369)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-04 (-80 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-57 days, 391 cases)
#   End:         2020-04-18 (-34 days, 23 days after peak cases)
#   Day Zero:    2020-04-09 (-44 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-47 days, 4 deaths)
#
# Parameters:
#   Totals:      7,079 cases and 100 deaths at end of 2020-05-20
#   Smoothed:    7,078 cases and 100 deaths at end of 2020-05-20 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-20, compared to 7 days earlier)
#   Growth:      23 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='US', dilation=3.5, d_cases=8).analyse()
# Out:
# United States of America data to end of 2020-05-23:
#   1,622,670 cases, 97,087 deaths
#   4,960 cases per million, 297 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         67% through outbreak
#   Start:       2020-02-25 (-88 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-46 days, 31,900 cases)
#   End:         2020-06-29 ( 38 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-71 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-35 days, 2,719 deaths)
#
# Parameters:
#   Totals:      1,551,853 cases and 93,439 deaths at end of 2020-05-20
#   Smoothed:    1,551,853 cases and 93,439 deaths at end of 2020-05-20 (7 points)
#   Spread:      Peak infection rate 11.5 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-20, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RU', lag=6, dilation=3, d_cases=1.4).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-23:
#   335,882 cases, 3,388 deaths
#   2,325 cases per million, 23 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         50% through outbreak
#   Start:       2020-03-14 (-70 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 (-14 days, 10,982 cases)
#   End:         2020-07-25 ( 64 days, 78 days after peak cases)
#   Day Zero:    2020-04-06 (-47 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-20 ( -3 days, 121 deaths)
#
# Parameters:
#   Totals:      308,705 cases and 2,972 deaths at end of 2020-05-20
#   Smoothed:    308,704 cases and 2,972 deaths at end of 2020-05-20 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-20, compared to 7 days earlier)
#   Growth:      56 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP', dilation=2.2, d_cases=1.3).analyse(ylog=1)
# Out:
# Japan data to end of 2020-05-23:
#   16,550 cases, 820 deaths
#   131 cases per million, 6 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         72% through outbreak
#   Start:       2020-02-16 (-97 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-40 days, 642 cases)
#   End:         2020-06-25 ( 34 days, 74 days after peak cases)
#   Day Zero:    2020-03-28 (-56 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-28 days, 29 deaths)
#
# Parameters:
#   Totals:      16,424 cases and 777 deaths at end of 2020-05-20
#   Smoothed:    16,423 cases and 776 deaths at end of 2020-05-20 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-20, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SG', dilation=3.3).analyse()
# Out:
# Singapore data to end of 2020-05-23:
#   31,068 cases, 23 deaths
#   5,510 cases per million, 4 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         46% through outbreak
#   Start:       2020-02-12 (-101 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-30 days, 1,004 cases)
#   End:         2020-09-11 (112 days, 142 days after peak cases)
#
# Parameters:
#   Totals:      29,364 cases and 22 deaths at end of 2020-05-20
#   Smoothed:    29,363 cases and 21 deaths at end of 2020-05-20 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-20, compared to 7 days earlier)
#   Growth:      71 days (Start -> Peak Cases)
#                X = 51,426, r = 8.0, L = 4,014, dilation = 3.3, c = 51.4% for cases
#
# Outcome: 51,026 total cases, 50 total deaths by end of 2020-09-11
# ...

# %%
covid.Region(geoId='BR', growth_days=80, lag=6, dilation=3).analyse()
# Out:
# Brazil data to end of 2020-05-23:
#   347,398 cases, 22,013 deaths
#   1,658 cases per million, 105 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         29% through outbreak
#   Start:       2020-03-11 (-73 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-30 (  7 days, 0 cases)
#   End:         2020-11-05 (167 days, 160 days after peak cases)
#   Day Zero:    2020-03-25 (-59 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-05 ( 13 days)
#
# Parameters:
#   Totals:      291,579 cases and 18,859 deaths at end of 2020-05-20
#   Smoothed:    291,578 cases and 18,859 deaths at end of 2020-05-20 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.5 (2020-05-20, compared to 7 days earlier)
#   Growth:      80 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MX', growth_days=75, dilation=3).analyse()
# Out:
# Mexico data to end of 2020-05-23:
#   65,856 cases, 7,179 deaths
#   522 cases per million, 57 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         29% through outbreak
#   Start:       2020-03-15 (-69 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-29 (  6 days, 0 cases)
#   End:         2020-10-25 (156 days, 150 days after peak cases)
#   Day Zero:    2020-04-02 (-51 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-02 ( 10 days)
#
# Parameters:
#   Totals:      56,594 cases and 6,090 deaths at end of 2020-05-20
#   Smoothed:    56,594 cases and 6,090 deaths at end of 2020-05-20 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.4 (2020-05-20, compared to 7 days earlier)
#   Growth:      75 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='PE', growth_days=68, dilation=2.5, d_cases=3).analyse()
# Out:
# Peru data to end of 2020-05-23:
#   115,754 cases, 3,373 deaths
#   3,619 cases per million, 105 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         34% through outbreak
#   Start:       2020-03-15 (-69 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-18 ( -5 days, 4,031 cases)
#   End:         2020-09-22 (123 days, 128 days after peak cases)
#   Day Zero:    2020-04-02 (-51 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-18 ( -5 days, 126 deaths)
#
# Parameters:
#   Totals:      104,020 cases and 3,024 deaths at end of 2020-05-20
#   Smoothed:    104,020 cases and 3,024 deaths at end of 2020-05-20 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-05-20, compared to 7 days earlier)
#   Growth:      64 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='CL', growth_days=75).analyse(ylog=1)
# Out:
# Chile data to end of 2020-05-23:
#   65,393 cases, 673 deaths
#   3,492 cases per million, 36 deaths per million (2018 population = 18,729,160)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         45% through outbreak
#   Start:       2020-03-13 (-71 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-27 (  4 days, 2 cases)
#   End:         2020-08-09 ( 79 days, 75 days after peak cases)
#   Day Zero:    2020-04-08 (-45 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-31 (  8 days)
#
# Parameters:
#   Totals:      53,617 cases and 544 deaths at end of 2020-05-20
#   Smoothed:    53,617 cases and 544 deaths at end of 2020-05-20 (7 points)
#   Spread:      Peak infection rate 4.2 (2020-03-22, compared to 7 days earlier)
#                Latest infection rate 1.7 (2020-05-20, compared to 7 days earlier)
#   Growth:      75 days (Start -> Peak Cases)
# ...
