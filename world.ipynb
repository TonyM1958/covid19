# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/data-national-14-day-notification-rate-covid-19">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=0, ylog=1, dilation=1, d_clip=3, smooth=7)
covid.data_load('download.json')

# %%
covid.Region(geoId='USA').analyse()
# Out:
# United States data to end of 2021-02-11:
#   27,694,168 cases, 486,325 deaths
#   83,668 cases per million, 1,469 deaths per million (2019 population = 331,002,647)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         56% through outbreak
#   Start:       2020-02-23 (-354 days, when 50 or more cases were reported)
#   Peak Cases:  2021-01-04 (-38 days, 254,685 cases)
#   End:         2021-11-15 (278 days, 316 days after peak cases)
#   Day Zero:    2020-03-10 (-338 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-01-18 (-24 days, 3,360 deaths)
#
# Parameters:
#   Totals:      27,400,337 cases and 476,534 deaths at end of 2021-02-08
#   Smoothed:    27,400,336 cases and 476,533 deaths at end of 2021-02-08 (7 points)
#   Spread:      Peak infection rate 9.8 (2020-03-16, compared to 7 days earlier)
#                Latest infection rate 1.0 (2021-02-08, compared to 7 days earlier)
#   Growth:      316 days (Start -> Peak Cases)
#                X = 38,559,498, r = 8.0, L = 1,018,738, dilation = 1, c = 62.4% for cases
#   Lag:         14 days (Peak Cases -> Peak Deaths)
#                X = 753,135, r = 8.0, L = 13,438, dilation = 1, c = 54.7% for deaths
#
# Outcome: 38,546,567 total cases, 752,775 total deaths by end of 2021-11-15
#   71.8% of predicted cases and 64.6% of predicted deaths reported to date
#   100.0% of predicted cases and 100.0% of predicted deaths reported by end date
#   116,493 cases per million (11.65%), 2,275 deaths per million (0.228%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-01-29   98,205    2,875  26,419,330  446,230   118,815    3,004  26,398,720  446,101
# 2021-01-30   98,205    2,875  26,517,535  449,105   111,945    2,961  26,510,665  449,062
# 2021-01-31   98,205    2,875  26,615,740  451,980   105,075    2,918  26,615,740  451,980
# 2021-02-01   98,205    2,875  26,713,945  454,855    98,206    2,875  26,713,945  454,855
# 2021-02-02   98,205    2,875  26,812,150  457,730    98,168    2,931  26,812,114  457,786
# 2021-02-03   98,205    2,875  26,910,355  460,605    98,131    2,986  26,910,245  460,772
# 2021-02-04   98,210    2,877  27,008,565  463,482    98,093    3,042  27,008,338  463,813
# 2021-02-05   97,943    3,263  27,106,508  466,745    98,056    3,097  27,106,394  466,910
# 2021-02-06   97,943    3,263  27,204,451  470,008    98,019    3,152  27,204,413  470,063
# 2021-02-07   97,943    3,263  27,302,394  473,271    97,981    3,208  27,302,394  473,271
# 2021-02-08   97,943    3,263  27,400,337  476,534    97,943    3,263  27,400,337  476,534
# 2021-02-09   97,943    3,263  27,498,280  479,797
# 2021-02-10   97,943    3,263  27,596,223  483,060
# 2021-02-11   97,945    3,265  27,694,168  486,325
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-02-08  201,849    4,446 27,400,337  476,534
# 2021-02-09  199,707    4,416 27,600,044  480,950
# 2021-02-10  197,536    4,385 27,797,580  485,336
# 2021-02-11  195,338    4,354 27,992,919  489,689  <-- latest raw data
# 2021-02-12  193,115    4,321 28,186,034  494,010
# 2021-02-13  190,869    4,287 28,376,903  498,296
# 2021-02-14  188,602    4,252 28,565,505  502,548
# 2021-02-15  186,315    4,216 28,751,820  506,764
# 2021-02-16  184,012    4,179 28,935,832  510,943
# 2021-02-17  181,693    4,141 29,117,525  515,084

# %%
covid.Region(geoId='RUS').analyse()
# Out:
# Russia data to end of 2021-02-11:
#   4,086,090 cases, 80,520 deaths
#   27,999 cases per million, 552 deaths per million (2019 population = 145,934,460)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         59% through outbreak
#   Start:       2020-03-10 (-338 days, when 50 or more cases were reported)
#   Peak Cases:  2020-12-21 (-52 days, 45,052 cases)
#   End:         2021-10-02 (234 days, 286 days after peak cases)
#   Day Zero:    2020-04-02 (-315 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-12-21 (-52 days, 873 deaths)
#
# Parameters:
#   Totals:      4,041,993 cases and 79,040 deaths at end of 2021-02-08
#   Smoothed:    4,041,993 cases and 79,040 deaths at end of 2021-02-08 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-03-20, compared to 7 days earlier)
#                Latest infection rate 0.9 (2021-02-08, compared to 7 days earlier)
#   Growth:      286 days (Start -> Peak Cases)
#                X = 5,054,563, r = 8.0, L = 180,209, dilation = 1, c = 35.1% for cases
#   Lag:         0 days (Peak Cases -> Peak Deaths)
#                X = 98,840, r = 8.0, L = 3,493, dilation = 1, c = 42.0% for deaths
#
# Outcome: 5,052,868 total cases, 98,807 total deaths by end of 2021-10-02
#   80.8% of predicted cases and 81.5% of predicted deaths reported to date
#   100.0% of predicted cases and 100.0% of predicted deaths reported by end date
#   34,636 cases per million (3.46%), 677 deaths per million (0.068%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-01-29   16,444      492   3,884,531   74,111    17,319      508   3,883,656   74,094
# 2021-01-30   16,444      492   3,900,975   74,603    17,027      503   3,900,683   74,597
# 2021-01-31   16,444      492   3,917,419   75,095    16,736      498   3,917,419   75,095
# 2021-02-01   16,444      492   3,933,863   75,587    16,444      493   3,933,863   75,588
# 2021-02-02   16,444      492   3,950,307   76,079    16,195      493   3,950,058   76,080
# 2021-02-03   16,444      492   3,966,751   76,571    15,946      493   3,966,004   76,573
# 2021-02-04   16,446      497   3,983,197   77,068    15,696      493   3,981,700   77,067
# 2021-02-05   14,699      493   3,997,896   77,561    15,447      493   3,997,148   77,560
# 2021-02-06   14,699      493   4,012,595   78,054    15,198      493   4,012,345   78,053
# 2021-02-07   14,699      493   4,027,294   78,547    14,949      494   4,027,294   78,547
# 2021-02-08   14,699      493   4,041,993   79,040    14,699      493   4,041,993   79,040
# 2021-02-09   14,699      493   4,056,692   79,533
# 2021-02-10   14,699      493   4,071,391   80,026
# 2021-02-11   14,699      494   4,086,090   80,520
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-02-08   22,842      447  4,041,993   79,040
# 2021-02-09   22,462      439  4,064,455   79,479
# 2021-02-10   22,083      432  4,086,539   79,911
# 2021-02-11   21,705      424  4,108,244   80,336  <-- latest raw data
# 2021-02-12   21,329      417  4,129,573   80,753
# 2021-02-13   20,954      410  4,150,527   81,162
# 2021-02-14   20,581      402  4,171,108   81,565
# 2021-02-15   20,210      395  4,191,318   81,960
# 2021-02-16   19,841      388  4,211,158   82,348
# 2021-02-17   19,474      381  4,230,633   82,729

# %%
covid.Region(geoId='JPN').analyse()
# Out:
# Japan data to end of 2021-02-11:
#   415,782 cases, 6,952 deaths
#   3,287 cases per million, 55 deaths per million (2019 population = 126,476,458)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         55% through outbreak
#   Start:       2020-02-12 (-365 days, when 50 or more cases were reported)
#   Peak Cases:  2021-01-04 (-38 days, 6,129 cases)
#   End:         2021-11-26 (289 days, 327 days after peak cases)
#   Day Zero:    2020-03-26 (-322 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-01-25 (-17 days, 100 deaths)
#
# Parameters:
#   Totals:      411,154 cases and 6,711 deaths at end of 2021-02-08
#   Smoothed:    411,153 cases and 6,711 deaths at end of 2021-02-08 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-23, compared to 7 days earlier)
#                Latest infection rate 0.7 (2021-02-08, compared to 7 days earlier)
#   Growth:      327 days (Start -> Peak Cases)
#                X = 583,742, r = 8.0, L = 24,517, dilation = 1, c = 13.0% for cases
#   Lag:         21 days (Peak Cases -> Peak Deaths)
#                X = 11,419, r = 8.0, L = 401, dilation = 1, c = 27.5% for deaths
#
# Outcome: 583,547 total cases, 11,412 total deaths by end of 2021-11-26
#   71.2% of predicted cases and 60.9% of predicted deaths reported to date
#   100.0% of predicted cases and 99.9% of predicted deaths reported by end date
#   4,615 cases per million (0.46%), 90 deaths per million (0.009%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-01-29    2,210       96     391,728    5,818     3,030       98     390,907    5,815
# 2021-01-30    2,210       96     393,938    5,914     2,757       98     393,664    5,912
# 2021-01-31    2,210       96     396,148    6,010     2,484       97     396,147    6,009
# 2021-02-01    2,210       96     398,358    6,106     2,210       96     398,358    6,106
# 2021-02-02    2,210       96     400,568    6,202     2,115       94     400,472    6,199
# 2021-02-03    2,210       96     402,778    6,298     2,019       91     402,491    6,291
# 2021-02-04    2,212       97     404,990    6,395     1,924       89     404,415    6,379
# 2021-02-05    1,541       79     406,531    6,474     1,828       86     406,243    6,466
# 2021-02-06    1,541       79     408,072    6,553     1,732       84     407,975    6,550
# 2021-02-07    1,541       79     409,613    6,632     1,637       82     409,612    6,631
# 2021-02-08    1,541       79     411,154    6,711     1,542       80     411,154    6,711
# 2021-02-09    1,541       79     412,695    6,790
# 2021-02-10    1,541       79     414,236    6,869
# 2021-02-11    1,546       83     415,782    6,952
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-02-08    2,989       68    411,154    6,711
# 2021-02-09    2,960       68    414,114    6,779
# 2021-02-10    2,929       67    417,043    6,846
# 2021-02-11    2,899       67    419,942    6,913  <-- latest raw data
# 2021-02-12    2,868       67    422,809    6,979
# 2021-02-13    2,836       66    425,646    7,046
# 2021-02-14    2,805       66    428,451    7,111
# 2021-02-15    2,773       65    431,223    7,177
# 2021-02-16    2,741       65    433,964    7,242
# 2021-02-17    2,708       65    436,672    7,306

# %%
covid.Region(geoId='SGP').analyse()
# Out:
# Singapore data to end of 2021-02-11:
#   59,800 cases, 29 deaths
#   10,222 cases per million, 5 deaths per million (2019 population = 5,850,343)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-08 (-369 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-20 (-297 days, 1,005 cases)
#   End:         2020-06-30 (-225 days, 72 days after peak cases)
#
# Parameters:
#   Totals:      59,755 cases and 29 deaths at end of 2021-02-08
#   Smoothed:    59,754 cases and 28 deaths at end of 2021-02-08 (7 points)
#   Spread:      Peak infection rate 3.3 (2020-04-13, compared to 7 days earlier)
#                Latest infection rate 0.6 (2021-02-08, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                X = 44,511, r = 8.0, L = 4,020, dilation = 1, c = 54.7% for cases
#
# Outcome: 44,491 total cases, 26 total deaths at end of 2020-07-01
#   7,605 cases per million (0.76%), 4 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-01-29       23        0      59,559       29        27        0      59,554       29
# 2021-01-30       23        0      59,582       29        26        0      59,580       29
# 2021-01-31       23        0      59,605       29        25        0      59,605       29
# 2021-02-01       23        0      59,628       29        23        0      59,628       29
# 2021-02-02       23        0      59,651       29        22        0      59,650       29
# 2021-02-03       23        0      59,674       29        21        0      59,671       29
# 2021-02-04       25        0      59,699       29        19        0      59,690       29
# 2021-02-05       14        0      59,713       29        18        0      59,708       29
# 2021-02-06       14        0      59,727       29        17        0      59,725       29
# 2021-02-07       14        0      59,741       29        16        0      59,741       29
# 2021-02-08       14        0      59,755       29        14        0      59,755       29
# 2021-02-09       14        0      59,769       29
# 2021-02-10       14        0      59,783       29
# 2021-02-11       17        0      59,800       29
#
#   ** first wave ended **

# %%
covid.Region(geoId='BRA').analyse()
# Out:
# Brazil data to end of 2021-02-11:
#   9,866,710 cases, 239,773 deaths
#   46,419 cases per million, 1,128 deaths per million (2019 population = 212,559,409)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         56% through outbreak
#   Start:       2020-03-06 (-342 days, when 50 or more cases were reported)
#   Peak Cases:  2021-01-04 (-38 days, 56,838 cases)
#   End:         2021-11-03 (266 days, 304 days after peak cases)
#   Day Zero:    2020-03-21 (-327 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-02-08 ( -3 days, 1,086 deaths)
#
# Parameters:
#   Totals:      9,730,151 cases and 236,514 deaths at end of 2021-02-08
#   Smoothed:    9,730,151 cases and 236,513 deaths at end of 2021-02-08 (7 points)
#   Spread:      Peak infection rate 7.7 (2020-03-16, compared to 7 days earlier)
#                Latest infection rate 1.0 (2021-02-08, compared to 7 days earlier)
#   Growth:      304 days (Start -> Peak Cases)
#                X = 16,004,483, r = 4.0, L = 227,351, dilation = 1, c = 57.3% for cases
#   Lag:         35 days (Peak Cases -> Peak Deaths)
#                X = 476,667, r = 4.0, L = 4,344, dilation = 1, c = 46.5% for deaths
#
# Outcome: 15,716,623 total cases, 463,221 total deaths by end of 2021-11-03
#   61.6% of predicted cases and 50.3% of predicted deaths reported to date
#   98.2% of predicted cases and 97.2% of predicted deaths reported by end date
#   75,294 cases per million (7.53%), 2,243 deaths per million (0.224%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-01-29   45,536    1,010   9,274,858  226,109    47,935    1,032   9,272,458  226,086
# 2021-01-30   45,536    1,010   9,320,394  227,119    47,136    1,025   9,319,593  227,111
# 2021-01-31   45,536    1,010   9,365,930  228,129    46,336    1,018   9,365,929  228,129
# 2021-02-01   45,536    1,010   9,411,466  229,139    45,537    1,010   9,411,466  229,139
# 2021-02-02   45,536    1,010   9,457,002  230,149    45,534    1,021   9,457,000  230,160
# 2021-02-03   45,536    1,010   9,502,538  231,159    45,532    1,032   9,502,532  231,192
# 2021-02-04   45,541    1,011   9,548,079  232,170    45,529    1,043   9,548,061  232,235
# 2021-02-05   45,518    1,086   9,593,597  233,256    45,526    1,054   9,593,587  233,288
# 2021-02-06   45,518    1,086   9,639,115  234,342    45,524    1,064   9,639,111  234,353
# 2021-02-07   45,518    1,086   9,684,633  235,428    45,521    1,075   9,684,632  235,428
# 2021-02-08   45,518    1,086   9,730,151  236,514    45,519    1,086   9,730,151  236,514
# 2021-02-09   45,518    1,086   9,775,669  237,600
# 2021-02-10   45,518    1,086   9,821,187  238,686
# 2021-02-11   45,523    1,087   9,866,710  239,773
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-02-08   50,883    1,587  9,730,151  236,514
# 2021-02-09   50,729    1,587  9,780,880  238,101
# 2021-02-10   50,572    1,587  9,831,453  239,687
# 2021-02-11   50,412    1,586  9,881,864  241,273  <-- latest raw data
# 2021-02-12   50,247    1,586  9,932,112  242,859
# 2021-02-13   50,080    1,585  9,982,191  244,444
# 2021-02-14   49,908    1,584 10,032,100  246,029
# 2021-02-15   49,734    1,583 10,081,834  247,612
# 2021-02-16   49,556    1,582 10,131,389  249,195
# 2021-02-17   49,374    1,581 10,180,764  250,776

# %%
covid.Region(geoId='CHL').analyse()
# Out:
# Chile data to end of 2021-02-11:
#   779,541 cases, 19,624 deaths
#   40,779 cases per million, 1,027 deaths per million (2019 population = 19,116,209)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-10 (-338 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-15 (-241 days, 9,723 cases)
#   End:         2020-09-19 (-144 days, 97 days after peak cases)
#   Day Zero:    2020-04-05 (-312 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-07-13 (-213 days, 218 deaths)
#
# Parameters:
#   Totals:      769,170 cases and 19,380 deaths at end of 2021-02-08
#   Smoothed:    769,169 cases and 19,379 deaths at end of 2021-02-08 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.0 (2021-02-08, compared to 7 days earlier)
#   Growth:      97 days (Start -> Peak Cases)
#                X = 451,465, r = 7.67, L = 38,892, dilation = 1, c = 70.8% for cases
#   Lag:         28 days (Peak Cases -> Peak Deaths)
#                X = 12,692, r = 5.45, L = 870, dilation = 1, c = 66.5% for deaths
#
# Outcome: 451,257 total cases, 12,436 total deaths at end of 2020-09-20
#   23,606 cases per million (2.36%), 651 deaths per million (0.065%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-01-29    3,494       74     734,382   18,611     3,693       76     734,181   18,608
# 2021-01-30    3,494       74     737,876   18,685     3,627       75     737,808   18,684
# 2021-01-31    3,494       74     741,370   18,759     3,561       75     741,369   18,759
# 2021-02-01    3,494       74     744,864   18,833     3,495       74     744,864   18,833
# 2021-02-02    3,494       74     748,358   18,907     3,489       75     748,353   18,908
# 2021-02-03    3,494       74     751,852   18,981     3,483       76     751,836   18,984
# 2021-02-04    3,498       75     755,350   19,056     3,478       77     755,314   19,061
# 2021-02-05    3,455       81     758,805   19,137     3,472       78     758,786   19,140
# 2021-02-06    3,455       81     762,260   19,218     3,467       79     762,253   19,219
# 2021-02-07    3,455       81     765,715   19,299     3,461       80     765,714   19,299
# 2021-02-08    3,455       81     769,170   19,380     3,456       81     769,170   19,380
# 2021-02-09    3,455       81     772,625   19,461
# 2021-02-10    3,455       81     776,080   19,542
# 2021-02-11    3,461       82     779,541   19,624
#
#   ** first wave ended **

# %%
covid.Region(geoId='PER').analyse()
# Out:
# Peru data to end of 2021-02-11:
#   1,238,501 cases, 43,880 deaths
#   37,562 cases per million, 1,331 deaths per million (2019 population = 32,971,846)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-10 (-338 days, when 50 or more cases were reported)
#   Peak Cases:  2020-08-17 (-178 days, 8,340 cases)
#   End:         2021-01-23 (-18 days, 160 days after peak cases)
#   Day Zero:    2020-03-30 (-318 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-08-10 (-185 days, 744 deaths)
#
# Parameters:
#   Totals:      1,216,298 cases and 43,204 deaths at end of 2021-02-08
#   Smoothed:    1,216,297 cases and 43,204 deaths at end of 2021-02-08 (7 points)
#   Spread:      Peak infection rate 3.7 (2020-04-06, compared to 7 days earlier)
#                Latest infection rate 1.2 (2021-02-08, compared to 7 days earlier)
#   Growth:      160 days (Start -> Peak Cases)
#                X = 1,125,272, r = 5.0, L = 33,360, dilation = 1, c = 64.7% for cases
#   Lag:         -7 days (Peak Cases -> Peak Deaths)
#                X = 40,386, r = 8.0, L = 2,976, dilation = 1, c = 13.2% for deaths
#
# Outcome: 1,117,742 total cases, 40,377 total deaths at end of 2021-01-24
#   33,900 cases per million (3.39%), 1,225 deaths per million (0.122%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-01-29    6,283      161   1,148,999   41,342     6,266      178   1,149,015   41,324
# 2021-01-30    6,283      161   1,155,282   41,503     6,272      173   1,155,287   41,496
# 2021-01-31    6,283      161   1,161,565   41,664     6,278      167   1,161,564   41,663
# 2021-02-01    6,283      161   1,167,848   41,825     6,283      161   1,167,848   41,824
# 2021-02-02    6,283      161   1,174,131   41,986     6,443      170   1,174,290   41,994
# 2021-02-03    6,283      161   1,180,414   42,147     6,602      179   1,180,893   42,173
# 2021-02-04    6,284      161   1,186,698   42,308     6,762      188   1,187,655   42,361
# 2021-02-05    7,400      224   1,194,098   42,532     6,921      197   1,194,576   42,558
# 2021-02-06    7,400      224   1,201,498   42,756     7,081      206   1,201,657   42,764
# 2021-02-07    7,400      224   1,208,898   42,980     7,241      215   1,208,898   42,979
# 2021-02-08    7,400      224   1,216,298   43,204     7,400      225   1,216,298   43,204
# 2021-02-09    7,400      224   1,223,698   43,428
# 2021-02-10    7,400      224   1,231,098   43,652
# 2021-02-11    7,403      228   1,238,501   43,880
#
#   ** first wave ended **

# %%
covid.Region(geoId='MEX').analyse()
# Out:
# Mexico data to end of 2021-02-11:
#   1,995,892 cases, 174,657 deaths
#   15,480 cases per million, 1,355 deaths per million (2019 population = 128,932,753)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         53% through outbreak
#   Start:       2020-03-05 (-343 days, when 50 or more cases were reported)
#   Peak Cases:  2021-01-18 (-24 days, 17,463 cases)
#   End:         2021-12-02 (295 days, 319 days after peak cases)
#   Day Zero:    2020-03-30 (-318 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-01-18 (-24 days, 1,289 deaths)
#
# Parameters:
#   Totals:      1,970,229 cases and 171,259 deaths at end of 2021-02-08
#   Smoothed:    1,970,228 cases and 171,258 deaths at end of 2021-02-08 (7 points)
#   Spread:      Peak infection rate 3.3 (2020-03-15, compared to 7 days earlier)
#                Latest infection rate 0.9 (2021-02-08, compared to 7 days earlier)
#   Growth:      319 days (Start -> Peak Cases)
#                X = 3,119,894, r = 8.0, L = 69,850, dilation = 1, c = 46.6% for cases
#   Lag:         0 days (Peak Cases -> Peak Deaths)
#                X = 298,900, r = 4.61, L = 5,157, dilation = 1, c = 46.7% for deaths
#
# Outcome: 3,118,847 total cases, 295,953 total deaths by end of 2021-12-02
#   64.0% of predicted cases and 58.4% of predicted deaths reported to date
#   100.0% of predicted cases and 99.0% of predicted deaths reported by end date
#   24,198 cases per million (2.42%), 2,318 deaths per million (0.232%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-01-29    9,472    1,090   1,879,180  160,190    11,411    1,163   1,877,241  160,116
# 2021-01-30    9,472    1,090   1,888,652  161,280    10,765    1,139   1,888,005  161,255
# 2021-01-31    9,472    1,090   1,898,124  162,370    10,119    1,114   1,898,124  162,370
# 2021-02-01    9,472    1,090   1,907,596  163,460     9,472    1,090   1,907,596  163,460
# 2021-02-02    9,472    1,090   1,917,068  164,550     9,341    1,096   1,916,937  164,556
# 2021-02-03    9,472    1,090   1,926,540  165,640     9,210    1,102   1,926,147  165,658
# 2021-02-04    9,473    1,091   1,936,013  166,731     9,079    1,108   1,935,226  166,766
# 2021-02-05    8,554    1,132   1,944,567  167,863     8,948    1,114   1,944,173  167,880
# 2021-02-06    8,554    1,132   1,953,121  168,995     8,816    1,120   1,952,990  169,001
# 2021-02-07    8,554    1,132   1,961,675  170,127     8,685    1,126   1,961,675  170,127
# 2021-02-08    8,554    1,132   1,970,229  171,259     8,554    1,132   1,970,229  171,259
# 2021-02-09    8,554    1,132   1,978,783  172,391
# 2021-02-10    8,554    1,132   1,987,337  173,523
# 2021-02-11    8,555    1,134   1,995,892  174,657
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-02-08   18,271    1,066  1,970,229  171,259
# 2021-02-09   18,150    1,064  1,988,379  172,323
# 2021-02-10   18,026    1,061  2,006,405  173,384
# 2021-02-11   17,897    1,058  2,024,302  174,442  <-- latest raw data
# 2021-02-12   17,763    1,056  2,042,065  175,498
# 2021-02-13   17,626    1,053  2,059,692  176,551
# 2021-02-14   17,485    1,050  2,077,177  177,601
# 2021-02-15   17,340    1,047  2,094,517  178,648
# 2021-02-16   17,192    1,044  2,111,709  179,692
# 2021-02-17   17,040    1,041  2,128,748  180,733

# %%
covid.Region(geoId='IND').analyse()
# Out:
# India data to end of 2021-02-11:
#   10,916,589 cases, 155,732 deaths
#   7,911 cases per million, 113 deaths per million (2019 population = 1,380,004,385)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         92% through outbreak
#   Start:       2020-03-07 (-341 days, when 50 or more cases were reported)
#   Peak Cases:  2020-09-07 (-157 days, 91,688 cases)
#   End:         2021-03-09 ( 27 days, 184 days after peak cases)
#   Day Zero:    2020-03-28 (-320 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-09-14 (-150 days, 1,166 deaths)
#
# Parameters:
#   Totals:      10,882,990 cases and 155,452 deaths at end of 2021-02-08
#   Smoothed:    10,882,990 cases and 155,451 deaths at end of 2021-02-08 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 1.0 (2021-02-08, compared to 7 days earlier)
#   Growth:      184 days (Start -> Peak Cases)
#                X = 10,918,010, r = 6.83, L = 366,750, dilation = 1, c = 82.2% for cases
#   Lag:         7 days (Peak Cases -> Peak Deaths)
#                X = 158,338, r = 4.97, L = 4,662, dilation = 1, c = 87.1% for deaths
#
# Outcome: 10,906,200 total cases, 157,020 total deaths by end of 2021-03-09
#   100.0% of predicted cases and 98.4% of predicted deaths reported to date
#   99.9% of predicted cases and 99.2% of predicted deaths reported by end date
#   7,912 cases per million (0.79%), 115 deaths per million (0.011%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-01-29   11,512       98  10,769,122  154,490    12,081      113  10,768,553  154,474
# 2021-01-30   11,512       98  10,780,634  154,588    11,891      108  10,780,444  154,582
# 2021-01-31   11,512       98  10,792,146  154,686    11,702      103  10,792,146  154,686
# 2021-02-01   11,512       98  10,803,658  154,784    11,512       98  10,803,658  154,784
# 2021-02-02   11,512       98  10,815,170  154,882    11,467       98  10,815,125  154,882
# 2021-02-03   11,512       98  10,826,682  154,980    11,423       97  10,826,548  154,979
# 2021-02-04   11,512      100  10,838,194  155,080    11,378       96  10,837,925  155,075
# 2021-02-05   11,199       93  10,849,393  155,173    11,333       95  10,849,259  155,170
# 2021-02-06   11,199       93  10,860,592  155,266    11,288       95  10,860,547  155,265
# 2021-02-07   11,199       93  10,871,791  155,359    11,244       94  10,871,791  155,359
# 2021-02-08   11,199       93  10,882,990  155,452    11,199       93  10,882,990  155,452
# 2021-02-09   11,199       93  10,894,189  155,545
# 2021-02-10   11,199       93  10,905,388  155,638
# 2021-02-11   11,201       94  10,916,589  155,732
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-02-08    1,328       78 10,882,990  155,452
# 2021-02-09    1,280       76 10,884,270  155,528
# 2021-02-10    1,234       74 10,885,504  155,602
# 2021-02-11    1,189       72 10,886,693  155,675  <-- latest raw data
# 2021-02-12    1,146       70 10,887,840  155,745
# 2021-02-13    1,105       69 10,888,944  155,814
# 2021-02-14    1,065       67 10,890,009  155,881
# 2021-02-15    1,026       65 10,891,035  155,946
# 2021-02-16      989       63 10,892,024  156,009
# 2021-02-17      953       62 10,892,977  156,071

# %%
covid.Region(geoId='CHN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2021-02-11:
#   100,599 cases, 4,829 deaths
#   70 cases per million, 3 deaths per million (2019 population = 1,439,323,774)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-09 (-399 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-367 days, 4,346 cases)
#   End:         2020-03-12 (-335 days, 32 days after peak cases)
#   Day Zero:    2020-01-21 (-387 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-10 (-367 days, 123 deaths)
#
# Parameters:
#   Totals:      100,508 cases and 4,826 deaths at end of 2021-02-08
#   Smoothed:    100,507 cases and 4,825 deaths at end of 2021-02-08 (7 points)
#   Spread:      Peak infection rate 29.4 (2020-12-14, compared to 7 days earlier)
#                Latest infection rate 0.6 (2021-02-08, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
#                X = 81,130, r = 5.52, L = 17,382, dilation = 0.7, c = 81.5% for cases
#   Lag:         0 days (Peak Cases -> Peak Deaths)
#                X = 3,239, r = 5.17, L = 492, dilation = 1, c = 88.8% for deaths
#
# Outcome: 81,086 total cases, 3,224 total deaths at end of 2020-03-13
#   56 cases per million (0.01%), 2 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-01-29       46        0     100,109    4,817        77        1     100,078    4,815
# 2021-01-30       46        0     100,155    4,817        67        1     100,144    4,816
# 2021-01-31       46        0     100,201    4,817        57        1     100,201    4,817
# 2021-02-01       46        0     100,247    4,817        46        1     100,247    4,818
# 2021-02-02       46        0     100,293    4,817        44        1     100,291    4,819
# 2021-02-03       46        0     100,339    4,817        42        1     100,333    4,820
# 2021-02-04       49        5     100,388    4,822        40        1     100,373    4,821
# 2021-02-05       30        1     100,418    4,823        37        1     100,410    4,822
# 2021-02-06       30        1     100,448    4,824        35        1     100,445    4,823
# 2021-02-07       30        1     100,478    4,825        33        2     100,478    4,825
# 2021-02-08       30        1     100,508    4,826        30        1     100,508    4,826
# 2021-02-09       30        1     100,538    4,827
# 2021-02-10       30        1     100,568    4,828
# 2021-02-11       31        1     100,599    4,829
#
#   ** first wave ended **

# %%
covid.Region(geoId='KOR').analyse(ylog=1)
# Out:
# South Korea data to end of 2021-02-11:
#   83,869 cases, 1,527 deaths
#   1,636 cases per million, 30 deaths per million (2019 population = 51,269,183)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         59% through outbreak
#   Start:       2020-02-12 (-365 days, when 50 or more cases were reported)
#   Peak Cases:  2020-12-14 (-59 days, 1,015 cases)
#   End:         2021-10-15 (247 days, 306 days after peak cases)
#   Day Zero:    2020-03-06 (-342 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-12-28 (-45 days, 23 deaths)
#
# Parameters:
#   Totals:      82,717 cases and 1,502 deaths at end of 2021-02-08
#   Smoothed:    82,716 cases and 1,502 deaths at end of 2021-02-08 (7 points)
#   Spread:      Peak infection rate 10.5 (2020-02-18, compared to 7 days earlier)
#                Latest infection rate 1.0 (2021-02-08, compared to 7 days earlier)
#   Growth:      306 days (Start -> Peak Cases)
#                X = 101,607, r = 8.0, L = 4,061, dilation = 1, c = 16.1% for cases
#   Lag:         14 days (Peak Cases -> Peak Deaths)
#                X = 1,996, r = 8.0, L = 92, dilation = 1, c = -11.9% for deaths
#
# Outcome: 101,573 total cases, 1,995 total deaths by end of 2021-10-15
#   82.5% of predicted cases and 76.5% of predicted deaths reported to date
#   100.0% of predicted cases and 99.9% of predicted deaths reported by end date
#   1,982 cases per million (0.20%), 39 deaths per million (0.004%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-01-29      382        7      78,890    1,432       402        8      78,869    1,430
# 2021-01-30      382        7      79,272    1,439       395        8      79,265    1,438
# 2021-01-31      382        7      79,654    1,446       389        8      79,654    1,445
# 2021-02-01      382        7      80,036    1,453       382        7      80,036    1,452
# 2021-02-02      382        7      80,418    1,460       383        7      80,419    1,459
# 2021-02-03      382        7      80,800    1,467       383        7      80,801    1,466
# 2021-02-04      385        7      81,185    1,474       383        7      81,184    1,473
# 2021-02-05      383        7      81,568    1,481       383        7      81,567    1,480
# 2021-02-06      383        7      81,951    1,488       383        7      81,950    1,487
# 2021-02-07      383        7      82,334    1,495       383        7      82,334    1,494
# 2021-02-08      383        7      82,717    1,502       383        8      82,717    1,502
# 2021-02-09      383        7      83,100    1,509
# 2021-02-10      383        7      83,483    1,516
# 2021-02-11      386       11      83,869    1,527
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-02-08      405       10     82,717    1,502
# 2021-02-09      399       10     83,116    1,512
# 2021-02-10      392       10     83,508    1,521
# 2021-02-11      386        9     83,894    1,531  <-- latest raw data
# 2021-02-12      379        9     84,273    1,540
# 2021-02-13      373        9     84,646    1,549
# 2021-02-14      366        9     85,012    1,558
# 2021-02-15      360        9     85,372    1,567
# 2021-02-16      354        9     85,725    1,576
# 2021-02-17      347        9     86,072    1,584

# %%
covid.Region(geoId='NZL', d_cases=3).analyse(ylog=0)
# Out:
# New Zealand data to end of 2021-02-11:
#   1,980 cases, 25 deaths
#   411 cases per million, 5 deaths per million (2019 population = 4,822,233)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-16 (-332 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-325 days, 64 cases)
#   End:         2020-04-12 (-304 days, 21 days after peak cases)
#
# Parameters:
#   Totals:      1,972 cases and 25 deaths at end of 2021-02-08
#   Smoothed:    1,971 cases and 24 deaths at end of 2021-02-08 (7 points)
#   Spread:      Peak infection rate 30.5 (2020-08-10, compared to 7 days earlier)
#                Latest infection rate 0.9 (2021-02-08, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,104, r = 4.0, L = 257, dilation = 3, c = 91.0% for cases
#
# Outcome: 1,084 total cases, 9 total deaths at end of 2020-04-13
#   225 cases per million (0.02%), 2 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-01-29        2        0       1,949       25         2        0       1,948       25
# 2021-01-30        2        0       1,951       25         2        0       1,951       25
# 2021-01-31        2        0       1,953       25         2        0       1,953       25
# 2021-02-01        2        0       1,955       25         2        0       1,955       25
# 2021-02-02        2        0       1,957       25         2        0       1,958       25
# 2021-02-03        2        0       1,959       25         2        0       1,960       25
# 2021-02-04        5        0       1,964       25         2        0       1,962       25
# 2021-02-05        2        0       1,966       25         2        0       1,965       25
# 2021-02-06        2        0       1,968       25         2        0       1,967       25
# 2021-02-07        2        0       1,970       25         2        0       1,970       25
# 2021-02-08        2        0       1,972       25         2        0       1,972       25
# 2021-02-09        2        0       1,974       25
# 2021-02-10        2        0       1,976       25
# 2021-02-11        4        0       1,980       25
#
#   ** first wave ended **

# %%
covid.Region(geoId='AUS').analyse()
# Out:
# Australia data to end of 2021-02-11:
#   28,900 cases, 909 deaths
#   1,133 cases per million, 36 deaths per million (2019 population = 25,499,881)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-02 (-346 days, when 50 or more cases were reported)
#   Peak Cases:  2020-07-27 (-199 days, 503 cases)
#   End:         2020-12-20 (-52 days, 147 days after peak cases)
#   Day Zero:    2020-04-07 (-310 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-08-31 (-164 days, 20 deaths)
#
# Parameters:
#   Totals:      28,878 cases and 909 deaths at end of 2021-02-08
#   Smoothed:    28,878 cases and 908 deaths at end of 2021-02-08 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-16, compared to 7 days earlier)
#                Latest infection rate 1.6 (2021-02-08, compared to 7 days earlier)
#   Growth:      147 days (Start -> Peak Cases)
#                X = 28,271, r = 8.0, L = 2,011, dilation = 1, c = 21.8% for cases
#   Lag:         35 days (Peak Cases -> Peak Deaths)
#                X = 910, r = 8.0, L = 81, dilation = 1, c = 14.9% for deaths
#
# Outcome: 28,262 total cases, 908 total deaths at end of 2020-12-21
#   1,108 cases per million (0.11%), 36 deaths per million (0.004%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2021-01-29        4        0      28,822      909         6        0      28,820      909
# 2021-01-30        4        0      28,826      909         5        0      28,825      909
# 2021-01-31        4        0      28,830      909         5        0      28,830      909
# 2021-02-01        4        0      28,834      909         5        0      28,834      909
# 2021-02-02        4        0      28,838      909         5        0      28,839      909
# 2021-02-03        4        0      28,842      909         5        0      28,845      909
# 2021-02-04        8        0      28,850      909         6        0      28,851      909
# 2021-02-05        7        0      28,857      909         6        0      28,857      909
# 2021-02-06        7        0      28,864      909         7        0      28,864      909
# 2021-02-07        7        0      28,871      909         7        0      28,871      909
# 2021-02-08        7        0      28,878      909         7        0      28,878      909
# 2021-02-09        7        0      28,885      909
# 2021-02-10        7        0      28,892      909
# 2021-02-11        8        0      28,900      909
#
#   ** first wave ended **
