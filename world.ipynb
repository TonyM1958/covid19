# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='US', dilation=3.3, d_cases=7).analyse()
# Out:
# United States of America data to end of 2020-05-24:
#   1,643,238 cases, 97,720 deaths
#   5,023 cases per million, 299 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         68% through outbreak
#   Start:       2020-02-25 (-89 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-47 days, 31,963 cases)
#   End:         2020-06-29 ( 37 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-72 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-36 days, 2,722 deaths)
#
# Parameters:
#   Totals:      1,577,287 cases and 94,702 deaths at end of 2020-05-21
#   Smoothed:    1,577,286 cases and 94,702 deaths at end of 2020-05-21 (7 points)
#   Spread:      Peak infection rate 11.5 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-21, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
#                X = 2,429,459, r = 8.0, L = 127,853, dilation = 7, c = 90.9% for cases
#   Lag:         11 days (Peak Cases -> Peak Deaths)
#                X = 116,478, r = 8.0, L = 10,888, dilation = 3.3, c = 77.4% for deaths
#
# Outcome: 2,205,188 total cases, 114,780 total deaths by end of 2020-06-29
#   67.6% of predicted cases and 83.9% of predicted deaths reported to date
#   90.8% of predicted cases and 98.5% of predicted deaths reported by end date
#   7,426 cases per million (0.74%), 356 deaths per million (0.036%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-11   18,117    1,156   1,347,916   80,684    23,003    1,466   1,350,870   81,437
# 2020-05-12   22,048    1,703   1,369,964   82,387    22,796    1,488   1,373,666   82,925
# 2020-05-13   20,782    1,746   1,390,746   84,133    22,636    1,426   1,396,302   84,352
# 2020-05-14   27,143    1,773   1,417,889   85,906    22,438    1,437   1,418,739   85,789
# 2020-05-15   25,508    1,662   1,443,397   87,568    22,970    1,385   1,441,709   87,173
# 2020-05-16   24,487    1,186   1,467,884   88,754    22,673    1,365   1,464,382   88,539
# 2020-05-17   18,873      808   1,486,757   89,562    23,031    1,333   1,487,413   89,872
# 2020-05-18   21,841      791   1,508,598   90,353    22,786    1,260   1,510,199   91,131
# 2020-05-19   19,970    1,568   1,528,568   91,921    22,592    1,209   1,532,791   92,340
# 2020-05-20   23,285    1,518   1,551,853   93,439    22,127    1,193   1,554,918   93,534
# 2020-05-21   25,434    1,263   1,577,287   94,702    22,369    1,168   1,577,287   94,702
# 2020-05-22   24,147    1,305   1,601,434   96,007
# 2020-05-23   21,236    1,080   1,622,670   97,087
# 2020-05-24   20,568      633   1,643,238   97,720
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-21   22,368    1,174  1,577,287   94,702
# 2020-05-22   22,041    1,124  1,599,328   95,826
# 2020-05-23   21,713    1,076  1,621,041   96,902
# 2020-05-24   21,385    1,029  1,642,426   97,932  <-- latest raw data
# 2020-05-25   21,056      984  1,663,483   98,915
# 2020-05-26   20,728      940  1,684,210   99,855
# 2020-05-27   20,399      897  1,704,609  100,752
# 2020-05-28   20,071      856  1,724,680  101,608
# 2020-05-29   19,743      816  1,744,423  102,424
# 2020-05-30   19,416      778  1,763,840  103,202

# %%
covid.Region(geoId='RU', dilation=3, d_cases=1.8).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-24:
#   344,481 cases, 3,541 deaths
#   2,384 cases per million, 25 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         44% through outbreak
#   Start:       2020-03-14 (-71 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 (-15 days, 10,978 cases)
#   End:         2020-08-16 ( 85 days, 100 days after peak cases)
#   Day Zero:    2020-04-06 (-48 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-21 ( -3 days, 129 deaths)
#
# Parameters:
#   Totals:      317,554 cases and 3,099 deaths at end of 2020-05-21
#   Smoothed:    317,553 cases and 3,099 deaths at end of 2020-05-21 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-21, compared to 7 days earlier)
#   Growth:      56 days (Start -> Peak Cases)
#                X = 530,882, r = 6.36, L = 43,911, dilation = 1.8, c = 92.2% for cases
#   Lag:         12 days (Peak Cases -> Peak Deaths)
#                X = 11,615, r = 4.47, L = 517, dilation = 3, c = 83.7% for deaths
#
# Outcome: 529,917 total cases, 10,595 total deaths by end of 2020-08-16
#   64.9% of predicted cases and 30.5% of predicted deaths reported to date
#   99.8% of predicted cases and 91.2% of predicted deaths reported by end date
#   3,674 cases per million (0.37%), 80 deaths per million (0.008%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-11   11,656       94     221,344    2,009    10,723       97     220,538    2,005
# 2020-05-12   10,899      107     232,243    2,116    10,708       99     231,246    2,103
# 2020-05-13   10,028       96     242,271    2,212    10,477      101     241,723    2,204
# 2020-05-14    9,974       93     252,245    2,305    10,291      102     252,014    2,306
# 2020-05-15   10,598      113     262,843    2,418     9,901      101     261,915    2,407
# 2020-05-16    9,200      119     272,043    2,537     9,668      102     271,583    2,510
# 2020-05-17    9,709       94     281,752    2,631     9,487      108     281,070    2,618
# 2020-05-18    8,926       91     290,678    2,722     9,326      113     290,396    2,731
# 2020-05-19    9,263      115     299,941    2,837     9,083      118     299,479    2,849
# 2020-05-20    8,764      135     308,705    2,972     9,117      121     308,596    2,970
# 2020-05-21    8,849      127     317,554    3,099     8,958      129     317,554    3,099
# 2020-05-22    8,894      150     326,448    3,249
# 2020-05-23    9,434      139     335,882    3,388
# 2020-05-24    8,599      153     344,481    3,541
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-21    9,376      122    317,554    3,099
# 2020-05-22    9,156      122    326,710    3,221
# 2020-05-23    8,927      122    335,638    3,343
# 2020-05-24    8,689      122    344,327    3,465  <-- latest raw data
# 2020-05-25    8,444      122    352,772    3,587
# 2020-05-26    8,194      122    360,965    3,709
# 2020-05-27    7,938      121    368,904    3,830
# 2020-05-28    7,679      121    376,583    3,952
# 2020-05-29    7,419      121    384,002    4,073
# 2020-05-30    7,157      121    391,158    4,193

# %%
covid.Region(geoId='JP', dilation=2.2, d_cases=1.3).analyse(ylog=1)
# Out:
# Japan data to end of 2020-05-24:
#   16,581 cases, 830 deaths
#   131 cases per million, 7 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         73% through outbreak
#   Start:       2020-02-16 (-98 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-41 days, 644 cases)
#   End:         2020-06-25 ( 33 days, 74 days after peak cases)
#   Day Zero:    2020-03-28 (-57 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-29 days, 29 deaths)
#
# Parameters:
#   Totals:      16,513 cases and 796 deaths at end of 2020-05-21
#   Smoothed:    16,513 cases and 795 deaths at end of 2020-05-21 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-21, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
#                X = 16,804, r = 8.0, L = 2,576, dilation = 1.3, c = 69.0% for cases
#   Lag:         12 days (Peak Cases -> Peak Deaths)
#                X = 1,004, r = 8.0, L = 116, dilation = 2.2, c = 60.7% for deaths
#
# Outcome: 16,799 total cases, 985 total deaths by end of 2020-06-25
#   98.7% of predicted cases and 82.6% of predicted deaths reported to date
#   100.0% of predicted cases and 98.0% of predicted deaths reported by end date
#   133 cases per million (0.01%), 8 deaths per million (0.001%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-11       76       22      15,874      643        92       22      15,939      650
# 2020-05-12      150       25      16,024      668        87       18      16,026      668
# 2020-05-13       55       19      16,079      687        77       19      16,103      686
# 2020-05-14      114       23      16,193      710        73       18      16,176      705
# 2020-05-15       44       15      16,237      725        70       17      16,246      722
# 2020-05-16       48       19      16,285      744        52       15      16,298      736
# 2020-05-17       20        5      16,305      749        49       13      16,347      749
# 2020-05-18       60       14      16,365      763        46       12      16,393      762
# 2020-05-19       20        8      16,385      771        43       12      16,436      774
# 2020-05-20       39        6      16,424      777        38       11      16,473      784
# 2020-05-21       89       19      16,513      796        40       12      16,513      796
# 2020-05-22       23       12      16,536      808
# 2020-05-23       14       12      16,550      820
# 2020-05-24       31       10      16,581      830
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-21       33       12     16,513      796
# 2020-05-22       30       11     16,543      807
# 2020-05-23       27       11     16,569      818
# 2020-05-24       24       10     16,593      829  <-- latest raw data
# 2020-05-25       22       10     16,615      839
# 2020-05-26       19        9     16,634      848
# 2020-05-27       17        9     16,652      857
# 2020-05-28       16        9     16,667      866
# 2020-05-29       14        8     16,681      874
# 2020-05-30       13        8     16,694      882

# %%
covid.Region(geoId='SG', dilation=3.3).analyse()
# Out:
# Singapore data to end of 2020-05-24:
#   31,616 cases, 23 deaths
#   5,607 cases per million, 4 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         46% through outbreak
#   Start:       2020-02-12 (-102 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-31 days, 1,002 cases)
#   End:         2020-09-11 (111 days, 142 days after peak cases)
#
# Parameters:
#   Totals:      29,812 cases and 23 deaths at end of 2020-05-21
#   Smoothed:    29,812 cases and 23 deaths at end of 2020-05-21 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-21, compared to 7 days earlier)
#   Growth:      71 days (Start -> Peak Cases)
#                X = 51,263, r = 8.0, L = 4,006, dilation = 3.3, c = 51.2% for cases
#
# Outcome: 50,864 total cases, 51 total deaths by end of 2020-09-11
#   61.7% of predicted cases and 43.2% of predicted deaths reported to date
#   99.2% of predicted cases and 95.7% of predicted deaths reported by end date
#   9,091 cases per million (0.91%), 9 deaths per million (0.001%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-11      451        1      23,787       21       734    < 0.5      23,831       21
# 2020-05-12      884        0      24,671       21       738    < 0.5      24,569       21
# 2020-05-13      675        0      25,346       21       697    < 0.5      25,266       21
# 2020-05-14      752        0      26,098       21       669    < 0.5      25,935       22
# 2020-05-15      793        0      26,891       21       649    < 0.5      26,583       22
# 2020-05-16      465        1      27,356       22       587    < 0.5      27,170       22
# 2020-05-17      682        0      28,038       22       572    < 0.5      27,742       22
# 2020-05-18      305        0      28,343       22       529    < 0.5      28,271       22
# 2020-05-19      451        0      28,794       22       503    < 0.5      28,774       23
# 2020-05-20      570        0      29,364       22       528    < 0.5      29,303       23
# 2020-05-21      448        1      29,812       23       509    < 0.5      29,812       23
# 2020-05-22      614        0      30,426       23
# 2020-05-23      642        0      31,068       23
# 2020-05-24      548        0      31,616       23
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-21      541        1     29,812       23
# 2020-05-22      533        1     30,345       24
# 2020-05-23      525        1     30,870       24
# 2020-05-24      516        1     31,386       25  <-- latest raw data
# 2020-05-25      508        1     31,893       25
# 2020-05-26      499        1     32,392       26
# 2020-05-27      490        1     32,882       26
# 2020-05-28      481        1     33,364       27
# 2020-05-29      473        1     33,836       27
# 2020-05-30      464        1     34,300       28

# %%
covid.Region(geoId='BR', growth_days=77, dilation=2.5).analyse()
# Out:
# Brazil data to end of 2020-05-24:
#   363,211 cases, 22,666 deaths
#   1,734 cases per million, 108 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         31% through outbreak
#   Start:       2020-03-11 (-74 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-27 (  3 days, --- cases)
#   End:         2020-10-27 (157 days, 154 days after peak cases)
#   Day Zero:    2020-03-24 (-61 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-31 (  7 days)
#
# Parameters:
#   Totals:      310,087 cases and 20,047 deaths at end of 2020-05-21
#   Smoothed:    310,086 cases and 20,047 deaths at end of 2020-05-21 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.6 (2020-05-21, compared to 7 days earlier)
#   Growth:      77 days (Start -> Peak Cases)
#                X = 1,431,670, r = 6.91, L = 75,020, dilation = 2.5, c = 88.6% for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#                X = 103,425, r = 5.39, L = 4,247, dilation = 2.5, c = 94.0% for deaths
#
# Outcome: 1,425,986 total cases, 101,898 total deaths by end of 2020-10-27
#   25.4% of predicted cases and 21.9% of predicted deaths reported to date
#   99.6% of predicted cases and 98.5% of predicted deaths reported by end date
#   6,835 cases per million (0.68%), 494 deaths per million (0.049%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-11    5,632      396     168,331   11,519     9,695      697     171,809   11,895
# 2020-05-12    9,258      881     177,589   12,400    10,421      708     182,230   12,602
# 2020-05-13   11,385      749     188,974   13,149    11,037      720     193,267   13,322
# 2020-05-14   13,944      844     202,918   13,993    11,206      718     204,473   14,040
# 2020-05-15   15,305      824     218,223   14,817    12,279      758     216,752   14,799
# 2020-05-16   14,919      816     233,142   15,633    13,444      801     230,196   15,600
# 2020-05-17    7,938      485     241,080   16,118    14,669      821     244,864   16,421
# 2020-05-18   13,140      674     254,220   16,792    15,321      871     260,185   17,292
# 2020-05-19   17,408    1,179     271,628   17,971    16,107      896     276,293   18,188
# 2020-05-20   19,951      888     291,579   18,859    16,334      918     292,627   19,105
# 2020-05-21   18,508    1,188     310,087   20,047    17,460      942     310,087   20,047
# 2020-05-22   20,803    1,001     330,890   21,048
# 2020-05-23   16,508      965     347,398   22,013
# 2020-05-24   15,813      653     363,211   22,666
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-21   17,118      925    310,087   20,047
# 2020-05-22   17,493      946    327,580   20,993
# 2020-05-23   17,808      966    345,388   21,959
# 2020-05-24   18,059      983    363,447   22,942  <-- latest raw data
# 2020-05-25   18,240      999    381,687   23,941
# 2020-05-26   18,351    1,012    400,038   24,953
# 2020-05-27   18,387    1,023    418,425   25,976
# 2020-05-28   18,382    1,032    436,807   27,008
# 2020-05-29   18,364    1,038    455,171   28,046
# 2020-05-30   18,334    1,042    473,505   29,089

# %%
covid.Region(geoId='CL', growth_days=74).analyse(ylog=1)
# Out:
# Chile data to end of 2020-05-24:
#   69,102 cases, 718 deaths
#   3,690 cases per million, 38 deaths per million (2018 population = 18,729,160)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         47% through outbreak
#   Start:       2020-03-13 (-72 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-26 (  2 days, --- cases)
#   End:         2020-08-07 ( 76 days, 74 days after peak cases)
#   Day Zero:    2020-04-08 (-46 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-30 (  6 days)
#
# Parameters:
#   Totals:      57,581 cases and 589 deaths at end of 2020-05-21
#   Smoothed:    57,580 cases and 589 deaths at end of 2020-05-21 (7 points)
#   Spread:      Peak infection rate 4.2 (2020-03-22, compared to 7 days earlier)
#                Latest infection rate 1.7 (2020-05-21, compared to 7 days earlier)
#   Growth:      74 days (Start -> Peak Cases)
#                X = 151,328, r = 8.0, L = 15,548, dilation = 1, c = 77.0% for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#                X = 2,066, r = 8.0, L = 191, dilation = 1, c = 59.6% for deaths
#
# Outcome: 151,277 total cases, 2,065 total deaths by end of 2020-08-07
#   45.7% of predicted cases and 34.7% of predicted deaths reported to date
#   100.0% of predicted cases and 99.9% of predicted deaths reported by end date
#   8,080 cases per million (0.81%), 110 deaths per million (0.011%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-11    1,197       11      30,063      323     1,779       10      30,740      323
# 2020-05-12    1,658       12      31,721      335     1,938       14      32,678      337
# 2020-05-13    2,660       11      34,381      346     2,029       17      34,708      354
# 2020-05-14    2,659       12      37,040      358     2,130       20      36,838      374
# 2020-05-15    2,502       36      39,542      394     2,285       22      39,123      396
# 2020-05-16    1,886       27      41,428      421     2,551       25      41,673      420
# 2020-05-17    2,353       29      43,781      450     2,747       28      44,421      449
# 2020-05-18    2,278       28      46,059      478     2,934       33      47,354      481
# 2020-05-19    3,520       31      49,579      509     3,187       34      50,542      515
# 2020-05-20    4,038       35      53,617      544     3,423       36      53,964      551
# 2020-05-21    3,964       45      57,581      589     3,617       38      57,581      589
# 2020-05-22    4,276       41      61,857      630
# 2020-05-23    3,536       43      65,393      673
# 2020-05-24    3,709       45      69,102      718
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-21    3,806       44     57,581      589
# 2020-05-22    3,906       47     61,487      636
# 2020-05-23    3,986       49     65,472      684
# 2020-05-24    4,044       50     69,516      735  <-- latest raw data
# 2020-05-25    4,079       52     73,596      787
# 2020-05-26    4,091       53     77,687      840
# 2020-05-27    4,079       54     81,766      894
# 2020-05-28    4,044       55     85,810      950
# 2020-05-29    3,986       56     89,796    1,005
# 2020-05-30    3,906       56     93,702    1,061

# %%
covid.Region(geoId='PE', dilation=2.5, d_cases=3).analyse()
# Out:
# Peru data to end of 2020-05-24:
#   119,959 cases, 3,456 deaths
#   3,750 cases per million, 108 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         35% through outbreak
#   Start:       2020-03-15 (-70 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-18 ( -6 days, 4,060 cases)
#   End:         2020-09-22 (122 days, 128 days after peak cases)
#   Day Zero:    2020-04-02 (-52 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-18 ( -6 days, 126 deaths)
#
# Parameters:
#   Totals:      108,769 cases and 3,148 deaths at end of 2020-05-21
#   Smoothed:    108,769 cases and 3,147 deaths at end of 2020-05-21 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-21, compared to 7 days earlier)
#   Growth:      64 days (Start -> Peak Cases)
#                X = 377,887, r = 5.11, L = 16,240, dilation = 3, c = 89.6% for cases
#   Lag:         0 days (Peak Cases -> Peak Deaths)
#                X = 9,554, r = 5.56, L = 505, dilation = 2.5, c = 89.4% for deaths
#
# Outcome: 365,757 total cases, 9,444 total deaths by end of 2020-09-22
#   31.7% of predicted cases and 36.2% of predicted deaths reported to date
#   96.8% of predicted cases and 98.8% of predicted deaths reported by end date
#   11,813 cases per million (1.18%), 299 deaths per million (0.030%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-11    1,515       72      68,822    1,961     3,183       92      70,907    1,990
# 2020-05-12    3,237       96      72,059    2,057     3,265       97      74,172    2,087
# 2020-05-13    4,247      112      76,306    2,169     3,391      102      77,563    2,189
# 2020-05-14    4,298       98      80,604    2,267     3,599      109      81,162    2,297
# 2020-05-15    3,891      126      84,495    2,393     3,764      119      84,926    2,416
# 2020-05-16    4,046      130      88,541    2,523     3,953      123      88,879    2,539
# 2020-05-17    3,732      125      92,273    2,648     3,995      123      92,874    2,662
# 2020-05-18    2,660      141      94,933    2,789     4,060      126      96,934    2,788
# 2020-05-19    4,550      125      99,483    2,914     3,921      122     100,855    2,910
# 2020-05-20    4,537      110     104,020    3,024     3,923      122     104,778    3,032
# 2020-05-21    4,749      124     108,769    3,148     3,991      116     108,769    3,148
# 2020-05-22    2,929       96     111,698    3,244
# 2020-05-23    4,056      129     115,754    3,373
# 2020-05-24    4,205       83     119,959    3,456
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-21    3,843      119    108,769    3,148
# 2020-05-22    3,838      119    112,607    3,267
# 2020-05-23    3,832      119    116,439    3,386
# 2020-05-24    3,824      118    120,263    3,504  <-- latest raw data
# 2020-05-25    3,816      118    124,079    3,622
# 2020-05-26    3,806      117    127,884    3,739
# 2020-05-27    3,794      117    131,678    3,855
# 2020-05-28    3,781      116    135,460    3,971
# 2020-05-29    3,768      115    139,227    4,087
# 2020-05-30    3,752      114    142,980    4,201

# %%
covid.Region(geoId='MX', growth_days=75, dilation=3).analyse()
# Out:
# Mexico data to end of 2020-05-24:
#   68,620 cases, 7,394 deaths
#   544 cases per million, 59 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         30% through outbreak
#   Start:       2020-03-15 (-70 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-29 (  5 days, 0 cases)
#   End:         2020-10-25 (155 days, 150 days after peak cases)
#   Day Zero:    2020-04-02 (-52 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-02 (  9 days)
#
# Parameters:
#   Totals:      59,567 cases and 6,510 deaths at end of 2020-05-21
#   Smoothed:    59,567 cases and 6,510 deaths at end of 2020-05-21 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.4 (2020-05-21, compared to 7 days earlier)
#   Growth:      75 days (Start -> Peak Cases)
#                X = 321,564, r = 5.38, L = 11,960, dilation = 3, c = 92.6% for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#                X = 42,067, r = 5.3, L = 1,521, dilation = 3, c = 91.9% for deaths
#
# Outcome: 312,871 total cases, 40,756 total deaths by end of 2020-10-25
#   21.3% of predicted cases and 17.6% of predicted deaths reported to date
#   97.3% of predicted cases and 96.9% of predicted deaths reported by end date
#   2,548 cases per million (0.25%), 333 deaths per million (0.033%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-11    1,305      108      36,327    3,573     1,845      219      36,586    3,773
# 2020-05-12    1,997      353      38,324    3,926     1,920      232      38,506    4,005
# 2020-05-13    1,862      294      40,186    4,220     1,945      244      40,451    4,249
# 2020-05-14    2,409      257      42,595    4,477     2,018      247      42,468    4,495
# 2020-05-15    2,437      290      45,032    4,767     2,175      254      44,643    4,749
# 2020-05-16    2,112      278      47,144    5,045     2,277      251      46,920    5,000
# 2020-05-17    2,075      132      49,219    5,177     2,332      270      49,252    5,269
# 2020-05-18    2,414      155      51,633    5,332     2,412      293      51,664    5,562
# 2020-05-19    2,713      334      54,346    5,666     2,486      320      54,151    5,883
# 2020-05-20    2,248      424      56,594    6,090     2,659      308      56,810    6,190
# 2020-05-21    2,973      420      59,567    6,510     2,757      320      59,567    6,510
# 2020-05-22    2,960      479      62,527    6,989
# 2020-05-23    3,329      190      65,856    7,179
# 2020-05-24    2,764      215      68,620    7,394
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-21    2,701      318     59,567    6,510
# 2020-05-22    2,753      327     62,320    6,837
# 2020-05-23    2,798      335     65,118    7,171
# 2020-05-24    2,837      343     67,955    7,514  <-- latest raw data
# 2020-05-25    2,870      350     70,825    7,864
# 2020-05-26    2,896      356     73,721    8,220
# 2020-05-27    2,915      362     76,636    8,582
# 2020-05-28    2,926      367     79,561    8,949
# 2020-05-29    2,929      371     82,491    9,320
# 2020-05-30    2,929      374     85,420    9,694

# %%
covid.Region(geoId='CN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2020-05-24:
#   84,095 cases, 4,638 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-130 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-104 days, 4,690 cases)
#   End:         2020-03-06 (-78 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-120 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-99 days, 128 deaths)
#
# Parameters:
#   Totals:      84,079 cases and 4,638 deaths at end of 2020-05-21
#   Smoothed:    84,079 cases and 4,637 deaths at end of 2020-05-21 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-21, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
#                X = 80,834, r = 5.02, L = 18,758, dilation = 0.7, c = 84.1% for cases
#   Lag:         5 days (Peak Cases -> Peak Deaths)
#                X = 3,210, r = 4.05, L = 510, dilation = 1, c = 94.8% for deaths
#
# Outcome: 80,814 total cases, 3,099 total deaths at end of 2020-03-07
#   58 cases per million (0.01%), 2 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-11        1        0      84,011    4,637         8        0      84,011    4,637
# 2020-05-12        7        0      84,018    4,637         9        0      84,020    4,637
# 2020-05-13        6        0      84,024    4,637         8    < 0.5      84,028    4,637
# 2020-05-14        5        0      84,029    4,637         6    < 0.5      84,034    4,637
# 2020-05-15        9        0      84,038    4,637         7    < 0.5      84,041    4,637
# 2020-05-16        6        1      84,044    4,638         7    < 0.5      84,048    4,638
# 2020-05-17       10        0      84,054    4,638         6    < 0.5      84,054    4,638
# 2020-05-18        9        0      84,063    4,638         7    < 0.5      84,061    4,638
# 2020-05-19        2        0      84,065    4,638         6    < 0.5      84,067    4,638
# 2020-05-20        2        0      84,067    4,638         6        0      84,073    4,638
# 2020-05-21       12        0      84,079    4,638         6        0      84,079    4,638
# 2020-05-22        2        0      84,081    4,638
# 2020-05-23        3        0      84,084    4,638
# 2020-05-24       11        0      84,095    4,638
#
#   ** first wave ended **

# %%
covid.Region(geoId='KR', dilation=3, d_cases=1).analyse(ylog=1)
# Out:
# South Korea data to end of 2020-05-24:
#   11,206 cases, 267 deaths
#   217 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-97 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-83 days, 609 cases)
#   End:         2020-03-15 (-69 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-77 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-69 days, 5 deaths)
#
# Parameters:
#   Totals:      11,142 cases and 264 deaths at end of 2020-05-21
#   Smoothed:    11,142 cases and 264 deaths at end of 2020-05-21 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-21, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
#                X = 8,493, r = 4.03, L = 2,434, dilation = 1, c = 93.3% for cases
#   Lag:         14 days (Peak Cases -> Peak Deaths)
#                X = 165, r = 4.0, L = 18, dilation = 3, c = 80.7% for deaths
#
# Outcome: 8,320 total cases, 81 total deaths at end of 2020-03-16
#   161 cases per million (0.02%), 2 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-11       27        2      10,936      258        28        1      10,930      257
# 2020-05-12       26        1      10,962      259        28        1      10,958      258
# 2020-05-13       29        1      10,991      260        25        1      10,983      259
# 2020-05-14       27        0      11,018      260        22        1      11,006      260
# 2020-05-15       19        2      11,037      262        20        1      11,026      261
# 2020-05-16       13        0      11,050      262        21        1      11,047      261
# 2020-05-17       15        1      11,065      263        19        1      11,066      262
# 2020-05-18       13        0      11,078      263        18        1      11,084      262
# 2020-05-19       32        0      11,110      263        18        1      11,102      263
# 2020-05-20       12        1      11,122      264        20        1      11,122      263
# 2020-05-21       20        0      11,142      264        20        1      11,142      264
# 2020-05-22       23        2      11,165      266
# 2020-05-23       25        0      11,190      266
# 2020-05-24       16        1      11,206      267
#
#   ** first wave ended **

# %%
covid.Region(geoId='NZ', dilation=3.1).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-05-24:
#   1,154 cases, 21 deaths
#   236 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-65 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-58 days, 72 cases)
#   End:         2020-04-09 (-44 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,154 cases and 21 deaths at end of 2020-05-21
#   Smoothed:    1,153 cases and 21 deaths at end of 2020-05-21 (7 points)
#   Spread:      Peak infection rate 2.5 (2020-05-21, compared to 7 days earlier)
#                Latest infection rate 2.5 (2020-05-21, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,106, r = 4.0, L = 288, dilation = 3.1, c = 89.2% for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
#   212 cases per million (0.02%), 1 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-11        0        0       1,147       21         1        0       1,146       21
# 2020-05-12        0        0       1,147       21         1        0       1,147       21
# 2020-05-13        0        0       1,147       21         1        0       1,148       21
# 2020-05-14        1        0       1,148       21     < 0.5        0       1,148       21
# 2020-05-15        0        0       1,148       21         1        0       1,149       21
# 2020-05-16        1        0       1,149       21         1        0       1,150       21
# 2020-05-17        0        0       1,149       21         1        0       1,151       21
# 2020-05-18        4        0       1,153       21         1        0       1,152       21
# 2020-05-19        0        0       1,153       21         1        0       1,153       21
# 2020-05-20        0        0       1,153       21         1        0       1,153       21
# 2020-05-21        1        0       1,154       21         1        0       1,154       21
# 2020-05-22        0        0       1,154       21
# 2020-05-23        0        0       1,154       21
# 2020-05-24        0        0       1,154       21
#
#   ** first wave ended **

# %%
covid.Region(geoId='AU').analyse(ylog=1)
# Out:
# Australia data to end of 2020-05-24:
#   7,109 cases, 102 deaths
#   284 cases per million, 4 deaths per million (2018 population = 24,992,369)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-04 (-81 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-58 days, 390 cases)
#   End:         2020-04-18 (-35 days, 23 days after peak cases)
#   Day Zero:    2020-04-09 (-45 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-48 days, 4 deaths)
#
# Parameters:
#   Totals:      7,081 cases and 100 deaths at end of 2020-05-21
#   Smoothed:    7,080 cases and 100 deaths at end of 2020-05-21 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-21, compared to 7 days earlier)
#   Growth:      23 days (Start -> Peak Cases)
#                X = 6,616, r = 5.48, L = 1,561, dilation = 1, c = 87.6% for cases
#   Lag:         10 days (Peak Cases -> Peak Deaths)
#                X = 73, r = 5.16, L = 16, dilation = 1, c = 85.4% for deaths
#
# Outcome: 6,612 total cases, 70 total deaths at end of 2020-04-19
#   265 cases per million (0.03%), 3 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-11        7        0       6,948       97        13    < 0.5       6,947       97
# 2020-05-12       16        0       6,964       97        15    < 0.5       6,962       97
# 2020-05-13       11        1       6,975       98        15    < 0.5       6,977       97
# 2020-05-14       14        0       6,989       98        15    < 0.5       6,992       97
# 2020-05-15       30        0       7,019       98        16    < 0.5       7,008       98
# 2020-05-16       17        0       7,036       98        15    < 0.5       7,023       98
# 2020-05-17        9        0       7,045       98        15    < 0.5       7,038       98
# 2020-05-18       15        1       7,060       99        13    < 0.5       7,051       98
# 2020-05-19        8        0       7,068       99        11    < 0.5       7,062       99
# 2020-05-20       11        1       7,079      100        10        1       7,072       99
# 2020-05-21        2        0       7,081      100         9        1       7,081      100
# 2020-05-22       14        1       7,095      101
# 2020-05-23       11        1       7,106      102
# 2020-05-24        3        0       7,109      102
#
#   ** first wave ended **
