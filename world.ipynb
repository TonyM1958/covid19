# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://coronavirus.data.gov.uk/">coronavirus.data.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='CN').analyse(ylog=1)
# Out:
# China data to end of 2020-05-05:
#   83,968 cases, 4,637 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-111 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-85 days, 4,690 cases)
#   End:         2020-03-06 (-59 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-101 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-80 days, 128 deaths)
#
# Parameters:
#   Totals:      83,961 cases and 4,637 deaths at end of 2020-05-02
#   Smoothed:    83,960 cases and 4,637 deaths at end of 2020-05-02 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.4 (2020-05-02, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='KR').analyse(ylog=0)
# Out:
# South Korea data to end of 2020-05-05:
#   10,806 cases, 255 deaths
#   209 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-78 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-64 days, 609 cases)
#   End:         2020-03-15 (-50 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-58 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-04 (-62 days, 5 deaths)
#
# Parameters:
#   Totals:      10,793 cases and 250 deaths at end of 2020-05-02
#   Smoothed:    10,793 cases and 250 deaths at end of 2020-05-02 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-02, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZ', dilation=3).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-05-05:
#   1,138 cases, 21 deaths
#   233 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-46 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-39 days, 72 cases)
#   End:         2020-04-09 (-25 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,136 cases and 20 deaths at end of 2020-05-02
#   Smoothed:    1,136 cases and 20 deaths at end of 2020-05-02 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-02, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,100, r = 4.0, L = 288, dilation = 3 for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
# ...

# %%
covid.Region(geoId='US', dilation=1.7, d_cases=4).analyse()
# Out:
# United States of America data to end of 2020-05-05:
#   1,204,475 cases, 71,078 deaths
#   3,682 cases per million, 217 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         53% through outbreak
#   Start:       2020-02-25 (-70 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-28 days, 32,111 cases)
#   End:         2020-06-29 ( 56 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-53 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-17 days, 2,724 deaths)
#
# Parameters:
#   Totals:      1,133,069 cases and 66,385 deaths at end of 2020-05-02
#   Smoothed:    1,133,069 cases and 66,385 deaths at end of 2020-05-02 (7 points)
#   Spread:      Peak infection rate 12.5 (2020-03-07, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-02, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RU', growth_days=55, lag=3).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-05:
#   155,370 cases, 1,451 deaths
#   1,075 cases per million, 10 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         45% through outbreak
#   Start:       2020-03-14 (-52 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-08 (  3 days, --- cases)
#   End:         2020-07-01 ( 58 days, 55 days after peak cases)
#   Day Zero:    2020-04-06 (-29 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-11 (  6 days)
#
# Parameters:
#   Totals:      124,054 cases and 1,222 deaths at end of 2020-05-02
#   Smoothed:    124,054 cases and 1,222 deaths at end of 2020-05-02 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.5 (2020-05-02, compared to 7 days earlier)
#   Growth:      55 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP', dilation=2, d_cases=1.4).analyse()
# Out:
# Japan data to end of 2020-05-05:
#   15,354 cases, 543 deaths
#   121 cases per million, 4 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         56% through outbreak
#   Start:       2020-02-16 (-79 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-22 days, 646 cases)
#   End:         2020-06-30 ( 57 days, 79 days after peak cases)
#   Day Zero:    2020-03-27 (-39 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-10 days, 30 deaths)
#
# Parameters:
#   Totals:      14,839 cases and 492 deaths at end of 2020-05-02
#   Smoothed:    14,839 cases and 491 deaths at end of 2020-05-02 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-02, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SG', dilation=3).analyse()
# Out:
# Singapore data to end of 2020-05-05:
#   19,410 cases, 18 deaths
#   3,442 cases per million, 3 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         38% through outbreak
#   Start:       2020-02-12 (-83 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-12 days, 1,005 cases)
#   End:         2020-09-11 (130 days, 142 days after peak cases)
#
# Parameters:
#   Totals:      17,548 cases and 17 deaths at end of 2020-05-02
#   Smoothed:    17,548 cases and 16 deaths at end of 2020-05-02 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-02, compared to 7 days earlier)
#   Growth:      71 days (Start -> Peak Cases)
#                X = 45,783, r = 8.0, L = 4,020, dilation = 3 for cases
#
# Outcome: 45,563 total cases, 59 total deaths by end of 2020-09-11
# ...

# %%
covid.Region(geoId='BR', growth_days=51).analyse()
# Out:
# Brazil data to end of 2020-05-05:
#   114,715 cases, 7,921 deaths
#   548 cases per million, 38 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         50% through outbreak
#   Start:       2020-03-11 (-55 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-02 ( -3 days, 6,124 cases)
#   End:         2020-06-22 ( 49 days, 52 days after peak cases)
#   Day Zero:    2020-03-24 (-42 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-06 (  1 days)
#
# Parameters:
#   Totals:      96,559 cases and 6,750 deaths at end of 2020-05-02
#   Smoothed:    96,559 cases and 6,749 deaths at end of 2020-05-02 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.5 (2020-05-02, compared to 7 days earlier)
#   Growth:      52 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MX', lag=6, dilation=2).analyse()
# Out:
# Mexico data to end of 2020-05-05:
#   26,025 cases, 2,507 deaths
#   206 cases per million, 20 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         34% through outbreak
#   Start:       2020-03-15 (-51 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-01 ( -4 days, 1,343 cases)
#   End:         2020-08-02 ( 90 days, 94 days after peak cases)
#   Day Zero:    2020-04-02 (-33 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-07 (  2 days)
#
# Parameters:
#   Totals:      22,088 cases and 2,061 deaths at end of 2020-05-02
#   Smoothed:    22,087 cases and 2,061 deaths at end of 2020-05-02 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-02, compared to 7 days earlier)
#   Growth:      47 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='PE', growth_days=49, dilation=2.5).analyse()
# Out:
# Peru data to end of 2020-05-05:
#   51,189 cases, 1,444 deaths
#   1,600 cases per million, 45 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-15 (-51 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-03 ( -2 days, --- cases)
#   End:         2020-08-08 ( 96 days, 98 days after peak cases)
#   Day Zero:    2020-04-02 (-33 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-02 ( -3 days, 84 deaths)
#
# Parameters:
#   Totals:      42,534 cases and 1,200 deaths at end of 2020-05-02
#   Smoothed:    42,534 cases and 1,199 deaths at end of 2020-05-02 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.5 (2020-05-02, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...
