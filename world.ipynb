# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://coronavirus.data.gov.uk/">coronavirus.data.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='CN').analyse(ylog=1)
# Out:
# China data to end of 2020-05-06:
#   83,970 cases, 4,637 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-112 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-86 days, 4,690 cases)
#   End:         2020-03-06 (-60 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-102 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-81 days, 128 deaths)
#
# Parameters:
#   Totals:      83,964 cases and 4,637 deaths at end of 2020-05-03
#   Smoothed:    83,964 cases and 4,637 deaths at end of 2020-05-03 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.4 (2020-05-03, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='KR').analyse(ylog=0)
# Out:
# South Korea data to end of 2020-05-06:
#   10,810 cases, 256 deaths
#   209 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-79 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-65 days, 609 cases)
#   End:         2020-03-15 (-51 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-59 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-51 days, 5 deaths)
#
# Parameters:
#   Totals:      10,801 cases and 252 deaths at end of 2020-05-03
#   Smoothed:    10,801 cases and 252 deaths at end of 2020-05-03 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-03, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZ', dilation=3).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-05-06:
#   1,139 cases, 21 deaths
#   233 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-47 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-40 days, 72 cases)
#   End:         2020-04-09 (-26 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,137 cases and 20 deaths at end of 2020-05-03
#   Smoothed:    1,137 cases and 20 deaths at end of 2020-05-03 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-03, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,100, r = 4.0, L = 288, dilation = 3 for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
# ...

# %%
covid.Region(geoId='US', dilation=2.2, d_cases=4).analyse()
# Out:
# United States of America data to end of 2020-05-06:
#   1,228,603 cases, 73,431 deaths
#   3,755 cases per million, 224 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         54% through outbreak
#   Start:       2020-02-25 (-71 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-29 days, 32,052 cases)
#   End:         2020-06-29 ( 55 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-54 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-18 days, 2,705 deaths)
#
# Parameters:
#   Totals:      1,158,041 cases and 67,682 deaths at end of 2020-05-03
#   Smoothed:    1,158,041 cases and 67,681 deaths at end of 2020-05-03 (7 points)
#   Spread:      Peak infection rate 12.5 (2020-03-07, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-03, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RU', growth_days=57, lag=3).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-06:
#   165,929 cases, 1,537 deaths
#   1,148 cases per million, 11 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         44% through outbreak
#   Start:       2020-03-14 (-53 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-10 (  4 days, 0 cases)
#   End:         2020-07-05 ( 61 days, 57 days after peak cases)
#   Day Zero:    2020-04-06 (-30 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-13 (  7 days)
#
# Parameters:
#   Totals:      134,687 cases and 1,280 deaths at end of 2020-05-03
#   Smoothed:    134,687 cases and 1,280 deaths at end of 2020-05-03 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.6 (2020-05-03, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP', dilation=1.8, d_cases=1.4).analyse()
# Out:
# Japan data to end of 2020-05-06:
#   15,463 cases, 551 deaths
#   122 cases per million, 4 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         57% through outbreak
#   Start:       2020-02-16 (-80 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-23 days, 647 cases)
#   End:         2020-06-30 ( 56 days, 79 days after peak cases)
#   Day Zero:    2020-03-27 (-40 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-11 days, 30 deaths)
#
# Parameters:
#   Totals:      15,057 cases and 510 deaths at end of 2020-05-03
#   Smoothed:    15,057 cases and 509 deaths at end of 2020-05-03 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-03, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SG', dilation=3).analyse()
# Out:
# Singapore data to end of 2020-05-06:
#   20,198 cases, 20 deaths
#   3,582 cases per million, 4 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         38% through outbreak
#   Start:       2020-02-11 (-85 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-13 days, 1,005 cases)
#   End:         2020-09-13 (131 days, 144 days after peak cases)
#
# Parameters:
#   Totals:      18,205 cases and 18 deaths at end of 2020-05-03
#   Smoothed:    18,205 cases and 17 deaths at end of 2020-05-03 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-03, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                X = 46,095, r = 8.0, L = 4,021, dilation = 3 for cases
#
# Outcome: 45,874 total cases, 68 total deaths by end of 2020-09-13
# ...

# %%
covid.Region(geoId='BR', growth_days=56, dilation=2).analyse()
# Out:
# Brazil data to end of 2020-05-06:
#   125,218 cases, 8,536 deaths
#   598 cases per million, 41 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         32% through outbreak
#   Start:       2020-03-11 (-56 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-06 (  0 days, --- cases)
#   End:         2020-08-25 (112 days, 112 days after peak cases)
#   Day Zero:    2020-03-25 (-42 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-03 ( -3 days, 433 deaths)
#
# Parameters:
#   Totals:      101,147 cases and 7,025 deaths at end of 2020-05-03
#   Smoothed:    101,147 cases and 7,024 deaths at end of 2020-05-03 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.5 (2020-05-03, compared to 7 days earlier)
#   Growth:      56 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MX', growth_days=51, dilation=2).analyse()
# Out:
# Mexico data to end of 2020-05-06:
#   27,634 cases, 2,704 deaths
#   219 cases per million, 21 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         32% through outbreak
#   Start:       2020-03-15 (-52 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-05 ( -1 days, --- cases)
#   End:         2020-08-14 (101 days, 102 days after peak cases)
#   Day Zero:    2020-04-02 (-34 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-03 ( -3 days, 135 deaths)
#
# Parameters:
#   Totals:      23,471 cases and 2,154 deaths at end of 2020-05-03
#   Smoothed:    23,471 cases and 2,154 deaths at end of 2020-05-03 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.4 (2020-05-03, compared to 7 days earlier)
#   Growth:      51 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='PE', growth_days=50, dilation=2.5).analyse()
# Out:
# Peru data to end of 2020-05-06:
#   54,817 cases, 1,533 deaths
#   1,714 cases per million, 48 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-15 (-52 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-04 ( -2 days, --- cases)
#   End:         2020-08-11 ( 98 days, 100 days after peak cases)
#   Day Zero:    2020-04-02 (-34 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-02 ( -4 days, 84 deaths)
#
# Parameters:
#   Totals:      45,928 cases and 1,286 deaths at end of 2020-05-03
#   Smoothed:    45,928 cases and 1,286 deaths at end of 2020-05-03 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.4 (2020-05-03, compared to 7 days earlier)
#   Growth:      50 days (Start -> Peak Cases)
# ...
