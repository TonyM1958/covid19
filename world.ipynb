# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://coronavirus.data.gov.uk/">coronavirus.data.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='CN').analyse(ylog=1)
# Out:
# China data to end of 2020-05-08:
#   83,976 cases, 4,637 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-114 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-88 days, 4,689 cases)
#   End:         2020-03-06 (-62 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-104 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-83 days, 128 deaths)
#
# Parameters:
#   Totals:      83,968 cases and 4,637 deaths at end of 2020-05-05
#   Smoothed:    83,968 cases and 4,637 deaths at end of 2020-05-05 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.3 (2020-05-05, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='KR').analyse(ylog=0)
# Out:
# South Korea data to end of 2020-05-08:
#   10,840 cases, 256 deaths
#   210 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-81 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-67 days, 609 cases)
#   End:         2020-03-15 (-53 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-61 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-53 days, 5 deaths)
#
# Parameters:
#   Totals:      10,806 cases and 255 deaths at end of 2020-05-05
#   Smoothed:    10,806 cases and 255 deaths at end of 2020-05-05 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-05, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZ', dilation=3).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-05-08:
#   1,142 cases, 21 deaths
#   234 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-49 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-42 days, 72 cases)
#   End:         2020-04-09 (-28 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,138 cases and 21 deaths at end of 2020-05-05
#   Smoothed:    1,137 cases and 21 deaths at end of 2020-05-05 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-05, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,098, r = 4.0, L = 288, dilation = 3 for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
# ...

# %%
covid.Region(geoId='US', dilation=3.5, d_cases=5).analyse()
# Out:
# United States of America data to end of 2020-05-08:
#   1,283,929 cases, 77,180 deaths
#   3,924 cases per million, 236 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         56% through outbreak
#   Start:       2020-02-25 (-73 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-31 days, 31,888 cases)
#   End:         2020-06-29 ( 53 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-56 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-20 days, 2,700 deaths)
#
# Parameters:
#   Totals:      1,204,475 cases and 71,078 deaths at end of 2020-05-05
#   Smoothed:    1,204,474 cases and 71,078 deaths at end of 2020-05-05 (7 points)
#   Spread:      Peak infection rate 11.5 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-05, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RU', growth_days=57, lag=3).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-08:
#   187,859 cases, 1,723 deaths
#   1,300 cases per million, 12 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         46% through outbreak
#   Start:       2020-03-14 (-55 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-10 (  2 days, --- cases)
#   End:         2020-07-05 ( 59 days, 57 days after peak cases)
#   Day Zero:    2020-04-06 (-32 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-13 (  5 days)
#
# Parameters:
#   Totals:      155,370 cases and 1,451 deaths at end of 2020-05-05
#   Smoothed:    155,369 cases and 1,451 deaths at end of 2020-05-05 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.6 (2020-05-05, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP', dilation=1.5, d_cases=1.3).analyse()
# Out:
# Japan data to end of 2020-05-08:
#   15,628 cases, 601 deaths
#   124 cases per million, 5 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         60% through outbreak
#   Start:       2020-02-16 (-82 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-25 days, 645 cases)
#   End:         2020-06-25 ( 49 days, 74 days after peak cases)
#   Day Zero:    2020-03-28 (-41 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-13 days, 29 deaths)
#
# Parameters:
#   Totals:      15,354 cases and 543 deaths at end of 2020-05-05
#   Smoothed:    15,354 cases and 543 deaths at end of 2020-05-05 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-05, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SG', dilation=3.3).analyse()
# Out:
# Singapore data to end of 2020-05-08:
#   21,707 cases, 20 deaths
#   3,850 cases per million, 4 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         39% through outbreak
#   Start:       2020-02-12 (-86 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-15 days, 998 cases)
#   End:         2020-09-11 (127 days, 142 days after peak cases)
#
# Parameters:
#   Totals:      19,410 cases and 18 deaths at end of 2020-05-05
#   Smoothed:    19,410 cases and 17 deaths at end of 2020-05-05 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-05, compared to 7 days earlier)
#   Growth:      71 days (Start -> Peak Cases)
#                X = 49,071, r = 8.0, L = 3,993, dilation = 3.3 for cases
#
# Outcome: 48,689 total cases, 66 total deaths by end of 2020-09-11
# ...

# %%
covid.Region(geoId='BR', growth_days=65, dilation=2.5).analyse()
# Out:
# Brazil data to end of 2020-05-08:
#   145,328 cases, 9,897 deaths
#   694 cases per million, 47 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         28% through outbreak
#   Start:       2020-03-11 (-58 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-15 (  7 days, 0 cases)
#   End:         2020-09-21 (137 days, 130 days after peak cases)
#   Day Zero:    2020-03-25 (-44 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-19 ( 11 days)
#
# Parameters:
#   Totals:      114,715 cases and 7,921 deaths at end of 2020-05-05
#   Smoothed:    114,715 cases and 7,920 deaths at end of 2020-05-05 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.4 (2020-05-05, compared to 7 days earlier)
#   Growth:      65 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MX', growth_days=55, dilation=2.5).analyse()
# Out:
# Mexico data to end of 2020-05-08:
#   31,522 cases, 3,160 deaths
#   250 cases per million, 25 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         31% through outbreak
#   Start:       2020-03-15 (-54 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 (  1 days, --- cases)
#   End:         2020-08-26 (111 days, 110 days after peak cases)
#   Day Zero:    2020-04-02 (-36 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-05 ( -3 days, 167 deaths)
#
# Parameters:
#   Totals:      26,025 cases and 2,507 deaths at end of 2020-05-05
#   Smoothed:    26,024 cases and 2,506 deaths at end of 2020-05-05 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.4 (2020-05-05, compared to 7 days earlier)
#   Growth:      55 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='PE', growth_days=55, dilation=2.5).analyse()
# Out:
# Peru data to end of 2020-05-08:
#   61,847 cases, 1,714 deaths
#   1,933 cases per million, 54 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         34% through outbreak
#   Start:       2020-03-15 (-54 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-04 ( -4 days, 3,046 cases)
#   End:         2020-08-11 ( 96 days, 100 days after peak cases)
#   Day Zero:    2020-04-02 (-36 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-02 ( -6 days, 84 deaths)
#
# Parameters:
#   Totals:      51,189 cases and 1,444 deaths at end of 2020-05-05
#   Smoothed:    51,189 cases and 1,444 deaths at end of 2020-05-05 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-05, compared to 7 days earlier)
#   Growth:      50 days (Start -> Peak Cases)
# ...
