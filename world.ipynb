# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='CN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2020-05-22:
#   84,081 cases, 4,638 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-128 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-102 days, 4,690 cases)
#   End:         2020-03-06 (-76 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-118 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-97 days, 128 deaths)
#
# Parameters:
#   Totals:      84,065 cases and 4,638 deaths at end of 2020-05-19
#   Smoothed:    84,065 cases and 4,637 deaths at end of 2020-05-19 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-19, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
#                X = 80,831, r = 5.02, L = 18,758, dilation = 0.7, c = 84.1% for cases
#   Lag:         5 days (Peak Cases -> Peak Deaths)
#                X = 3,210, r = 4.05, L = 510, dilation = 1, c = 94.8% for deaths
#
# Outcome: 80,814 total cases, 3,099 total deaths at end of 2020-03-07
#   58 cases per million (0.01%), 2 deaths per million (0.000%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-09       15        0      83,991    4,637         7        0      83,993    4,637
# 2020-05-10       19        0      84,010    4,637         8        0      84,001    4,637
# 2020-05-11        1        0      84,011    4,637         8        0      84,009    4,637
# 2020-05-12        7        0      84,018    4,637         9        0      84,018    4,637
# 2020-05-13        6        0      84,024    4,637         8    < 0.5      84,025    4,637
# 2020-05-14        5        0      84,029    4,637         6    < 0.5      84,031    4,637
# 2020-05-15        9        0      84,038    4,637         7    < 0.5      84,039    4,637
# 2020-05-16        6        1      84,044    4,638         7    < 0.5      84,046    4,638
# 2020-05-17       10        0      84,054    4,638         6    < 0.5      84,052    4,638
# 2020-05-18        9        0      84,063    4,638         7    < 0.5      84,059    4,638
# 2020-05-19        2        0      84,065    4,638         6    < 0.5      84,065    4,638
# 2020-05-20        2        0      84,067    4,638
# 2020-05-21       12        0      84,079    4,638
# 2020-05-22        2        0      84,081    4,638

# %%
covid.Region(geoId='KR', dilation=3, d_cases=1).analyse(ylog=1)
# Out:
# South Korea data to end of 2020-05-22:
#   11,165 cases, 266 deaths
#   216 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-95 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-81 days, 609 cases)
#   End:         2020-03-15 (-67 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-75 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-67 days, 5 deaths)
#
# Parameters:
#   Totals:      11,110 cases and 263 deaths at end of 2020-05-19
#   Smoothed:    11,110 cases and 263 deaths at end of 2020-05-19 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-19, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
#                X = 8,500, r = 4.03, L = 2,436, dilation = 1, c = 93.3% for cases
#   Lag:         14 days (Peak Cases -> Peak Deaths)
#                X = 165, r = 4.0, L = 18, dilation = 3, c = 80.6% for deaths
#
# Outcome: 8,320 total cases, 81 total deaths at end of 2020-03-16
#   161 cases per million (0.02%), 2 deaths per million (0.000%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-09       34        0      10,874      256        22        1      10,884      256
# 2020-05-10       35        0      10,909      256        26        1      10,910      257
# 2020-05-11       27        2      10,936      258        28        1      10,938      257
# 2020-05-12       26        1      10,962      259        28        1      10,966      258
# 2020-05-13       29        1      10,991      260        25        1      10,992      259
# 2020-05-14       27        0      11,018      260        22        1      11,014      260
# 2020-05-15       19        2      11,037      262        20        1      11,034      261
# 2020-05-16       13        0      11,050      262        21        1      11,055      261
# 2020-05-17       15        1      11,065      263        19        1      11,074      262
# 2020-05-18       13        0      11,078      263        18        1      11,092      262
# 2020-05-19       32        0      11,110      263        18        1      11,110      263
# 2020-05-20       12        1      11,122      264
# 2020-05-21       20        0      11,142      264
# 2020-05-22       23        2      11,165      266

# %%
covid.Region(geoId='NZ', dilation=3.1).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-05-22:
#   1,154 cases, 21 deaths
#   236 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-63 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-56 days, 72 cases)
#   End:         2020-04-09 (-42 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,153 cases and 21 deaths at end of 2020-05-19
#   Smoothed:    1,152 cases and 21 deaths at end of 2020-05-19 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-19, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,106, r = 4.0, L = 288, dilation = 3.1, c = 89.2% for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
#   212 cases per million (0.02%), 1 deaths per million (0.000%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-09        2        0       1,144       21         1        0       1,145       21
# 2020-05-10        3        0       1,147       21         1        0       1,146       21
# 2020-05-11        0        0       1,147       21         1        0       1,147       21
# 2020-05-12        0        0       1,147       21         1        0       1,148       21
# 2020-05-13        0        0       1,147       21         1        0       1,148       21
# 2020-05-14        1        0       1,148       21     < 0.5        0       1,149       21
# 2020-05-15        0        0       1,148       21         1        0       1,150       21
# 2020-05-16        1        0       1,149       21         1        0       1,150       21
# 2020-05-17        0        0       1,149       21         1        0       1,151       21
# 2020-05-18        4        0       1,153       21         1        0       1,152       21
# 2020-05-19        0        0       1,153       21         1        0       1,153       21
# 2020-05-20        0        0       1,153       21
# 2020-05-21        1        0       1,154       21
# 2020-05-22        0        0       1,154       21

# %%
covid.Region(geoId='AU').analyse(ylog=1)
# Out:
# Australia data to end of 2020-05-22:
#   7,095 cases, 101 deaths
#   284 cases per million, 4 deaths per million (2018 population = 24,992,369)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-04 (-79 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-56 days, 391 cases)
#   End:         2020-04-18 (-33 days, 23 days after peak cases)
#   Day Zero:    2020-04-09 (-43 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-46 days, 4 deaths)
#
# Parameters:
#   Totals:      7,068 cases and 99 deaths at end of 2020-05-19
#   Smoothed:    7,067 cases and 99 deaths at end of 2020-05-19 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-19, compared to 7 days earlier)
#   Growth:      23 days (Start -> Peak Cases)
#                X = 6,622, r = 5.48, L = 1,562, dilation = 1, c = 87.6% for cases
#   Lag:         10 days (Peak Cases -> Peak Deaths)
#                X = 73, r = 5.16, L = 16, dilation = 1, c = 85.2% for deaths
#
# Outcome: 6,612 total cases, 70 total deaths at end of 2020-04-19
#   265 cases per million (0.03%), 3 deaths per million (0.000%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-09       15        0       6,929       97        16    < 0.5       6,926       97
# 2020-05-10       12        0       6,941       97        14    < 0.5       6,940       97
# 2020-05-11        7        0       6,948       97        13    < 0.5       6,953       97
# 2020-05-12       16        0       6,964       97        15    < 0.5       6,968       97
# 2020-05-13       11        1       6,975       98        15    < 0.5       6,983       97
# 2020-05-14       14        0       6,989       98        15    < 0.5       6,998       97
# 2020-05-15       30        0       7,019       98        16    < 0.5       7,014       98
# 2020-05-16       17        0       7,036       98        15    < 0.5       7,029       98
# 2020-05-17        9        0       7,045       98        15    < 0.5       7,044       98
# 2020-05-18       15        1       7,060       99        13    < 0.5       7,057       99
# 2020-05-19        8        0       7,068       99        11    < 0.5       7,068       99
# 2020-05-20       11        1       7,079      100
# 2020-05-21        2        0       7,081      100
# 2020-05-22       14        1       7,095      101

# %%
covid.Region(geoId='US', dilation=3.5, d_cases=8).analyse()
# Out:
# United States of America data to end of 2020-05-22:
#   1,601,434 cases, 96,007 deaths
#   4,895 cases per million, 293 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         67% through outbreak
#   Start:       2020-02-25 (-87 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-45 days, 31,875 cases)
#   End:         2020-06-29 ( 39 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-70 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-34 days, 2,710 deaths)
#
# Parameters:
#   Totals:      1,528,568 cases and 91,921 deaths at end of 2020-05-19
#   Smoothed:    1,528,567 cases and 91,921 deaths at end of 2020-05-19 (7 points)
#   Spread:      Peak infection rate 11.5 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-19, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
#                X = 2,700,017, r = 7.27, L = 127,501, dilation = 8, c = 89.1% for cases
#   Lag:         11 days (Peak Cases -> Peak Deaths)
#                X = 126,591, r = 6.92, L = 10,838, dilation = 3.5, c = 75.7% for deaths
#
# Outcome: 2,322,377 total cases, 122,648 total deaths by end of 2020-06-29
#   59.3% of predicted cases and 75.8% of predicted deaths reported to date
#   86.0% of predicted cases and 96.9% of predicted deaths reported by end date
#   8,253 cases per million (0.83%), 387 deaths per million (0.039%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-09   25,612    1,614   1,309,541   78,794    23,592    1,612   1,301,093   78,082
# 2020-05-10   20,258      734   1,329,799   79,528    23,115    1,526   1,324,208   79,608
# 2020-05-11   18,117    1,156   1,347,916   80,684    22,940    1,459   1,347,148   81,068
# 2020-05-12   22,048    1,703   1,369,964   82,387    22,734    1,481   1,369,882   82,549
# 2020-05-13   20,782    1,746   1,390,746   84,133    22,573    1,420   1,392,455   83,969
# 2020-05-14   27,143    1,773   1,417,889   85,906    22,376    1,431   1,414,831   85,399
# 2020-05-15   25,508    1,662   1,443,397   87,568    22,907    1,379   1,437,737   86,778
# 2020-05-16   24,487    1,186   1,467,884   88,754    22,610    1,359   1,460,348   88,137
# 2020-05-17   18,873      808   1,486,757   89,562    22,967    1,327   1,483,315   89,464
# 2020-05-18   21,841      791   1,508,598   90,353    22,724    1,254   1,506,038   90,718
# 2020-05-19   19,970    1,568   1,528,568   91,921    22,530    1,203   1,528,568   91,921
# 2020-05-20   23,285    1,518   1,551,853   93,439
# 2020-05-21   25,434    1,263   1,577,287   94,702
# 2020-05-22   24,147    1,305   1,601,434   96,007
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-19   24,413    1,446  1,528,568   91,921
# 2020-05-20   24,188    1,404  1,552,756   93,325
# 2020-05-21   23,959    1,362  1,576,715   94,687
# 2020-05-22   23,729    1,320  1,600,444   96,007  <-- latest raw data
# 2020-05-23   23,496    1,279  1,623,940   97,286
# 2020-05-24   23,262    1,239  1,647,202   98,525
# 2020-05-25   23,025    1,199  1,670,227   99,724
# 2020-05-26   22,787    1,160  1,693,013  100,883
# 2020-05-27   22,547    1,121  1,715,560  102,004
# 2020-05-28   22,306    1,083  1,737,866  103,087

# %%
covid.Region(geoId='RU', dilation=2.5, d_cases=1.4).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-22:
#   326,448 cases, 3,249 deaths
#   2,259 cases per million, 22 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         49% through outbreak
#   Start:       2020-03-14 (-69 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 (-13 days, 10,995 cases)
#   End:         2020-07-25 ( 65 days, 78 days after peak cases)
#   Day Zero:    2020-04-06 (-46 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-19 ( -3 days, 118 deaths)
#
# Parameters:
#   Totals:      299,941 cases and 2,837 deaths at end of 2020-05-19
#   Smoothed:    299,941 cases and 2,837 deaths at end of 2020-05-19 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-19, compared to 7 days earlier)
#   Growth:      56 days (Start -> Peak Cases)
#                X = 460,822, r = 6.36, L = 43,979, dilation = 1.4, c = 92.9% for cases
#   Lag:         10 days (Peak Cases -> Peak Deaths)
#                X = 9,299, r = 4.5, L = 470, dilation = 2.5, c = 85.5% for deaths
#
# Outcome: 460,000 total cases, 8,360 total deaths by end of 2020-07-25
#   70.8% of predicted cases and 34.9% of predicted deaths reported to date
#   99.8% of predicted cases and 89.9% of predicted deaths reported by end date
#   3,190 cases per million (0.32%), 64 deaths per million (0.006%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-09   10,817      104     198,676    1,827    10,995       94     199,220    1,805
# 2020-05-10   11,012       88     209,688    1,915    10,919       96     210,138    1,900
# 2020-05-11   11,656       94     221,344    2,009    10,739       96     220,877    1,996
# 2020-05-12   10,899      107     232,243    2,116    10,725       98     231,602    2,095
# 2020-05-13   10,028       96     242,271    2,212    10,493      100     242,095    2,195
# 2020-05-14    9,974       93     252,245    2,305    10,307      101     252,402    2,297
# 2020-05-15   10,598      113     262,843    2,418     9,917      101     262,319    2,397
# 2020-05-16    9,200      119     272,043    2,537     9,683      102     272,001    2,499
# 2020-05-17    9,709       94     281,752    2,631     9,502      108     281,503    2,607
# 2020-05-18    8,926       91     290,678    2,722     9,341      112     290,844    2,719
# 2020-05-19    9,263      115     299,941    2,837     9,097      118     299,941    2,837
# 2020-05-20    8,764      135     308,705    2,972
# 2020-05-21    8,849      127     317,554    3,099
# 2020-05-22    8,894      150     326,448    3,249
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-19    9,305      113    299,941    2,837
# 2020-05-20    9,007      113    308,948    2,950
# 2020-05-21    8,694      113    317,642    3,062
# 2020-05-22    8,371      113    326,013    3,175  <-- latest raw data
# 2020-05-23    8,039      112    334,051    3,287
# 2020-05-24    7,702      112    341,753    3,399
# 2020-05-25    7,361      112    349,114    3,511
# 2020-05-26    7,021      111    356,135    3,622
# 2020-05-27    6,681      111    362,816    3,733
# 2020-05-28    6,346      110    369,162    3,844

# %%
covid.Region(geoId='JP', dilation=2.1, d_cases=1.3).analyse(ylog=1)
# Out:
# Japan data to end of 2020-05-22:
#   16,536 cases, 808 deaths
#   131 cases per million, 6 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         71% through outbreak
#   Start:       2020-02-16 (-96 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-39 days, 642 cases)
#   End:         2020-06-25 ( 35 days, 74 days after peak cases)
#   Day Zero:    2020-03-28 (-55 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-27 days, 29 deaths)
#
# Parameters:
#   Totals:      16,385 cases and 771 deaths at end of 2020-05-19
#   Smoothed:    16,385 cases and 770 deaths at end of 2020-05-19 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-19, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
#                X = 16,744, r = 8.0, L = 2,568, dilation = 1.3, c = 68.9% for cases
#   Lag:         12 days (Peak Cases -> Peak Deaths)
#                X = 982, r = 8.0, L = 115, dilation = 2.1, c = 61.9% for deaths
#
# Outcome: 16,739 total cases, 967 total deaths by end of 2020-06-25
#   98.8% of predicted cases and 82.2% of predicted deaths reported to date
#   100.0% of predicted cases and 98.4% of predicted deaths reported by end date
#   132 cases per million (0.01%), 8 deaths per million (0.001%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-09      119       12      15,747      613        96       18      15,710      606
# 2020-05-10       51        8      15,798      621        88       19      15,798      626
# 2020-05-11       76       22      15,874      643        92       22      15,890      648
# 2020-05-12      150       25      16,024      668        87       18      15,977      665
# 2020-05-13       55       19      16,079      687        77       19      16,053      684
# 2020-05-14      114       23      16,193      710        72       18      16,126      702
# 2020-05-15       44       15      16,237      725        70       17      16,196      719
# 2020-05-16       48       19      16,285      744        52       15      16,247      734
# 2020-05-17       20        5      16,305      749        49       13      16,297      747
# 2020-05-18       60       14      16,365      763        46       12      16,342      759
# 2020-05-19       20        8      16,385      771        43       12      16,385      771
# 2020-05-20       39        6      16,424      777
# 2020-05-21       89       19      16,513      796
# 2020-05-22       23       12      16,536      808
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-19       40       12     16,385      771
# 2020-05-20       36       12     16,421      783
# 2020-05-21       33       11     16,454      794
# 2020-05-22       29       11     16,483      805  <-- latest raw data
# 2020-05-23       27       10     16,510      816
# 2020-05-24       24       10     16,534      825
# 2020-05-25       21        9     16,555      835
# 2020-05-26       19        9     16,575      844
# 2020-05-27       17        8     16,592      852
# 2020-05-28       16        8     16,608      860

# %%
covid.Region(geoId='SG', dilation=3.3).analyse()
# Out:
# Singapore data to end of 2020-05-22:
#   30,426 cases, 23 deaths
#   5,396 cases per million, 4 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         46% through outbreak
#   Start:       2020-02-12 (-100 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-29 days, 1,002 cases)
#   End:         2020-09-11 (113 days, 142 days after peak cases)
#
# Parameters:
#   Totals:      28,794 cases and 22 deaths at end of 2020-05-19
#   Smoothed:    28,793 cases and 22 deaths at end of 2020-05-19 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-19, compared to 7 days earlier)
#   Growth:      71 days (Start -> Peak Cases)
#                X = 51,393, r = 8.0, L = 4,009, dilation = 3.3, c = 51.5% for cases
#
# Outcome: 50,993 total cases, 52 total deaths by end of 2020-09-11
#   59.2% of predicted cases and 43.0% of predicted deaths reported to date
#   99.2% of predicted cases and 97.2% of predicted deaths reported by end date
#   9,114 cases per million (0.91%), 9 deaths per million (0.001%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-09      753        0      22,460       20       749    < 0.5      22,379       20
# 2020-05-10      876        0      23,336       20       733    < 0.5      23,112       20
# 2020-05-11      451        1      23,787       21       735    < 0.5      23,847       20
# 2020-05-12      884        0      24,671       21       738    < 0.5      24,585       20
# 2020-05-13      675        0      25,346       21       697    < 0.5      25,283       21
# 2020-05-14      752        0      26,098       21       670    < 0.5      25,953       21
# 2020-05-15      793        0      26,891       21       649    < 0.5      26,602       21
# 2020-05-16      465        1      27,356       22       587    < 0.5      27,189       21
# 2020-05-17      682        0      28,038       22       572    < 0.5      27,761       21
# 2020-05-18      305        0      28,343       22       529    < 0.5      28,290       22
# 2020-05-19      451        0      28,794       22       504    < 0.5      28,794       22
# 2020-05-20      570        0      29,364       22
# 2020-05-21      448        1      29,812       23
# 2020-05-22      614        0      30,426       23
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-19      559        1     28,794       22
# 2020-05-20      551        1     29,345       23
# 2020-05-21      543        1     29,888       23
# 2020-05-22      534        1     30,422       24  <-- latest raw data
# 2020-05-23      526        1     30,948       24
# 2020-05-24      517        1     31,465       25
# 2020-05-25      509        1     31,974       25
# 2020-05-26      500        1     32,474       26
# 2020-05-27      491        1     32,966       26
# 2020-05-28      483        1     33,448       27

# %%
covid.Region(geoId='BR', growth_days=80, lag=6, dilation=3).analyse()
# Out:
# Brazil data to end of 2020-05-22:
#   330,890 cases, 21,048 deaths
#   1,580 cases per million, 100 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         29% through outbreak
#   Start:       2020-03-11 (-72 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-30 (  8 days, 0 cases)
#   End:         2020-11-05 (168 days, 160 days after peak cases)
#   Day Zero:    2020-03-25 (-58 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-05 ( 14 days)
#
# Parameters:
#   Totals:      271,628 cases and 17,971 deaths at end of 2020-05-19
#   Smoothed:    271,628 cases and 17,970 deaths at end of 2020-05-19 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.5 (2020-05-19, compared to 7 days earlier)
#   Growth:      80 days (Start -> Peak Cases)
#                X = 1,831,979, r = 6.61, L = 77,344, dilation = 3, c = 91.1% for cases
#   Lag:         6 days (Peak Cases -> Peak Deaths)
#                X = 141,217, r = 5.25, L = 4,762, dilation = 3, c = 92.5% for deaths
#
# Outcome: 1,809,896 total cases, 136,517 total deaths by end of 2020-11-05
#   18.1% of predicted cases and 14.9% of predicted deaths reported to date
#   98.8% of predicted cases and 96.7% of predicted deaths reported by end date
#   8,746 cases per million (0.87%), 674 deaths per million (0.067%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-09   10,611      730     155,939   10,627     8,837      636     150,417   10,408
# 2020-05-10    6,760      496     162,699   11,123     8,961      656     159,377   11,064
# 2020-05-11    5,632      396     168,331   11,519     9,531      689     168,908   11,753
# 2020-05-12    9,258      881     177,589   12,400    10,245      699     179,154   12,452
# 2020-05-13   11,385      749     188,974   13,149    10,851      711     190,004   13,163
# 2020-05-14   13,944      844     202,918   13,993    11,016      710     201,021   13,873
# 2020-05-15   15,305      824     218,223   14,817    12,072      749     213,092   14,622
# 2020-05-16   14,919      816     233,142   15,633    13,217      792     226,309   15,414
# 2020-05-17    7,938      485     241,080   16,118    14,421      811     240,730   16,225
# 2020-05-18   13,140      674     254,220   16,792    15,062      860     255,793   17,086
# 2020-05-19   17,408    1,179     271,628   17,971    15,835      885     271,628   17,971
# 2020-05-20   19,951      888     291,579   18,859
# 2020-05-21   18,508    1,188     310,087   20,047
# 2020-05-22   20,803    1,001     330,890   21,048
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-19   15,603      879    271,628   17,971
# 2020-05-20   16,138      908    287,766   18,879
# 2020-05-21   16,644      936    304,411   19,814
# 2020-05-22   17,114      963    321,525   20,778  <-- latest raw data
# 2020-05-23   17,544      990    339,069   21,768
# 2020-05-24   17,928    1,016    356,998   22,784
# 2020-05-25   18,262    1,040    375,260   23,824
# 2020-05-26   18,542    1,063    393,802   24,887
# 2020-05-27   18,763    1,084    412,565   25,971
# 2020-05-28   18,923    1,104    431,488   27,075

# %%
covid.Region(geoId='MX', growth_days=70, dilation=3).analyse()
# Out:
# Mexico data to end of 2020-05-22:
#   62,527 cases, 6,989 deaths
#   495 cases per million, 55 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         31% through outbreak
#   Start:       2020-03-15 (-68 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-24 (  2 days, --- cases)
#   End:         2020-10-10 (142 days, 140 days after peak cases)
#   Day Zero:    2020-04-02 (-50 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-28 (  6 days)
#
# Parameters:
#   Totals:      54,346 cases and 5,666 deaths at end of 2020-05-19
#   Smoothed:    54,345 cases and 5,666 deaths at end of 2020-05-19 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-19, compared to 7 days earlier)
#   Growth:      70 days (Start -> Peak Cases)
#                X = 260,664, r = 5.38, L = 10,353, dilation = 3, c = 93.3% for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#                X = 33,737, r = 5.7, L = 1,407, dilation = 3, c = 89.4% for deaths
#
# Outcome: 253,618 total cases, 32,918 total deaths by end of 2020-10-10
#   24.0% of predicted cases and 20.7% of predicted deaths reported to date
#   97.3% of predicted cases and 97.6% of predicted deaths reported by end date
#   2,066 cases per million (0.21%), 267 deaths per million (0.027%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-09    1,938      193      33,460    3,353     1,754      197      33,076    3,213
# 2020-05-10    1,562      112      35,022    3,465     1,790      210      34,867    3,424
# 2020-05-11    1,305      108      36,327    3,573     1,851      210      36,718    3,634
# 2020-05-12    1,997      353      38,324    3,926     1,927      223      38,645    3,857
# 2020-05-13    1,862      294      40,186    4,220     1,952      235      40,597    4,092
# 2020-05-14    2,409      257      42,595    4,477     2,025      238      42,621    4,330
# 2020-05-15    2,437      290      45,032    4,767     2,183      244      44,805    4,574
# 2020-05-16    2,112      278      47,144    5,045     2,285      242      47,090    4,816
# 2020-05-17    2,075      132      49,219    5,177     2,340      260      49,430    5,075
# 2020-05-18    2,414      155      51,633    5,332     2,421      282      51,851    5,357
# 2020-05-19    2,713      334      54,346    5,666     2,495      309      54,346    5,666
# 2020-05-20    2,248      424      56,594    6,090
# 2020-05-21    2,973      420      59,567    6,510
# 2020-05-22    2,960      479      62,527    6,989
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-19    2,453      306     54,346    5,666
# 2020-05-20    2,485      314     56,831    5,980
# 2020-05-21    2,511      322     59,342    6,302
# 2020-05-22    2,529      328     61,872    6,630  <-- latest raw data
# 2020-05-23    2,541      334     64,412    6,965
# 2020-05-24    2,544      339     66,957    7,304
# 2020-05-25    2,544      343     69,501    7,647
# 2020-05-26    2,543      346     72,043    7,994
# 2020-05-27    2,541      348     74,584    8,341
# 2020-05-28    2,538      349     77,122    8,690

# %%
covid.Region(geoId='PE', growth_days=68, dilation=2.5, d_cases=3).analyse()
# Out:
# Peru data to end of 2020-05-22:
#   111,698 cases, 3,244 deaths
#   3,492 cases per million, 101 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         34% through outbreak
#   Start:       2020-03-15 (-68 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-18 ( -4 days, 4,005 cases)
#   End:         2020-09-22 (124 days, 128 days after peak cases)
#   Day Zero:    2020-04-02 (-50 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-18 ( -4 days, 127 deaths)
#
# Parameters:
#   Totals:      99,483 cases and 2,914 deaths at end of 2020-05-19
#   Smoothed:    99,483 cases and 2,914 deaths at end of 2020-05-19 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-05-19, compared to 7 days earlier)
#   Growth:      64 days (Start -> Peak Cases)
#                X = 371,916, r = 5.11, L = 16,019, dilation = 3, c = 89.0% for cases
#   Lag:         0 days (Peak Cases -> Peak Deaths)
#                X = 9,569, r = 5.56, L = 506, dilation = 2.5, c = 89.0% for deaths
#
# Outcome: 359,977 total cases, 9,459 total deaths by end of 2020-09-22
#   30.0% of predicted cases and 33.9% of predicted deaths reported to date
#   96.8% of predicted cases and 98.8% of predicted deaths reported by end date
#   11,626 cases per million (1.16%), 299 deaths per million (0.030%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-09    3,168      100      65,015    1,814     2,967       88      63,747    1,809
# 2020-05-10    2,292       75      67,307    1,889     3,056       91      66,803    1,900
# 2020-05-11    1,515       72      68,822    1,961     3,139       92      69,942    1,992
# 2020-05-12    3,237       96      72,059    2,057     3,220       98      73,162    2,090
# 2020-05-13    4,247      112      76,306    2,169     3,345      102      76,508    2,191
# 2020-05-14    4,298       98      80,604    2,267     3,550      109      80,057    2,300
# 2020-05-15    3,891      126      84,495    2,393     3,713      119      83,770    2,419
# 2020-05-16    4,046      130      88,541    2,523     3,899      123      87,670    2,542
# 2020-05-17    3,732      125      92,273    2,648     3,941      123      91,610    2,665
# 2020-05-18    2,660      141      94,933    2,789     4,005      127      95,615    2,792
# 2020-05-19    4,550      125      99,483    2,914     3,868      122      99,483    2,914
# 2020-05-20    4,537      110     104,020    3,024
# 2020-05-21    4,749      124     108,769    3,148
# 2020-05-22    2,929       96     111,698    3,244
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-19    3,787      120     99,483    2,914
# 2020-05-20    3,785      120    103,268    3,034
# 2020-05-21    3,782      119    107,050    3,153
# 2020-05-22    3,777      119    110,828    3,272  <-- latest raw data
# 2020-05-23    3,771      119    114,599    3,391
# 2020-05-24    3,764      118    118,363    3,509
# 2020-05-25    3,755      118    122,118    3,627
# 2020-05-26    3,745      117    125,863    3,745
# 2020-05-27    3,734      117    129,598    3,862
# 2020-05-28    3,722      116    133,319    3,978

# %%
covid.Region(geoId='CL', growth_days=75).analyse(ylog=1)
# Out:
# Chile data to end of 2020-05-22:
#   61,857 cases, 630 deaths
#   3,303 cases per million, 34 deaths per million (2018 population = 18,729,160)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         45% through outbreak
#   Start:       2020-03-13 (-70 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-27 (  5 days, 3 cases)
#   End:         2020-08-09 ( 80 days, 75 days after peak cases)
#   Day Zero:    2020-04-08 (-44 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-31 (  9 days)
#
# Parameters:
#   Totals:      49,579 cases and 509 deaths at end of 2020-05-19
#   Smoothed:    49,578 cases and 509 deaths at end of 2020-05-19 (7 points)
#   Spread:      Peak infection rate 4.2 (2020-03-22, compared to 7 days earlier)
#                Latest infection rate 1.6 (2020-05-19, compared to 7 days earlier)
#   Growth:      75 days (Start -> Peak Cases)
#                X = 157,016, r = 7.72, L = 14,747, dilation = 1, c = 77.9% for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#                X = 2,246, r = 8.0, L = 194, dilation = 1, c = 55.1% for deaths
#
# Outcome: 156,946 total cases, 2,245 total deaths by end of 2020-08-09
#   39.4% of predicted cases and 28.0% of predicted deaths reported to date
#   100.0% of predicted cases and 99.9% of predicted deaths reported by end date
#   8,384 cases per million (0.84%), 120 deaths per million (0.012%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-09    1,247       10      27,219      304     1,360        8      26,821      300
# 2020-05-10    1,647        8      28,866      312     1,588        9      28,409      309
# 2020-05-11    1,197       11      30,063      323     1,746       10      30,155      319
# 2020-05-12    1,658       12      31,721      335     1,901       14      32,056      333
# 2020-05-13    2,660       11      34,381      346     1,991       16      34,047      350
# 2020-05-14    2,659       12      37,040      358     2,090       19      36,136      369
# 2020-05-15    2,502       36      39,542      394     2,241       22      38,377      391
# 2020-05-16    1,886       27      41,428      421     2,502       24      40,879      416
# 2020-05-17    2,353       29      43,781      450     2,695       28      43,575      443
# 2020-05-18    2,278       28      46,059      478     2,878       32      46,453      476
# 2020-05-19    3,520       31      49,579      509     3,126       33      49,579      509
# 2020-05-20    4,038       35      53,617      544
# 2020-05-21    3,964       45      57,581      589
# 2020-05-22    4,276       41      61,857      630
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-19    3,427       41     49,579      509
# 2020-05-20    3,560       43     53,139      552
# 2020-05-21    3,680       46     56,818      598
# 2020-05-22    3,786       48     60,604      646  <-- latest raw data
# 2020-05-23    3,875       50     64,479      696
# 2020-05-24    3,947       52     68,426      748
# 2020-05-25    3,999       54     72,425      803
# 2020-05-26    4,031       56     76,456      858
# 2020-05-27    4,042       57     80,498      916
# 2020-05-28    4,031       58     84,529      974
