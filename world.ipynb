# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='US', dilation=3.3, d_cases=7).analyse()
# Out:
# United States of America data to end of 2020-05-25:
#   1,662,302 cases, 98,220 deaths
#   5,081 cases per million, 300 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         69% through outbreak
#   Start:       2020-02-25 (-90 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-48 days, 32,007 cases)
#   End:         2020-06-29 ( 36 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-73 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-37 days, 2,727 deaths)
#
# Parameters:
#   Totals:      1,601,434 cases and 96,007 deaths at end of 2020-05-22
#   Smoothed:    1,601,433 cases and 96,007 deaths at end of 2020-05-22 (7 points)
#   Spread:      Peak infection rate 12.5 (2020-03-07, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-22, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RU', dilation=3, d_cases=2).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-25:
#   353,427 cases, 3,633 deaths
#   2,446 cases per million, 25 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         41% through outbreak
#   Start:       2020-03-14 (-72 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 (-16 days, 10,976 cases)
#   End:         2020-08-28 ( 96 days, 112 days after peak cases)
#   Day Zero:    2020-04-06 (-49 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-22 ( -3 days, 130 deaths)
#
# Parameters:
#   Totals:      326,448 cases and 3,249 deaths at end of 2020-05-22
#   Smoothed:    326,448 cases and 3,249 deaths at end of 2020-05-22 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-22, compared to 7 days earlier)
#   Growth:      56 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP', dilation=2.2, d_cases=1.3).analyse(ylog=1)
# Out:
# Japan data to end of 2020-05-25:
#   16,623 cases, 846 deaths
#   131 cases per million, 7 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         73% through outbreak
#   Start:       2020-02-16 (-99 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-42 days, 644 cases)
#   End:         2020-06-25 ( 32 days, 74 days after peak cases)
#   Day Zero:    2020-03-28 (-58 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-30 days, 29 deaths)
#
# Parameters:
#   Totals:      16,536 cases and 808 deaths at end of 2020-05-22
#   Smoothed:    16,536 cases and 807 deaths at end of 2020-05-22 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-22, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SG', dilation=3.3).analyse()
# Out:
# Singapore data to end of 2020-05-25:
#   31,960 cases, 23 deaths
#   5,668 cases per million, 4 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         47% through outbreak
#   Start:       2020-02-12 (-103 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-32 days, 1,005 cases)
#   End:         2020-09-11 (110 days, 142 days after peak cases)
#
# Parameters:
#   Totals:      30,426 cases and 23 deaths at end of 2020-05-22
#   Smoothed:    30,425 cases and 23 deaths at end of 2020-05-22 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-22, compared to 7 days earlier)
#   Growth:      71 days (Start -> Peak Cases)
#                X = 51,400, r = 8.0, L = 4,019, dilation = 3.3, c = 51.1% for cases
#
# Outcome: 51,000 total cases, 50 total deaths by end of 2020-09-11
# ...

# %%
covid.Region(geoId='BR', dilation=2.5).analyse()
# Out:
# Brazil data to end of 2020-05-25:
#   374,898 cases, 23,473 deaths
#   1,790 cases per million, 112 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         34% through outbreak
#   Start:       2020-03-11 (-75 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-21 ( -4 days, 17,650 cases)
#   End:         2020-10-09 (138 days, 142 days after peak cases)
#   Day Zero:    2020-03-24 (-62 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-25 (  0 days, --- deaths)
#
# Parameters:
#   Totals:      330,890 cases and 21,048 deaths at end of 2020-05-22
#   Smoothed:    330,890 cases and 21,047 deaths at end of 2020-05-22 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.4 (2020-05-22, compared to 7 days earlier)
#   Growth:      71 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='CL', dilation=3).analyse(ylog=1)
# Out:
# Chile data to end of 2020-05-25:
#   73,997 cases, 761 deaths
#   3,951 cases per million, 41 deaths per million (2018 population = 18,729,160)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-13 (-73 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-22 ( -3 days, 4,009 cases)
#   End:         2020-10-08 (137 days, 140 days after peak cases)
#   Day Zero:    2020-04-08 (-47 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-26 (  1 days)
#
# Parameters:
#   Totals:      61,857 cases and 630 deaths at end of 2020-05-22
#   Smoothed:    61,857 cases and 630 deaths at end of 2020-05-22 (7 points)
#   Spread:      Peak infection rate 4.2 (2020-03-22, compared to 7 days earlier)
#                Latest infection rate 1.7 (2020-05-22, compared to 7 days earlier)
#   Growth:      70 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='PE', dilation=2.5, d_cases=3).analyse()
# Out:
# Peru data to end of 2020-05-25:
#   123,979 cases, 3,629 deaths
#   3,876 cases per million, 113 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-15 (-71 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-22 ( -3 days, 4,140 cases)
#   End:         2020-10-04 (133 days, 136 days after peak cases)
#   Day Zero:    2020-04-02 (-53 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-18 ( -7 days, 125 deaths)
#
# Parameters:
#   Totals:      111,698 cases and 3,244 deaths at end of 2020-05-22
#   Smoothed:    111,698 cases and 3,244 deaths at end of 2020-05-22 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-22, compared to 7 days earlier)
#   Growth:      68 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MX', dilation=3).analyse()
# Out:
# Mexico data to end of 2020-05-25:
#   71,105 cases, 7,633 deaths
#   563 cases per million, 60 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-15 (-71 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-22 ( -3 days, 2,776 cases)
#   End:         2020-10-04 (133 days, 136 days after peak cases)
#   Day Zero:    2020-04-02 (-53 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-26 (  1 days)
#
# Parameters:
#   Totals:      62,527 cases and 6,989 deaths at end of 2020-05-22
#   Smoothed:    62,526 cases and 6,989 deaths at end of 2020-05-22 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-22, compared to 7 days earlier)
#   Growth:      68 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='CN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2020-05-25:
#   84,102 cases, 4,638 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-131 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-105 days, 4,689 cases)
#   End:         2020-03-06 (-79 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-121 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-100 days, 128 deaths)
#
# Parameters:
#   Totals:      84,081 cases and 4,638 deaths at end of 2020-05-22
#   Smoothed:    84,081 cases and 4,637 deaths at end of 2020-05-22 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-22, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='KR', dilation=3, d_cases=1).analyse(ylog=1)
# Out:
# South Korea data to end of 2020-05-25:
#   11,225 cases, 269 deaths
#   217 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-98 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-84 days, 609 cases)
#   End:         2020-03-15 (-70 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-78 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-70 days, 5 deaths)
#
# Parameters:
#   Totals:      11,165 cases and 266 deaths at end of 2020-05-22
#   Smoothed:    11,165 cases and 266 deaths at end of 2020-05-22 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-22, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZ', dilation=3.1).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-05-25:
#   1,154 cases, 21 deaths
#   236 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-66 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-59 days, 72 cases)
#   End:         2020-04-09 (-45 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,154 cases and 21 deaths at end of 2020-05-22
#   Smoothed:    1,154 cases and 21 deaths at end of 2020-05-22 (7 points)
#   Spread:      Peak infection rate 2.5 (2020-05-21, compared to 7 days earlier)
#                Latest infection rate 0.2 (2020-05-22, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,106, r = 4.0, L = 288, dilation = 3.1, c = 89.2% for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
# ...

# %%
covid.Region(geoId='AU').analyse(ylog=1)
# Out:
# Australia data to end of 2020-05-25:
#   7,118 cases, 102 deaths
#   285 cases per million, 4 deaths per million (2018 population = 24,992,369)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-04 (-82 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-59 days, 391 cases)
#   End:         2020-04-18 (-36 days, 23 days after peak cases)
#   Day Zero:    2020-04-09 (-46 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-49 days, 4 deaths)
#
# Parameters:
#   Totals:      7,095 cases and 101 deaths at end of 2020-05-22
#   Smoothed:    7,094 cases and 100 deaths at end of 2020-05-22 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-22, compared to 7 days earlier)
#   Growth:      23 days (Start -> Peak Cases)
# ...
