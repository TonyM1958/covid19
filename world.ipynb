# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=0, ylog=1, dilation=3)
covid.data_load('download.json')

# %%
covid.Region(geoId='US', dilation=4, d_cases=8).analyse()
# Out:
# United States of America data to end of 2020-06-01:
#   1,811,277 cases, 105,147 deaths
#   5,536 cases per million, 321 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         75% through outbreak
#   Start:       2020-02-25 (-97 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-55 days, 31,962 cases)
#   End:         2020-06-29 ( 29 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-80 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-44 days, 2,725 deaths)
#
# Parameters:
#   Totals:      1,747,087 cases and 102,836 deaths at end of 2020-05-29
#   Smoothed:    1,747,086 cases and 102,835 deaths at end of 2020-05-29 (7 points)
#   Spread:      Peak infection rate 11.5 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-29, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RU').analyse()
# Out:
# Russia data to end of 2020-06-01:
#   423,741 cases, 5,037 deaths
#   2,933 cases per million, 35 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         45% through outbreak
#   Start:       2020-03-14 (-79 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 (-23 days, 10,932 cases)
#   End:         2020-08-28 ( 89 days, 112 days after peak cases)
#   Day Zero:    2020-04-06 (-56 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-29 ( -3 days, 201 deaths)
#
# Parameters:
#   Totals:      387,623 cases and 4,374 deaths at end of 2020-05-29
#   Smoothed:    387,622 cases and 4,374 deaths at end of 2020-05-29 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-29, compared to 7 days earlier)
#   Growth:      56 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP', dilation=2.2, d_cases=1.5).analyse()
# Out:
# Japan data to end of 2020-06-01:
#   16,930 cases, 894 deaths
#   134 cases per million, 7 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         73% through outbreak
#   Start:       2020-02-16 (-106 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-49 days, 644 cases)
#   End:         2020-07-06 ( 36 days, 85 days after peak cases)
#   Day Zero:    2020-03-28 (-65 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-37 days, 29 deaths)
#
# Parameters:
#   Totals:      16,804 cases and 886 deaths at end of 2020-05-29
#   Smoothed:    16,804 cases and 885 deaths at end of 2020-05-29 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-05-29, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SG').analyse()
# Out:
# Singapore data to end of 2020-06-01:
#   35,292 cases, 24 deaths
#   6,259 cases per million, 4 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         50% through outbreak
#   Start:       2020-02-11 (-111 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-39 days, 1,006 cases)
#   End:         2020-09-13 (105 days, 144 days after peak cases)
#
# Parameters:
#   Totals:      33,860 cases and 23 deaths at end of 2020-05-29
#   Smoothed:    33,859 cases and 22 deaths at end of 2020-05-29 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-29, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                X = 48,833, r = 8.0, L = 4,023, dilation = 3, c = 51.8% for cases
#
# Outcome: 48,598 total cases, 38 total deaths by end of 2020-09-13
# ...

# %%
covid.Region(geoId='BR').analyse()
# Out:
# Brazil data to end of 2020-06-01:
#   526,447 cases, 29,937 deaths
#   2,513 cases per million, 143 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         34% through outbreak
#   Start:       2020-03-11 (-82 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-28 ( -4 days, 21,729 cases)
#   End:         2020-10-30 (152 days, 156 days after peak cases)
#   Day Zero:    2020-03-24 (-69 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-26 ( -6 days, 987 deaths)
#
# Parameters:
#   Totals:      465,166 cases and 27,878 deaths at end of 2020-05-29
#   Smoothed:    465,165 cases and 27,877 deaths at end of 2020-05-29 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-29, compared to 7 days earlier)
#   Growth:      78 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='CL').analyse()
# Out:
# Chile data to end of 2020-06-01:
#   105,159 cases, 1,113 deaths
#   5,615 cases per million, 59 deaths per million (2018 population = 18,729,160)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-13 (-80 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-29 ( -3 days, 4,431 cases)
#   End:         2020-10-29 (151 days, 154 days after peak cases)
#   Day Zero:    2020-04-08 (-54 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-02 (  1 days)
#
# Parameters:
#   Totals:      90,638 cases and 944 deaths at end of 2020-05-29
#   Smoothed:    90,638 cases and 943 deaths at end of 2020-05-29 (7 points)
#   Spread:      Peak infection rate 4.2 (2020-03-22, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-29, compared to 7 days earlier)
#   Growth:      77 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='PE').analyse()
# Out:
# Peru data to end of 2020-06-01:
#   170,039 cases, 4,634 deaths
#   5,316 cases per million, 145 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-15 (-78 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-29 ( -3 days, 6,531 cases)
#   End:         2020-10-25 (147 days, 150 days after peak cases)
#   Day Zero:    2020-04-02 (-60 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-28 ( -4 days, 150 deaths)
#
# Parameters:
#   Totals:      148,285 cases and 4,230 deaths at end of 2020-05-29
#   Smoothed:    148,285 cases and 4,230 deaths at end of 2020-05-29 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.6 (2020-05-29, compared to 7 days earlier)
#   Growth:      75 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MX').analyse()
# Out:
# Mexico data to end of 2020-06-01:
#   93,435 cases, 10,167 deaths
#   740 cases per million, 81 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-15 (-78 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-29 ( -3 days, 3,202 cases)
#   End:         2020-10-25 (147 days, 150 days after peak cases)
#   Day Zero:    2020-04-02 (-60 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-27 ( -5 days, 376 deaths)
#
# Parameters:
#   Totals:      84,627 cases and 9,415 deaths at end of 2020-05-29
#   Smoothed:    84,627 cases and 9,415 deaths at end of 2020-05-29 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-29, compared to 7 days earlier)
#   Growth:      75 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IN').analyse()
# Out:
# India data to end of 2020-06-01:
#   198,706 cases, 5,598 deaths
#   147 cases per million, 4 deaths per million (2018 population = 1,352,617,328)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-10 (-83 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-29 ( -3 days, 7,589 cases)
#   End:         2020-11-04 (157 days, 160 days after peak cases)
#   Day Zero:    2020-04-02 (-60 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-02 (  1 days)
#
# Parameters:
#   Totals:      173,763 cases and 4,971 deaths at end of 2020-05-29
#   Smoothed:    173,762 cases and 4,971 deaths at end of 2020-05-29 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-02, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-05-29, compared to 7 days earlier)
#   Growth:      80 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='CN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2020-06-01:
#   84,154 cases, 4,638 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-138 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-112 days, 4,689 cases)
#   End:         2020-03-06 (-86 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-128 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-107 days, 128 deaths)
#
# Parameters:
#   Totals:      84,123 cases and 4,638 deaths at end of 2020-05-29
#   Smoothed:    84,123 cases and 4,637 deaths at end of 2020-05-29 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-29, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='KR', d_cases=1).analyse(ylog=1)
# Out:
# South Korea data to end of 2020-06-01:
#   11,541 cases, 272 deaths
#   224 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-105 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-91 days, 610 cases)
#   End:         2020-03-15 (-77 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-85 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-77 days, 5 deaths)
#
# Parameters:
#   Totals:      11,441 cases and 269 deaths at end of 2020-05-29
#   Smoothed:    11,441 cases and 269 deaths at end of 2020-05-29 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 2.1 (2020-05-29, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZ').analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-06-01:
#   1,154 cases, 22 deaths
#   236 cases per million, 5 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-73 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-66 days, 72 cases)
#   End:         2020-04-09 (-52 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,154 cases and 22 deaths at end of 2020-05-29
#   Smoothed:    1,153 cases and 22 deaths at end of 2020-05-29 (7 points)
#   Spread:      Peak infection rate 2.5 (2020-05-21, compared to 7 days earlier)
#                Latest infection rate 0.0 (2020-05-29, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,099, r = 4.0, L = 288, dilation = 3, c = 88.9% for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
# ...

# %%
covid.Region(geoId='AU').analyse()
# Out:
# Australia data to end of 2020-06-01:
#   7,204 cases, 103 deaths
#   288 cases per million, 4 deaths per million (2018 population = 24,992,369)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-04 (-89 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-66 days, 391 cases)
#   End:         2020-05-11 (-20 days, 46 days after peak cases)
#   Day Zero:    2020-04-09 (-53 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-56 days, 4 deaths)
#
# Parameters:
#   Totals:      7,173 cases and 103 deaths at end of 2020-05-29
#   Smoothed:    7,172 cases and 102 deaths at end of 2020-05-29 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 1.5 (2020-05-29, compared to 7 days earlier)
#   Growth:      23 days (Start -> Peak Cases)
# ...
