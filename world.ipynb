# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='CN', dilation=1.1, d_cases=0.9).analyse(ylog=1)
# Out:
# China data to end of 2020-05-11:
#   84,011 cases, 4,637 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-117 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-91 days, 4,689 cases)
#   End:         2020-03-06 (-65 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-107 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-86 days, 128 deaths)
#
# Parameters:
#   Totals:      83,976 cases and 4,637 deaths at end of 2020-05-08
#   Smoothed:    83,976 cases and 4,637 deaths at end of 2020-05-08 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 1.6 (2020-05-08, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
#                X = 80,961, r = 5.39, L = 18,755, dilation = 0.9, c = 81.1% for cases
#   Lag:         5 days (Peak Cases -> Peak Deaths)
#                X = 3,237, r = 4.17, L = 510, dilation = 1.1, c = 94.2% for deaths
#
# Outcome: 80,814 total cases, 3,099 total deaths at end of 2020-03-07
#   58 cases per million, 2 deaths per million (2018 population = 1,392,730,000)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-04-28        2        0      83,940    4,637         9    < 0.5      83,927    4,637
# 2020-04-29        4        0      83,944    4,637         7    < 0.5      83,934    4,637
# 2020-04-30       12        0      83,956    4,637         7        0      83,942    4,637
# 2020-05-01        3        0      83,959    4,637         4        0      83,946    4,637
# 2020-05-02        2        0      83,961    4,637         4        0      83,950    4,637
# 2020-05-03        3        0      83,964    4,637         4        0      83,953    4,637
# 2020-05-04        2        0      83,966    4,637         3        0      83,956    4,637
# 2020-05-05        2        0      83,968    4,637         2        0      83,959    4,637
# 2020-05-06        2        0      83,970    4,637         4        0      83,963    4,637
# 2020-05-07        6        0      83,976    4,637         7        0      83,970    4,637
# 2020-05-08        0        0      83,976    4,637         6        0      83,976    4,637
# 2020-05-09       15        0      83,991    4,637
# 2020-05-10       19        0      84,010    4,637
# 2020-05-11        1        0      84,011    4,637

# %%
covid.Region(geoId='KR', dilation=3, d_cases=1).analyse(ylog=1)
# Out:
# South Korea data to end of 2020-05-11:
#   10,936 cases, 258 deaths
#   212 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-84 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-70 days, 608 cases)
#   End:         2020-03-15 (-56 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-64 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-56 days, 5 deaths)
#
# Parameters:
#   Totals:      10,840 cases and 256 deaths at end of 2020-05-08
#   Smoothed:    10,840 cases and 256 deaths at end of 2020-05-08 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 2.5 (2020-05-08, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
#                X = 8,482, r = 4.03, L = 2,431, dilation = 1, c = 93.1% for cases
#   Lag:         14 days (Peak Cases -> Peak Deaths)
#                X = 165, r = 4.0, L = 18, dilation = 3, c = 80.0% for deaths
#
# Outcome: 8,320 total cases, 81 total deaths at end of 2020-03-16
#   161 cases per million, 2 deaths per million (2018 population = 51,635,256)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-04-28        9        2      10,761      246         9        1      10,740      246
# 2020-04-29        4        1      10,765      247         9        1      10,750      247
# 2020-04-30        9        1      10,774      248         9        1      10,759      248
# 2020-05-01        6        2      10,780      250         7        1      10,766      249
# 2020-05-02       13        0      10,793      250         6        1      10,772      251
# 2020-05-03        8        2      10,801      252         6        1      10,779      252
# 2020-05-04        3        2      10,804      254         7        1      10,786      253
# 2020-05-05        2        1      10,806      255         9        1      10,794      254
# 2020-05-06        4        1      10,810      256        12        1      10,806      255
# 2020-05-07       12        0      10,822      256        15        1      10,821      255
# 2020-05-08       18        0      10,840      256        19        1      10,840      256
# 2020-05-09       34        0      10,874      256
# 2020-05-10       35        0      10,909      256
# 2020-05-11       27        2      10,936      258

# %%
covid.Region(geoId='NZ', dilation=3.1).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-05-11:
#   1,147 cases, 21 deaths
#   235 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-52 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-45 days, 72 cases)
#   End:         2020-04-09 (-31 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,142 cases and 21 deaths at end of 2020-05-08
#   Smoothed:    1,142 cases and 21 deaths at end of 2020-05-08 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-08, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,105, r = 4.0, L = 288, dilation = 3.1, c = 89.1% for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
#   212 cases per million, 1 deaths per million (2018 population = 4,885,500)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-04-28        2        0       1,126       19         2    < 0.5       1,126       19
# 2020-04-29        3        0       1,129       19         2    < 0.5       1,128       19
# 2020-04-30        3        0       1,132       19         2    < 0.5       1,131       19
# 2020-05-01        2        1       1,134       20         2    < 0.5       1,132       20
# 2020-05-02        2        0       1,136       20         2    < 0.5       1,134       20
# 2020-05-03        1        0       1,137       20         1    < 0.5       1,136       20
# 2020-05-04        0        0       1,137       20         1    < 0.5       1,137       20
# 2020-05-05        1        1       1,138       21         1    < 0.5       1,138       21
# 2020-05-06        1        0       1,139       21         1    < 0.5       1,139       21
# 2020-05-07        2        0       1,141       21         1    < 0.5       1,141       21
# 2020-05-08        1        0       1,142       21         1    < 0.5       1,142       21
# 2020-05-09        2        0       1,144       21
# 2020-05-10        3        0       1,147       21
# 2020-05-11        0        0       1,147       21

# %%
covid.Region(geoId='US', dilation=1.6, d_cases=3.8).analyse()
# Out:
# United States of America data to end of 2020-05-11:
#   1,347,916 cases, 80,684 deaths
#   4,120 cases per million, 247 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         58% through outbreak
#   Start:       2020-02-25 (-76 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-34 days, 32,036 cases)
#   End:         2020-06-29 ( 50 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-59 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-23 days, 2,735 deaths)
#
# Parameters:
#   Totals:      1,283,929 cases and 77,180 deaths at end of 2020-05-08
#   Smoothed:    1,283,928 cases and 77,180 deaths at end of 2020-05-08 (7 points)
#   Spread:      Peak infection rate 12.5 (2020-03-07, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-08, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
#                X = 1,932,423, r = 6.39, L = 128,143, dilation = 3.8, c = 93.2% for cases
#   Lag:         11 days (Peak Cases -> Peak Deaths)
#                X = 92,883, r = 6.02, L = 10,939, dilation = 1.6, c = 87.2% for deaths
#
# Outcome: 1,867,771 total cases, 92,749 total deaths by end of 2020-06-29
#   69.8% of predicted cases and 86.9% of predicted deaths reported to date
#   96.7% of predicted cases and 99.9% of predicted deaths reported by end date
#   5,907 cases per million, 284 deaths per million (2018 population = 327,167,434)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-04-28   24,132    2,110   1,012,583   58,355    30,555    2,022   1,020,055   59,242
# 2020-04-29   27,326    2,611   1,039,909   60,966    27,798    1,899   1,047,852   61,141
# 2020-04-30   29,917    2,040   1,069,826   63,006    27,528    1,843   1,075,380   62,984
# 2020-05-01   33,955    2,062   1,103,781   65,068    27,535    1,826   1,102,915   64,810
# 2020-05-02   29,288    1,317   1,133,069   66,385    27,493    1,831   1,130,409   66,640
# 2020-05-03   24,972    1,297   1,158,041   67,682    27,035    1,794   1,157,444   68,434
# 2020-05-04   22,593    1,252   1,180,634   68,934    26,814    1,822   1,184,258   70,256
# 2020-05-05   23,841    2,144   1,204,475   71,078    25,811    1,743   1,210,069   71,999
# 2020-05-06   24,128    2,353   1,228,603   73,431    25,284    1,786   1,235,353   73,785
# 2020-05-07   28,369    2,239   1,256,972   75,670    24,609    1,705   1,259,962   75,489
# 2020-05-08   26,957    1,510   1,283,929   77,180    23,967    1,691   1,283,929   77,180
# 2020-05-09   25,612    1,614   1,309,541   78,794
# 2020-05-10   20,258      734   1,329,799   79,528
# 2020-05-11   18,117    1,156   1,347,916   80,684
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-08   21,788    1,255  1,283,929   77,180
# 2020-05-09   21,306    1,176  1,305,235   78,356
# 2020-05-10   20,824    1,101  1,326,059   79,457
# 2020-05-11   20,341    1,028  1,346,400   80,485  <-- latest raw data
# 2020-05-12   19,859      958  1,366,259   81,443
# 2020-05-13   19,379      892  1,385,639   82,335
# 2020-05-14   18,902      829  1,404,540   83,164
# 2020-05-15   18,427      770  1,422,967   83,934
# 2020-05-16   17,955      714  1,440,922   84,648
# 2020-05-17   17,488      661  1,458,409   85,310

# %%
covid.Region(geoId='RU', growth_days=59, lag=5).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-11:
#   221,344 cases, 2,009 deaths
#   1,532 cases per million, 14 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         47% through outbreak
#   Start:       2020-03-14 (-58 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-12 (  1 days, --- cases)
#   End:         2020-07-09 ( 60 days, 59 days after peak cases)
#   Day Zero:    2020-04-06 (-35 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-08 ( -3 days, 93 deaths)
#
# Parameters:
#   Totals:      187,859 cases and 1,723 deaths at end of 2020-05-08
#   Smoothed:    187,858 cases and 1,723 deaths at end of 2020-05-08 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-08, compared to 7 days earlier)
#   Growth:      59 days (Start -> Peak Cases)
#                X = 455,948, r = 5.89, L = 45,193, dilation = 1, c = 90.4% for cases
#   Lag:         -4 days (Peak Cases -> Peak Deaths)
#                X = 3,363, r = 6.34, L = 372, dilation = 1, c = 89.9% for deaths
#
# Outcome: 454,690 total cases, 3,359 total deaths by end of 2020-07-09
#   48.5% of predicted cases and 59.7% of predicted deaths reported to date
#   99.7% of predicted cases and 99.9% of predicted deaths reported by end date
#   3,156 cases per million, 23 deaths per million (2018 population = 144,478,050)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-04-28    6,411       72      93,558      867     6,539       79      93,724      899
# 2020-04-29    5,841      105      99,399      972     7,061       77     100,785      976
# 2020-04-30    7,099      101     106,498    1,073     7,671       76     108,456    1,052
# 2020-05-01    7,933       96     114,431    1,169     8,297       80     116,752    1,132
# 2020-05-02    9,623       53     124,054    1,222     8,823       83     125,576    1,215
# 2020-05-03   10,633       58     134,687    1,280     9,497       81     135,073    1,295
# 2020-05-04   10,581       76     145,268    1,356    10,087       79     145,159    1,374
# 2020-05-05   10,102       95     155,370    1,451    10,482       79     155,641    1,453
# 2020-05-06   10,559       86     165,929    1,537    10,652       86     166,293    1,539
# 2020-05-07   11,231       88     177,160    1,625    10,706       91     176,999    1,630
# 2020-05-08   10,699       98     187,859    1,723    10,860       93     187,859    1,723
# 2020-05-09   10,817      104     198,676    1,827
# 2020-05-10   11,012       88     209,688    1,915
# 2020-05-11   11,656       94     221,344    2,009
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-08   10,969       91    187,859    1,723
# 2020-05-09   11,160       90    199,019    1,813
# 2020-05-10   11,299       90    210,318    1,903
# 2020-05-11   11,384       88    221,702    1,991  <-- latest raw data
# 2020-05-12   11,412       87    233,114    2,078
# 2020-05-13   11,384       84    244,498    2,162
# 2020-05-14   11,299       82    255,797    2,244
# 2020-05-15   11,160       79    266,957    2,323
# 2020-05-16   10,969       76    277,926    2,399
# 2020-05-17   10,730       72    288,656    2,471

# %%
covid.Region(geoId='JP', dilation=1.1, d_cases=1.1).analyse()
# Out:
# Japan data to end of 2020-05-11:
#   15,874 cases, 643 deaths
#   125 cases per million, 5 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         69% through outbreak
#   Start:       2020-02-16 (-85 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-28 days, 643 cases)
#   End:         2020-06-13 ( 34 days, 62 days after peak cases)
#   Day Zero:    2020-03-27 (-45 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-16 days, 30 deaths)
#
# Parameters:
#   Totals:      15,628 cases and 601 deaths at end of 2020-05-08
#   Smoothed:    15,628 cases and 600 deaths at end of 2020-05-08 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.4 (2020-05-08, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
#                X = 16,260, r = 8.0, L = 2,571, dilation = 1.1, c = 74.5% for cases
#   Lag:         12 days (Peak Cases -> Peak Deaths)
#                X = 714, r = 8.0, L = 118, dilation = 1.1, c = 63.8% for deaths
#
# Outcome: 16,254 total cases, 713 total deaths by end of 2020-06-13
#   97.6% of predicted cases and 90.0% of predicted deaths reported to date
#   100.0% of predicted cases and 99.8% of predicted deaths reported by end date
#   129 cases per million, 6 deaths per million (2018 population = 126,529,100)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-04-28      276       13      13,852      389       236       18      13,842      403
# 2020-04-29      236       26      14,088      415       237       21      14,079      424
# 2020-04-30      193       17      14,281      432       239       23      14,318      447
# 2020-05-01      263       26      14,544      458       236       21      14,554      468
# 2020-05-02      295       34      14,839      492       215       22      14,769      491
# 2020-05-03      218       18      15,057      510       196       20      14,965      510
# 2020-05-04      174       11      15,231      521       181       18      15,146      529
# 2020-05-05      123       22      15,354      543       155       21      15,301      549
# 2020-05-06      109        8      15,463      551       130       18      15,430      567
# 2020-05-07       84        6      15,547      557       106       16      15,536      583
# 2020-05-08       81       44      15,628      601        92       18      15,628      601
# 2020-05-09      119       12      15,747      613
# 2020-05-10       51        8      15,798      621
# 2020-05-11       76       22      15,874      643
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-08       83       13     15,628      601
# 2020-05-09       73       12     15,701      613
# 2020-05-10       65       11     15,767      623
# 2020-05-11       58       10     15,824      633  <-- latest raw data
# 2020-05-12       51        9     15,876      642
# 2020-05-13       45        8     15,921      650
# 2020-05-14       40        7     15,961      657
# 2020-05-15       35        6     15,996      663
# 2020-05-16       31        6     16,028      669
# 2020-05-17       28        5     16,055      674

# %%
covid.Region(geoId='SG', dilation=3.2).analyse()
# Out:
# Singapore data to end of 2020-05-11:
#   23,787 cases, 21 deaths
#   4,219 cases per million, 4 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         40% through outbreak
#   Start:       2020-02-11 (-90 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-18 days, 1,006 cases)
#   End:         2020-09-13 (126 days, 144 days after peak cases)
#
# Parameters:
#   Totals:      21,707 cases and 20 deaths at end of 2020-05-08
#   Smoothed:    21,707 cases and 20 deaths at end of 2020-05-08 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-05-08, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                X = 49,349, r = 8.0, L = 4,023, dilation = 3.2, c = 46.1% for cases
#
# Outcome: 49,019 total cases, 65 total deaths by end of 2020-09-13
#   48.2% of predicted cases and 31.3% of predicted deaths reported to date
#   99.3% of predicted cases and 97.0% of predicted deaths reported by end date
#   8,752 cases per million, 12 deaths per million (2018 population = 5,638,676)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-04-28      528        0      14,951       14       847        1      14,954       14
# 2020-04-29      690        0      15,641       14       694        1      15,648       15
# 2020-04-30      528        1      16,169       15       655        1      16,303       16
# 2020-05-01      932        1      17,101       16       623        1      16,926       16
# 2020-05-02      447        1      17,548       17       637        1      17,563       17
# 2020-05-03      657        1      18,205       18       651        1      18,215       18
# 2020-05-04      573        0      18,778       18       682        1      18,897       18
# 2020-05-05      632        0      19,410       18       658        1      19,555       19
# 2020-05-06      788        2      20,198       20       702    < 0.5      20,257       19
# 2020-05-07      741        0      20,939       20       734    < 0.5      20,991       20
# 2020-05-08      768        0      21,707       20       716    < 0.5      21,707       20
# 2020-05-09      753        0      22,460       20
# 2020-05-10      876        0      23,336       20
# 2020-05-11      451        1      23,787       21
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-08      613        1     21,707       20
# 2020-05-09      607        1     22,314       21
# 2020-05-10      601        1     22,916       21
# 2020-05-11      595        1     23,511       22  <-- latest raw data
# 2020-05-12      589        1     24,100       23
# 2020-05-13      582        1     24,682       23
# 2020-05-14      575        1     25,257       24
# 2020-05-15      568        1     25,826       25
# 2020-05-16      561        1     26,387       25
# 2020-05-17      554        1     26,940       26

# %%
covid.Region(geoId='BR', lag=3, dilation=2.5).analyse()
# Out:
# Brazil data to end of 2020-05-11:
#   168,331 cases, 11,519 deaths
#   804 cases per million, 55 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         34% through outbreak
#   Start:       2020-03-11 (-61 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-07 ( -4 days, 8,880 cases)
#   End:         2020-08-28 (110 days, 114 days after peak cases)
#   Day Zero:    2020-03-24 (-48 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-10 ( -1 days, --- deaths)
#
# Parameters:
#   Totals:      145,328 cases and 9,897 deaths at end of 2020-05-08
#   Smoothed:    145,327 cases and 9,897 deaths at end of 2020-05-08 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.5 (2020-05-08, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
#                X = 463,336, r = 7.39, L = 35,520, dilation = 2.5, c = 78.0% for cases
#   Lag:         3 days (Peak Cases -> Peak Deaths)
#                X = 37,743, r = 6.36, L = 2,446, dilation = 2.5, c = 87.3% for deaths
#
# Outcome: 462,086 total cases, 37,479 total deaths by end of 2020-08-28
#   36.3% of predicted cases and 30.5% of predicted deaths reported to date
#   99.7% of predicted cases and 99.3% of predicted deaths reported by end date
#   2,212 cases per million, 180 deaths per million (2018 population = 209,469,333)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-04-28    5,385      474      71,886    5,017     5,568      383      74,142    5,106
# 2020-04-29    6,276      449      78,162    5,466     5,489      393      79,632    5,499
# 2020-04-30    7,218      435      85,380    5,901     5,664      406      85,296    5,905
# 2020-05-01    6,209      428      91,589    6,329     5,955      400      91,251    6,305
# 2020-05-02    4,970      421      96,559    6,750     6,179      418      97,430    6,723
# 2020-05-03    4,588      275     101,147    7,025     6,789      442     104,219    7,165
# 2020-05-04    6,633      296     107,780    7,321     7,174      467     111,393    7,632
# 2020-05-05    6,935      600     114,715    7,921     7,753      513     119,146    8,145
# 2020-05-06   10,503      615     125,218    8,536     8,567      558     127,712    8,703
# 2020-05-07    9,888      610     135,106    9,146     8,880      590     136,592    9,293
# 2020-05-08   10,222      751     145,328    9,897     8,736      604     145,328    9,897
# 2020-05-09   10,611      730     155,939   10,627
# 2020-05-10    6,760      496     162,699   11,123
# 2020-05-11    5,632      396     168,331   11,519
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-08    8,590      596    145,328    9,897
# 2020-05-09    8,573      602    153,901   10,499
# 2020-05-10    8,544      604    162,445   11,103
# 2020-05-11    8,504      604    170,949   11,707  <-- latest raw data
# 2020-05-12    8,453      603    179,402   12,309
# 2020-05-13    8,391      601    187,794   12,911
# 2020-05-14    8,319      599    196,112   13,510
# 2020-05-15    8,236      596    204,349   14,106
# 2020-05-16    8,144      593    212,493   14,699
# 2020-05-17    8,043      589    220,536   15,289

# %%
covid.Region(geoId='MX', lag=3, dilation=2.5).analyse()
# Out:
# Mexico data to end of 2020-05-11:
#   36,327 cases, 3,573 deaths
#   288 cases per million, 28 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         34% through outbreak
#   Start:       2020-03-15 (-57 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-07 ( -4 days, 1,658 cases)
#   End:         2020-08-20 (102 days, 106 days after peak cases)
#   Day Zero:    2020-04-02 (-39 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-07 ( -4 days, 191 deaths)
#
# Parameters:
#   Totals:      31,522 cases and 3,160 deaths at end of 2020-05-08
#   Smoothed:    31,521 cases and 3,160 deaths at end of 2020-05-08 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-05-08, compared to 7 days earlier)
#   Growth:      53 days (Start -> Peak Cases)
#                X = 101,819, r = 5.84, L = 6,632, dilation = 2.5, c = 90.4% for cases
#   Lag:         0 days (Peak Cases -> Peak Deaths)
#                X = 10,155, r = 6.23, L = 762, dilation = 2.5, c = 85.1% for deaths
#
# Outcome: 100,878 total cases, 10,086 total deaths by end of 2020-08-20
#   35.7% of predicted cases and 35.2% of predicted deaths reported to date
#   99.1% of predicted cases and 99.3% of predicted deaths reported by end date
#   807 cases per million, 80 deaths per million (2018 population = 126,190,788)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-04-28    1,223      135      16,752    1,569     1,129      109      17,018    1,632
# 2020-04-29    1,047      163      17,799    1,732     1,184      110      18,202    1,742
# 2020-04-30    1,425      127      19,224    1,859     1,262      117      19,464    1,859
# 2020-05-01    1,515      113      20,739    1,972     1,346      122      20,810    1,981
# 2020-05-02    1,349       89      22,088    2,061     1,331      136      22,141    2,117
# 2020-05-03    1,383       93      23,471    2,154     1,412      141      23,553    2,259
# 2020-05-04    1,434      117      24,905    2,271     1,492      160      25,044    2,419
# 2020-05-05    1,120      236      26,025    2,507     1,548      173      26,592    2,592
# 2020-05-06    1,609      197      27,634    2,704     1,632      188      28,224    2,780
# 2020-05-07    1,982      257      29,616    2,961     1,658      191      29,882    2,971
# 2020-05-08    1,906      199      31,522    3,160     1,640      189      31,522    3,160
# 2020-05-09    1,938      193      33,460    3,353
# 2020-05-10    1,562      112      35,022    3,465
# 2020-05-11    1,305      108      36,327    3,573
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-08    1,612      171     31,522    3,160
# 2020-05-09    1,610      171     33,132    3,331
# 2020-05-10    1,606      171     34,738    3,502
# 2020-05-11    1,601      170     36,339    3,671  <-- latest raw data
# 2020-05-12    1,594      169     37,933    3,840
# 2020-05-13    1,585      168     39,518    4,008
# 2020-05-14    1,575      167     41,094    4,175
# 2020-05-15    1,564      165     42,658    4,341
# 2020-05-16    1,551      164     44,209    4,505
# 2020-05-17    1,537      162     45,746    4,667

# %%
covid.Region(geoId='PE', lag=3, dilation=2.5).analyse()
# Out:
# Peru data to end of 2020-05-11:
#   68,822 cases, 1,961 deaths
#   2,151 cases per million, 61 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         35% through outbreak
#   Start:       2020-03-15 (-57 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-06 ( -5 days, 3,253 cases)
#   End:         2020-08-17 ( 99 days, 104 days after peak cases)
#   Day Zero:    2020-04-02 (-39 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-09 ( -2 days, --- deaths)
#
# Parameters:
#   Totals:      61,847 cases and 1,714 deaths at end of 2020-05-08
#   Smoothed:    61,847 cases and 1,713 deaths at end of 2020-05-08 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-08, compared to 7 days earlier)
#   Growth:      52 days (Start -> Peak Cases)
#                X = 186,949, r = 6.53, L = 13,010, dilation = 2.5, c = 88.2% for cases
#   Lag:         3 days (Peak Cases -> Peak Deaths)
#                X = 6,138, r = 5.22, L = 353, dilation = 2.5, c = 93.1% for deaths
#
# Outcome: 185,949 total cases, 6,034 total deaths by end of 2020-08-17
#   36.8% of predicted cases and 31.9% of predicted deaths reported to date
#   99.5% of predicted cases and 98.3% of predicted deaths reported by end date
#   5,844 cases per million, 192 deaths per million (2018 population = 31,989,256)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-04-28    2,491       72      31,190      854     2,722       70      32,415      884
# 2020-04-29    2,741       89      33,931      943     2,489       72      34,904      956
# 2020-04-30    3,045      108      36,976    1,051     2,664       80      37,568    1,036
# 2020-05-01    3,483       73      40,459    1,124     2,702       80      40,270    1,116
# 2020-05-02    2,075       76      42,534    1,200     2,894       84      43,163    1,200
# 2020-05-03    3,394       86      45,928    1,286     3,022       84      46,185    1,285
# 2020-05-04    1,444       58      47,372    1,344     3,118       82      49,303    1,367
# 2020-05-05    3,817      100      51,189    1,444     3,095       84      52,398    1,452
# 2020-05-06    3,628       89      54,817    1,533     3,253       88      55,650    1,539
# 2020-05-07    3,709       94      58,526    1,627     3,093       86      58,743    1,626
# 2020-05-08    3,321       87      61,847    1,714     3,104       88      61,847    1,714
# 2020-05-09    3,168      100      65,015    1,814
# 2020-05-10    2,292       75      67,307    1,889
# 2020-05-11    1,515       72      68,822    1,961
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-08    3,357       89     61,847    1,714
# 2020-05-09    3,346       89     65,193    1,803
# 2020-05-10    3,332       89     68,525    1,892
# 2020-05-11    3,313       89     71,838    1,981  <-- latest raw data
# 2020-05-12    3,290       89     75,128    2,069
# 2020-05-13    3,264       88     78,392    2,158
# 2020-05-14    3,233       88     81,625    2,246
# 2020-05-15    3,199       88     84,824    2,333
# 2020-05-16    3,162       87     87,986    2,420
# 2020-05-17    3,121       87     91,107    2,507
