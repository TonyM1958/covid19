# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='CN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2020-05-21:
#   84,079 cases, 4,638 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-127 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-101 days, 4,690 cases)
#   End:         2020-03-06 (-75 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-117 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-96 days, 128 deaths)
#
# Parameters:
#   Totals:      84,063 cases and 4,638 deaths at end of 2020-05-18
#   Smoothed:    84,063 cases and 4,638 deaths at end of 2020-05-18 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-18, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
#                X = 80,835, r = 5.02, L = 18,759, dilation = 0.7, c = 84.1% for cases
#   Lag:         5 days (Peak Cases -> Peak Deaths)
#                X = 3,210, r = 4.05, L = 510, dilation = 1, c = 94.8% for deaths
#
# Outcome: 80,814 total cases, 3,099 total deaths at end of 2020-03-07
#   58 cases per million (0.01%), 2 deaths per million (0.000%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-08        0        0      83,976    4,637         6        0      83,990    4,637
# 2020-05-09       15        0      83,991    4,637         7        0      83,998    4,637
# 2020-05-10       19        0      84,010    4,637         8        0      84,005    4,637
# 2020-05-11        1        0      84,011    4,637         8        0      84,013    4,637
# 2020-05-12        7        0      84,018    4,637         9        0      84,022    4,637
# 2020-05-13        6        0      84,024    4,637         8    < 0.5      84,029    4,637
# 2020-05-14        5        0      84,029    4,637         6    < 0.5      84,036    4,637
# 2020-05-15        9        0      84,038    4,637         7    < 0.5      84,043    4,638
# 2020-05-16        6        1      84,044    4,638         7    < 0.5      84,050    4,638
# 2020-05-17       10        0      84,054    4,638         6    < 0.5      84,056    4,638
# 2020-05-18        9        0      84,063    4,638         7    < 0.5      84,063    4,638
# 2020-05-19        2        0      84,065    4,638
# 2020-05-20        2        0      84,067    4,638
# 2020-05-21       12        0      84,079    4,638

# %%
covid.Region(geoId='KR', dilation=3, d_cases=1).analyse(ylog=1)
# Out:
# South Korea data to end of 2020-05-21:
#   11,142 cases, 264 deaths
#   216 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-94 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-80 days, 608 cases)
#   End:         2020-03-15 (-66 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-74 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-66 days, 5 deaths)
#
# Parameters:
#   Totals:      11,078 cases and 263 deaths at end of 2020-05-18
#   Smoothed:    11,078 cases and 263 deaths at end of 2020-05-18 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-18, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
#                X = 8,489, r = 4.03, L = 2,433, dilation = 1, c = 93.3% for cases
#   Lag:         14 days (Peak Cases -> Peak Deaths)
#                X = 165, r = 4.0, L = 18, dilation = 3, c = 80.6% for deaths
#
# Outcome: 8,320 total cases, 81 total deaths at end of 2020-03-16
#   161 cases per million (0.02%), 2 deaths per million (0.000%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-08       18        0      10,840      256        19        1      10,849      256
# 2020-05-09       34        0      10,874      256        22        1      10,871      257
# 2020-05-10       35        0      10,909      256        26        1      10,897      257
# 2020-05-11       27        2      10,936      258        28        1      10,925      258
# 2020-05-12       26        1      10,962      259        28        1      10,953      259
# 2020-05-13       29        1      10,991      260        25        1      10,978      260
# 2020-05-14       27        0      11,018      260        22        1      11,000      261
# 2020-05-15       19        2      11,037      262        20        1      11,020      261
# 2020-05-16       13        0      11,050      262        21        1      11,042      262
# 2020-05-17       15        1      11,065      263        19        1      11,060      262
# 2020-05-18       13        0      11,078      263        18        1      11,078      263
# 2020-05-19       32        0      11,110      263
# 2020-05-20       12        1      11,122      264
# 2020-05-21       20        0      11,142      264

# %%
covid.Region(geoId='NZ', dilation=3.1).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-05-21:
#   1,154 cases, 21 deaths
#   236 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-62 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-55 days, 72 cases)
#   End:         2020-04-09 (-41 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,153 cases and 21 deaths at end of 2020-05-18
#   Smoothed:    1,153 cases and 21 deaths at end of 2020-05-18 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-18, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,107, r = 4.0, L = 289, dilation = 3.1, c = 89.1% for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
#   212 cases per million (0.02%), 1 deaths per million (0.000%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-08        1        0       1,142       21         1    < 0.5       1,144       21
# 2020-05-09        2        0       1,144       21         1        0       1,146       21
# 2020-05-10        3        0       1,147       21         1        0       1,147       21
# 2020-05-11        0        0       1,147       21         1        0       1,148       21
# 2020-05-12        0        0       1,147       21         1        0       1,149       21
# 2020-05-13        0        0       1,147       21         1        0       1,149       21
# 2020-05-14        1        0       1,148       21     < 0.5        0       1,150       21
# 2020-05-15        0        0       1,148       21         1        0       1,150       21
# 2020-05-16        1        0       1,149       21         1        0       1,151       21
# 2020-05-17        0        0       1,149       21         1        0       1,152       21
# 2020-05-18        4        0       1,153       21         1        0       1,153       21
# 2020-05-19        0        0       1,153       21
# 2020-05-20        0        0       1,153       21
# 2020-05-21        1        0       1,154       21

# %%
covid.Region(geoId='AU').analyse(ylog=1)
# Out:
# Australia data to end of 2020-05-21:
#   7,081 cases, 100 deaths
#   283 cases per million, 4 deaths per million (2018 population = 24,992,369)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-04 (-78 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-55 days, 391 cases)
#   End:         2020-04-18 (-32 days, 23 days after peak cases)
#   Day Zero:    2020-04-09 (-42 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-45 days, 4 deaths)
#
# Parameters:
#   Totals:      7,060 cases and 99 deaths at end of 2020-05-18
#   Smoothed:    7,060 cases and 99 deaths at end of 2020-05-18 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-18, compared to 7 days earlier)
#   Growth:      23 days (Start -> Peak Cases)
#                X = 6,625, r = 5.48, L = 1,563, dilation = 1, c = 87.5% for cases
#   Lag:         10 days (Peak Cases -> Peak Deaths)
#                X = 73, r = 5.16, L = 16, dilation = 1, c = 85.2% for deaths
#
# Outcome: 6,612 total cases, 70 total deaths at end of 2020-04-19
#   265 cases per million (0.03%), 3 deaths per million (0.000%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-08       18        0       6,914       97        18    < 0.5       6,912       97
# 2020-05-09       15        0       6,929       97        16    < 0.5       6,928       97
# 2020-05-10       12        0       6,941       97        14    < 0.5       6,943       97
# 2020-05-11        7        0       6,948       97        13    < 0.5       6,956       97
# 2020-05-12       16        0       6,964       97        15    < 0.5       6,971       98
# 2020-05-13       11        1       6,975       98        15    < 0.5       6,986       98
# 2020-05-14       14        0       6,989       98        15    < 0.5       7,001       98
# 2020-05-15       30        0       7,019       98        16    < 0.5       7,017       98
# 2020-05-16       17        0       7,036       98        15    < 0.5       7,032       98
# 2020-05-17        9        0       7,045       98        15    < 0.5       7,047       99
# 2020-05-18       15        1       7,060       99        13    < 0.5       7,060       99
# 2020-05-19        8        0       7,068       99
# 2020-05-20       11        1       7,079      100
# 2020-05-21        2        0       7,081      100

# %%
covid.Region(geoId='US', dilation=3.5, d_cases=7).analyse()
# Out:
# United States of America data to end of 2020-05-21:
#   1,577,287 cases, 94,702 deaths
#   4,821 cases per million, 289 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         66% through outbreak
#   Start:       2020-02-25 (-86 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-44 days, 31,930 cases)
#   End:         2020-06-29 ( 40 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-69 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-33 days, 2,699 deaths)
#
# Parameters:
#   Totals:      1,508,598 cases and 90,353 deaths at end of 2020-05-18
#   Smoothed:    1,508,597 cases and 90,353 deaths at end of 2020-05-18 (7 points)
#   Spread:      Peak infection rate 11.5 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-18, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
#                X = 2,458,555, r = 7.78, L = 127,718, dilation = 7, c = 90.7% for cases
#   Lag:         11 days (Peak Cases -> Peak Deaths)
#                X = 127,922, r = 6.73, L = 10,795, dilation = 3.5, c = 75.8% for deaths
#
# Outcome: 2,218,390 total cases, 123,562 total deaths by end of 2020-06-29
#   64.2% of predicted cases and 74.0% of predicted deaths reported to date
#   90.2% of predicted cases and 96.6% of predicted deaths reported by end date
#   7,515 cases per million (0.75%), 391 deaths per million (0.039%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-08   26,957    1,510   1,283,929   77,180    23,888    1,668   1,279,673   76,163
# 2020-05-09   25,612    1,614   1,309,541   78,794    23,632    1,606   1,303,305   77,768
# 2020-05-10   20,258      734   1,329,799   79,528    23,154    1,520   1,326,459   79,288
# 2020-05-11   18,117    1,156   1,347,916   80,684    22,979    1,453   1,349,438   80,742
# 2020-05-12   22,048    1,703   1,369,964   82,387    22,772    1,475   1,372,210   82,217
# 2020-05-13   20,782    1,746   1,390,746   84,133    22,612    1,414   1,394,822   83,631
# 2020-05-14   27,143    1,773   1,417,889   85,906    22,414    1,425   1,417,235   85,056
# 2020-05-15   25,508    1,662   1,443,397   87,568    22,946    1,373   1,440,181   86,429
# 2020-05-16   24,487    1,186   1,467,884   88,754    22,649    1,354   1,462,830   87,783
# 2020-05-17   18,873      808   1,486,757   89,562    23,006    1,321   1,485,836   89,104
# 2020-05-18   21,841      791   1,508,598   90,353    22,762    1,249   1,508,598   90,353
# 2020-05-19   19,970    1,568   1,528,568   91,921
# 2020-05-20   23,285    1,518   1,551,853   93,439
# 2020-05-21   25,434    1,263   1,577,287   94,702
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-18   23,455    1,500  1,508,598   90,353
# 2020-05-19   23,147    1,459  1,531,745   91,812
# 2020-05-20   22,836    1,419  1,554,581   93,231
# 2020-05-21   22,525    1,378  1,577,106   94,610  <-- latest raw data
# 2020-05-22   22,211    1,338  1,599,317   95,948
# 2020-05-23   21,897    1,298  1,621,214   97,246
# 2020-05-24   21,582    1,259  1,642,796   98,505
# 2020-05-25   21,266    1,220  1,664,061   99,725
# 2020-05-26   20,950    1,182  1,685,011  100,907
# 2020-05-27   20,633    1,144  1,705,644  102,052

# %%
covid.Region(geoId='RU', lag=5, dilation=2.5, d_cases=1.4).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-21:
#   317,554 cases, 3,099 deaths
#   2,198 cases per million, 21 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         49% through outbreak
#   Start:       2020-03-14 (-68 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 (-12 days, 10,988 cases)
#   End:         2020-07-25 ( 66 days, 78 days after peak cases)
#   Day Zero:    2020-04-06 (-45 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-18 ( -3 days, 112 deaths)
#
# Parameters:
#   Totals:      290,678 cases and 2,722 deaths at end of 2020-05-18
#   Smoothed:    290,678 cases and 2,722 deaths at end of 2020-05-18 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-18, compared to 7 days earlier)
#   Growth:      56 days (Start -> Peak Cases)
#                X = 461,242, r = 6.34, L = 43,953, dilation = 1.4, c = 92.8% for cases
#   Lag:         9 days (Peak Cases -> Peak Deaths)
#                X = 8,945, r = 4.53, L = 449, dilation = 2.5, c = 86.4% for deaths
#
# Outcome: 460,406 total cases, 8,079 total deaths by end of 2020-07-25
#   68.8% of predicted cases and 34.6% of predicted deaths reported to date
#   99.8% of predicted cases and 90.3% of predicted deaths reported by end date
#   3,192 cases per million (0.32%), 62 deaths per million (0.006%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-08   10,699       98     187,859    1,723    10,875       92     188,117    1,712
# 2020-05-09   10,817      104     198,676    1,827    10,988       94     199,106    1,806
# 2020-05-10   11,012       88     209,688    1,915    10,913       96     210,019    1,902
# 2020-05-11   11,656       94     221,344    2,009    10,733       96     220,751    1,998
# 2020-05-12   10,899      107     232,243    2,116    10,718       98     231,470    2,097
# 2020-05-13   10,028       96     242,271    2,212    10,487      101     241,957    2,197
# 2020-05-14    9,974       93     252,245    2,305    10,301      101     252,258    2,299
# 2020-05-15   10,598      113     262,843    2,418     9,911      101     262,169    2,400
# 2020-05-16    9,200      119     272,043    2,537     9,677      102     271,846    2,502
# 2020-05-17    9,709       94     281,752    2,631     9,496      108     281,342    2,610
# 2020-05-18    8,926       91     290,678    2,722     9,336      112     290,678    2,722
# 2020-05-19    9,263      115     299,941    2,837
# 2020-05-20    8,764      135     308,705    2,972
# 2020-05-21    8,849      127     317,554    3,099
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-18    9,578      109    290,678    2,722
# 2020-05-19    9,298      109    299,976    2,831
# 2020-05-20    9,001      109    308,977    2,940
# 2020-05-21    8,690      109    317,668    3,049  <-- latest raw data
# 2020-05-22    8,368      109    326,036    3,157
# 2020-05-23    8,038      108    334,074    3,265
# 2020-05-24    7,702      108    341,776    3,373
# 2020-05-25    7,364      108    349,140    3,481
# 2020-05-26    7,024      107    356,164    3,588
# 2020-05-27    6,686      107    362,850    3,695

# %%
covid.Region(geoId='JP', dilation=2.1, d_cases=1.3).analyse(ylog=1)
# Out:
# Japan data to end of 2020-05-21:
#   16,513 cases, 796 deaths
#   131 cases per million, 6 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         70% through outbreak
#   Start:       2020-02-16 (-95 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-38 days, 643 cases)
#   End:         2020-06-25 ( 36 days, 74 days after peak cases)
#   Day Zero:    2020-03-28 (-54 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-26 days, 29 deaths)
#
# Parameters:
#   Totals:      16,365 cases and 763 deaths at end of 2020-05-18
#   Smoothed:    16,365 cases and 762 deaths at end of 2020-05-18 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-18, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
#                X = 16,765, r = 8.0, L = 2,572, dilation = 1.3, c = 68.8% for cases
#   Lag:         12 days (Peak Cases -> Peak Deaths)
#                X = 988, r = 8.0, L = 116, dilation = 2.1, c = 61.9% for deaths
#
# Outcome: 16,759 total cases, 973 total deaths by end of 2020-06-25
#   98.5% of predicted cases and 80.5% of predicted deaths reported to date
#   100.0% of predicted cases and 98.4% of predicted deaths reported by end date
#   133 cases per million (0.01%), 8 deaths per million (0.001%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-08       81       44      15,628      601        92       17      15,636      592
# 2020-05-09      119       12      15,747      613        96       18      15,731      610
# 2020-05-10       51        8      15,798      621        88       19      15,820      629
# 2020-05-11       76       22      15,874      643        92       22      15,912      651
# 2020-05-12      150       25      16,024      668        87       18      15,999      669
# 2020-05-13       55       19      16,079      687        77       19      16,076      687
# 2020-05-14      114       23      16,193      710        72       18      16,148      706
# 2020-05-15       44       15      16,237      725        70       17      16,218      723
# 2020-05-16       48       19      16,285      744        52       15      16,270      738
# 2020-05-17       20        5      16,305      749        49       13      16,319      751
# 2020-05-18       60       14      16,365      763        46       12      16,365      763
# 2020-05-19       20        8      16,385      771
# 2020-05-20       39        6      16,424      777
# 2020-05-21       89       19      16,513      796
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-18       45       13     16,365      763
# 2020-05-19       40       13     16,405      776
# 2020-05-20       36       12     16,442      788
# 2020-05-21       33       11     16,474      799  <-- latest raw data
# 2020-05-22       29       11     16,504      810
# 2020-05-23       27       10     16,530      820
# 2020-05-24       24       10     16,554      830
# 2020-05-25       22        9     16,576      840
# 2020-05-26       19        9     16,595      849
# 2020-05-27       17        8     16,613      857

# %%
covid.Region(geoId='SG', dilation=3.3).analyse()
# Out:
# Singapore data to end of 2020-05-21:
#   29,812 cases, 23 deaths
#   5,287 cases per million, 4 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         45% through outbreak
#   Start:       2020-02-12 (-99 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-28 days, 1,004 cases)
#   End:         2020-09-11 (114 days, 142 days after peak cases)
#
# Parameters:
#   Totals:      28,343 cases and 22 deaths at end of 2020-05-18
#   Smoothed:    28,342 cases and 21 deaths at end of 2020-05-18 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-18, compared to 7 days earlier)
#   Growth:      71 days (Start -> Peak Cases)
#                X = 51,589, r = 8.0, L = 4,016, dilation = 3.3, c = 51.7% for cases
#
# Outcome: 51,188 total cases, 53 total deaths by end of 2020-09-11
#   57.8% of predicted cases and 41.9% of predicted deaths reported to date
#   99.2% of predicted cases and 96.5% of predicted deaths reported by end date
#   9,149 cases per million (0.91%), 10 deaths per million (0.001%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-08      768        0      21,707       20       715    < 0.5      21,669       20
# 2020-05-09      753        0      22,460       20       751    < 0.5      22,420       20
# 2020-05-10      876        0      23,336       20       735    < 0.5      23,155       20
# 2020-05-11      451        1      23,787       21       736    < 0.5      23,891       21
# 2020-05-12      884        0      24,671       21       740    < 0.5      24,631       21
# 2020-05-13      675        0      25,346       21       699    < 0.5      25,330       21
# 2020-05-14      752        0      26,098       21       671    < 0.5      26,001       21
# 2020-05-15      793        0      26,891       21       650    < 0.5      26,651       21
# 2020-05-16      465        1      27,356       22       588    < 0.5      27,240       22
# 2020-05-17      682        0      28,038       22       573    < 0.5      27,813       22
# 2020-05-18      305        0      28,343       22       530    < 0.5      28,343       22
# 2020-05-19      451        0      28,794       22
# 2020-05-20      570        0      29,364       22
# 2020-05-21      448        1      29,812       23
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-18      569        1     28,343       22
# 2020-05-19      561        1     28,904       23
# 2020-05-20      553        1     29,457       23
# 2020-05-21      545        1     30,002       24  <-- latest raw data
# 2020-05-22      536        1     30,538       24
# 2020-05-23      528        1     31,066       25
# 2020-05-24      519        1     31,586       25
# 2020-05-25      511        1     32,096       26
# 2020-05-26      502        1     32,598       26
# 2020-05-27      493        1     33,092       27

# %%
covid.Region(geoId='BR', growth_days=76, lag=5, dilation=3).analyse()
# Out:
# Brazil data to end of 2020-05-21:
#   310,087 cases, 20,047 deaths
#   1,480 cases per million, 96 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         30% through outbreak
#   Start:       2020-03-11 (-71 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-26 (  5 days, 0 cases)
#   End:         2020-10-24 (157 days, 152 days after peak cases)
#   Day Zero:    2020-03-25 (-57 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-31 ( 10 days)
#
# Parameters:
#   Totals:      254,220 cases and 16,792 deaths at end of 2020-05-18
#   Smoothed:    254,220 cases and 16,792 deaths at end of 2020-05-18 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.6 (2020-05-18, compared to 7 days earlier)
#   Growth:      76 days (Start -> Peak Cases)
#                X = 1,489,044, r = 6.7, L = 67,646, dilation = 3, c = 89.0% for cases
#   Lag:         5 days (Peak Cases -> Peak Deaths)
#                X = 113,434, r = 5.33, L = 4,134, dilation = 3, c = 93.1% for deaths
#
# Outcome: 1,472,171 total cases, 109,893 total deaths by end of 2020-10-24
#   20.8% of predicted cases and 17.7% of predicted deaths reported to date
#   98.9% of predicted cases and 96.9% of predicted deaths reported by end date
#   7,109 cases per million (0.71%), 542 deaths per million (0.054%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-08   10,222      751     145,328    9,897     8,458      586     140,709    9,604
# 2020-05-09   10,611      730     155,939   10,627     8,783      626     149,492   10,230
# 2020-05-10    6,760      496     162,699   11,123     8,906      644     158,397   10,874
# 2020-05-11    5,632      396     168,331   11,519     9,472      677     167,870   11,551
# 2020-05-12    9,258      881     177,589   12,400    10,182      687     178,052   12,238
# 2020-05-13   11,385      749     188,974   13,149    10,784      699     188,836   12,937
# 2020-05-14   13,944      844     202,918   13,993    10,949      698     199,785   13,635
# 2020-05-15   15,305      824     218,223   14,817    11,997      736     211,782   14,371
# 2020-05-16   14,919      816     233,142   15,633    13,136      778     224,918   15,149
# 2020-05-17    7,938      485     241,080   16,118    14,332      797     239,250   15,947
# 2020-05-18   13,140      674     254,220   16,792    14,970      845     254,220   16,792
# 2020-05-19   17,408    1,179     271,628   17,971
# 2020-05-20   19,951      888     291,579   18,859
# 2020-05-21   18,508    1,188     310,087   20,047
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-18   14,628      828    254,220   16,792
# 2020-05-19   15,045      853    269,265   17,645
# 2020-05-20   15,420      876    284,686   18,521
# 2020-05-21   15,747      898    300,433   19,418  <-- latest raw data
# 2020-05-22   16,021      918    316,454   20,336
# 2020-05-23   16,239      937    332,693   21,273
# 2020-05-24   16,397      954    349,091   22,228
# 2020-05-25   16,493      969    365,584   23,197
# 2020-05-26   16,525      982    382,109   24,179
# 2020-05-27   16,522      993    398,631   25,172

# %%
covid.Region(geoId='MX', growth_days=70, dilation=3).analyse()
# Out:
# Mexico data to end of 2020-05-21:
#   59,567 cases, 6,510 deaths
#   472 cases per million, 52 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         30% through outbreak
#   Start:       2020-03-15 (-67 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-24 (  3 days, --- cases)
#   End:         2020-10-10 (143 days, 140 days after peak cases)
#   Day Zero:    2020-04-02 (-49 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-28 (  7 days)
#
# Parameters:
#   Totals:      51,633 cases and 5,332 deaths at end of 2020-05-18
#   Smoothed:    51,632 cases and 5,332 deaths at end of 2020-05-18 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-18, compared to 7 days earlier)
#   Growth:      70 days (Start -> Peak Cases)
#                X = 258,964, r = 5.34, L = 10,156, dilation = 3, c = 93.6% for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#                X = 32,722, r = 5.44, L = 1,301, dilation = 3, c = 91.2% for deaths
#
# Outcome: 251,820 total cases, 31,783 total deaths by end of 2020-10-10
#   23.0% of predicted cases and 19.9% of predicted deaths reported to date
#   97.2% of predicted cases and 97.1% of predicted deaths reported by end date
#   2,052 cases per million (0.21%), 259 deaths per million (0.026%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-08    1,906      199      31,522    3,160     1,622      180      31,191    3,002
# 2020-05-09    1,938      193      33,460    3,353     1,747      196      32,938    3,198
# 2020-05-10    1,562      112      35,022    3,465     1,783      209      34,720    3,407
# 2020-05-11    1,305      108      36,327    3,573     1,843      209      36,564    3,617
# 2020-05-12    1,997      353      38,324    3,926     1,919      222      38,483    3,839
# 2020-05-13    1,862      294      40,186    4,220     1,944      234      40,426    4,073
# 2020-05-14    2,409      257      42,595    4,477     2,016      237      42,443    4,309
# 2020-05-15    2,437      290      45,032    4,767     2,174      243      44,616    4,552
# 2020-05-16    2,112      278      47,144    5,045     2,276      240      46,892    4,793
# 2020-05-17    2,075      132      49,219    5,177     2,330      258      49,222    5,051
# 2020-05-18    2,414      155      51,633    5,332     2,411      281      51,633    5,332
# 2020-05-19    2,713      334      54,346    5,666
# 2020-05-20    2,248      424      56,594    6,090
# 2020-05-21    2,973      420      59,567    6,510
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-18    2,387      279     51,633    5,332
# 2020-05-19    2,425      287     54,058    5,619
# 2020-05-20    2,456      294     56,514    5,913
# 2020-05-21    2,481      300     58,995    6,213  <-- latest raw data
# 2020-05-22    2,499      306     61,495    6,519
# 2020-05-23    2,510      311     64,005    6,831
# 2020-05-24    2,514      316     66,519    7,146
# 2020-05-25    2,514      319     69,033    7,465
# 2020-05-26    2,512      321     71,545    7,786
# 2020-05-27    2,510      323     74,056    8,109

# %%
covid.Region(geoId='PE', growth_days=68, dilation=2.5, d_cases=3).analyse()
# Out:
# Peru data to end of 2020-05-21:
#   108,769 cases, 3,148 deaths
#   3,400 cases per million, 98 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         31% through outbreak
#   Start:       2020-03-15 (-67 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-22 (  1 days, --- cases)
#   End:         2020-10-04 (137 days, 136 days after peak cases)
#   Day Zero:    2020-04-02 (-49 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-18 ( -3 days, 126 deaths)
#
# Parameters:
#   Totals:      94,933 cases and 2,789 deaths at end of 2020-05-18
#   Smoothed:    94,933 cases and 2,789 deaths at end of 2020-05-18 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-18, compared to 7 days earlier)
#   Growth:      68 days (Start -> Peak Cases)
#                X = 430,131, r = 4.83, L = 16,227, dilation = 3, c = 88.0% for cases
#   Lag:         -4 days (Peak Cases -> Peak Deaths)
#                X = 9,568, r = 5.92, L = 505, dilation = 2.5, c = 88.6% for deaths
#
# Outcome: 413,586 total cases, 9,496 total deaths by end of 2020-10-04
#   25.3% of predicted cases and 32.9% of predicted deaths reported to date
#   96.2% of predicted cases and 99.2% of predicted deaths reported by end date
#   13,446 cases per million (1.34%), 299 deaths per million (0.030%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-08    3,321       87      61,847    1,714     3,028       89      60,346    1,719
# 2020-05-09    3,168      100      65,015    1,814     2,946       88      63,293    1,807
# 2020-05-10    2,292       75      67,307    1,889     3,034       91      66,326    1,898
# 2020-05-11    1,515       72      68,822    1,961     3,117       92      69,443    1,990
# 2020-05-12    3,237       96      72,059    2,057     3,197       97      72,641    2,088
# 2020-05-13    4,247      112      76,306    2,169     3,321      102      75,962    2,189
# 2020-05-14    4,298       98      80,604    2,267     3,525      109      79,486    2,298
# 2020-05-15    3,891      126      84,495    2,393     3,686      119      83,173    2,417
# 2020-05-16    4,046      130      88,541    2,523     3,872      123      87,044    2,540
# 2020-05-17    3,732      125      92,273    2,648     3,913      123      90,957    2,663
# 2020-05-18    2,660      141      94,933    2,789     3,976      126      94,933    2,789
# 2020-05-19    4,550      125      99,483    2,914
# 2020-05-20    4,537      110     104,020    3,024
# 2020-05-21    4,749      124     108,769    3,148
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-18    3,836      120     94,933    2,789
# 2020-05-19    3,870      120     98,803    2,909
# 2020-05-20    3,894      120    102,697    3,028
# 2020-05-21    3,909      119    106,607    3,148  <-- latest raw data
# 2020-05-22    3,914      119    110,521    3,267
# 2020-05-23    3,914      119    114,434    3,386
# 2020-05-24    3,912      118    118,346    3,504
# 2020-05-25    3,909      118    122,255    3,622
# 2020-05-26    3,905      117    126,161    3,739
# 2020-05-27    3,900      117    130,061    3,856

# %%
covid.Region(geoId='CL').analyse(ylog=1)
# Out:
# Chile data to end of 2020-05-21:
#   57,581 cases, 589 deaths
#   3,074 cases per million, 31 deaths per million (2018 population = 18,729,160)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         50% through outbreak
#   Start:       2020-03-13 (-69 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-18 ( -3 days, 2,854 cases)
#   End:         2020-07-22 ( 63 days, 66 days after peak cases)
#   Day Zero:    2020-04-08 (-43 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-22 (  1 days)
#
# Parameters:
#   Totals:      46,059 cases and 478 deaths at end of 2020-05-18
#   Smoothed:    46,059 cases and 478 deaths at end of 2020-05-18 (7 points)
#   Spread:      Peak infection rate 4.2 (2020-03-22, compared to 7 days earlier)
#                Latest infection rate 1.6 (2020-05-18, compared to 7 days earlier)
#   Growth:      66 days (Start -> Peak Cases)
#                X = 89,433, r = 8.0, L = 11,414, dilation = 1, c = 64.3% for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#                X = 1,209, r = 8.0, L = 138, dilation = 1, c = 44.0% for deaths
#
# Outcome: 89,403 total cases, 1,208 total deaths by end of 2020-07-22
#   64.4% of predicted cases and 48.7% of predicted deaths reported to date
#   100.0% of predicted cases and 99.9% of predicted deaths reported by end date
#   4,775 cases per million (0.48%), 65 deaths per million (0.006%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-05-08    1,391        9      25,972      294     1,309        7      25,246      293
# 2020-05-09    1,247       10      27,219      304     1,348        8      26,594      301
# 2020-05-10    1,647        8      28,866      312     1,574        9      28,168      311
# 2020-05-11    1,197       11      30,063      323     1,731       10      29,899      321
# 2020-05-12    1,658       12      31,721      335     1,885       14      31,784      335
# 2020-05-13    2,660       11      34,381      346     1,974       17      33,758      351
# 2020-05-14    2,659       12      37,040      358     2,072       19      35,830      371
# 2020-05-15    2,502       36      39,542      394     2,222       22      38,052      393
# 2020-05-16    1,886       27      41,428      421     2,481       25      40,533      417
# 2020-05-17    2,353       29      43,781      450     2,672       28      43,205      445
# 2020-05-18    2,278       28      46,059      478     2,854       33      46,059      478
# 2020-05-19    3,520       31      49,579      509
# 2020-05-20    4,038       35      53,617      544
# 2020-05-21    3,964       45      57,581      589
#
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-05-18    2,711       35     46,059      478
# 2020-05-19    2,701       35     48,760      513
# 2020-05-20    2,672       36     51,432      550
# 2020-05-21    2,623       37     54,055      586  <-- latest raw data
# 2020-05-22    2,558       37     56,613      623
# 2020-05-23    2,477       37     59,089      659
# 2020-05-24    2,382       36     61,471      695
# 2020-05-25    2,276       35     63,747      731
# 2020-05-26    2,162       35     65,909      765
# 2020-05-27    2,041       33     67,950      799
