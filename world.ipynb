# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='CN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2020-05-19:
#   84,065 cases, 4,638 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-125 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-99 days, 4,689 cases)
#   End:         2020-03-06 (-73 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-115 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-94 days, 128 deaths)
#
# Parameters:
#   Totals:      84,044 cases and 4,638 deaths at end of 2020-05-16
#   Smoothed:    84,043 cases and 4,638 deaths at end of 2020-05-16 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-16, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='KR', dilation=3, d_cases=1).analyse(ylog=1)
# Out:
# South Korea data to end of 2020-05-19:
#   11,110 cases, 263 deaths
#   215 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-92 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-78 days, 609 cases)
#   End:         2020-03-15 (-64 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-72 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-64 days, 5 deaths)
#
# Parameters:
#   Totals:      11,050 cases and 262 deaths at end of 2020-05-16
#   Smoothed:    11,050 cases and 262 deaths at end of 2020-05-16 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-16, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZ', dilation=3.1).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-05-19:
#   1,153 cases, 21 deaths
#   236 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-60 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-53 days, 72 cases)
#   End:         2020-04-09 (-39 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,149 cases and 21 deaths at end of 2020-05-16
#   Smoothed:    1,149 cases and 21 deaths at end of 2020-05-16 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-16, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,105, r = 4.0, L = 288, dilation = 3.1, c = 89.1% for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
# ...

# %%
covid.Region(geoId='US', dilation=2.5, d_cases=5).analyse()
# Out:
# United States of America data to end of 2020-05-19:
#   1,528,568 cases, 91,921 deaths
#   4,672 cases per million, 281 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         64% through outbreak
#   Start:       2020-02-25 (-84 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-42 days, 32,040 cases)
#   End:         2020-06-29 ( 42 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-67 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-31 days, 2,729 deaths)
#
# Parameters:
#   Totals:      1,467,884 cases and 88,754 deaths at end of 2020-05-16
#   Smoothed:    1,467,883 cases and 88,754 deaths at end of 2020-05-16 (7 points)
#   Spread:      Peak infection rate 12.5 (2020-03-07, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-16, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RU', lag=5, dilation=2.5, d_cases=2).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-19:
#   299,941 cases, 2,837 deaths
#   2,076 cases per million, 20 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         38% through outbreak
#   Start:       2020-03-14 (-66 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 (-10 days, 10,996 cases)
#   End:         2020-08-28 (102 days, 112 days after peak cases)
#   Day Zero:    2020-04-06 (-43 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-16 ( -3 days, 104 deaths)
#
# Parameters:
#   Totals:      272,043 cases and 2,537 deaths at end of 2020-05-16
#   Smoothed:    272,043 cases and 2,537 deaths at end of 2020-05-16 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-16, compared to 7 days earlier)
#   Growth:      56 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP', dilation=2.4, d_cases=1.3).analyse(ylog=1)
# Out:
# Japan data to end of 2020-05-19:
#   16,385 cases, 771 deaths
#   129 cases per million, 6 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         69% through outbreak
#   Start:       2020-02-16 (-93 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-36 days, 644 cases)
#   End:         2020-06-25 ( 38 days, 74 days after peak cases)
#   Day Zero:    2020-03-28 (-52 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-24 days, 29 deaths)
#
# Parameters:
#   Totals:      16,285 cases and 744 deaths at end of 2020-05-16
#   Smoothed:    16,284 cases and 744 deaths at end of 2020-05-16 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-16, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SG', dilation=4.2).analyse()
# Out:
# Singapore data to end of 2020-05-19:
#   28,794 cases, 22 deaths
#   5,107 cases per million, 4 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         44% through outbreak
#   Start:       2020-02-11 (-98 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-26 days, 1,008 cases)
#   End:         2020-09-13 (118 days, 144 days after peak cases)
#
# Parameters:
#   Totals:      27,356 cases and 22 deaths at end of 2020-05-16
#   Smoothed:    27,356 cases and 22 deaths at end of 2020-05-16 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-16, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                X = 61,925, r = 8.0, L = 4,033, dilation = 4.2, c = 49.4% for cases
#
# Outcome: 60,583 total cases, 65 total deaths by end of 2020-09-13
# ...

# %%
covid.Region(geoId='BR', growth_days=70, dilation=2.5).analyse()
# Out:
# Brazil data to end of 2020-05-19:
#   271,628 cases, 17,408 deaths
#   1,297 cases per million, 83 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         31% through outbreak
#   Start:       2020-03-11 (-69 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-20 (  1 days, --- cases)
#   End:         2020-10-06 (141 days, 140 days after peak cases)
#   Day Zero:    2020-03-24 (-56 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-16 ( -3 days, 726 deaths)
#
# Parameters:
#   Totals:      233,142 cases and 15,633 deaths at end of 2020-05-16
#   Smoothed:    233,141 cases and 15,633 deaths at end of 2020-05-16 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.5 (2020-05-16, compared to 7 days earlier)
#   Growth:      70 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MX', growth_days=65, dilation=3).analyse()
# Out:
# Mexico data to end of 2020-05-19:
#   54,346 cases, 5,666 deaths
#   431 cases per million, 45 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         32% through outbreak
#   Start:       2020-03-15 (-65 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-19 (  0 days, --- cases)
#   End:         2020-09-25 (130 days, 130 days after peak cases)
#   Day Zero:    2020-04-02 (-47 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-15 ( -4 days, 256 deaths)
#
# Parameters:
#   Totals:      47,144 cases and 5,045 deaths at end of 2020-05-16
#   Smoothed:    47,143 cases and 5,044 deaths at end of 2020-05-16 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-16, compared to 7 days earlier)
#   Growth:      65 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='PE', growth_days=67, dilation=2.5, d_cases=3).analyse()
# Out:
# Peru data to end of 2020-05-19:
#   99,483 cases, 2,914 deaths
#   3,110 cases per million, 91 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         31% through outbreak
#   Start:       2020-03-15 (-65 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-21 (  2 days, --- cases)
#   End:         2020-10-01 (136 days, 134 days after peak cases)
#   Day Zero:    2020-04-02 (-47 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-25 (  6 days)
#
# Parameters:
#   Totals:      88,541 cases and 2,523 deaths at end of 2020-05-16
#   Smoothed:    88,541 cases and 2,523 deaths at end of 2020-05-16 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-16, compared to 7 days earlier)
#   Growth:      67 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='AU').analyse(ylog=1)
# Out:
# Australia data to end of 2020-05-19:
#   7,068 cases, 99 deaths
#   283 cases per million, 4 deaths per million (2018 population = 24,992,369)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-04 (-76 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-53 days, 391 cases)
#   End:         2020-04-18 (-30 days, 23 days after peak cases)
#   Day Zero:    2020-04-09 (-40 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-43 days, 4 deaths)
#
# Parameters:
#   Totals:      7,036 cases and 98 deaths at end of 2020-05-16
#   Smoothed:    7,035 cases and 97 deaths at end of 2020-05-16 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-16, compared to 7 days earlier)
#   Growth:      23 days (Start -> Peak Cases)
# ...
