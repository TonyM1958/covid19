# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=0, ylog=1, dilation=3, d_clip=3)
covid.data_load('download.json')

# %%
covid.Region(geoId='US', dilation=4.6, d_cases=15).analyse()
# Out:
# United States of America data to end of 2020-06-18:
#   2,191,052 cases, 118,434 deaths
#   6,658 cases per million, 360 deaths per million (2019 population = 329,064,917)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         66% through outbreak
#   Start:       2020-02-25 (-114 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-72 days, 31,887 cases)
#   End:         2020-08-10 ( 54 days, 126 days after peak cases)
#   Day Zero:    2020-03-13 (-97 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-61 days, 2,708 deaths)
#
# Parameters:
#   Totals:      2,114,026 cases and 116,127 deaths at end of 2020-06-15
#   Smoothed:    2,114,025 cases and 116,127 deaths at end of 2020-06-15 (7 points)
#   Spread:      Peak infection rate 11.5 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-06-15, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RU', dilation=2.8, d_cases=5).analyse()
# Out:
# Russia data to end of 2020-06-18:
#   561,091 cases, 7,790 deaths
#   4,897 cases per million, 68 deaths per million (2019 population = 114,587,226)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         42% through outbreak
#   Start:       2020-03-14 (-96 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 (-40 days, 10,990 cases)
#   End:         2020-10-23 (128 days, 168 days after peak cases)
#   Day Zero:    2020-04-06 (-73 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-15 ( -3 days, 178 deaths)
#
# Parameters:
#   Totals:      537,210 cases and 7,091 deaths at end of 2020-06-15
#   Smoothed:    537,209 cases and 7,091 deaths at end of 2020-06-15 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-06-15, compared to 7 days earlier)
#   Growth:      56 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP', dilation=1.8, d_cases=3).analyse()
# Out:
# Japan data to end of 2020-06-18:
#   17,740 cases, 935 deaths
#   140 cases per million, 7 deaths per million (2019 population = 126,860,299)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         53% through outbreak
#   Start:       2020-02-16 (-123 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-66 days, 644 cases)
#   End:         2020-09-30 (105 days, 171 days after peak cases)
#   Day Zero:    2020-03-28 (-82 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-54 days, 29 deaths)
#
# Parameters:
#   Totals:      17,587 cases and 927 deaths at end of 2020-06-15
#   Smoothed:    17,587 cases and 926 deaths at end of 2020-06-15 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 1.5 (2020-06-15, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SG').analyse()
# Out:
# Singapore data to end of 2020-06-18:
#   41,473 cases, 26 deaths
#   7,145 cases per million, 4 deaths per million (2019 population = 5,804,343)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         43% through outbreak
#   Start:       2020-02-11 (-128 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-56 days, 1,007 cases)
#   End:         2020-11-24 (160 days, 216 days after peak cases)
#
# Parameters:
#   Totals:      40,818 cases and 26 deaths at end of 2020-06-15
#   Smoothed:    40,818 cases and 25 deaths at end of 2020-06-15 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-06-15, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                X = 49,876, r = 8.0, L = 4,029, dilation = 3, c = 54.4% for cases
#
# Outcome: 49,859 total cases, 34 total deaths by end of 2020-11-24
# ...

# %%
covid.Region(geoId='BR').analyse()
# Out:
# Brazil data to end of 2020-06-18:
#   978,142 cases, 47,748 deaths
#   4,635 cases per million, 226 deaths per million (2019 population = 211,049,519)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         27% through outbreak
#   Start:       2020-03-11 (-99 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-07 (-11 days, 26,598 cases)
#   End:         2021-02-25 (253 days, 264 days after peak cases)
#   Day Zero:    2020-03-25 (-85 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-01 (-17 days, 1,026 deaths)
#
# Parameters:
#   Totals:      888,271 cases and 43,959 deaths at end of 2020-06-15
#   Smoothed:    888,270 cases and 43,958 deaths at end of 2020-06-15 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-06-15, compared to 7 days earlier)
#   Growth:      88 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='CL').analyse()
# Out:
# Chile data to end of 2020-06-18:
#   225,103 cases, 3,841 deaths
#   11,878 cases per million, 203 deaths per million (2019 population = 18,952,035)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         25% through outbreak
#   Start:       2020-03-13 (-97 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-14 ( -4 days, 9,865 cases)
#   End:         2021-03-19 (275 days, 279 days after peak cases)
#   Day Zero:    2020-04-08 (-71 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-10 ( -8 days, 223 deaths)
#
# Parameters:
#   Totals:      179,436 cases and 3,362 deaths at end of 2020-06-15
#   Smoothed:    179,436 cases and 3,361 deaths at end of 2020-06-15 (7 points)
#   Spread:      Peak infection rate 4.2 (2020-03-22, compared to 7 days earlier)
#                Latest infection rate 2.0 (2020-06-15, compared to 7 days earlier)
#   Growth:      93 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='PE').analyse()
# Out:
# Peru data to end of 2020-06-18:
#   244,388 cases, 7,461 deaths
#   7,517 cases per million, 229 deaths per million (2019 population = 32,510,462)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         31% through outbreak
#   Start:       2020-03-15 (-95 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-29 (-20 days, 6,580 cases)
#   End:         2021-01-08 (205 days, 225 days after peak cases)
#   Day Zero:    2020-04-02 (-77 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-14 ( -4 days, 193 deaths)
#
# Parameters:
#   Totals:      232,992 cases and 6,860 deaths at end of 2020-06-15
#   Smoothed:    232,992 cases and 6,860 deaths at end of 2020-06-15 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-06-15, compared to 7 days earlier)
#   Growth:      75 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MX').analyse()
# Out:
# Mexico data to end of 2020-06-18:
#   165,455 cases, 19,747 deaths
#   1,297 cases per million, 155 deaths per million (2019 population = 127,575,529)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         25% through outbreak
#   Start:       2020-03-15 (-95 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-15 ( -3 days, 4,466 cases)
#   End:         2021-03-17 (273 days, 276 days after peak cases)
#   Day Zero:    2020-04-02 (-77 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-06 (-12 days, 563 deaths)
#
# Parameters:
#   Totals:      150,264 cases and 17,580 deaths at end of 2020-06-15
#   Smoothed:    150,264 cases and 17,580 deaths at end of 2020-06-15 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-06-15, compared to 7 days earlier)
#   Growth:      92 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IN').analyse()
# Out:
# India data to end of 2020-06-18:
#   380,532 cases, 12,573 deaths
#   278 cases per million, 9 deaths per million (2019 population = 1,366,417,756)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         25% through outbreak
#   Start:       2020-03-10 (-100 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-15 ( -3 days, 11,830 cases)
#   End:         2021-04-01 (288 days, 291 days after peak cases)
#   Day Zero:    2020-04-02 (-77 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-13 ( -5 days, 555 deaths)
#
# Parameters:
#   Totals:      343,091 cases and 9,900 deaths at end of 2020-06-15
#   Smoothed:    343,091 cases and 9,900 deaths at end of 2020-06-15 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-02, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-06-15, compared to 7 days earlier)
#   Growth:      97 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='CN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2020-06-18:
#   84,494 cases, 4,638 deaths
#   59 cases per million, 3 deaths per million (2019 population = 1,433,783,692)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-155 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-129 days, 4,690 cases)
#   End:         2020-03-06 (-103 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-145 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-124 days, 128 deaths)
#
# Parameters:
#   Totals:      84,378 cases and 4,638 deaths at end of 2020-06-15
#   Smoothed:    84,377 cases and 4,637 deaths at end of 2020-06-15 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 6.2 (2020-06-15, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='KR', d_cases=1).analyse(ylog=1)
# Out:
# South Korea data to end of 2020-06-18:
#   12,306 cases, 280 deaths
#   240 cases per million, 5 deaths per million (2019 population = 51,225,321)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-122 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-108 days, 608 cases)
#   End:         2020-03-15 (-94 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-102 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-94 days, 5 deaths)
#
# Parameters:
#   Totals:      12,155 cases and 278 deaths at end of 2020-06-15
#   Smoothed:    12,155 cases and 278 deaths at end of 2020-06-15 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-06-15, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZ', d_cases=3).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-06-18:
#   1,157 cases, 22 deaths
#   242 cases per million, 5 deaths per million (2019 population = 4,783,062)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-90 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-83 days, 72 cases)
#   End:         2020-04-16 (-62 days, 21 days after peak cases)
#
# Parameters:
#   Totals:      1,156 cases and 22 deaths at end of 2020-06-15
#   Smoothed:    1,156 cases and 21 deaths at end of 2020-06-15 (7 points)
#   Spread:      Peak infection rate 2.5 (2020-05-21, compared to 7 days earlier)
#                Latest infection rate 0.0 (2020-05-31, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,113, r = 4.0, L = 288, dilation = 3, c = 88.7% for cases
#
# Outcome: 1,094 total cases, 11 total deaths at end of 2020-04-17
# ...

# %%
covid.Region(geoId='AU', dilation=2.2, d_cases=1.1).analyse()
# Out:
# Australia data to end of 2020-06-18:
#   7,391 cases, 102 deaths
#   293 cases per million, 4 deaths per million (2019 population = 25,203,200)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-04 (-106 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-83 days, 390 cases)
#   End:         2020-04-20 (-58 days, 25 days after peak cases)
#   Day Zero:    2020-04-09 (-70 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-73 days, 4 deaths)
#
# Parameters:
#   Totals:      7,335 cases and 102 deaths at end of 2020-06-15
#   Smoothed:    7,334 cases and 102 deaths at end of 2020-06-15 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 2.4 (2020-06-15, compared to 7 days earlier)
#   Growth:      23 days (Start -> Peak Cases)
# ...
