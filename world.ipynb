# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/data-national-14-day-notification-rate-covid-19">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=0, ylog=1, dilation=1, d_clip=3, smooth=7)
covid.data_load('download.json')

# %%
covid.Region(geoId='USA').analyse()
# Out:
# United States Of America data to end of 2021-09-02:
#   38,457,581 cases, 630,210 deaths
#   116,185 cases per million, 1,904 deaths per million (2019 population = 331,002,647)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         89% through outbreak
#   Start:       2020-03-01 (-550 days, when 50 or more cases were reported)
#   Peak Cases:  2021-01-04 (-241 days, 254,685 cases)
#   End:         2021-11-08 ( 68 days, 309 days after peak cases)
#   Day Zero:    2020-03-17 (-534 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-01-18 (-227 days, 3,360 deaths)
#
# Parameters:
#   Totals:      38,076,802 cases and 626,027 deaths at end of 2021-08-30
#   Smoothed:    38,076,801 cases and 626,027 deaths at end of 2021-08-30 (7 points)
#   Spread:      Peak infection rate 9.8 (2020-03-23, compared to 7 days earlier)
#                Latest infection rate 0.7 (2021-08-30, compared to 7 days earlier)
#   Growth:      309 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RUS').analyse()
# Out:
# Russia data to end of 2021-09-02:
#   6,830,496 cases, 184,267 deaths
#   46,805 cases per million, 1,263 deaths per million (2019 population = 145,934,460)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         93% through outbreak
#   Start:       2020-03-17 (-534 days, when 50 or more cases were reported)
#   Peak Cases:  2020-12-28 (-248 days, 45,052 cases)
#   End:         2021-10-09 ( 38 days, 286 days after peak cases)
#   Day Zero:    2020-04-09 (-511 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-08-30 ( -3 days, 908 deaths)
#
# Parameters:
#   Totals:      6,774,876 cases and 181,542 deaths at end of 2021-08-30
#   Smoothed:    6,774,875 cases and 181,541 deaths at end of 2021-08-30 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-03-27, compared to 7 days earlier)
#                Latest infection rate 1.0 (2021-08-30, compared to 7 days earlier)
#   Growth:      286 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JPN').analyse()
# Out:
# Japan data to end of 2021-09-02:
#   1,533,387 cases, 15,966 deaths
#   12,124 cases per million, 126 deaths per million (2019 population = 126,476,458)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         51% through outbreak
#   Start:       2020-02-19 (-561 days, when 50 or more cases were reported)
#   Peak Cases:  2021-08-16 (-17 days, 21,294 cases)
#   End:         2023-02-10 (527 days, 544 days after peak cases)
#   Day Zero:    2020-04-02 (-518 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-05-17 (-108 days, 110 deaths)
#
# Parameters:
#   Totals:      1,471,004 cases and 15,768 deaths at end of 2021-08-30
#   Smoothed:    1,471,003 cases and 15,768 deaths at end of 2021-08-30 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 1.1 (2021-08-30, compared to 7 days earlier)
#   Growth:      544 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SGP').analyse()
# Out:
# Singapore data to end of 2021-09-02:
#   68,487 cases, 55 deaths
#   11,706 cases per million, 9 deaths per million (2019 population = 5,850,343)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-15 (-565 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-27 (-493 days, 1,005 cases)
#   End:         2020-07-07 (-421 days, 72 days after peak cases)
#   Day Zero:    2021-08-24 ( -9 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-04 (-486 days, 1 deaths)
#
# Parameters:
#   Totals:      67,970 cases and 55 deaths at end of 2021-08-30
#   Smoothed:    67,969 cases and 54 deaths at end of 2021-08-30 (7 points)
#   Spread:      Peak infection rate 5.1 (2021-07-12, compared to 7 days earlier)
#                Latest infection rate 1.2 (2021-08-30, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BRA').analyse()
# Out:
# Brazil data to end of 2021-09-02:
#   20,641,318 cases, 578,749 deaths
#   97,108 cases per million, 2,723 deaths per million (2019 population = 212,559,409)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         73% through outbreak
#   Start:       2020-03-13 (-538 days, when 50 or more cases were reported)
#   Peak Cases:  2021-03-15 (-171 days, 75,417 cases)
#   End:         2022-03-16 (196 days, 367 days after peak cases)
#   Day Zero:    2020-03-28 (-523 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-04-05 (-150 days, 3,124 deaths)
#
# Parameters:
#   Totals:      20,581,960 cases and 577,011 deaths at end of 2021-08-30
#   Smoothed:    20,581,959 cases and 577,010 deaths at end of 2021-08-30 (7 points)
#   Spread:      Peak infection rate 7.7 (2020-03-23, compared to 7 days earlier)
#                Latest infection rate 0.8 (2021-08-30, compared to 7 days earlier)
#   Growth:      367 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='CHL').analyse()
# Out:
# Chile data to end of 2021-09-02:
#   1,625,363 cases, 36,784 deaths
#   85,025 cases per million, 1,924 deaths per million (2019 population = 19,116,209)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-17 (-534 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-22 (-437 days, 9,723 cases)
#   End:         2020-09-26 (-340 days, 97 days after peak cases)
#   Day Zero:    2020-04-12 (-508 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-07-20 (-409 days, 218 deaths)
#
# Parameters:
#   Totals:      1,623,991 cases and 36,703 deaths at end of 2021-08-30
#   Smoothed:    1,623,991 cases and 36,702 deaths at end of 2021-08-30 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 0.8 (2021-08-30, compared to 7 days earlier)
#   Growth:      97 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='PER').analyse()
# Out:
# Peru data to end of 2021-09-02:
#   2,143,358 cases, 197,402 deaths
#   65,006 cases per million, 5,987 deaths per million (2019 population = 32,971,846)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         69% through outbreak
#   Start:       2020-03-17 (-534 days, when 50 or more cases were reported)
#   Peak Cases:  2021-04-05 (-150 days, 9,016 cases)
#   End:         2022-04-23 (234 days, 384 days after peak cases)
#   Day Zero:    2020-03-28 (-523 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-04-19 (-136 days, 807 deaths)
#
# Parameters:
#   Totals:      2,140,821 cases and 197,290 deaths at end of 2021-08-30
#   Smoothed:    2,140,820 cases and 197,290 deaths at end of 2021-08-30 (7 points)
#   Spread:      Peak infection rate 3.7 (2020-04-13, compared to 7 days earlier)
#                Latest infection rate 0.8 (2021-08-30, compared to 7 days earlier)
#   Growth:      384 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MEX').analyse()
# Out:
# Mexico data to end of 2021-09-02:
#   3,374,186 cases, 259,112 deaths
#   26,170 cases per million, 2,010 deaths per million (2019 population = 128,932,753)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         52% through outbreak
#   Start:       2020-03-12 (-539 days, when 50 or more cases were reported)
#   Peak Cases:  2021-08-09 (-24 days, 18,587 cases)
#   End:         2023-01-05 (491 days, 515 days after peak cases)
#   Day Zero:    2020-04-06 (-514 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-01-18 (-227 days, 1,289 deaths)
#
# Parameters:
#   Totals:      3,334,651 cases and 256,977 deaths at end of 2021-08-30
#   Smoothed:    3,334,650 cases and 256,977 deaths at end of 2021-08-30 (7 points)
#   Spread:      Peak infection rate 3.3 (2020-03-22, compared to 7 days earlier)
#                Latest infection rate 0.8 (2021-08-30, compared to 7 days earlier)
#   Growth:      515 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IND').analyse()
# Out:
# India data to end of 2021-09-02:
#   32,895,023 cases, 439,004 deaths
#   23,837 cases per million, 318 deaths per million (2019 population = 1,380,004,385)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         65% through outbreak
#   Start:       2020-03-14 (-537 days, when 50 or more cases were reported)
#   Peak Cases:  2021-04-26 (-129 days, 401,081 cases)
#   End:         2022-06-07 (279 days, 408 days after peak cases)
#   Day Zero:    2020-04-04 (-516 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-05-17 (-108 days, 4,190 deaths)
#
# Parameters:
#   Totals:      32,770,873 cases and 437,914 deaths at end of 2021-08-30
#   Smoothed:    32,770,872 cases and 437,913 deaths at end of 2021-08-30 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-06, compared to 7 days earlier)
#                Latest infection rate 1.0 (2021-08-30, compared to 7 days earlier)
#   Growth:      408 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='CHN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2021-09-02:
#   106,294 cases, 4,834 deaths
#   74 cases per million, 3 deaths per million (2019 population = 1,439,323,774)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-16 (-595 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-17 (-563 days, 4,346 cases)
#   End:         2020-03-19 (-531 days, 32 days after peak cases)
#   Day Zero:    2020-01-28 (-583 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-17 (-563 days, 123 deaths)
#
# Parameters:
#   Totals:      106,206 cases and 4,834 deaths at end of 2021-08-30
#   Smoothed:    106,205 cases and 4,834 deaths at end of 2021-08-30 (7 points)
#   Spread:      Peak infection rate 29.4 (2020-12-21, compared to 7 days earlier)
#                Latest infection rate 0.8 (2021-08-30, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='KOR').analyse(ylog=1)
# Out:
# South Korea data to end of 2021-09-02:
#   255,194 cases, 2,165 deaths
#   4,978 cases per million, 42 deaths per million (2019 population = 51,269,183)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         52% through outbreak
#   Start:       2020-02-19 (-561 days, when 50 or more cases were reported)
#   Peak Cases:  2021-08-09 (-24 days, 1,862 cases)
#   End:         2023-01-27 (513 days, 537 days after peak cases)
#   Day Zero:    2020-03-13 (-538 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-01-04 (-241 days, 23 deaths)
#
# Parameters:
#   Totals:      250,167 cases and 2,146 deaths at end of 2021-08-30
#   Smoothed:    250,167 cases and 2,145 deaths at end of 2021-08-30 (7 points)
#   Spread:      Peak infection rate 10.5 (2020-02-25, compared to 7 days earlier)
#                Latest infection rate 1.0 (2021-08-30, compared to 7 days earlier)
#   Growth:      537 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZL', d_cases=3).analyse(ylog=0)
# Out:
# New Zealand data to end of 2021-09-02:
#   3,399 cases, 27 deaths
#   705 cases per million, 6 deaths per million (2019 population = 4,822,233)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         25% through outbreak
#   Start:       2020-03-23 (-528 days, when 50 or more cases were reported)
#   Peak Cases:  2021-08-23 (-10 days, 66 cases)
#   End:         2025-11-23 (1544 days, 1554 days after peak cases)
#
# Parameters:
#   Totals:      3,282 cases and 26 deaths at end of 2021-08-30
#   Smoothed:    3,281 cases and 26 deaths at end of 2021-08-30 (7 points)
#   Spread:      Peak infection rate 30.5 (2020-08-17, compared to 7 days earlier)
#                Latest infection rate 0.6 (2021-08-30, compared to 7 days earlier)
#   Growth:      518 days (Start -> Peak Cases)
#                X = 12,413, r = 8.0, L = 265, dilation = 3, c = -162.7% for cases
#
# Outcome: 12,408 total cases, 26 total deaths by end of 2025-11-23
# ...

# %%
covid.Region(geoId='AUS').analyse()
# Out:
# Australia data to end of 2021-09-02:
#   61,417 cases, 1,038 deaths
#   2,409 cases per million, 41 deaths per million (2019 population = 25,499,881)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         50% through outbreak
#   Start:       2020-03-08 (-543 days, when 50 or more cases were reported)
#   Peak Cases:  2021-08-30 ( -3 days, 1,479 cases)
#   End:         2023-02-20 (537 days, 540 days after peak cases)
#   Day Zero:    2020-04-14 (-506 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-09-07 (-360 days, 20 deaths)
#
# Parameters:
#   Totals:      56,980 cases and 1,018 deaths at end of 2021-08-30
#   Smoothed:    56,979 cases and 1,017 deaths at end of 2021-08-30 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-23, compared to 7 days earlier)
#                Latest infection rate 1.4 (2021-08-30, compared to 7 days earlier)
#   Growth:      540 days (Start -> Peak Cases)
# ...
