# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://coronavirus.data.gov.uk/">coronavirus.data.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='CN').analyse(ylog=1)
# Out:
# China data to end of 2020-05-04:
#   83,966 cases, 4,637 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-110 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-84 days, 4,690 cases)
#   End:         2020-03-06 (-58 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-100 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-79 days, 128 deaths)
#
# Parameters:
#   Totals:      83,959 cases and 4,637 deaths at end of 2020-05-01
#   Smoothed:    83,959 cases and 4,637 deaths at end of 2020-05-01 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.3 (2020-05-01, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='KR').analyse(ylog=0)
# Out:
# South Korea data to end of 2020-05-04:
#   10,804 cases, 254 deaths
#   209 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-77 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-63 days, 609 cases)
#   End:         2020-03-15 (-49 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-57 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-49 days, 5 deaths)
#
# Parameters:
#   Totals:      10,780 cases and 250 deaths at end of 2020-05-01
#   Smoothed:    10,780 cases and 250 deaths at end of 2020-05-01 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-01, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='US', dilation=1.2, d_cases=5).analyse()
# Out:
# United States of America data to end of 2020-05-04:
#   1,180,634 cases, 68,934 deaths
#   3,609 cases per million, 211 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         52% through outbreak
#   Start:       2020-02-25 (-69 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-27 days, 32,061 cases)
#   End:         2020-06-29 ( 57 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-52 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-16 days, 2,746 deaths)
#
# Parameters:
#   Totals:      1,103,781 cases and 65,068 deaths at end of 2020-05-01
#   Smoothed:    1,103,781 cases and 65,068 deaths at end of 2020-05-01 (7 points)
#   Spread:      Peak infection rate 12.5 (2020-03-07, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-01, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RU', growth_days=54, lag=4).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-04:
#   145,268 cases, 1,356 deaths
#   1,005 cases per million, 9 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         44% through outbreak
#   Start:       2020-03-14 (-51 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-07 (  3 days, --- cases)
#   End:         2020-06-29 ( 57 days, 54 days after peak cases)
#   Day Zero:    2020-04-06 (-28 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-11 (  7 days)
#
# Parameters:
#   Totals:      114,431 cases and 1,169 deaths at end of 2020-05-01
#   Smoothed:    114,431 cases and 1,169 deaths at end of 2020-05-01 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.5 (2020-05-01, compared to 7 days earlier)
#   Growth:      54 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZ', dilation=3).analyse()
# Out:
# New Zealand data to end of 2020-05-04:
#   1,137 cases, 20 deaths
#   233 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-45 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-38 days, 72 cases)
#   End:         2020-04-09 (-24 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,134 cases and 20 deaths at end of 2020-05-01
#   Smoothed:    1,133 cases and 20 deaths at end of 2020-05-01 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-01, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,100, r = 4.0, L = 288, dilation = 3 for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
# ...

# %%
covid.Region(geoId='JP', dilation=2.2, d_cases=1.6).analyse()
# Out:
# Japan data to end of 2020-05-04:
#   15,231 cases, 521 deaths
#   120 cases per million, 4 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         51% through outbreak
#   Start:       2020-02-16 (-78 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-21 days, 642 cases)
#   End:         2020-07-12 ( 70 days, 91 days after peak cases)
#   Day Zero:    2020-03-28 (-37 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 ( -9 days, 29 deaths)
#
# Parameters:
#   Totals:      14,544 cases and 458 deaths at end of 2020-05-01
#   Smoothed:    14,543 cases and 457 deaths at end of 2020-05-01 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-01, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SG', dilation=3).analyse()
# Out:
# Singapore data to end of 2020-05-04:
#   18,778 cases, 18 deaths
#   3,330 cases per million, 3 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         37% through outbreak
#   Start:       2020-02-11 (-83 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-11 days, 1,016 cases)
#   End:         2020-09-13 (133 days, 144 days after peak cases)
#
# Parameters:
#   Totals:      17,101 cases and 16 deaths at end of 2020-05-01
#   Smoothed:    17,101 cases and 16 deaths at end of 2020-05-01 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-01, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                X = 46,478, r = 8.0, L = 4,065, dilation = 3 for cases
#
# Outcome: 46,255 total cases, 58 total deaths by end of 2020-09-13
# ...

# %%
covid.Region(geoId='BR', growth_days=51).analyse()
# Out:
# Brazil data to end of 2020-05-04:
#   107,780 cases, 7,321 deaths
#   515 cases per million, 35 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         50% through outbreak
#   Start:       2020-03-11 (-54 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-01 ( -3 days, 5,977 cases)
#   End:         2020-06-20 ( 48 days, 51 days after peak cases)
#   Day Zero:    2020-03-24 (-41 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-30 ( -4 days, 407 deaths)
#
# Parameters:
#   Totals:      91,589 cases and 6,329 deaths at end of 2020-05-01
#   Smoothed:    91,589 cases and 6,328 deaths at end of 2020-05-01 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.6 (2020-05-01, compared to 7 days earlier)
#   Growth:      51 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MX', growth_days=48, dilation=2.5).analyse()
# Out:
# Mexico data to end of 2020-05-04:
#   24,905 cases, 2,271 deaths
#   197 cases per million, 18 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-15 (-50 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-02 ( -2 days, --- cases)
#   End:         2020-08-05 ( 94 days, 96 days after peak cases)
#   Day Zero:    2020-04-02 (-32 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-01 ( -3 days, 121 deaths)
#
# Parameters:
#   Totals:      20,739 cases and 1,972 deaths at end of 2020-05-01
#   Smoothed:    20,739 cases and 1,971 deaths at end of 2020-05-01 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.4 (2020-05-01, compared to 7 days earlier)
#   Growth:      48 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='PE', growth_days=45, dilation=2.5).analyse()
# Out:
# Peru data to end of 2020-05-04:
#   47,372 cases, 1,344 deaths
#   1,481 cases per million, 42 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         36% through outbreak
#   Start:       2020-03-15 (-50 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-28 ( -6 days, 2,735 cases)
#   End:         2020-07-24 ( 82 days, 88 days after peak cases)
#   Day Zero:    2020-04-02 (-32 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-02 ( -2 days, --- deaths)
#
# Parameters:
#   Totals:      40,459 cases and 1,124 deaths at end of 2020-05-01
#   Smoothed:    40,458 cases and 1,123 deaths at end of 2020-05-01 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.5 (2020-05-01, compared to 7 days earlier)
#   Growth:      44 days (Start -> Peak Cases)
# ...
