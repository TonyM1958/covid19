# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=0, ylog=1, dilation=4, d_clip=3, smooth=7)
covid.data_load('download.json')

# %%
covid.Region(geoId='US').analyse()
# Out:
# United States of America data to end of 2021-01-11:
#   22,423,006 cases, 374,442 deaths
#   68,142 cases per million, 1,138 deaths per million (2019 population = 329,064,917)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         25% through outbreak
#   Start:       2020-02-27 (-319 days, when 50 or more cases were reported)
#   Peak Cases:  2021-01-08 ( -3 days, 254,685 cases)
#   End:         2023-08-13 (945 days, 948 days after peak cases)
#   Day Zero:    2020-03-14 (-303 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-01-12 (  1 days)
#
# Parameters:
#   Totals:      21,658,950 cases and 364,646 deaths at end of 2021-01-08
#   Smoothed:    21,658,950 cases and 364,646 deaths at end of 2021-01-08 (7 points)
#   Spread:      Peak infection rate 9.8 (2020-03-20, compared to 7 days earlier)
#                Latest infection rate 1.2 (2021-01-08, compared to 7 days earlier)
#   Growth:      316 days (Start -> Peak Cases)
#                X = 107,508,714, r = 8.0, L = 1,018,738, dilation = 4, c = 64.4% for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#                X = 1,905,723, r = 8.0, L = 13,091, dilation = 4, c = 38.2% for deaths
#
# Outcome: 107,242,886 total cases, 1,900,891 total deaths by end of 2023-08-13
#   20.9% of predicted cases and 19.6% of predicted deaths reported to date
#   99.8% of predicted cases and 99.7% of predicted deaths reported by end date
#   326,710 cases per million (32.67%), 5,791 deaths per million (0.579%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-12-29  212,651    2,609  19,364,302  335,935   201,524    2,450  19,375,428  336,093
# 2020-12-30  212,651    2,609  19,576,953  338,544   205,233    2,503  19,580,661  338,596
# 2020-12-31  212,651    2,609  19,789,604  341,153   208,942    2,556  19,789,603  341,152
# 2021-01-01  212,651    2,609  20,002,255  343,762   212,652    2,609  20,002,255  343,762
# 2021-01-02  212,651    2,609  20,214,906  346,371   218,657    2,703  20,220,912  346,464
# 2021-01-03  212,651    2,609  20,427,557  348,980   224,661    2,796  20,445,573  349,261
# 2021-01-04  212,657    2,610  20,640,214  351,590   230,666    2,890  20,676,239  352,150
# 2021-01-05  254,684    3,264  20,894,898  354,854   236,671    2,983  20,912,910  355,134
# 2021-01-06  254,684    3,264  21,149,582  358,118   242,675    3,077  21,155,585  358,211
# 2021-01-07  254,684    3,264  21,404,266  361,382   248,680    3,171  21,404,265  361,381
# 2021-01-08  254,684    3,264  21,658,950  364,646   254,685    3,265  21,658,950  364,646
# 2021-01-09  254,684    3,264  21,913,634  367,910
# 2021-01-10  254,684    3,264  22,168,318  371,174
# 2021-01-11  254,688    3,268  22,423,006  374,442
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-01-08  272,619    4,820 21,658,950  364,646
# 2021-01-09  272,616    4,826 21,931,566  369,472
# 2021-01-10  272,608    4,830 22,204,174  374,301
# 2021-01-11  272,594    4,832 22,476,769  379,133  <-- latest raw data
# 2021-01-12  272,575    4,833 22,749,344  383,966
# 2021-01-13  272,551    4,833 23,021,895  388,798
# 2021-01-14  272,521    4,832 23,294,416  393,631
# 2021-01-15  272,485    4,832 23,566,901  398,463
# 2021-01-16  272,444    4,832 23,839,345  403,295
# 2021-01-17  272,398    4,831 24,111,743  408,126

# %%
covid.Region(geoId='RU').analyse()
# Out:
# Russia data to end of 2021-01-11:
#   3,425,269 cases, 62,273 deaths
#   23,481 cases per million, 427 deaths per million (2019 population = 145,872,260)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         26% through outbreak
#   Start:       2020-03-14 (-303 days, when 50 or more cases were reported)
#   Peak Cases:  2020-12-25 (-17 days, 45,052 cases)
#   End:         2023-05-01 (841 days, 858 days after peak cases)
#   Day Zero:    2020-04-06 (-280 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-12-25 (-17 days, 873 deaths)
#
# Parameters:
#   Totals:      3,354,498 cases and 60,864 deaths at end of 2021-01-08
#   Smoothed:    3,354,497 cases and 60,864 deaths at end of 2021-01-08 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-03-24, compared to 7 days earlier)
#                Latest infection rate 0.9 (2021-01-08, compared to 7 days earlier)
#   Growth:      286 days (Start -> Peak Cases)
#                X = 13,931,457, r = 8.0, L = 180,209, dilation = 4, c = 39.4% for cases
#   Lag:         0 days (Peak Cases -> Peak Deaths)
#                X = 252,772, r = 8.0, L = 3,493, dilation = 4, c = 35.5% for deaths
#
# Outcome: 13,897,010 total cases, 252,147 total deaths by end of 2023-05-01
#   24.6% of predicted cases and 24.6% of predicted deaths reported to date
#   99.8% of predicted cases and 99.8% of predicted deaths reported by end date
#   95,505 cases per million (9.55%), 1,733 deaths per million (0.173%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-12-29   26,014      531   3,104,049   55,796    34,174      678   3,095,889   55,648
# 2020-12-30   26,014      531   3,130,063   56,327    31,454      629   3,127,343   56,277
# 2020-12-31   26,014      531   3,156,077   56,858    28,734      580   3,156,077   56,858
# 2021-01-01   26,014      531   3,182,091   57,389    26,015      532   3,182,092   57,390
# 2021-01-02   26,014      531   3,208,105   57,920    25,668      523   3,207,760   57,913
# 2021-01-03   26,014      531   3,234,119   58,451    25,322      514   3,233,082   58,427
# 2021-01-04   26,019      537   3,260,138   58,988    24,976      505   3,258,058   58,932
# 2021-01-05   23,590      469   3,283,728   59,457    24,630      496   3,282,688   59,428
# 2021-01-06   23,590      469   3,307,318   59,926    24,283      488   3,306,971   59,916
# 2021-01-07   23,590      469   3,330,908   60,395    23,937      479   3,330,908   60,395
# 2021-01-08   23,590      469   3,354,498   60,864    23,590      469   3,354,498   60,864
# 2021-01-09   23,590      469   3,378,088   61,333
# 2021-01-10   23,590      469   3,401,678   61,802
# 2021-01-11   23,591      471   3,425,269   62,273
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-01-08   38,939      707  3,354,498   60,864
# 2021-01-09   38,926      706  3,393,424   61,570
# 2021-01-10   38,911      706  3,432,335   62,276
# 2021-01-11   38,895      706  3,471,230   62,982  <-- latest raw data
# 2021-01-12   38,879      705  3,510,109   63,687
# 2021-01-13   38,861      705  3,548,970   64,392
# 2021-01-14   38,843      705  3,587,812   65,097
# 2021-01-15   38,823      704  3,626,636   65,802
# 2021-01-16   38,803      704  3,665,438   66,506
# 2021-01-17   38,782      704  3,704,220   67,209

# %%
covid.Region(geoId='JP').analyse()
# Out:
# Japan data to end of 2021-01-11:
#   286,752 cases, 4,044 deaths
#   2,260 cases per million, 32 deaths per million (2019 population = 126,860,299)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         25% through outbreak
#   Start:       2020-02-16 (-330 days, when 50 or more cases were reported)
#   Peak Cases:  2021-01-08 ( -3 days, 6,129 cases)
#   End:         2023-09-15 (978 days, 981 days after peak cases)
#   Day Zero:    2020-03-30 (-287 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-01-12 (  1 days)
#
# Parameters:
#   Totals:      268,363 cases and 3,851 deaths at end of 2021-01-08
#   Smoothed:    268,363 cases and 3,851 deaths at end of 2021-01-08 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-27, compared to 7 days earlier)
#                Latest infection rate 1.8 (2021-01-08, compared to 7 days earlier)
#   Growth:      327 days (Start -> Peak Cases)
#                X = 1,332,358, r = 8.0, L = 24,517, dilation = 4, c = -11.3% for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#                X = 20,094, r = 8.0, L = 254, dilation = 4, c = 19.5% for deaths
#
# Outcome: 1,329,064 total cases, 20,044 total deaths by end of 2023-09-15
#   21.5% of predicted cases and 20.1% of predicted deaths reported to date
#   99.8% of predicted cases and 99.7% of predicted deaths reported by end date
#   10,503 cases per million (1.05%), 158 deaths per million (0.016%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-12-29    3,373       49     223,609    3,301     3,257       50     223,724    3,300
# 2020-12-30    3,373       49     226,982    3,350     3,296       50     227,020    3,349
# 2020-12-31    3,373       49     230,355    3,399     3,335       49     230,355    3,398
# 2021-01-01    3,373       49     233,728    3,448     3,373       50     233,728    3,448
# 2021-01-02    3,373       49     237,101    3,497     3,767       52     237,494    3,500
# 2021-01-03    3,373       49     240,474    3,546     4,160       54     241,655    3,553
# 2021-01-04    3,373       53     243,847    3,599     4,554       56     246,209    3,609
# 2021-01-05    6,129       63     249,976    3,662     4,948       58     251,157    3,666
# 2021-01-06    6,129       63     256,105    3,725     5,342       60     256,498    3,726
# 2021-01-07    6,129       63     262,234    3,788     5,735       62     262,234    3,787
# 2021-01-08    6,129       63     268,363    3,851     6,129       64     268,363    3,851
# 2021-01-09    6,129       63     274,492    3,914
# 2021-01-10    6,129       63     280,621    3,977
# 2021-01-11    6,131       67     286,752    4,044
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-01-08    3,265       49    268,363    3,851
# 2021-01-09    3,265       49    271,628    3,900
# 2021-01-10    3,265       49    274,893    3,949
# 2021-01-11    3,265       49    278,157    3,999  <-- latest raw data
# 2021-01-12    3,264       49    281,422    4,048
# 2021-01-13    3,264       49    284,686    4,097
# 2021-01-14    3,264       49    287,950    4,146
# 2021-01-15    3,263       49    291,213    4,196
# 2021-01-16    3,263       49    294,476    4,245
# 2021-01-17    3,262       49    297,739    4,294

# %%
covid.Region(geoId='SG').analyse()
# Out:
# Singapore data to end of 2021-01-11:
#   58,907 cases, 29 deaths
#   10,149 cases per million, 5 deaths per million (2019 population = 5,804,343)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-12 (-334 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-24 (-262 days, 1,005 cases)
#   End:         2020-11-25 (-46 days, 216 days after peak cases)
#
# Parameters:
#   Totals:      58,817 cases and 29 deaths at end of 2021-01-08
#   Smoothed:    58,817 cases and 28 deaths at end of 2021-01-08 (7 points)
#   Spread:      Peak infection rate 3.3 (2020-04-17, compared to 7 days earlier)
#                Latest infection rate 1.2 (2021-01-08, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                X = 58,325, r = 8.0, L = 4,020, dilation = 4, c = 38.7% for cases
#
# Outcome: 58,181 total cases, 28 total deaths at end of 2020-11-26
#   10,024 cases per million (1.00%), 5 deaths per million (0.001%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-12-29       24        0      58,548       29        20        0      58,551       29
# 2020-12-30       24        0      58,572       29        22        0      58,573       29
# 2020-12-31       24        0      58,596       29        23        0      58,596       29
# 2021-01-01       24        0      58,620       29        25        0      58,621       29
# 2021-01-02       24        0      58,644       29        26        0      58,646       29
# 2021-01-03       24        0      58,668       29        26        0      58,673       29
# 2021-01-04       29        0      58,697       29        27        0      58,700       29
# 2021-01-05       30        0      58,727       29        28        0      58,728       29
# 2021-01-06       30        0      58,757       29        29        0      58,757       29
# 2021-01-07       30        0      58,787       29        30        0      58,787       29
# 2021-01-08       30        0      58,817       29        30        0      58,817       29
# 2021-01-09       30        0      58,847       29
# 2021-01-10       30        0      58,877       29
# 2021-01-11       30        0      58,907       29
#
#   ** first wave ended **

# %%
covid.Region(geoId='BR').analyse()
# Out:
# Brazil data to end of 2021-01-11:
#   8,131,612 cases, 203,580 deaths
#   38,529 cases per million, 965 deaths per million (2019 population = 211,049,519)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         25% through outbreak
#   Start:       2020-03-10 (-307 days, when 50 or more cases were reported)
#   Peak Cases:  2021-01-08 ( -3 days, 56,838 cases)
#   End:         2023-07-08 (909 days, 912 days after peak cases)
#   Day Zero:    2020-03-25 (-292 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-01-12 (  1 days)
#
# Parameters:
#   Totals:      7,961,098 cases and 200,338 deaths at end of 2021-01-08
#   Smoothed:    7,961,098 cases and 200,338 deaths at end of 2021-01-08 (7 points)
#   Spread:      Peak infection rate 7.7 (2020-03-20, compared to 7 days earlier)
#                Latest infection rate 1.6 (2021-01-08, compared to 7 days earlier)
#   Growth:      304 days (Start -> Peak Cases)
#                X = 39,597,727, r = 4.0, L = 227,351, dilation = 4, c = 50.2% for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#                X = 1,022,335, r = 4.0, L = 4,324, dilation = 4, c = 39.2% for deaths
#
# Outcome: 37,719,771 total cases, 973,239 total deaths by end of 2023-07-08
#   20.5% of predicted cases and 19.9% of predicted deaths reported to date
#   95.3% of predicted cases and 95.2% of predicted deaths reported by end date
#   187,623 cases per million (18.76%), 4,844 deaths per million (0.484%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-12-29   35,637      697   7,519,922  191,836    33,875      634   7,521,684  191,898
# 2020-12-30   35,637      697   7,555,559  192,533    34,462      655   7,556,146  192,553
# 2020-12-31   35,637      697   7,591,196  193,230    35,050      677   7,591,196  193,230
# 2021-01-01   35,637      697   7,626,833  193,927    35,637      697   7,626,833  193,927
# 2021-01-02   35,637      697   7,662,470  194,624    38,666      752   7,665,499  194,678
# 2021-01-03   35,637      697   7,698,107  195,321    41,695      806   7,707,194  195,485
# 2021-01-04   35,639      697   7,733,746  196,018    44,723      861   7,751,917  196,346
# 2021-01-05   56,838    1,080   7,790,584  197,098    47,752      916   7,799,670  197,262
# 2021-01-06   56,838    1,080   7,847,422  198,178    50,781      971   7,850,450  198,232
# 2021-01-07   56,838    1,080   7,904,260  199,258    53,810    1,025   7,904,260  199,258
# 2021-01-08   56,838    1,080   7,961,098  200,338    56,838    1,080   7,961,098  200,338
# 2021-01-09   56,838    1,080   8,017,936  201,418
# 2021-01-10   56,838    1,080   8,074,774  202,498
# 2021-01-11   56,838    1,082   8,131,612  203,580
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-01-08   54,132    1,397  7,961,098  200,338
# 2021-01-09   54,132    1,397  8,015,230  201,735
# 2021-01-10   54,132    1,397  8,069,362  203,132
# 2021-01-11   54,131    1,398  8,123,493  204,530  <-- latest raw data
# 2021-01-12   54,130    1,398  8,177,623  205,928
# 2021-01-13   54,129    1,398  8,231,751  207,325
# 2021-01-14   54,127    1,398  8,285,878  208,723
# 2021-01-15   54,125    1,398  8,340,004  210,120
# 2021-01-16   54,123    1,398  8,394,126  211,518
# 2021-01-17   54,120    1,398  8,448,247  212,916

# %%
covid.Region(geoId='CL').analyse()
# Out:
# Chile data to end of 2021-01-11:
#   645,892 cases, 17,162 deaths
#   34,080 cases per million, 906 deaths per million (2019 population = 18,952,035)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         77% through outbreak
#   Start:       2020-03-14 (-303 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-19 (-206 days, 9,723 cases)
#   End:         2021-04-05 ( 85 days, 291 days after peak cases)
#   Day Zero:    2020-04-09 (-277 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-07-17 (-178 days, 218 deaths)
#
# Parameters:
#   Totals:      634,019 cases and 16,991 deaths at end of 2021-01-08
#   Smoothed:    634,018 cases and 16,991 deaths at end of 2021-01-08 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-03-22, compared to 7 days earlier)
#                Latest infection rate 1.7 (2021-01-08, compared to 7 days earlier)
#   Growth:      97 days (Start -> Peak Cases)
#                X = 648,442, r = 8.0, L = 38,892, dilation = 4, c = -2.1% for cases
#   Lag:         28 days (Peak Cases -> Peak Deaths)
#                X = 17,683, r = 8.0, L = 870, dilation = 4, c =  5.7% for deaths
#
# Outcome: 646,838 total cases, 17,606 total deaths by end of 2021-04-05
#   99.6% of predicted cases and 97.0% of predicted deaths reported to date
#   99.8% of predicted cases and 99.6% of predicted deaths reported by end date
#   34,215 cases per million (3.42%), 933 deaths per million (0.093%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-12-29    2,309       46     604,337   16,489     2,210       41     604,436   16,493
# 2020-12-30    2,309       46     606,646   16,535     2,243       43     606,679   16,536
# 2020-12-31    2,309       46     608,955   16,581     2,276       45     608,955   16,581
# 2021-01-01    2,309       46     611,264   16,627     2,309       46     611,264   16,627
# 2021-01-02    2,309       46     613,573   16,673     2,544       48     613,808   16,675
# 2021-01-03    2,309       46     615,882   16,719     2,780       49     616,588   16,724
# 2021-01-04    2,309       48     618,191   16,767     3,015       51     619,603   16,774
# 2021-01-05    3,957       56     622,148   16,823     3,251       52     622,854   16,826
# 2021-01-06    3,957       56     626,105   16,879     3,486       53     626,340   16,880
# 2021-01-07    3,957       56     630,062   16,935     3,722       55     630,062   16,935
# 2021-01-08    3,957       56     634,019   16,991     3,957       56     634,019   16,991
# 2021-01-09    3,957       56     637,976   17,047
# 2021-01-10    3,957       56     641,933   17,103
# 2021-01-11    3,959       59     645,892   17,162
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-01-08      316       15    634,019   16,991
# 2021-01-09      310       15    634,329   17,006
# 2021-01-10      304       14    634,633   17,020
# 2021-01-11      298       14    634,931   17,034  <-- latest raw data
# 2021-01-12      292       14    635,223   17,048
# 2021-01-13      286       14    635,509   17,062
# 2021-01-14      280       13    635,789   17,075
# 2021-01-15      275       13    636,064   17,088
# 2021-01-16      269       13    636,334   17,101
# 2021-01-17      264       13    636,598   17,114

# %%
covid.Region(geoId='PE').analyse()
# Out:
# Peru data to end of 2021-01-11:
#   1,037,350 cases, 38,335 deaths
#   31,908 cases per million, 1,179 deaths per million (2019 population = 32,510,462)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         47% through outbreak
#   Start:       2020-03-14 (-303 days, when 50 or more cases were reported)
#   Peak Cases:  2020-08-21 (-143 days, 8,340 cases)
#   End:         2021-12-13 (337 days, 480 days after peak cases)
#   Day Zero:    2020-04-03 (-283 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-08-14 (-150 days, 744 deaths)
#
# Parameters:
#   Totals:      1,030,366 cases and 38,137 deaths at end of 2021-01-08
#   Smoothed:    1,030,365 cases and 38,136 deaths at end of 2021-01-08 (7 points)
#   Spread:      Peak infection rate 3.7 (2020-04-10, compared to 7 days earlier)
#                Latest infection rate 1.3 (2021-01-08, compared to 7 days earlier)
#   Growth:      160 days (Start -> Peak Cases)
#                X = 1,345,984, r = 8.0, L = 33,360, dilation = 4, c = 29.2% for cases
#   Lag:         -7 days (Peak Cases -> Peak Deaths)
#                X = 48,739, r = 8.0, L = 2,976, dilation = 4, c = -127.8% for deaths
#
# Outcome: 1,342,656 total cases, 48,628 total deaths by end of 2021-12-13
#   77.1% of predicted cases and 78.7% of predicted deaths reported to date
#   99.8% of predicted cases and 99.8% of predicted deaths reported by end date
#   41,402 cases per million (4.14%), 1,499 deaths per million (0.150%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-12-29    1,735       49   1,010,643   37,574     1,630       50   1,010,747   37,573
# 2020-12-30    1,735       49   1,012,378   37,623     1,665       50   1,012,412   37,623
# 2020-12-31    1,735       49   1,014,113   37,672     1,700       49   1,014,113   37,672
# 2021-01-01    1,735       49   1,015,848   37,721     1,736       50   1,015,848   37,722
# 2021-01-02    1,735       49   1,017,583   37,770     1,820       52   1,017,669   37,774
# 2021-01-03    1,735       49   1,019,318   37,819     1,905       55   1,019,573   37,828
# 2021-01-04    1,740       54   1,021,058   37,873     1,989       57   1,021,563   37,885
# 2021-01-05    2,327       66   1,023,385   37,939     2,074       59   1,023,637   37,945
# 2021-01-06    2,327       66   1,025,712   38,005     2,159       62   1,025,795   38,007
# 2021-01-07    2,327       66   1,028,039   38,071     2,243       64   1,028,039   38,071
# 2021-01-08    2,327       66   1,030,366   38,137     2,327       66   1,030,366   38,137
# 2021-01-09    2,327       66   1,032,693   38,203
# 2021-01-10    2,327       66   1,035,020   38,269
# 2021-01-11    2,330       66   1,037,350   38,335
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-01-08    3,401      116  1,030,366   38,137
# 2021-01-09    3,371      115  1,033,737   38,252
# 2021-01-10    3,341      114  1,037,078   38,365
# 2021-01-11    3,312      113  1,040,390   38,478  <-- latest raw data
# 2021-01-12    3,282      112  1,043,673   38,589
# 2021-01-13    3,253      110  1,046,926   38,700
# 2021-01-14    3,224      109  1,050,149   38,809
# 2021-01-15    3,195      108  1,053,344   38,918
# 2021-01-16    3,166      107  1,056,510   39,025
# 2021-01-17    3,137      106  1,059,647   39,132

# %%
covid.Region(geoId='MX').analyse()
# Out:
# Mexico data to end of 2021-01-11:
#   1,541,633 cases, 134,368 deaths
#   12,084 cases per million, 1,053 deaths per million (2019 population = 127,575,529)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         25% through outbreak
#   Start:       2020-03-09 (-308 days, when 50 or more cases were reported)
#   Peak Cases:  2021-01-08 ( -3 days, 13,268 cases)
#   End:         2023-07-11 (912 days, 915 days after peak cases)
#   Day Zero:    2020-04-03 (-283 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-01-12 (  1 days)
#
# Parameters:
#   Totals:      1,501,827 cases and 131,301 deaths at end of 2021-01-08
#   Smoothed:    1,501,826 cases and 131,300 deaths at end of 2021-01-08 (7 points)
#   Spread:      Peak infection rate 3.3 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 1.6 (2021-01-08, compared to 7 days earlier)
#   Growth:      305 days (Start -> Peak Cases)
#                X = 7,455,756, r = 4.48, L = 53,073, dilation = 4, c = 50.4% for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#                X = 669,987, r = 4.0, L = 4,091, dilation = 4, c = 47.2% for deaths
#
# Outcome: 7,206,265 total cases, 637,813 total deaths by end of 2023-07-11
#   20.7% of predicted cases and 20.1% of predicted deaths reported to date
#   96.7% of predicted cases and 95.2% of predicted deaths reported by end date
#   58,442 cases per million (5.84%), 5,252 deaths per million (0.525%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-12-29    8,475      622   1,397,905  123,477     8,732      616   1,397,647  123,483
# 2020-12-30    8,475      622   1,406,380  124,099     8,646      618   1,406,294  124,101
# 2020-12-31    8,475      622   1,414,855  124,721     8,561      620   1,414,855  124,721
# 2021-01-01    8,475      622   1,423,330  125,343     8,475      623   1,423,330  125,343
# 2021-01-02    8,475      622   1,431,805  125,965     9,160      680   1,432,489  126,023
# 2021-01-03    8,475      622   1,440,280  126,587     9,844      737   1,442,334  126,760
# 2021-01-04    8,475      626   1,448,755  127,213    10,529      794   1,452,863  127,554
# 2021-01-05   13,268    1,022   1,462,023  128,235    11,214      851   1,464,077  128,405
# 2021-01-06   13,268    1,022   1,475,291  129,257    11,899      908   1,475,975  129,313
# 2021-01-07   13,268    1,022   1,488,559  130,279    12,583      965   1,488,559  130,279
# 2021-01-08   13,268    1,022   1,501,827  131,301    13,268    1,022   1,501,827  131,301
# 2021-01-09   13,268    1,022   1,515,095  132,323
# 2021-01-10   13,268    1,022   1,528,363  133,345
# 2021-01-11   13,270    1,023   1,541,633  134,368
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-01-08   11,248      912  1,501,827  131,301
# 2021-01-09   11,248      913  1,513,075  132,214
# 2021-01-10   11,248      913  1,524,324  133,126
# 2021-01-11   11,248      913  1,535,572  134,039  <-- latest raw data
# 2021-01-12   11,248      913  1,546,820  134,952
# 2021-01-13   11,247      913  1,558,067  135,865
# 2021-01-14   11,247      913  1,569,314  136,778
# 2021-01-15   11,247      913  1,580,561  137,691
# 2021-01-16   11,246      913  1,591,807  138,604
# 2021-01-17   11,245      913  1,603,052  139,517

# %%
covid.Region(geoId='IN').analyse()
# Out:
# India data to end of 2021-01-11:
#   10,466,595 cases, 151,160 deaths
#   7,660 cases per million, 111 deaths per million (2019 population = 1,366,417,756)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         41% through outbreak
#   Start:       2020-03-11 (-306 days, when 50 or more cases were reported)
#   Peak Cases:  2020-09-11 (-122 days, 91,688 cases)
#   End:         2022-03-16 (430 days, 552 days after peak cases)
#   Day Zero:    2020-04-01 (-285 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-09-18 (-115 days, 1,166 deaths)
#
# Parameters:
#   Totals:      10,412,541 cases and 150,509 deaths at end of 2021-01-08
#   Smoothed:    10,412,540 cases and 150,508 deaths at end of 2021-01-08 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-03, compared to 7 days earlier)
#                Latest infection rate 1.0 (2021-01-08, compared to 7 days earlier)
#   Growth:      184 days (Start -> Peak Cases)
#                X = 16,746,510, r = 7.19, L = 366,750, dilation = 4, c = 57.9% for cases
#   Lag:         7 days (Peak Cases -> Peak Deaths)
#                X = 300,357, r = 5.06, L = 4,662, dilation = 4, c = 56.4% for deaths
#
# Outcome: 16,670,508 total cases, 293,447 total deaths by end of 2022-03-16
#   62.5% of predicted cases and 50.3% of predicted deaths reported to date
#   99.5% of predicted cases and 97.7% of predicted deaths reported by end date
#   12,256 cases per million (1.23%), 220 deaths per million (0.022%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-12-29   18,942      249  10,226,813  148,150    20,150      271  10,225,605  148,127
# 2020-12-30   18,942      249  10,245,755  148,399    19,747      264  10,245,352  148,390
# 2020-12-31   18,942      249  10,264,697  148,648    19,345      257  10,264,697  148,647
# 2021-01-01   18,942      249  10,283,639  148,897    18,943      250  10,283,640  148,897
# 2021-01-02   18,942      249  10,302,581  149,146    18,811      245  10,302,450  149,142
# 2021-01-03   18,942      249  10,321,523  149,395    18,679      240  10,321,129  149,382
# 2021-01-04   18,946      254  10,340,469  149,649    18,547      235  10,339,675  149,617
# 2021-01-05   18,018      215  10,358,487  149,864    18,415      230  10,358,090  149,847
# 2021-01-06   18,018      215  10,376,505  150,079    18,283      225  10,376,372  150,073
# 2021-01-07   18,018      215  10,394,523  150,294    18,151      221  10,394,523  150,293
# 2021-01-08   18,018      215  10,412,541  150,509    18,018      216  10,412,541  150,509
# 2021-01-09   18,018      215  10,430,559  150,724
# 2021-01-10   18,018      215  10,448,577  150,939
# 2021-01-11   18,018      221  10,466,595  151,160
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-01-08   47,640      727 10,412,541  150,509
# 2021-01-09   47,396      725 10,459,937  151,234
# 2021-01-10   47,152      723 10,507,089  151,957
# 2021-01-11   46,907      721 10,553,996  152,678  <-- latest raw data
# 2021-01-12   46,663      719 10,600,658  153,398
# 2021-01-13   46,417      718 10,647,076  154,115
# 2021-01-14   46,172      716 10,693,248  154,831
# 2021-01-15   45,927      714 10,739,174  155,545
# 2021-01-16   45,681      712 10,784,855  156,257
# 2021-01-17   45,435      710 10,830,290  156,967

# %%
covid.Region(geoId='CN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2021-01-11:
#   96,824 cases, 4,787 deaths
#   68 cases per million, 3 deaths per million (2019 population = 1,433,783,692)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-13 (-364 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-14 (-332 days, 4,346 cases)
#   End:         2020-03-16 (-300 days, 32 days after peak cases)
#   Day Zero:    2020-01-25 (-352 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-14 (-332 days, 123 deaths)
#
# Parameters:
#   Totals:      96,561 cases and 4,785 deaths at end of 2021-01-08
#   Smoothed:    96,560 cases and 4,785 deaths at end of 2021-01-08 (7 points)
#   Spread:      Peak infection rate 29.4 (2020-12-18, compared to 7 days earlier)
#                Latest infection rate 0.7 (2021-01-08, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
#                X = 81,131, r = 5.52, L = 17,382, dilation = 0.7, c = 80.7% for cases
#   Lag:         0 days (Peak Cases -> Peak Deaths)
#                X = 3,239, r = 5.17, L = 492, dilation = 1, c = 88.7% for deaths
#
# Outcome: 81,086 total cases, 3,224 total deaths at end of 2020-03-17
#   57 cases per million (0.01%), 2 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-12-29      131        2      95,426    4,773        90        2      95,467    4,773
# 2020-12-30      131        2      95,557    4,775       104        2      95,570    4,775
# 2020-12-31      131        2      95,688    4,777       117        2      95,687    4,777
# 2021-01-01      131        2      95,819    4,779       131        2      95,819    4,779
# 2021-01-02      131        2      95,950    4,781       125        2      95,944    4,780
# 2021-01-03      131        2      96,081    4,783       119        1      96,062    4,782
# 2021-01-04      132        2      96,213    4,785       112        1      96,174    4,783
# 2021-01-05       87        0      96,300    4,785       106        1      96,281    4,784
# 2021-01-06       87        0      96,387    4,785       100        1      96,380    4,784
# 2021-01-07       87        0      96,474    4,785        93    < 0.5      96,474    4,785
# 2021-01-08       87        0      96,561    4,785        87    < 0.5      96,561    4,785
# 2021-01-09       87        0      96,648    4,785
# 2021-01-10       87        0      96,735    4,785
# 2021-01-11       89        2      96,824    4,787
#
#   ** first wave ended **

# %%
covid.Region(geoId='KR').analyse(ylog=1)
# Out:
# South Korea data to end of 2021-01-11:
#   69,114 cases, 1,140 deaths
#   1,349 cases per million, 22 deaths per million (2019 population = 51,225,321)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         27% through outbreak
#   Start:       2020-02-16 (-330 days, when 50 or more cases were reported)
#   Peak Cases:  2020-12-18 (-24 days, 1,015 cases)
#   End:         2023-06-23 (894 days, 918 days after peak cases)
#   Day Zero:    2020-03-10 (-307 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-01-01 (-10 days, 23 deaths)
#
# Parameters:
#   Totals:      67,032 cases and 1,069 deaths at end of 2021-01-08
#   Smoothed:    67,032 cases and 1,069 deaths at end of 2021-01-08 (7 points)
#   Spread:      Peak infection rate 10.5 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 0.7 (2021-01-08, compared to 7 days earlier)
#   Growth:      306 days (Start -> Peak Cases)
#                X = 261,432, r = 8.0, L = 4,061, dilation = 4, c = 13.4% for cases
#   Lag:         14 days (Peak Cases -> Peak Deaths)
#                X = 4,861, r = 8.0, L = 92, dilation = 4, c = -30.3% for deaths
#
# Outcome: 260,785 total cases, 4,848 total deaths by end of 2023-06-23
#   26.4% of predicted cases and 23.4% of predicted deaths reported to date
#   99.8% of predicted cases and 99.7% of predicted deaths reported by end date
#   5,104 cases per million (0.51%), 95 deaths per million (0.009%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-12-29      940       23      58,620      842       972       21      58,587      843
# 2020-12-30      940       23      59,560      865       961       22      59,548      865
# 2020-12-31      940       23      60,500      888       951       22      60,499      887
# 2021-01-01      940       23      61,440      911       941       23      61,440      911
# 2021-01-02      940       23      62,380      934       905       23      62,345      934
# 2021-01-03      940       23      63,320      957       870       23      63,215      956
# 2021-01-04      944       24      64,264      981       834       23      64,049      979
# 2021-01-05      692       22      64,956    1,003       799       23      64,848    1,002
# 2021-01-06      692       22      65,648    1,025       763       22      65,611    1,024
# 2021-01-07      692       22      66,340    1,047       728       22      66,339    1,046
# 2021-01-08      692       22      67,032    1,069       693       23      67,032    1,069
# 2021-01-09      692       22      67,724    1,091
# 2021-01-10      692       22      68,416    1,113
# 2021-01-11      698       27      69,114    1,140
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-01-08      681       13     67,032    1,069
# 2021-01-09      681       13     67,713    1,082
# 2021-01-10      681       13     68,394    1,094
# 2021-01-11      680       13     69,074    1,107  <-- latest raw data
# 2021-01-12      680       13     69,754    1,120
# 2021-01-13      680       13     70,434    1,133
# 2021-01-14      679       13     71,113    1,145
# 2021-01-15      679       13     71,792    1,158
# 2021-01-16      678       13     72,471    1,171
# 2021-01-17      678       13     73,149    1,183

# %%
covid.Region(geoId='NZ', d_cases=3).analyse(ylog=0)
# Out:
# New Zealand data to end of 2021-01-11:
#   2,222 cases, 25 deaths
#   465 cases per million, 5 deaths per million (2019 population = 4,783,062)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-297 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-290 days, 64 cases)
#   End:         2020-04-16 (-269 days, 21 days after peak cases)
#
# Parameters:
#   Totals:      2,201 cases and 25 deaths at end of 2021-01-08
#   Smoothed:    2,200 cases and 24 deaths at end of 2021-01-08 (7 points)
#   Spread:      Peak infection rate 30.5 (2020-08-14, compared to 7 days earlier)
#                Latest infection rate 0.1 (2021-01-08, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,104, r = 4.0, L = 257, dilation = 3, c = 92.0% for cases
#
# Outcome: 1,084 total cases, 9 total deaths at end of 2020-04-17
#   227 cases per million (0.02%), 2 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-12-29       56        0       1,844       25        34        0       1,865       25
# 2020-12-30       56        0       1,900       25        41        0       1,907       25
# 2020-12-31       56        0       1,956       25        49        0       1,955       25
# 2021-01-01       56        0       2,012       25        56        0       2,011       25
# 2021-01-02       56        0       2,068       25        49        0       2,060       25
# 2021-01-03       56        0       2,124       25        42        0       2,102       25
# 2021-01-04       57        0       2,181       25        34        0       2,136       25
# 2021-01-05        5        0       2,186       25        27        0       2,163       25
# 2021-01-06        5        0       2,191       25        20        0       2,183       25
# 2021-01-07        5        0       2,196       25        12        0       2,195       25
# 2021-01-08        5        0       2,201       25         6        0       2,201       25
# 2021-01-09        5        0       2,206       25
# 2021-01-10        5        0       2,211       25
# 2021-01-11       11        0       2,222       25
#
#   ** first wave ended **

# %%
covid.Region(geoId='AU').analyse()
# Out:
# Australia data to end of 2021-01-11:
#   28,614 cases, 909 deaths
#   1,135 cases per million, 36 deaths per million (2019 population = 25,203,200)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         52% through outbreak
#   Start:       2020-03-06 (-311 days, when 50 or more cases were reported)
#   Peak Cases:  2020-07-31 (-164 days, 503 cases)
#   End:         2021-10-14 (277 days, 441 days after peak cases)
#   Day Zero:    2020-04-11 (-275 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-09-04 (-129 days, 20 deaths)
#
# Parameters:
#   Totals:      28,564 cases and 909 deaths at end of 2021-01-08
#   Smoothed:    28,564 cases and 908 deaths at end of 2021-01-08 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-20, compared to 7 days earlier)
#                Latest infection rate 0.6 (2021-01-08, compared to 7 days earlier)
#   Growth:      147 days (Start -> Peak Cases)
#                X = 33,953, r = 8.0, L = 2,011, dilation = 4, c = -117.1% for cases
#   Lag:         35 days (Peak Cases -> Peak Deaths)
#                X = 1,197, r = 8.0, L = 81, dilation = 4, c = -131.8% for deaths
#
# Outcome: 33,869 total cases, 1,192 total deaths by end of 2021-10-14
#   84.3% of predicted cases and 75.9% of predicted deaths reported to date
#   99.8% of predicted cases and 99.5% of predicted deaths reported by end date
#   1,347 cases per million (0.13%), 48 deaths per million (0.005%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-12-29       27        0      28,339      908        23        0      28,342      908
# 2020-12-30       27        0      28,366      908        24        0      28,367      908
# 2020-12-31       27        0      28,393      908        26        0      28,392      908
# 2021-01-01       27        0      28,420      908        27    < 0.5      28,420      908
# 2021-01-02       27        0      28,447      908        26    < 0.5      28,445      908
# 2021-01-03       27        0      28,474      908        24    < 0.5      28,469      908
# 2021-01-04       30        1      28,504      909        22    < 0.5      28,492      909
# 2021-01-05       15        0      28,519      909        21    < 0.5      28,512      909
# 2021-01-06       15        0      28,534      909        19    < 0.5      28,531      909
# 2021-01-07       15        0      28,549      909        17    < 0.5      28,548      909
# 2021-01-08       15        0      28,564      909        16        0      28,564      909
# 2021-01-09       15        0      28,579      909
# 2021-01-10       15        0      28,594      909
# 2021-01-11       20        0      28,614      909
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2021-01-08       67        3     28,564      909
# 2021-01-09       66        3     28,630      912
# 2021-01-10       66        3     28,696      916
# 2021-01-11       65        3     28,761      919  <-- latest raw data
# 2021-01-12       64        3     28,825      922
# 2021-01-13       63        3     28,888      925
# 2021-01-14       63        3     28,951      929
# 2021-01-15       62        3     29,013      932
# 2021-01-16       61        3     29,074      935
# 2021-01-17       61        3     29,135      938
