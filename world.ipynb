# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://coronavirus.data.gov.uk/">coronavirus.data.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='CN', dilation=1.0, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2020-05-10:
#   84,010 cases, 4,637 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-116 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-90 days, 4,689 cases)
#   End:         2020-03-06 (-64 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-106 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-85 days, 128 deaths)
#
# Parameters:
#   Totals:      83,976 cases and 4,637 deaths at end of 2020-05-07
#   Smoothed:    83,976 cases and 4,637 deaths at end of 2020-05-07 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-07, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='KR', dilation=3, d_cases=0.9).analyse(ylog=1)
# Out:
# South Korea data to end of 2020-05-10:
#   10,909 cases, 256 deaths
#   211 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-83 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-69 days, 608 cases)
#   End:         2020-03-15 (-55 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-63 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-55 days, 5 deaths)
#
# Parameters:
#   Totals:      10,822 cases and 256 deaths at end of 2020-05-07
#   Smoothed:    10,822 cases and 256 deaths at end of 2020-05-07 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 1.7 (2020-05-07, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZ', dilation=3.1).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-05-10:
#   1,147 cases, 21 deaths
#   235 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-51 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-44 days, 72 cases)
#   End:         2020-04-09 (-30 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,141 cases and 21 deaths at end of 2020-05-07
#   Smoothed:    1,141 cases and 20 deaths at end of 2020-05-07 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-07, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,105, r = 4.0, L = 288, dilation = 3.1, c = 89.1% for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
# ...

# %%
covid.Region(geoId='US', dilation=1.6, d_cases=5).analyse()
# Out:
# United States of America data to end of 2020-05-10:
#   1,329,799 cases, 79,528 deaths
#   4,065 cases per million, 243 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         57% through outbreak
#   Start:       2020-02-25 (-75 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-33 days, 31,960 cases)
#   End:         2020-06-29 ( 51 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-58 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-22 days, 2,741 deaths)
#
# Parameters:
#   Totals:      1,256,972 cases and 75,670 deaths at end of 2020-05-07
#   Smoothed:    1,256,971 cases and 75,670 deaths at end of 2020-05-07 (7 points)
#   Spread:      Peak infection rate 11.5 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-07, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RU', growth_days=58, lag=4).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-10:
#   209,688 cases, 1,915 deaths
#   1,451 cases per million, 13 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         47% through outbreak
#   Start:       2020-03-14 (-57 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-11 (  1 days, --- cases)
#   End:         2020-07-07 ( 59 days, 58 days after peak cases)
#   Day Zero:    2020-04-06 (-34 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-07 ( -3 days, 90 deaths)
#
# Parameters:
#   Totals:      177,160 cases and 1,625 deaths at end of 2020-05-07
#   Smoothed:    177,159 cases and 1,625 deaths at end of 2020-05-07 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.4 (2020-05-07, compared to 7 days earlier)
#   Growth:      58 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP', dilation=0.9, d_cases=1.1).analyse()
# Out:
# Japan data to end of 2020-05-10:
#   15,798 cases, 621 deaths
#   125 cases per million, 5 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         68% through outbreak
#   Start:       2020-02-16 (-84 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-27 days, 643 cases)
#   End:         2020-06-13 ( 35 days, 62 days after peak cases)
#   Day Zero:    2020-03-29 (-42 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-15 days, 28 deaths)
#
# Parameters:
#   Totals:      15,547 cases and 557 deaths at end of 2020-05-07
#   Smoothed:    15,547 cases and 557 deaths at end of 2020-05-07 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.4 (2020-05-07, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SG', dilation=3).analyse()
# Out:
# Singapore data to end of 2020-05-10:
#   23,336 cases, 20 deaths
#   4,139 cases per million, 4 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         40% through outbreak
#   Start:       2020-02-12 (-88 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-17 days, 1,003 cases)
#   End:         2020-09-11 (125 days, 142 days after peak cases)
#
# Parameters:
#   Totals:      20,939 cases and 20 deaths at end of 2020-05-07
#   Smoothed:    20,938 cases and 20 deaths at end of 2020-05-07 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-07, compared to 7 days earlier)
#   Growth:      71 days (Start -> Peak Cases)
#                X = 46,490, r = 8.0, L = 4,013, dilation = 3, c = 46.8% for cases
#
# Outcome: 46,267 total cases, 64 total deaths by end of 2020-09-11
# ...

# %%
covid.Region(geoId='BR', growth_days=76, lag=4, dilation=2.5).analyse()
# Out:
# Brazil data to end of 2020-05-10:
#   162,699 cases, 11,123 deaths
#   777 cases per million, 53 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         25% through outbreak
#   Start:       2020-03-11 (-60 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-26 ( 16 days, 0 cases)
#   End:         2020-10-24 (168 days, 152 days after peak cases)
#   Day Zero:    2020-03-25 (-46 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-30 ( 20 days)
#
# Parameters:
#   Totals:      135,106 cases and 9,146 deaths at end of 2020-05-07
#   Smoothed:    135,106 cases and 9,146 deaths at end of 2020-05-07 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.6 (2020-05-07, compared to 7 days earlier)
#   Growth:      76 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MX', growth_days=60, lag=4, dilation=2.5).analyse()
# Out:
# Mexico data to end of 2020-05-10:
#   35,022 cases, 3,465 deaths
#   278 cases per million, 27 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         29% through outbreak
#   Start:       2020-03-15 (-56 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-14 (  4 days, 0 cases)
#   End:         2020-09-10 (124 days, 120 days after peak cases)
#   Day Zero:    2020-04-02 (-38 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-18 (  8 days)
#
# Parameters:
#   Totals:      29,616 cases and 2,961 deaths at end of 2020-05-07
#   Smoothed:    29,615 cases and 2,961 deaths at end of 2020-05-07 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-07, compared to 7 days earlier)
#   Growth:      60 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='PE', lag=5, dilation=2.5).analyse()
# Out:
# Peru data to end of 2020-05-10:
#   67,307 cases, 1,889 deaths
#   2,104 cases per million, 59 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         34% through outbreak
#   Start:       2020-03-15 (-56 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-06 ( -4 days, 3,241 cases)
#   End:         2020-08-17 (100 days, 104 days after peak cases)
#   Day Zero:    2020-04-02 (-38 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-06 ( -4 days, 88 deaths)
#
# Parameters:
#   Totals:      58,526 cases and 1,627 deaths at end of 2020-05-07
#   Smoothed:    58,526 cases and 1,627 deaths at end of 2020-05-07 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-05-07, compared to 7 days earlier)
#   Growth:      52 days (Start -> Peak Cases)
# ...
