# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://coronavirus.data.gov.uk/">coronavirus.data.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='CN').analyse(ylog=1)
# Out:
# China data to end of 2020-05-03:
#   83,964 cases, 4,637 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-109 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-83 days, 4,690 cases)
#   End:         2020-03-06 (-57 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-99 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-78 days, 128 deaths)
#
# Parameters:
#   Totals:      83,956 cases and 4,637 deaths at end of 2020-04-30
#   Smoothed:    83,955 cases and 4,637 deaths at end of 2020-04-30 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-04-30, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='US', dilation=1.4, d_cases=10).analyse()
# Out:
# United States of America data to end of 2020-05-03:
#   1,158,041 cases, 67,682 deaths
#   3,540 cases per million, 207 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         52% through outbreak
#   Start:       2020-02-25 (-68 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-26 days, 31,870 cases)
#   End:         2020-06-29 ( 58 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-51 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-15 days, 2,736 deaths)
#
# Parameters:
#   Totals:      1,069,826 cases and 63,006 deaths at end of 2020-04-30
#   Smoothed:    1,069,825 cases and 63,006 deaths at end of 2020-04-30 (7 points)
#   Spread:      Peak infection rate 11.5 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-30, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RU', growth_days=52, lag=7).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-03:
#   134,687 cases, 1,280 deaths
#   932 cases per million, 9 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         45% through outbreak
#   Start:       2020-03-14 (-50 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-05 (  2 days, --- cases)
#   End:         2020-06-25 ( 54 days, 52 days after peak cases)
#   Day Zero:    2020-04-06 (-27 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-28 ( -5 days, 81 deaths)
#
# Parameters:
#   Totals:      106,498 cases and 1,073 deaths at end of 2020-04-30
#   Smoothed:    106,498 cases and 1,073 deaths at end of 2020-04-30 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.4 (2020-04-30, compared to 7 days earlier)
#   Growth:      52 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZ', dilation=3).analyse()
# Out:
# New Zealand data to end of 2020-05-03:
#   1,137 cases, 20 deaths
#   233 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-44 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-37 days, 72 cases)
#   End:         2020-04-09 (-23 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,132 cases and 19 deaths at end of 2020-04-30
#   Smoothed:    1,132 cases and 19 deaths at end of 2020-04-30 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-30, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                L = 288, r = 4.0, dilation = 3 for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
# ...

# %%
covid.Region(geoId='JP', dilation=2.2, d_cases=1.6).analyse()
# Out:
# Japan data to end of 2020-05-03:
#   15,057 cases, 510 deaths
#   119 cases per million, 4 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         50% through outbreak
#   Start:       2020-02-16 (-77 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-20 days, 641 cases)
#   End:         2020-07-12 ( 71 days, 91 days after peak cases)
#   Day Zero:    2020-03-28 (-36 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 ( -8 days, 29 deaths)
#
# Parameters:
#   Totals:      14,281 cases and 432 deaths at end of 2020-04-30
#   Smoothed:    14,281 cases and 431 deaths at end of 2020-04-30 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-04-30, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
#                L = 2,564, r = 8.0, dilation = 1.6 for cases
# ...

# %%
covid.Region(geoId='SG', dilation=4).analyse()
# Out:
# Singapore data to end of 2020-05-03:
#   18,205 cases, 18 deaths
#   3,229 cases per million, 3 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         37% through outbreak
#   Start:       2020-02-12 (-81 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-10 days, 998 cases)
#   End:         2020-09-11 (132 days, 142 days after peak cases)
#
# Parameters:
#   Totals:      16,169 cases and 15 deaths at end of 2020-04-30
#   Smoothed:    16,168 cases and 15 deaths at end of 2020-04-30 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-30, compared to 7 days earlier)
#   Growth:      71 days (Start -> Peak Cases)
#                L = 3,990, r = 8.0, dilation = 4 for cases
#
# Outcome: 55,251 total cases, 68 total deaths by end of 2020-09-11
# ...

# %%
covid.Region(geoId='BR', growth_days=54).analyse()
# Out:
# Brazil data to end of 2020-05-03:
#   101,147 cases, 7,025 deaths
#   483 cases per million, 34 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         46% through outbreak
#   Start:       2020-03-11 (-53 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-04 (  1 days, --- cases)
#   End:         2020-06-26 ( 55 days, 54 days after peak cases)
#   Day Zero:    2020-03-24 (-40 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-30 ( -3 days, 406 deaths)
#
# Parameters:
#   Totals:      85,380 cases and 5,901 deaths at end of 2020-04-30
#   Smoothed:    85,380 cases and 5,900 deaths at end of 2020-04-30 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.7 (2020-04-30, compared to 7 days earlier)
#   Growth:      54 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MX', dilation=4).analyse()
# Out:
# Mexico data to end of 2020-05-03:
#   23,471 cases, 2,154 deaths
#   186 cases per million, 17 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-15 (-49 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-30 ( -3 days, 1,247 cases)
#   End:         2020-07-30 ( 89 days, 92 days after peak cases)
#   Day Zero:    2020-04-02 (-31 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-04 (  1 days)
#
# Parameters:
#   Totals:      19,224 cases and 1,859 deaths at end of 2020-04-30
#   Smoothed:    19,224 cases and 1,858 deaths at end of 2020-04-30 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.4 (2020-04-30, compared to 7 days earlier)
#   Growth:      46 days (Start -> Peak Cases)
#                L = 4,986, r = 5.89, dilation = 4 for cases
# ...

# %%
covid.Region(geoId='PE', dilation=4).analyse()
# Out:
# Peru data to end of 2020-05-03:
#   45,928 cases, 1,286 deaths
#   1,436 cases per million, 40 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         35% through outbreak
#   Start:       2020-03-15 (-49 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-28 ( -5 days, 2,679 cases)
#   End:         2020-07-24 ( 83 days, 88 days after peak cases)
#   Day Zero:    2020-04-02 (-31 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-02 ( -1 days, --- deaths)
#
# Parameters:
#   Totals:      36,976 cases and 1,051 deaths at end of 2020-04-30
#   Smoothed:    36,976 cases and 1,050 deaths at end of 2020-04-30 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.5 (2020-04-30, compared to 7 days earlier)
#   Growth:      44 days (Start -> Peak Cases)
# ...
