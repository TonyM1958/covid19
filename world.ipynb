# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='CN', dilation=1, d_cases=0.7).analyse(ylog=0)
# Out:
# China data to end of 2020-05-13:
#   84,024 cases, 4,637 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-119 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-93 days, 4,690 cases)
#   End:         2020-03-06 (-67 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-109 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-88 days, 128 deaths)
#
# Parameters:
#   Totals:      84,010 cases and 4,637 deaths at end of 2020-05-10
#   Smoothed:    84,009 cases and 4,637 deaths at end of 2020-05-10 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 2.1 (2020-05-10, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='KR', dilation=3, d_cases=1).analyse(ylog=0)
# Out:
# South Korea data to end of 2020-05-13:
#   10,991 cases, 260 deaths
#   213 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-86 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-72 days, 609 cases)
#   End:         2020-03-15 (-58 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-66 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-58 days, 5 deaths)
#
# Parameters:
#   Totals:      10,909 cases and 256 deaths at end of 2020-05-10
#   Smoothed:    10,909 cases and 255 deaths at end of 2020-05-10 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 4.0 (2020-05-10, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZ', dilation=3.1).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-05-13:
#   1,147 cases, 21 deaths
#   235 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-54 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-47 days, 72 cases)
#   End:         2020-04-09 (-33 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,147 cases and 21 deaths at end of 2020-05-10
#   Smoothed:    1,147 cases and 21 deaths at end of 2020-05-10 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-10, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,107, r = 4.0, L = 289, dilation = 3.1, c = 89.1% for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
# ...

# %%
covid.Region(geoId='US', dilation=2.6, d_cases=3.9).analyse()
# Out:
# United States of America data to end of 2020-05-13:
#   1,390,746 cases, 84,133 deaths
#   4,251 cases per million, 257 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         60% through outbreak
#   Start:       2020-02-25 (-78 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-36 days, 32,010 cases)
#   End:         2020-06-29 ( 48 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-61 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-25 days, 2,707 deaths)
#
# Parameters:
#   Totals:      1,329,799 cases and 79,528 deaths at end of 2020-05-10
#   Smoothed:    1,329,798 cases and 79,527 deaths at end of 2020-05-10 (7 points)
#   Spread:      Peak infection rate 12.5 (2020-03-07, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-10, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RU', lag=5).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-13:
#   242,271 cases, 2,212 deaths
#   1,677 cases per million, 15 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         51% through outbreak
#   Start:       2020-03-14 (-60 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 ( -4 days, 10,971 cases)
#   End:         2020-07-03 ( 52 days, 56 days after peak cases)
#   Day Zero:    2020-04-06 (-37 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-14 (  1 days)
#
# Parameters:
#   Totals:      209,688 cases and 1,915 deaths at end of 2020-05-10
#   Smoothed:    209,688 cases and 1,915 deaths at end of 2020-05-10 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-10, compared to 7 days earlier)
#   Growth:      56 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP', dilation=1.7, d_cases=1.3).analyse(ylog=0)
# Out:
# Japan data to end of 2020-05-13:
#   16,079 cases, 687 deaths
#   127 cases per million, 5 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         64% through outbreak
#   Start:       2020-02-16 (-87 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-30 days, 642 cases)
#   End:         2020-06-25 ( 44 days, 74 days after peak cases)
#   Day Zero:    2020-03-28 (-46 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-18 days, 29 deaths)
#
# Parameters:
#   Totals:      15,798 cases and 621 deaths at end of 2020-05-10
#   Smoothed:    15,797 cases and 620 deaths at end of 2020-05-10 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.4 (2020-05-10, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SG', dilation=3.5).analyse()
# Out:
# Singapore data to end of 2020-05-13:
#   25,346 cases, 21 deaths
#   4,495 cases per million, 4 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         41% through outbreak
#   Start:       2020-02-11 (-92 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-20 days, 1,012 cases)
#   End:         2020-09-13 (124 days, 144 days after peak cases)
#
# Parameters:
#   Totals:      23,336 cases and 20 deaths at end of 2020-05-10
#   Smoothed:    23,336 cases and 20 deaths at end of 2020-05-10 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-10, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                X = 53,594, r = 8.0, L = 4,047, dilation = 3.5, c = 47.6% for cases
#
# Outcome: 53,045 total cases, 64 total deaths by end of 2020-09-13
# ...

# %%
covid.Region(geoId='BR', lag=3, dilation=2.5).analyse()
# Out:
# Brazil data to end of 2020-05-13:
#   188,974 cases, 13,149 deaths
#   902 cases per million, 63 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-11 (-63 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-10 ( -3 days, 9,148 cases)
#   End:         2020-09-06 (117 days, 120 days after peak cases)
#   Day Zero:    2020-03-25 (-49 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-13 (  0 days, --- deaths)
#
# Parameters:
#   Totals:      162,699 cases and 11,123 deaths at end of 2020-05-10
#   Smoothed:    162,699 cases and 11,123 deaths at end of 2020-05-10 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.4 (2020-05-10, compared to 7 days earlier)
#   Growth:      60 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MX', lag=4, dilation=2.5).analyse()
# Out:
# Mexico data to end of 2020-05-13:
#   40,186 cases, 4,220 deaths
#   318 cases per million, 33 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-15 (-59 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-10 ( -3 days, 1,798 cases)
#   End:         2020-08-29 (109 days, 112 days after peak cases)
#   Day Zero:    2020-04-02 (-41 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-14 (  1 days)
#
# Parameters:
#   Totals:      35,022 cases and 3,465 deaths at end of 2020-05-10
#   Smoothed:    35,022 cases and 3,465 deaths at end of 2020-05-10 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-10, compared to 7 days earlier)
#   Growth:      56 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='PE', lag=3, dilation=2.5).analyse()
# Out:
# Peru data to end of 2020-05-13:
#   76,306 cases, 2,169 deaths
#   2,385 cases per million, 68 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         36% through outbreak
#   Start:       2020-03-15 (-59 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-06 ( -7 days, 3,221 cases)
#   End:         2020-08-17 ( 97 days, 104 days after peak cases)
#   Day Zero:    2020-04-02 (-41 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-10 ( -3 days, 91 deaths)
#
# Parameters:
#   Totals:      67,307 cases and 1,889 deaths at end of 2020-05-10
#   Smoothed:    67,307 cases and 1,888 deaths at end of 2020-05-10 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-10, compared to 7 days earlier)
#   Growth:      52 days (Start -> Peak Cases)
# ...
