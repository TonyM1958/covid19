# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=0, ylog=1, dilation=4, d_clip=3)
covid.data_load('download.json')

# %%
covid.Region(geoId='US').analyse()
# Out:
# United States of America data to end of 2020-11-17:
#   11,359,802 cases, 248,687 deaths
#   34,521 cases per million, 756 deaths per million (2019 population = 329,064,917)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         25% through outbreak
#   Start:       2020-02-25 (-266 days, when 50 or more cases were reported)
#   Peak Cases:  2020-11-14 ( -3 days, 157,697 cases)
#   End:         2023-01-11 (786 days, 789 days after peak cases)
#   Day Zero:    2020-03-13 (-249 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-213 days, 2,720 deaths)
#
# Parameters:
#   Totals:      10,904,891 cases and 245,600 deaths at end of 2020-11-14
#   Smoothed:    10,904,890 cases and 245,599 deaths at end of 2020-11-14 (7 points)
#   Spread:      Peak infection rate 12.5 (2020-03-07, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-11-14, compared to 7 days earlier)
#   Growth:      263 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RU').analyse()
# Out:
# Russia data to end of 2020-11-17:
#   1,971,013 cases, 33,931 deaths
#   13,512 cases per million, 233 deaths per million (2019 population = 145,872,260)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         25% through outbreak
#   Start:       2020-03-14 (-248 days, when 50 or more cases were reported)
#   Peak Cases:  2020-11-13 ( -4 days, 24,937 cases)
#   End:         2022-11-14 (728 days, 732 days after peak cases)
#   Day Zero:    2020-04-06 (-225 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-11-13 ( -4 days, 448 deaths)
#
# Parameters:
#   Totals:      1,903,253 cases and 32,834 deaths at end of 2020-11-14
#   Smoothed:    1,903,252 cases and 32,834 deaths at end of 2020-11-14 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-11-14, compared to 7 days earlier)
#   Growth:      244 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP', dilation=1, d_cases=2).analyse()
# Out:
# Japan data to end of 2020-11-17:
#   120,815 cases, 1,913 deaths
#   952 cases per million, 15 deaths per million (2019 population = 126,860,299)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         53% through outbreak
#   Start:       2020-02-16 (-275 days, when 50 or more cases were reported)
#   Peak Cases:  2020-08-04 (-105 days, 1,587 cases)
#   End:         2021-07-09 (235 days, 340 days after peak cases)
#   Day Zero:    2020-03-28 (-234 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-206 days, 29 deaths)
#
# Parameters:
#   Totals:      116,677 cases and 1,883 deaths at end of 2020-11-14
#   Smoothed:    116,676 cases and 1,883 deaths at end of 2020-11-14 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-04-04, compared to 7 days earlier)
#                Latest infection rate 1.5 (2020-11-14, compared to 7 days earlier)
#   Growth:      170 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SG', d_cases=3).analyse()
# Out:
# Singapore data to end of 2020-11-17:
#   58,130 cases, 28 deaths
#   10,015 cases per million, 5 deaths per million (2019 population = 5,804,343)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         96% through outbreak
#   Start:       2020-02-11 (-280 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-208 days, 1,005 cases)
#   End:         2020-11-24 (  8 days, 216 days after peak cases)
#
# Parameters:
#   Totals:      58,116 cases and 28 deaths at end of 2020-11-14
#   Smoothed:    58,116 cases and 28 deaths at end of 2020-11-14 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-11-14, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                X = 58,148, r = 8.0, L = 4,020, dilation = 3, c = 51.6% for cases
#
# Outcome: 58,129 total cases, 28 total deaths by end of 2020-11-24
# ...

# %%
covid.Region(geoId='BR', dilation=2).analyse()
# Out:
# Brazil data to end of 2020-11-17:
#   5,911,758 cases, 166,699 deaths
#   28,011 cases per million, 790 deaths per million (2019 population = 211,049,519)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         60% through outbreak
#   Start:       2020-03-11 (-251 days, when 50 or more cases were reported)
#   Peak Cases:  2020-07-26 (-114 days, 46,525 cases)
#   End:         2021-04-25 (160 days, 274 days after peak cases)
#   Day Zero:    2020-03-25 (-237 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-07-22 (-118 days, 1,100 deaths)
#
# Parameters:
#   Totals:      5,848,959 cases and 165,658 deaths at end of 2020-11-14
#   Smoothed:    5,848,958 cases and 165,658 deaths at end of 2020-11-14 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.6 (2020-11-14, compared to 7 days earlier)
#   Growth:      137 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='CL').analyse()
# Out:
# Chile data to end of 2020-11-17:
#   533,610 cases, 14,883 deaths
#   28,156 cases per million, 785 deaths per million (2019 population = 18,952,035)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         66% through outbreak
#   Start:       2020-03-13 (-249 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-14 (-156 days, 10,308 cases)
#   End:         2021-03-19 (123 days, 279 days after peak cases)
#   Day Zero:    2020-04-08 (-223 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-07-17 (-123 days, 230 deaths)
#
# Parameters:
#   Totals:      529,676 cases and 14,777 deaths at end of 2020-11-14
#   Smoothed:    529,675 cases and 14,777 deaths at end of 2020-11-14 (7 points)
#   Spread:      Peak infection rate 4.2 (2020-03-22, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-11-14, compared to 7 days earlier)
#   Growth:      93 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='PE').analyse()
# Out:
# Peru data to end of 2020-11-17:
#   939,931 cases, 35,317 deaths
#   28,912 cases per million, 1,086 deaths per million (2019 population = 32,510,462)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         40% through outbreak
#   Start:       2020-03-15 (-247 days, when 50 or more cases were reported)
#   Peak Cases:  2020-08-16 (-93 days, 8,557 cases)
#   End:         2021-11-20 (369 days, 462 days after peak cases)
#   Day Zero:    2020-04-02 (-229 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-08-12 (-97 days, 747 deaths)
#
# Parameters:
#   Totals:      934,899 cases and 35,177 deaths at end of 2020-11-14
#   Smoothed:    934,899 cases and 35,177 deaths at end of 2020-11-14 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-11-14, compared to 7 days earlier)
#   Growth:      154 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MX').analyse()
# Out:
# Mexico data to end of 2020-11-17:
#   1,011,153 cases, 99,026 deaths
#   7,926 cases per million, 776 deaths per million (2019 population = 127,575,529)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         48% through outbreak
#   Start:       2020-03-10 (-252 days, when 50 or more cases were reported)
#   Peak Cases:  2020-07-18 (-122 days, 7,188 cases)
#   End:         2021-08-11 (268 days, 390 days after peak cases)
#   Day Zero:    2020-04-02 (-229 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-24 (-146 days, 802 deaths)
#
# Parameters:
#   Totals:      1,003,253 cases and 98,259 deaths at end of 2020-11-14
#   Smoothed:    1,003,253 cases and 98,259 deaths at end of 2020-11-14 (7 points)
#   Spread:      Peak infection rate 3.5 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-11-14, compared to 7 days earlier)
#   Growth:      130 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IN').analyse()
# Out:
# India data to end of 2020-11-17:
#   8,912,907 cases, 130,993 deaths
#   6,523 cases per million, 96 deaths per million (2019 population = 1,366,417,756)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-10 (-252 days, when 50 or more cases were reported)
#   Peak Cases:  2020-09-13 (-65 days, 93,303 cases)
#   End:         2022-03-27 (496 days, 561 days after peak cases)
#   Day Zero:    2020-04-02 (-229 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-09-12 (-66 days, 1,168 deaths)
#
# Parameters:
#   Totals:      8,814,579 cases and 129,635 deaths at end of 2020-11-14
#   Smoothed:    8,814,579 cases and 129,634 deaths at end of 2020-11-14 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-02, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-11-14, compared to 7 days earlier)
#   Growth:      187 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='CN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2020-11-17:
#   92,475 cases, 4,749 deaths
#   64 cases per million, 3 deaths per million (2019 population = 1,433,783,692)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-307 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-281 days, 4,678 cases)
#   End:         2020-03-06 (-255 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-297 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-276 days, 128 deaths)
#
# Parameters:
#   Totals:      91,629 cases and 4,739 deaths at end of 2020-11-14
#   Smoothed:    91,629 cases and 4,738 deaths at end of 2020-11-14 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 4.9 (2020-11-14, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='KR').analyse(ylog=1)
# Out:
# South Korea data to end of 2020-11-17:
#   29,311 cases, 496 deaths
#   572 cases per million, 10 deaths per million (2019 population = 51,225,321)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-274 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-260 days, 608 cases)
#   End:         2020-04-12 (-218 days, 42 days after peak cases)
#   Day Zero:    2020-03-08 (-254 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-25 (-237 days, 7 deaths)
#
# Parameters:
#   Totals:      28,546 cases and 493 deaths at end of 2020-11-14
#   Smoothed:    28,546 cases and 493 deaths at end of 2020-11-14 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 1.7 (2020-11-14, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZ', d_cases=3).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-11-17:
#   1,652 cases, 25 deaths
#   345 cases per million, 5 deaths per million (2019 population = 4,783,062)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-242 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-235 days, 72 cases)
#   End:         2020-04-16 (-214 days, 21 days after peak cases)
#
# Parameters:
#   Totals:      1,645 cases and 25 deaths at end of 2020-11-14
#   Smoothed:    1,645 cases and 24 deaths at end of 2020-11-14 (7 points)
#   Spread:      Peak infection rate 79.0 (2020-08-15, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-11-14, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,113, r = 4.0, L = 288, dilation = 3, c = 92.0% for cases
#
# Outcome: 1,094 total cases, 11 total deaths at end of 2020-04-17
# ...

# %%
covid.Region(geoId='AU').analyse()
# Out:
# Australia data to end of 2020-11-17:
#   27,756 cases, 907 deaths
#   1,101 cases per million, 36 deaths per million (2019 population = 25,203,200)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         42% through outbreak
#   Start:       2020-03-04 (-258 days, when 50 or more cases were reported)
#   Peak Cases:  2020-08-02 (-107 days, 552 cases)
#   End:         2021-10-28 (346 days, 453 days after peak cases)
#   Day Zero:    2020-04-09 (-222 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-09-01 (-77 days, 22 deaths)
#
# Parameters:
#   Totals:      27,711 cases and 907 deaths at end of 2020-11-14
#   Smoothed:    27,711 cases and 906 deaths at end of 2020-11-14 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-11-14, compared to 7 days earlier)
#   Growth:      151 days (Start -> Peak Cases)
# ...
