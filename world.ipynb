# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='CN', dilation=1.1, d_cases=0.9).analyse(ylog=1)
# Out:
# China data to end of 2020-05-12:
#   84,018 cases, 4,637 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-118 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-92 days, 4,689 cases)
#   End:         2020-03-06 (-66 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-108 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-87 days, 128 deaths)
#
# Parameters:
#   Totals:      83,991 cases and 4,637 deaths at end of 2020-05-09
#   Smoothed:    83,991 cases and 4,637 deaths at end of 2020-05-09 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 1.8 (2020-05-09, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='KR', dilation=3, d_cases=1).analyse(ylog=1)
# Out:
# South Korea data to end of 2020-05-12:
#   10,962 cases, 259 deaths
#   212 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-85 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-71 days, 609 cases)
#   End:         2020-03-15 (-57 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-65 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-57 days, 5 deaths)
#
# Parameters:
#   Totals:      10,874 cases and 256 deaths at end of 2020-05-09
#   Smoothed:    10,874 cases and 256 deaths at end of 2020-05-09 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 3.5 (2020-05-09, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZ', dilation=3.1).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-05-12:
#   1,147 cases, 21 deaths
#   235 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-53 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-46 days, 72 cases)
#   End:         2020-04-09 (-32 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,144 cases and 21 deaths at end of 2020-05-09
#   Smoothed:    1,144 cases and 21 deaths at end of 2020-05-09 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-09, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,105, r = 4.0, L = 288, dilation = 3.1, c = 89.1% for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
# ...

# %%
covid.Region(geoId='US', dilation=1.8, d_cases=3.7).analyse()
# Out:
# United States of America data to end of 2020-05-12:
#   1,369,964 cases, 82,387 deaths
#   4,187 cases per million, 252 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         59% through outbreak
#   Start:       2020-02-25 (-77 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-35 days, 32,082 cases)
#   End:         2020-06-29 ( 49 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-60 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-24 days, 2,734 deaths)
#
# Parameters:
#   Totals:      1,309,541 cases and 78,794 deaths at end of 2020-05-09
#   Smoothed:    1,309,541 cases and 78,794 deaths at end of 2020-05-09 (7 points)
#   Spread:      Peak infection rate 12.5 (2020-03-07, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-09, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RU', growth_days=59, lag=5).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-12:
#   232,243 cases, 2,116 deaths
#   1,607 cases per million, 15 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         47% through outbreak
#   Start:       2020-03-14 (-59 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-12 (  0 days, --- cases)
#   End:         2020-07-09 ( 59 days, 59 days after peak cases)
#   Day Zero:    2020-04-06 (-36 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-09 ( -3 days, 95 deaths)
#
# Parameters:
#   Totals:      198,676 cases and 1,827 deaths at end of 2020-05-09
#   Smoothed:    198,675 cases and 1,827 deaths at end of 2020-05-09 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-05-09, compared to 7 days earlier)
#   Growth:      59 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP', dilation=1.5, d_cases=1.3).analyse()
# Out:
# Japan data to end of 2020-05-12:
#   16,024 cases, 668 deaths
#   127 cases per million, 5 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         63% through outbreak
#   Start:       2020-02-16 (-86 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-29 days, 644 cases)
#   End:         2020-06-25 ( 45 days, 74 days after peak cases)
#   Day Zero:    2020-03-28 (-45 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-17 days, 29 deaths)
#
# Parameters:
#   Totals:      15,747 cases and 613 deaths at end of 2020-05-09
#   Smoothed:    15,747 cases and 612 deaths at end of 2020-05-09 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.4 (2020-05-09, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SG', dilation=3.5).analyse()
# Out:
# Singapore data to end of 2020-05-12:
#   24,671 cases, 21 deaths
#   4,375 cases per million, 4 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         41% through outbreak
#   Start:       2020-02-11 (-91 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-19 days, 1,006 cases)
#   End:         2020-09-13 (125 days, 144 days after peak cases)
#
# Parameters:
#   Totals:      22,460 cases and 20 deaths at end of 2020-05-09
#   Smoothed:    22,460 cases and 19 deaths at end of 2020-05-09 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-05-09, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                X = 52,989, r = 8.0, L = 4,023, dilation = 3.5, c = 46.8% for cases
#
# Outcome: 52,446 total cases, 66 total deaths by end of 2020-09-13
# ...

# %%
covid.Region(geoId='BR', lag=3, dilation=2.5).analyse()
# Out:
# Brazil data to end of 2020-05-12:
#   177,589 cases, 12,400 deaths
#   848 cases per million, 59 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-11 (-62 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 ( -3 days, 9,161 cases)
#   End:         2020-09-03 (115 days, 118 days after peak cases)
#   Day Zero:    2020-03-24 (-49 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-12 (  0 days, --- deaths)
#
# Parameters:
#   Totals:      155,939 cases and 10,627 deaths at end of 2020-05-09
#   Smoothed:    155,938 cases and 10,627 deaths at end of 2020-05-09 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.5 (2020-05-09, compared to 7 days earlier)
#   Growth:      59 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MX', lag=3, dilation=2.5).analyse()
# Out:
# Mexico data to end of 2020-05-12:
#   38,324 cases, 3,926 deaths
#   304 cases per million, 31 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-15 (-58 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 ( -3 days, 1,775 cases)
#   End:         2020-08-26 (107 days, 110 days after peak cases)
#   Day Zero:    2020-04-02 (-40 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-12 (  0 days, --- deaths)
#
# Parameters:
#   Totals:      33,460 cases and 3,353 deaths at end of 2020-05-09
#   Smoothed:    33,459 cases and 3,352 deaths at end of 2020-05-09 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-09, compared to 7 days earlier)
#   Growth:      55 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='PE', lag=3, dilation=2.5).analyse()
# Out:
# Peru data to end of 2020-05-12:
#   72,059 cases, 2,057 deaths
#   2,253 cases per million, 64 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         35% through outbreak
#   Start:       2020-03-15 (-58 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-06 ( -6 days, 3,260 cases)
#   End:         2020-08-17 ( 98 days, 104 days after peak cases)
#   Day Zero:    2020-04-02 (-40 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-08 ( -4 days, 89 deaths)
#
# Parameters:
#   Totals:      65,015 cases and 1,814 deaths at end of 2020-05-09
#   Smoothed:    65,014 cases and 1,814 deaths at end of 2020-05-09 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-09, compared to 7 days earlier)
#   Growth:      52 days (Start -> Peak Cases)
# ...
