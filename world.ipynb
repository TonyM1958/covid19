# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
# covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='CN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2020-05-16:
#   84,044 cases, 4,638 deaths
#   60 cases per million, 3 deaths per million (2018 population = 1,392,730,000)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-122 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-96 days, 4,689 cases)
#   End:         2020-03-06 (-70 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-112 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-91 days, 128 deaths)
#
# Parameters:
#   Totals:      84,024 cases and 4,637 deaths at end of 2020-05-13
#   Smoothed:    84,024 cases and 4,636 deaths at end of 2020-05-13 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 1.8 (2020-05-13, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='KR', dilation=3, d_cases=1).analyse(ylog=1)
# Out:
# South Korea data to end of 2020-05-16:
#   11,050 cases, 262 deaths
#   214 cases per million, 5 deaths per million (2018 population = 51,635,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-89 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-75 days, 609 cases)
#   End:         2020-03-15 (-61 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-69 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-61 days, 5 deaths)
#
# Parameters:
#   Totals:      10,991 cases and 260 deaths at end of 2020-05-13
#   Smoothed:    10,991 cases and 260 deaths at end of 2020-05-13 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 2.2 (2020-05-13, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='NZ', dilation=3.1).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-05-16:
#   1,149 cases, 21 deaths
#   235 cases per million, 4 deaths per million (2018 population = 4,885,500)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-57 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-50 days, 72 cases)
#   End:         2020-04-09 (-36 days, 14 days after peak cases)
#
# Parameters:
#   Totals:      1,147 cases and 21 deaths at end of 2020-05-13
#   Smoothed:    1,147 cases and 21 deaths at end of 2020-05-13 (7 points)
#   Spread:      Peak infection rate 2.0 (2020-03-29, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-13, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,105, r = 4.0, L = 288, dilation = 3.1, c = 89.1% for cases
#
# Outcome: 1,035 total cases, 4 total deaths at end of 2020-04-10
# ...

# %%
covid.Region(geoId='US', dilation=3, d_cases=7).analyse()
# Out:
# United States of America data to end of 2020-05-16:
#   1,467,884 cases, 88,754 deaths
#   4,487 cases per million, 271 deaths per million (2018 population = 327,167,434)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         62% through outbreak
#   Start:       2020-02-25 (-81 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-07 (-39 days, 31,836 cases)
#   End:         2020-06-29 ( 45 days, 84 days after peak cases)
#   Day Zero:    2020-03-13 (-64 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-28 days, 2,715 deaths)
#
# Parameters:
#   Totals:      1,390,746 cases and 84,133 deaths at end of 2020-05-13
#   Smoothed:    1,390,745 cases and 84,133 deaths at end of 2020-05-13 (7 points)
#   Spread:      Peak infection rate 11.5 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-13, compared to 7 days earlier)
#   Growth:      42 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='RU', lag=5, dilation=2.5).analyse(ylog=1)
# Out:
# Russia data to end of 2020-05-16:
#   272,043 cases, 2,537 deaths
#   1,883 cases per million, 18 deaths per million (2018 population = 144,478,050)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         36% through outbreak
#   Start:       2020-03-14 (-63 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 ( -7 days, 11,003 cases)
#   End:         2020-08-28 (105 days, 112 days after peak cases)
#   Day Zero:    2020-04-06 (-40 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-14 ( -2 days, --- deaths)
#
# Parameters:
#   Totals:      242,271 cases and 2,212 deaths at end of 2020-05-13
#   Smoothed:    242,271 cases and 2,212 deaths at end of 2020-05-13 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-13, compared to 7 days earlier)
#   Growth:      56 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='JP', dilation=2.5, d_cases=1.3).analyse(ylog=1)
# Out:
# Japan data to end of 2020-05-16:
#   16,285 cases, 744 deaths
#   129 cases per million, 6 deaths per million (2018 population = 126,529,100)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         66% through outbreak
#   Start:       2020-02-16 (-90 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-13 (-33 days, 643 cases)
#   End:         2020-06-25 ( 41 days, 74 days after peak cases)
#   Day Zero:    2020-03-28 (-49 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-21 days, 29 deaths)
#
# Parameters:
#   Totals:      16,079 cases and 687 deaths at end of 2020-05-13
#   Smoothed:    16,078 cases and 686 deaths at end of 2020-05-13 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-03-30, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-13, compared to 7 days earlier)
#   Growth:      57 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SG', dilation=4.5).analyse()
# Out:
# Singapore data to end of 2020-05-16:
#   27,356 cases, 22 deaths
#   4,851 cases per million, 4 deaths per million (2018 population = 5,638,676)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         43% through outbreak
#   Start:       2020-02-12 (-94 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-23 days, 1,005 cases)
#   End:         2020-09-11 (119 days, 142 days after peak cases)
#
# Parameters:
#   Totals:      25,346 cases and 21 deaths at end of 2020-05-13
#   Smoothed:    25,346 cases and 21 deaths at end of 2020-05-13 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-13, compared to 7 days earlier)
#   Growth:      71 days (Start -> Peak Cases)
#                X = 64,224, r = 8.0, L = 4,019, dilation = 4.5, c = 49.8% for cases
#
# Outcome: 62,440 total cases, 69 total deaths by end of 2020-09-11
# ...

# %%
covid.Region(geoId='BR', growth_days=70, lag=6, dilation=2.5).analyse()
# Out:
# Brazil data to end of 2020-05-16:
#   233,142 cases, 15,633 deaths
#   1,113 cases per million, 75 deaths per million (2018 population = 209,469,333)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         30% through outbreak
#   Start:       2020-03-11 (-66 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-20 (  4 days, 0 cases)
#   End:         2020-10-06 (144 days, 140 days after peak cases)
#   Day Zero:    2020-03-25 (-52 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-26 ( 10 days)
#
# Parameters:
#   Totals:      188,974 cases and 13,149 deaths at end of 2020-05-13
#   Smoothed:    188,973 cases and 13,149 deaths at end of 2020-05-13 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-13, compared to 7 days earlier)
#   Growth:      70 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='MX', growth_days=65, lag=5, dilation=3).analyse()
# Out:
# Mexico data to end of 2020-05-16:
#   47,144 cases, 5,045 deaths
#   374 cases per million, 40 deaths per million (2018 population = 126,190,788)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         30% through outbreak
#   Start:       2020-03-15 (-62 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-19 (  3 days, --- cases)
#   End:         2020-09-25 (133 days, 130 days after peak cases)
#   Day Zero:    2020-04-02 (-44 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-24 (  8 days)
#
# Parameters:
#   Totals:      40,186 cases and 4,220 deaths at end of 2020-05-13
#   Smoothed:    40,186 cases and 4,220 deaths at end of 2020-05-13 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-05-13, compared to 7 days earlier)
#   Growth:      65 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='PE', growth_days=65, lag=6, dilation=2.5, d_cases=3).analyse()
# Out:
# Peru data to end of 2020-05-16:
#   88,541 cases, 2,523 deaths
#   2,768 cases per million, 79 deaths per million (2018 population = 31,989,256)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         30% through outbreak
#   Start:       2020-03-15 (-62 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-19 (  3 days, --- cases)
#   End:         2020-09-25 (133 days, 130 days after peak cases)
#   Day Zero:    2020-04-02 (-44 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-05-13 ( -3 days, 101 deaths)
#
# Parameters:
#   Totals:      76,306 cases and 2,169 deaths at end of 2020-05-13
#   Smoothed:    76,306 cases and 2,169 deaths at end of 2020-05-13 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-13, compared to 7 days earlier)
#   Growth:      65 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='AU').analyse(ylog=1)
# Out:
# Australia data to end of 2020-05-16:
#   7,036 cases, 98 deaths
#   282 cases per million, 4 deaths per million (2018 population = 24,992,369)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-04 (-73 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-50 days, 390 cases)
#   End:         2020-04-18 (-27 days, 23 days after peak cases)
#   Day Zero:    2020-04-09 (-37 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-40 days, 4 deaths)
#
# Parameters:
#   Totals:      6,975 cases and 98 deaths at end of 2020-05-13
#   Smoothed:    6,974 cases and 98 deaths at end of 2020-05-13 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-13, compared to 7 days earlier)
#   Growth:      23 days (Start -> Peak Cases)
# ...
