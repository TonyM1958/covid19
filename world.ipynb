# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=0, ylog=1, dilation=3, d_clip=3)
covid.data_load('download.json')

# %%
covid.Region(geoId='US', dilation=3, d_cases=4).analyse()
# Out:
# United States of America data to end of 2020-07-17:
#   3,647,715 cases, 139,266 deaths
#   11,085 cases per million, 423 deaths per million (2019 population = 329,064,917)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         25% through outbreak
#   Start:       2020-02-25 (-143 days, when 50 or more cases were reported)
#   Peak Cases:  2020-07-14 ( -3 days, 66,019 cases)
#   End:         2021-09-06 (417 days, 420 days after peak cases)
#   Day Zero:    2020-03-13 (-126 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-18 (-90 days, 2,710 deaths)
#
# Parameters:
#   Totals:      3,431,574 cases and 136,466 deaths at end of 2020-07-14
#   Smoothed:    3,431,573 cases and 136,465 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 11.5 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-07-14, compared to 7 days earlier)
#   Growth:      140 days (Start -> Peak Cases)
#                X = 16,931,450, r = 5.41, L = 264,074, dilation = 4, c = 49.3% for cases
#   Lag:         -87 days (Peak Cases -> Peak Deaths)
#                X = 180,450, r = 8.0, L = 10,839, dilation = 3, c = -5.5% for deaths
#
# Outcome: 16,642,848 total cases, 180,438 total deaths by end of 2021-09-06
#   21.5% of predicted cases and 77.2% of predicted deaths reported to date
#   98.3% of predicted cases and 100.0% of predicted deaths reported by end date
#   51,453 cases per million (5.15%), 548 deaths per million (0.055%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04   45,221      242   2,839,542  129,676    51,560      580   2,834,674  129,410
# 2020-07-05   49,093      271   2,888,635  129,947    52,538      606   2,887,212  130,016
# 2020-07-06   49,990      359   2,938,625  130,306    53,907      649   2,941,120  130,665
# 2020-07-07   57,473    1,174   2,996,098  131,480    55,644      665   2,996,764  131,329
# 2020-07-08   58,906      829   3,055,004  132,309    58,186      733   3,054,950  132,062
# 2020-07-09   63,004      982   3,118,008  133,291    59,350      750   3,114,300  132,812
# 2020-07-10   66,625      806   3,184,633  134,097    60,508      756   3,174,809  133,567
# 2020-07-11   63,051      717   3,247,684  134,814    62,083      711   3,236,892  134,278
# 2020-07-12   57,258      391   3,304,942  135,205    63,339      729   3,300,231  135,007
# 2020-07-13   58,114      400   3,363,056  135,605    65,324      722   3,365,555  135,729
# 2020-07-14   68,518      861   3,431,574  136,466    66,019      737   3,431,574  136,466
# 2020-07-15   67,717      953   3,499,291  137,419
# 2020-07-16   76,930      939   3,576,221  138,358
# 2020-07-17   71,494      908   3,647,715  139,266
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-07-14   66,198      709  3,431,574  136,466
# 2020-07-15   66,197      700  3,497,771  137,166
# 2020-07-16   66,192      691  3,563,963  137,857
# 2020-07-17   66,184      682  3,630,147  138,539  <-- latest raw data
# 2020-07-18   66,174      673  3,696,320  139,213
# 2020-07-19   66,160      664  3,762,480  139,877
# 2020-07-20   66,143      655  3,828,623  140,532
# 2020-07-21   66,123      646  3,894,745  141,178
# 2020-07-22   66,100      638  3,960,845  141,816
# 2020-07-23   66,073      629  4,026,918  142,445

# %%
covid.Region(geoId='RU', dilation=2, d_cases=5).analyse()
# Out:
# Russia data to end of 2020-07-17:
#   765,437 cases, 12,247 deaths
#   5,247 cases per million, 84 deaths per million (2019 population = 145,872,260)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         54% through outbreak
#   Start:       2020-03-14 (-125 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-09 (-69 days, 10,968 cases)
#   End:         2020-10-23 ( 99 days, 168 days after peak cases)
#   Day Zero:    2020-04-06 (-102 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-15 (-32 days, 179 deaths)
#
# Parameters:
#   Totals:      739,947 cases and 11,614 deaths at end of 2020-07-14
#   Smoothed:    739,946 cases and 11,614 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 4.8 (2020-03-28, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-07-14, compared to 7 days earlier)
#   Growth:      56 days (Start -> Peak Cases)
#                X = 980,489, r = 7.27, L = 43,873, dilation = 5, c = 89.1% for cases
#   Lag:         37 days (Peak Cases -> Peak Deaths)
#                X = 17,672, r = 4.0, L = 716, dilation = 2, c = 75.2% for deaths
#
# Outcome: 968,110 total cases, 17,509 total deaths by end of 2020-10-23
#   78.1% of predicted cases and 69.3% of predicted deaths reported to date
#   98.7% of predicted cases and 99.1% of predicted deaths reported by end date
#   6,722 cases per million (0.67%), 121 deaths per million (0.012%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04    6,632      168     674,515   10,027     6,618      167     673,650    9,977
# 2020-07-05    6,736      134     681,251   10,161     6,619      161     680,268   10,139
# 2020-07-06    6,611      135     687,862   10,296     6,583      165     686,851   10,304
# 2020-07-07    6,368      198     694,230   10,494     6,571      165     693,422   10,469
# 2020-07-08    6,562      173     700,792   10,667     6,568      168     699,990   10,636
# 2020-07-09    6,509      176     707,301   10,843     6,551      167     706,541   10,804
# 2020-07-10    6,635      174     713,936   11,017     6,540      163     713,081   10,966
# 2020-07-11    6,611      188     720,547   11,205     6,523      160     719,604   11,126
# 2020-07-12    6,615      130     727,162   11,335     6,503      157     726,107   11,283
# 2020-07-13    6,537      104     733,699   11,439     6,491      156     732,599   11,439
# 2020-07-14    6,248      175     739,947   11,614     7,348      175     739,947   11,614
# 2020-07-15    6,422      156     746,369   11,770
# 2020-07-16    6,428      167     752,797   11,937
# 2020-07-17   12,640      310     765,437   12,247
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-07-14    5,540      163    739,947   11,614
# 2020-07-15    5,441      161    745,388   11,775
# 2020-07-16    5,342      158    750,730   11,932
# 2020-07-17    5,244      155    755,974   12,087  <-- latest raw data
# 2020-07-18    5,148      152    761,122   12,239
# 2020-07-19    5,052      149    766,174   12,389
# 2020-07-20    4,957      146    771,131   12,535
# 2020-07-21    4,864      143    775,995   12,678
# 2020-07-22    4,771      140    780,766   12,819
# 2020-07-23    4,679      138    785,445   12,956

# %%
covid.Region(geoId='JP', dilation=2.4, d_cases=4).analyse()
# Out:
# Japan data to end of 2020-07-17:
#   24,132 cases, 985 deaths
#   190 cases per million, 8 deaths per million (2019 population = 126,860,299)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         68% through outbreak
#   Start:       2020-02-16 (-152 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-97 days, 548 cases)
#   End:         2020-09-22 ( 68 days, 165 days after peak cases)
#   Day Zero:    2020-03-28 (-111 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-25 (-83 days, 29 deaths)
#
# Parameters:
#   Totals:      22,508 cases and 984 deaths at end of 2020-07-14
#   Smoothed:    22,507 cases and 984 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 3.0 (2020-04-04, compared to 7 days earlier)
#                Latest infection rate 2.4 (2020-07-14, compared to 7 days earlier)
#   Growth:      55 days (Start -> Peak Cases)
#                X = 23,652, r = 8.0, L = 2,191, dilation = 4, c = 13.5% for cases
#   Lag:         14 days (Peak Cases -> Peak Deaths)
#                X = 994, r = 8.0, L = 116, dilation = 2.4, c = 55.4% for deaths
#
# Outcome: 23,594 total cases, 994 total deaths by end of 2020-09-22
#   102.0% of predicted cases and 99.0% of predicted deaths reported to date
#   99.8% of predicted cases and 99.9% of predicted deaths reported by end date
#   186 cases per million (0.02%), 8 deaths per million (0.001%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04      240        0      19,522      977       179        1      19,374      977
# 2020-07-05        0        0      19,522      977       185        1      19,560      978
# 2020-07-06      106        0      19,628      977       186        1      19,746      979
# 2020-07-07      353        1      19,981      978       205        1      19,950      979
# 2020-07-08      193        2      20,174      980       229        1      20,180      980
# 2020-07-09      197        1      20,371      981       282        1      20,462      981
# 2020-07-10      348        1      20,719      982       370        1      20,831      981
# 2020-07-11      410        0      21,129      982       360        1      21,192      982
# 2020-07-12      373        0      21,502      982       387        1      21,579      983
# 2020-07-13      718        0      22,220      982       442        1      22,021      984
# 2020-07-14      288        2      22,508      984       487    < 0.5      22,508      984
# 2020-07-15      382        1      22,890      985
# 2020-07-16      583        0      23,473      985
# 2020-07-17      659        0      24,132      985
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-07-14       42        1     22,508      984
# 2020-07-15       41        1     22,549      985
# 2020-07-16       40        1     22,588      985
# 2020-07-17       38        1     22,627      986  <-- latest raw data
# 2020-07-18       37        1     22,664      986
# 2020-07-19       36    < 0.5     22,699      987
# 2020-07-20       34    < 0.5     22,734      987
# 2020-07-21       33    < 0.5     22,767      988
# 2020-07-22       32    < 0.5     22,799      988
# 2020-07-23       31    < 0.5     22,830      988

# %%
covid.Region(geoId='SG').analyse()
# Out:
# Singapore data to end of 2020-07-17:
#   47,453 cases, 27 deaths
#   8,175 cases per million, 5 deaths per million (2019 population = 5,804,343)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         53% through outbreak
#   Start:       2020-02-11 (-157 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-23 (-85 days, 1,006 cases)
#   End:         2020-11-24 (131 days, 216 days after peak cases)
#
# Parameters:
#   Totals:      46,629 cases and 27 deaths at end of 2020-07-14
#   Smoothed:    46,629 cases and 26 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-04-14, compared to 7 days earlier)
#                Latest infection rate 1.6 (2020-07-14, compared to 7 days earlier)
#   Growth:      72 days (Start -> Peak Cases)
#                X = 49,994, r = 8.0, L = 4,024, dilation = 3, c = 54.1% for cases
#
# Outcome: 49,977 total cases, 29 total deaths by end of 2020-11-24
#   94.9% of predicted cases and 90.4% of predicted deaths reported to date
#   100.0% of predicted cases and 97.1% of predicted deaths reported by end date
#   8,613 cases per million (0.86%), 5 deaths per million (0.001%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04      185        0      44,664       26       176        0      44,663       26
# 2020-07-05        0        0      44,664       26       168        0      44,831       26
# 2020-07-06      319        0      44,983       26       159        0      44,990       26
# 2020-07-07      157        0      45,140       26       162        0      45,152       26
# 2020-07-08      158        0      45,298       26       160        0      45,312       26
# 2020-07-09      124        0      45,422       26       185        0      45,498       26
# 2020-07-10      191        0      45,613       26       186        0      45,683       26
# 2020-07-11      170        0      45,783       26       213    < 0.5      45,896       27
# 2020-07-12      178        0      45,961       26       226    < 0.5      46,122       27
# 2020-07-13      322        0      46,283       26       244    < 0.5      46,366       27
# 2020-07-14      346        1      46,629       27       263    < 0.5      46,629       27
# 2020-07-15      249        0      46,878       27
# 2020-07-16      248        0      47,126       27
# 2020-07-17      327        0      47,453       27
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-07-14      121    < 0.5     46,629       27
# 2020-07-15      117    < 0.5     46,746       27
# 2020-07-16      113    < 0.5     46,860       27
# 2020-07-17      110    < 0.5     46,969       27  <-- latest raw data
# 2020-07-18      106    < 0.5     47,075       27
# 2020-07-19      102    < 0.5     47,178       27
# 2020-07-20       99    < 0.5     47,277       28
# 2020-07-21       96    < 0.5     47,373       28
# 2020-07-22       92    < 0.5     47,465       28
# 2020-07-23       89    < 0.5     47,554       28

# %%
covid.Region(geoId='BR').analyse()
# Out:
# Brazil data to end of 2020-07-17:
#   2,046,328 cases, 77,851 deaths
#   9,696 cases per million, 369 deaths per million (2019 population = 211,049,519)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         28% through outbreak
#   Start:       2020-03-11 (-128 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-29 (-18 days, 38,240 cases)
#   End:         2021-05-24 (312 days, 330 days after peak cases)
#   Day Zero:    2020-03-25 (-114 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-07-13 ( -4 days, 1,069 deaths)
#
# Parameters:
#   Totals:      1,926,824 cases and 74,133 deaths at end of 2020-07-14
#   Smoothed:    1,926,824 cases and 74,133 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 9.3 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-07-14, compared to 7 days earlier)
#   Growth:      110 days (Start -> Peak Cases)
#                X = 5,471,150, r = 5.86, L = 152,958, dilation = 3, c = 92.1% for cases
#   Lag:         14 days (Peak Cases -> Peak Deaths)
#                X = 289,930, r = 4.0, L = 4,275, dilation = 3, c = 74.9% for deaths
#
# Outcome: 5,455,585 total cases, 283,772 total deaths by end of 2021-05-24
#   37.4% of predicted cases and 26.9% of predicted deaths reported to date
#   99.7% of predicted cases and 97.9% of predicted deaths reported by end date
#   25,924 cases per million (2.59%), 1,374 deaths per million (0.137%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04   37,923    1,091   1,577,004   64,265    37,927    1,018   1,559,016   63,679
# 2020-07-05   26,051      602   1,603,055   64,867    37,622    1,044   1,596,638   64,724
# 2020-07-06   20,229      620   1,623,284   65,487    36,842    1,040   1,633,480   65,763
# 2020-07-07   45,305    1,254   1,668,589   66,741    37,244    1,029   1,670,724   66,792
# 2020-07-08   44,571    1,223   1,713,160   67,964    37,400    1,026   1,708,124   67,819
# 2020-07-09   42,619    1,220   1,755,779   69,184    37,227    1,030   1,745,351   68,849
# 2020-07-10   45,048    1,214   1,800,827   70,398    37,235    1,046   1,782,585   69,895
# 2020-07-11   39,023    1,071   1,839,850   71,469    36,744    1,053   1,819,330   70,948
# 2020-07-12   24,831      631   1,864,681   72,100    36,083    1,054   1,855,413   72,002
# 2020-07-13   20,286      733   1,884,967   72,833    36,479    1,069   1,891,892   73,071
# 2020-07-14   41,857    1,300   1,926,824   74,133    34,932    1,062   1,926,824   74,133
# 2020-07-15   39,924    1,233   1,966,748   75,366
# 2020-07-16   45,403    1,322   2,012,151   76,688
# 2020-07-17   34,177    1,163   2,046,328   77,851
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-07-14   35,893    1,340  1,926,824   74,133
# 2020-07-15   35,806    1,340  1,962,630   75,473
# 2020-07-16   35,714    1,340  1,998,343   76,812
# 2020-07-17   35,616    1,339  2,033,959   78,152  <-- latest raw data
# 2020-07-18   35,513    1,339  2,069,473   79,490
# 2020-07-19   35,405    1,338  2,104,878   80,829
# 2020-07-20   35,292    1,338  2,140,170   82,166
# 2020-07-21   35,174    1,337  2,175,345   83,503
# 2020-07-22   35,051    1,336  2,210,396   84,839
# 2020-07-23   34,924    1,335  2,245,320   86,174

# %%
covid.Region(geoId='CL').analyse()
# Out:
# Chile data to end of 2020-07-17:
#   326,539 cases, 8,347 deaths
#   17,230 cases per million, 440 deaths per million (2019 population = 18,952,035)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         33% through outbreak
#   Start:       2020-03-13 (-126 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-14 (-33 days, 10,308 cases)
#   End:         2021-03-19 (246 days, 279 days after peak cases)
#   Day Zero:    2020-04-09 (-99 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-07-14 ( -3 days, 218 deaths)
#
# Parameters:
#   Totals:      319,493 cases and 7,069 deaths at end of 2020-07-14
#   Smoothed:    319,492 cases and 7,069 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 4.2 (2020-03-22, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-07-14, compared to 7 days earlier)
#   Growth:      93 days (Start -> Peak Cases)
#                X = 571,984, r = 8.0, L = 41,233, dilation = 3, c = 28.1% for cases
#   Lag:         30 days (Peak Cases -> Peak Deaths)
#                X = 27,788, r = 5.3, L = 872, dilation = 3, c = 59.1% for deaths
#
# Outcome: 571,792 total cases, 27,544 total deaths by end of 2021-03-19
#   57.1% of predicted cases and 30.0% of predicted deaths reported to date
#   100.0% of predicted cases and 99.1% of predicted deaths reported by end date
#   30,181 cases per million (3.02%), 1,466 deaths per million (0.147%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04    3,758      141     291,847    6,192     3,091      104     291,764    5,992
# 2020-07-05    3,685      116     295,532    6,308     3,007      114     294,770    6,106
# 2020-07-06    3,025       76     298,557    6,384     3,098      106     297,868    6,213
# 2020-07-07    2,462       50     301,019    6,434     3,028      102     300,896    6,314
# 2020-07-08    2,064      139     303,083    6,573     2,884       96     303,780    6,410
# 2020-07-09    3,133      109     306,216    6,682     2,788       93     306,568    6,503
# 2020-07-10    3,058       99     309,274    6,781     2,730       89     309,297    6,593
# 2020-07-11    2,755      100     312,029    6,881     2,640       88     311,937    6,681
# 2020-07-12    3,012       98     315,041    6,979     2,590       85     314,527    6,766
# 2020-07-13    2,616       45     317,657    7,024     2,498       85     317,026    6,851
# 2020-07-14    1,836       45     319,493    7,069     2,467      218     319,493    7,069
# 2020-07-15    1,712      117     321,205    7,186
# 2020-07-16    2,493      104     323,698    7,290
# 2020-07-17    2,841    1,057     326,539    8,347
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-07-14    5,141      199    319,493    7,069
# 2020-07-15    5,081      199    324,574    7,268
# 2020-07-16    5,020      199    329,594    7,467
# 2020-07-17    4,957      199    334,551    7,665  <-- latest raw data
# 2020-07-18    4,894      199    339,445    7,864
# 2020-07-19    4,831      198    344,276    8,062
# 2020-07-20    4,766      198    349,042    8,260
# 2020-07-21    4,701      198    353,743    8,458
# 2020-07-22    4,635      198    358,378    8,656
# 2020-07-23    4,569      197    362,947    8,853

# %%
covid.Region(geoId='PE').analyse()
# Out:
# Peru data to end of 2020-07-17:
#   345,537 cases, 12,799 deaths
#   10,628 cases per million, 394 deaths per million (2019 population = 32,510,462)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         40% through outbreak
#   Start:       2020-03-15 (-124 days, when 50 or more cases were reported)
#   Peak Cases:  2020-05-29 (-49 days, 6,578 cases)
#   End:         2021-01-08 (176 days, 225 days after peak cases)
#   Day Zero:    2020-04-02 (-106 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-26 (-21 days, 208 deaths)
#
# Parameters:
#   Totals:      333,867 cases and 12,229 deaths at end of 2020-07-14
#   Smoothed:    333,867 cases and 12,229 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-08, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-07-14, compared to 7 days earlier)
#   Growth:      75 days (Start -> Peak Cases)
#                X = 439,810, r = 8.0, L = 26,311, dilation = 3, c = 65.4% for cases
#   Lag:         28 days (Peak Cases -> Peak Deaths)
#                X = 32,451, r = 4.0, L = 833, dilation = 3, c = 82.0% for deaths
#
# Outcome: 439,663 total cases, 31,502 total deaths by end of 2021-01-08
#   78.6% of predicted cases and 39.4% of predicted deaths reported to date
#   100.0% of predicted cases and 97.1% of predicted deaths reported by end date
#   13,528 cases per million (1.35%), 998 deaths per million (0.100%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04    3,481      186     299,080   10,412     3,437      182     298,876   10,400
# 2020-07-05    3,638      177     302,718   10,589     3,489      182     302,366   10,582
# 2020-07-06    2,985      183     305,703   10,772     3,491      181     305,856   10,763
# 2020-07-07    3,575      180     309,278   10,952     3,434      182     309,291   10,945
# 2020-07-08    3,633      181     312,911   11,133     3,375      181     312,665   11,126
# 2020-07-09    3,537      181     316,448   11,314     3,372      183     316,037   11,309
# 2020-07-10    3,198      186     319,646   11,500     3,487      183     319,524   11,492
# 2020-07-11    3,064      182     322,710   11,682     3,512      182     323,036   11,675
# 2020-07-12    3,616      188     326,326   11,870     3,544      183     326,579   11,858
# 2020-07-13    3,797      184     330,123   12,054     3,590      186     330,169   12,044
# 2020-07-14    3,744      175     333,867   12,229     3,698      185     333,867   12,229
# 2020-07-15    3,857      188     337,724   12,417
# 2020-07-16    3,862      198     341,586   12,615
# 2020-07-17    3,951      184     345,537   12,799
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-07-14    3,202      215    333,867   12,229
# 2020-07-15    3,126      214    336,993   12,443
# 2020-07-16    3,050      213    340,044   12,656
# 2020-07-17    2,976      213    343,019   12,869  <-- latest raw data
# 2020-07-18    2,902      212    345,921   13,081
# 2020-07-19    2,829      211    348,750   13,292
# 2020-07-20    2,757      210    351,508   13,503
# 2020-07-21    2,686      210    354,194   13,713
# 2020-07-22    2,617      209    356,811   13,921
# 2020-07-23    2,548      208    359,358   14,129

# %%
covid.Region(geoId='MX').analyse()
# Out:
# Mexico data to end of 2020-07-17:
#   331,298 cases, 38,310 deaths
#   2,597 cases per million, 300 deaths per million (2019 population = 127,575,529)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         27% through outbreak
#   Start:       2020-03-15 (-124 days, when 50 or more cases were reported)
#   Peak Cases:  2020-07-07 (-10 days, 6,265 cases)
#   End:         2021-06-13 (332 days, 342 days after peak cases)
#   Day Zero:    2020-04-02 (-106 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-24 (-23 days, 800 deaths)
#
# Parameters:
#   Totals:      311,486 cases and 36,327 deaths at end of 2020-07-14
#   Smoothed:    311,485 cases and 36,327 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 2.8 (2020-03-25, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-07-14, compared to 7 days earlier)
#   Growth:      114 days (Start -> Peak Cases)
#                X = 1,074,439, r = 5.02, L = 25,058, dilation = 3, c = 91.4% for cases
#   Lag:         -13 days (Peak Cases -> Peak Deaths)
#                X = 90,311, r = 6.89, L = 3,199, dilation = 3, c = 79.4% for deaths
#
# Outcome: 1,067,359 total cases, 90,240 total deaths by end of 2021-06-13
#   30.8% of predicted cases and 42.4% of predicted deaths reported to date
#   99.3% of predicted cases and 99.9% of predicted deaths reported by end date
#   8,422 cases per million (0.84%), 708 deaths per million (0.071%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04    6,914      523     252,165   30,366     5,979      606     250,212   30,238
# 2020-07-05    4,683      273     256,848   30,639     6,166      612     256,378   30,851
# 2020-07-06    4,902      480     261,750   31,119     6,243      620     262,621   31,470
# 2020-07-07    6,258      895     268,008   32,014     6,265      621     268,886   32,091
# 2020-07-08    6,995      782     275,003   32,796     6,148      623     275,033   32,715
# 2020-07-09    7,280      730     282,283   33,526     6,119      624     281,152   33,339
# 2020-07-10    6,891      665     289,174   34,191     6,088      619     287,240   33,957
# 2020-07-11    6,094      539     295,268   34,730     6,201      616     293,442   34,573
# 2020-07-12    4,482      276     299,750   35,006     6,080      587     299,522   35,160
# 2020-07-13    4,685      443     304,435   35,449     5,956      578     305,478   35,739
# 2020-07-14    7,051      878     311,486   36,327     6,008      588     311,486   36,327
# 2020-07-15    6,149      579     317,635   36,906
# 2020-07-16    6,406      668     324,041   37,574
# 2020-07-17    7,257      736     331,298   38,310
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-07-14    5,933      656    311,486   36,327
# 2020-07-15    5,928      654    317,414   36,981
# 2020-07-16    5,923      651    323,337   37,632
# 2020-07-17    5,917      648    329,253   38,279  <-- latest raw data
# 2020-07-18    5,910      645    335,163   38,924
# 2020-07-19    5,903      642    341,066   39,566
# 2020-07-20    5,895      639    346,960   40,205
# 2020-07-21    5,886      635    352,847   40,840
# 2020-07-22    5,877      632    358,724   41,472
# 2020-07-23    5,867      628    364,591   42,100

# %%
covid.Region(geoId='IN').analyse()
# Out:
# India data to end of 2020-07-17:
#   1,038,716 cases, 26,273 deaths
#   760 cases per million, 19 deaths per million (2019 population = 1,366,417,756)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         25% through outbreak
#   Start:       2020-03-10 (-129 days, when 50 or more cases were reported)
#   Peak Cases:  2020-07-14 ( -3 days, 30,978 cases)
#   End:         2021-07-26 (375 days, 378 days after peak cases)
#   Day Zero:    2020-04-02 (-106 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-06-18 (-29 days, 595 deaths)
#
# Parameters:
#   Totals:      936,181 cases and 24,309 deaths at end of 2020-07-14
#   Smoothed:    936,181 cases and 24,309 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 4.7 (2020-04-02, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-07-14, compared to 7 days earlier)
#   Growth:      126 days (Start -> Peak Cases)
#                X = 3,691,820, r = 7.48, L = 123,910, dilation = 3, c = 77.1% for cases
#   Lag:         -26 days (Peak Cases -> Peak Deaths)
#                X = 53,478, r = 8.0, L = 2,380, dilation = 3, c = 59.3% for deaths
#
# Outcome: 3,689,747 total cases, 53,467 total deaths by end of 2021-07-26
#   28.1% of predicted cases and 49.1% of predicted deaths reported to date
#   99.9% of predicted cases and 100.0% of predicted deaths reported by end date
#   2,702 cases per million (0.27%), 39 deaths per million (0.004%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04   24,850      613     673,165   19,268    22,319      462     670,068   19,152
# 2020-07-05   24,248      425     697,413   19,693    23,134      469     693,203   19,621
# 2020-07-06   22,252      467     719,665   20,160    23,931      483     717,134   20,104
# 2020-07-07   22,752      482     742,417   20,642    24,549      494     741,683   20,598
# 2020-07-08   24,879      487     767,296   21,129    25,088      485     766,771   21,083
# 2020-07-09   26,506      475     793,802   21,604    25,721      496     792,492   21,579
# 2020-07-10   27,114      519     820,916   22,123    26,609      508     819,101   22,087
# 2020-07-11   28,637      551     849,553   22,674    27,559      522     846,660   22,609
# 2020-07-12   28,701      500     878,254   23,174    28,671      539     875,331   23,148
# 2020-07-13   28,498      553     906,752   23,727    29,873      569     905,203   23,718
# 2020-07-14   29,429      582     936,181   24,309    30,978      591     936,181   24,309
# 2020-07-15   32,695      606     968,876   24,915
# 2020-07-16   34,956      687   1,003,832   25,602
# 2020-07-17   34,884      671   1,038,716   26,273
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-07-14   27,427      394    936,181   24,309
# 2020-07-15   27,424      392    963,605   24,701
# 2020-07-16   27,416      390    991,022   25,091
# 2020-07-17   27,403      387  1,018,425   25,478  <-- latest raw data
# 2020-07-18   27,384      385  1,045,809   25,863
# 2020-07-19   27,360      382  1,073,169   26,245
# 2020-07-20   27,331      380  1,100,499   26,624
# 2020-07-21   27,296      377  1,127,795   27,001
# 2020-07-22   27,256      374  1,155,051   27,376
# 2020-07-23   27,210      371  1,182,261   27,747

# %%
covid.Region(geoId='CN', dilation=1, d_cases=0.7).analyse(ylog=1)
# Out:
# China data to end of 2020-07-17:
#   85,403 cases, 4,645 deaths
#   60 cases per million, 3 deaths per million (2019 population = 1,433,783,692)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-01-15 (-184 days, when 50 or more cases were reported)
#   Peak Cases:  2020-02-10 (-158 days, 4,690 cases)
#   End:         2020-03-06 (-132 days, 26 days after peak cases)
#   Day Zero:    2020-01-25 (-174 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-02-15 (-153 days, 128 deaths)
#
# Parameters:
#   Totals:      85,226 cases and 4,642 deaths at end of 2020-07-14
#   Smoothed:    85,225 cases and 4,642 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 59.2 (2020-01-21, compared to 7 days earlier)
#                Latest infection rate 1.9 (2020-07-14, compared to 7 days earlier)
#   Growth:      26 days (Start -> Peak Cases)
#                X = 80,834, r = 5.02, L = 18,758, dilation = 0.7, c = 84.3% for cases
#   Lag:         5 days (Peak Cases -> Peak Deaths)
#                X = 3,210, r = 4.05, L = 510, dilation = 1, c = 94.8% for deaths
#
# Outcome: 80,814 total cases, 3,099 total deaths at end of 2020-03-07
#   56 cases per million (0.01%), 2 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04       18        0      84,857    4,641        19        0      84,864    4,640
# 2020-07-05       14        0      84,871    4,641        19        0      84,883    4,640
# 2020-07-06       25        0      84,896    4,641        24        0      84,907    4,640
# 2020-07-07       21        0      84,917    4,641        28        0      84,935    4,640
# 2020-07-08       33        0      84,950    4,641        31        0      84,966    4,640
# 2020-07-09       46        0      84,996    4,641        35        0      85,001    4,640
# 2020-07-10       40        0      85,036    4,641        39    < 0.5      85,040    4,640
# 2020-07-11       35        0      85,071    4,641        44    < 0.5      85,085    4,641
# 2020-07-12       46        0      85,117    4,641        42    < 0.5      85,127    4,641
# 2020-07-13       55        1      85,172    4,642        47    < 0.5      85,174    4,641
# 2020-07-14       54        0      85,226    4,642        52        1      85,226    4,642
# 2020-07-15       20        2      85,246    4,644
# 2020-07-16       77        0      85,323    4,644
# 2020-07-17       80        1      85,403    4,645
#
#   ** first wave ended **

# %%
covid.Region(geoId='KR', d_cases=1).analyse(ylog=1)
# Out:
# South Korea data to end of 2020-07-17:
#   13,711 cases, 294 deaths
#   268 cases per million, 6 deaths per million (2019 population = 51,225,321)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-17 (-151 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-02 (-137 days, 608 cases)
#   End:         2020-03-15 (-123 days, 14 days after peak cases)
#   Day Zero:    2020-03-08 (-131 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-16 (-123 days, 5 deaths)
#
# Parameters:
#   Totals:      13,551 cases and 289 deaths at end of 2020-07-14
#   Smoothed:    13,551 cases and 289 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 61.1 (2020-02-22, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-07-14, compared to 7 days earlier)
#   Growth:      14 days (Start -> Peak Cases)
#                X = 8,487, r = 4.03, L = 2,432, dilation = 1, c = 94.5% for cases
#   Lag:         14 days (Peak Cases -> Peak Deaths)
#                X = 164, r = 4.0, L = 18, dilation = 3, c = 82.4% for deaths
#
# Outcome: 8,320 total cases, 81 total deaths at end of 2020-03-16
#   162 cases per million (0.02%), 2 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04       61        0      13,091      283        56    < 0.5      13,059      282
# 2020-07-05        0        0      13,091      283        56        1      13,115      282
# 2020-07-06       90        2      13,181      285        53        1      13,168      283
# 2020-07-07       63        0      13,244      285        49        1      13,217      284
# 2020-07-08       49        2      13,293      287        47        1      13,263      285
# 2020-07-09       45        1      13,338      288        55        1      13,319      286
# 2020-07-10       35        0      13,373      288        47        1      13,366      286
# 2020-07-11       44        1      13,417      289        44        1      13,410      287
# 2020-07-12       62        0      13,479      289        46        1      13,455      287
# 2020-07-13       33        0      13,512      289        48        1      13,503      288
# 2020-07-14       39        0      13,551      289        48        1      13,551      289
# 2020-07-15       61        2      13,612      291
# 2020-07-16       60        2      13,672      293
# 2020-07-17       39        1      13,711      294
#
#   ** first wave ended **

# %%
covid.Region(geoId='NZ', d_cases=3).analyse(ylog=0)
# Out:
# New Zealand data to end of 2020-07-17:
#   1,200 cases, 22 deaths
#   251 cases per million, 5 deaths per million (2019 population = 4,783,062)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-20 (-119 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-112 days, 72 cases)
#   End:         2020-04-16 (-91 days, 21 days after peak cases)
#
# Parameters:
#   Totals:      1,197 cases and 22 deaths at end of 2020-07-14
#   Smoothed:    1,197 cases and 21 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 5.0 (2020-06-20, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-07-14, compared to 7 days earlier)
#   Growth:      7 days (Start -> Peak Cases)
#                X = 1,113, r = 4.0, L = 288, dilation = 3, c = 89.1% for cases
#
# Outcome: 1,094 total cases, 11 total deaths at end of 2020-04-17
#   229 cases per million (0.02%), 2 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04        3        0       1,183       22         1        0       1,183       22
# 2020-07-05        0        0       1,183       22         1        0       1,184       22
# 2020-07-06        3        0       1,186       22         2        0       1,186       22
# 2020-07-07        1        0       1,187       22         2        0       1,188       22
# 2020-07-08        3        0       1,190       22         2        0       1,190       22
# 2020-07-09        2        0       1,192       22         2        0       1,191       22
# 2020-07-10        1        0       1,193       22         1        0       1,192       22
# 2020-07-11        1        0       1,194       22         1        0       1,194       22
# 2020-07-12        0        0       1,194       22         1        0       1,195       22
# 2020-07-13        1        0       1,195       22         1        0       1,196       22
# 2020-07-14        2        0       1,197       22         1        0       1,197       22
# 2020-07-15        1        0       1,198       22
# 2020-07-16        1        0       1,199       22
# 2020-07-17        1        0       1,200       22
#
#   ** first wave ended **

# %%
covid.Region(geoId='AU', dilation=2.2, d_cases=1.5).analyse()
# Out:
# Australia data to end of 2020-07-17:
#   11,235 cases, 116 deaths
#   446 cases per million, 5 deaths per million (2019 population = 25,203,200)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-05 (-134 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-112 days, 389 cases)
#   End:         2020-04-28 (-79 days, 33 days after peak cases)
#   Day Zero:    2020-04-09 (-99 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-102 days, 4 deaths)
#
# Parameters:
#   Totals:      10,251 cases and 108 deaths at end of 2020-07-14
#   Smoothed:    10,250 cases and 107 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 1.7 (2020-07-14, compared to 7 days earlier)
#   Growth:      22 days (Start -> Peak Cases)
#                X = 6,733, r = 5.81, L = 1,554, dilation = 1.5, c = 86.6% for cases
#   Lag:         10 days (Peak Cases -> Peak Deaths)
#                X = 94, r = 5.16, L = 16, dilation = 2.2, c = 72.2% for deaths
#
# Outcome: 6,746 total cases, 90 total deaths at end of 2020-04-29
#   268 cases per million (0.03%), 4 deaths per million (0.000%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04      107        0       8,362      104       131    < 0.5       8,291      103
# 2020-07-05       87        0       8,449      104       137    < 0.5       8,428      103
# 2020-07-06      137        2       8,586      106       150    < 0.5       8,578      103
# 2020-07-07      169        0       8,755      106       157    < 0.5       8,735      103
# 2020-07-08      131        0       8,886      106       169    < 0.5       8,904      104
# 2020-07-09      173        0       9,059      106       192        1       9,096      104
# 2020-07-10      300        0       9,359      106       198    < 0.5       9,294      105
# 2020-07-11      194        1       9,553      107       213    < 0.5       9,507      105
# 2020-07-12      244        1       9,797      108       229        1       9,735      106
# 2020-07-13      183        0       9,980      108       249        1       9,984      107
# 2020-07-14      271        0      10,251      108       267        1      10,251      108
# 2020-07-15      244        3      10,495      111
# 2020-07-16      315        2      10,810      113
# 2020-07-17      425        3      11,235      116
#
#   ** first wave ended **
