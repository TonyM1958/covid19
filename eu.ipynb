# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=3.3).analyse(ylog=1)
# Out:
# United Kingdom data to end of 2020-05-16:
#   240,161 cases, 34,466 deaths
#   3,612 cases per million, 518 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         60% through outbreak
#   Start:       2020-03-02 (-75 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-35 days, 5,517 cases)
#   End:         2020-06-29 ( 45 days, 80 days after peak cases)
#   Day Zero:    2020-03-15 (-62 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-35 days, 945 deaths)
#
# Parameters:
#   Totals:      229,705 cases and 33,186 deaths at end of 2020-05-13
#   Smoothed:    229,705 cases and 33,186 deaths at end of 2020-05-13 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-13, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=4, d_cases=3.5).analyse(ylog=1)
# note: ECDC cases data differs from Worldometer due to anti-body tests
# Out:
# Spain data to end of 2020-05-14:
#   230,183 cases, 27,459 deaths
#   4,926 cases per million, 588 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         87% through outbreak
#   Start:       2020-02-28 (-76 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-48 days, 7,912 cases)
#   End:         2020-05-21 (  8 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-64 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-44 days, 867 deaths)
#
# Parameters:
#   Totals:      228,252 cases and 26,920 deaths at end of 2020-05-11
#   Smoothed:    228,252 cases and 26,920 deaths at end of 2020-05-11 (7 points)
#   Spread:      Peak infection rate 12.3 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-11, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=3, d_cases=3.4).analyse()
# Out:
# Italy data to end of 2020-05-15:
#   223,885 cases, 31,610 deaths
#   3,705 cases per million, 523 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         87% through outbreak
#   Start:       2020-02-21 (-84 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-53 days, 5,647 cases)
#   End:         2020-05-23 (  9 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-74 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-46 days, 821 deaths)
#
# Parameters:
#   Totals:      221,216 cases and 30,911 deaths at end of 2020-05-12
#   Smoothed:    221,215 cases and 30,911 deaths at end of 2020-05-12 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-12, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=3.3, d_cases=3.5).analyse()
# Out:
# France data to end of 2020-05-15:
#   141,919 cases, 27,529 deaths
#   2,119 cases per million, 411 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         81% through outbreak
#   Start:       2020-02-27 (-78 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-47 days, 4,536 cases)
#   End:         2020-05-29 ( 15 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-65 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-39 days, 1,104 deaths)
#
# Parameters:
#   Totals:      140,227 cases and 26,991 deaths at end of 2020-05-12
#   Smoothed:    140,227 cases and 26,990 deaths at end of 2020-05-12 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.4 (2020-05-12, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1.7, d_cases=3.1).analyse()
# Out:
# Germany data to end of 2020-05-15:
#   173,772 cases, 7,881 deaths
#   2,095 cases per million, 95 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         74% through outbreak
#   Start:       2020-02-27 (-78 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-44 days, 5,592 cases)
#   End:         2020-06-07 ( 24 days, 68 days after peak cases)
#   Day Zero:    2020-03-20 (-56 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-28 days, 233 deaths)
#
# Parameters:
#   Totals:      171,306 cases and 7,634 deaths at end of 2020-05-12
#   Smoothed:    171,306 cases and 7,634 deaths at end of 2020-05-12 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-12, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=1.9, d_cases=1.2).analyse()
# Out:
# Belgium data to end of 2020-05-15:
#   54,644 cases, 8,959 deaths
#   4,784 cases per million, 784 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         81% through outbreak
#   Start:       2020-03-04 (-72 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-33 days, 1,455 cases)
#   End:         2020-05-27 ( 13 days, 46 days after peak cases)
#   Day Zero:    2020-03-21 (-55 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-32 days, 333 deaths)
#
# Parameters:
#   Totals:      53,779 cases and 8,761 deaths at end of 2020-05-12
#   Smoothed:    53,779 cases and 8,760 deaths at end of 2020-05-12 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-12, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=1.3, d_cases=2.5).analyse()
# Out:
# Ireland data to end of 2020-05-15:
#   23,956 cases, 1,518 deaths
#   4,936 cases per million, 313 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         65% through outbreak
#   Start:       2020-03-11 (-65 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-33 days, 900 cases)
#   End:         2020-06-14 ( 31 days, 64 days after peak cases)
#   Day Zero:    2020-03-30 (-46 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-23 days, 71 deaths)
#
# Parameters:
#   Totals:      23,242 cases and 1,488 deaths at end of 2020-05-12
#   Smoothed:    23,241 cases and 1,488 deaths at end of 2020-05-12 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-12, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=3).analyse()
# Out:
# Sweden data to end of 2020-05-15:
#   29,207 cases, 3,646 deaths
#   2,868 cases per million, 358 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         47% through outbreak
#   Start:       2020-03-04 (-72 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 (-23 days, 619 cases)
#   End:         2020-07-28 ( 75 days, 98 days after peak cases)
#   Day Zero:    2020-03-25 (-51 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-24 days, 105 deaths)
#
# Parameters:
#   Totals:      27,272 cases and 3,313 deaths at end of 2020-05-12
#   Smoothed:    27,271 cases and 3,313 deaths at end of 2020-05-12 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-12, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...
