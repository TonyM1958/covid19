# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=3.7, d_cases=2.3).analyse(ylog=1)
# Out:
# United Kingdom data to end of 2020-05-22:
#   254,195 cases, 36,393 deaths
#   3,823 cases per million, 547 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         65% through outbreak
#   Start:       2020-03-02 (-81 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-41 days, 5,548 cases)
#   End:         2020-06-29 ( 39 days, 80 days after peak cases)
#   Day Zero:    2020-03-15 (-68 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-41 days, 943 deaths)
#
# Parameters:
#   Totals:      248,818 cases and 35,341 deaths at end of 2020-05-19
#   Smoothed:    248,817 cases and 35,341 deaths at end of 2020-05-19 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-19, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=4).analyse(ylog=1)
# note: ECDC cases data differs from Worldometer due to anti-body tests
# Out:
# Spain data to end of 2020-05-21:
#   234,824 cases, 28,628 deaths
#   5,026 cases per million, 613 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         95% through outbreak
#   Start:       2020-02-28 (-83 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-55 days, 7,893 cases)
#   End:         2020-05-21 (  1 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-71 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-51 days, 865 deaths)
#
# Parameters:
#   Totals:      232,037 cases and 27,778 deaths at end of 2020-05-18
#   Smoothed:    232,036 cases and 27,778 deaths at end of 2020-05-18 (7 points)
#   Spread:      Peak infection rate 12.3 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-18, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=3.3, d_cases=3).analyse()
# Out:
# Italy data to end of 2020-05-22:
#   228,658 cases, 32,616 deaths
#   3,784 cases per million, 540 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         95% through outbreak
#   Start:       2020-02-21 (-91 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-60 days, 5,644 cases)
#   End:         2020-05-23 (  2 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-81 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-53 days, 821 deaths)
#
# Parameters:
#   Totals:      226,699 cases and 32,169 deaths at end of 2020-05-19
#   Smoothed:    226,698 cases and 32,168 deaths at end of 2020-05-19 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-19, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=3.3, d_cases=3.3).analyse()
# Out:
# France data to end of 2020-05-22:
#   144,566 cases, 28,289 deaths
#   2,158 cases per million, 422 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         88% through outbreak
#   Start:       2020-02-27 (-85 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-54 days, 4,538 cases)
#   End:         2020-05-29 (  8 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-72 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-46 days, 1,102 deaths)
#
# Parameters:
#   Totals:      143,427 cases and 28,022 deaths at end of 2020-05-19
#   Smoothed:    143,426 cases and 28,021 deaths at end of 2020-05-19 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-19, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1.8, d_cases=3.3).analyse()
# Out:
# Germany data to end of 2020-05-22:
#   177,850 cases, 8,216 deaths
#   2,145 cases per million, 99 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         80% through outbreak
#   Start:       2020-02-27 (-85 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-51 days, 5,595 cases)
#   End:         2020-06-07 ( 17 days, 68 days after peak cases)
#   Day Zero:    2020-03-20 (-63 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-35 days, 233 deaths)
#
# Parameters:
#   Totals:      176,007 cases and 8,090 deaths at end of 2020-05-19
#   Smoothed:    176,007 cases and 8,090 deaths at end of 2020-05-19 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-19, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=2.1, d_cases=1.5).analyse()
# Out:
# Belgium data to end of 2020-05-22:
#   56,511 cases, 9,212 deaths
#   4,948 cases per million, 807 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         78% through outbreak
#   Start:       2020-03-04 (-79 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-40 days, 1,454 cases)
#   End:         2020-06-08 ( 18 days, 58 days after peak cases)
#   Day Zero:    2020-03-21 (-62 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-39 days, 333 deaths)
#
# Parameters:
#   Totals:      55,791 cases and 9,108 deaths at end of 2020-05-19
#   Smoothed:    55,791 cases and 9,107 deaths at end of 2020-05-19 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-19, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=2, d_cases=2.5).analyse()
# Out:
# Ireland data to end of 2020-05-22:
#   24,506 cases, 1,592 deaths
#   5,049 cases per million, 328 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         72% through outbreak
#   Start:       2020-03-11 (-72 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-40 days, 903 cases)
#   End:         2020-06-14 ( 24 days, 64 days after peak cases)
#   Day Zero:    2020-03-30 (-53 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-30 days, 70 deaths)
#
# Parameters:
#   Totals:      24,251 cases and 1,561 deaths at end of 2020-05-19
#   Smoothed:    24,250 cases and 1,561 deaths at end of 2020-05-19 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.4 (2020-05-19, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=2.5).analyse()
# Out:
# Sweden data to end of 2020-05-22:
#   32,809 cases, 3,925 deaths
#   3,222 cases per million, 385 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         52% through outbreak
#   Start:       2020-03-04 (-79 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 (-30 days, 617 cases)
#   End:         2020-07-28 ( 68 days, 98 days after peak cases)
#   Day Zero:    2020-03-25 (-58 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-31 days, 107 deaths)
#
# Parameters:
#   Totals:      30,799 cases and 3,743 deaths at end of 2020-05-19
#   Smoothed:    30,799 cases and 3,743 deaths at end of 2020-05-19 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-19, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...
