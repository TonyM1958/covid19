# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=0, ylog=1, d_clip=2.5)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=2.8, d_cases=1.3).analyse(totals=4)
# Out:
# United Kingdom data to end of 2020-08-26:
#   328,846 cases, 41,465 deaths
#   4,934 cases per million, 622 deaths per million (2019 population = 66,647,112)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-01 (-178 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-20 (-128 days, 4,847 cases)
#   End:         2020-06-22 (-64 days, 64 days after peak cases)
#   Day Zero:    2020-03-15 (-164 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-10 (-138 days, 942 deaths)
#
# Parameters:
#   Totals:      325,642 cases and 41,429 deaths at end of 2020-08-23
#   Smoothed:    325,642 cases and 41,429 deaths at end of 2020-08-23 (7 points)
#   Spread:      Peak infection rate 6.4 (2020-03-13, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-08-23, compared to 7 days earlier)
#   Growth:      50 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=2).analyse(totals=4)
# Out:
# Sweden data to end of 2020-08-26:
#   87,072 cases, 5,817 deaths
#   8,511 cases per million, 569 deaths per million (2019 population = 10,230,185)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         52% through outbreak
#   Start:       2020-03-04 (-175 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-23 (-64 days, 1,294 cases)
#   End:         2021-01-30 (158 days, 222 days after peak cases)
#   Day Zero:    2020-03-25 (-154 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-127 days, 107 deaths)
#
# Parameters:
#   Totals:      86,068 cases and 5,810 deaths at end of 2020-08-23
#   Smoothed:    86,067 cases and 5,810 deaths at end of 2020-08-23 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-08-23, compared to 7 days earlier)
#   Growth:      111 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=2.8, d_cases=1.9).analyse()
# Out:
# Spain data to end of 2020-08-25:
#   419,849 cases, 28,971 deaths
#   8,945 cases per million, 617 deaths per million (2019 population = 46,937,060)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-28 (-179 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-151 days, 7,698 cases)
#   End:         2020-05-18 (-98 days, 53 days after peak cases)
#   Day Zero:    2020-03-11 (-167 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-147 days, 867 deaths)
#
# Parameters:
#   Totals:      386,054 cases and 28,838 deaths at end of 2020-08-22
#   Smoothed:    386,054 cases and 28,838 deaths at end of 2020-08-22 (7 points)
#   Spread:      Peak infection rate 12.3 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-08-22, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=2.2, d_cases=3).analyse()
# Out:
# Italy data to end of 2020-08-26:
#   262,540 cases, 35,458 deaths
#   4,350 cases per million, 587 deaths per million (2019 population = 60,359,546)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-21 (-187 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-156 days, 5,646 cases)
#   End:         2020-06-07 (-79 days, 77 days after peak cases)
#   Day Zero:    2020-03-02 (-177 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-149 days, 822 deaths)
#
# Parameters:
#   Totals:      259,345 cases and 35,437 deaths at end of 2020-08-23
#   Smoothed:    259,344 cases and 35,436 deaths at end of 2020-08-23 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 2.0 (2020-08-23, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=2.3, d_cases=2.2).analyse()
# Out:
# France data to end of 2020-08-26:
#   253,587 cases, 30,544 deaths
#   3,784 cases per million, 456 deaths per million (2019 population = 67,012,883)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-27 (-181 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-150 days, 4,560 cases)
#   End:         2020-06-04 (-82 days, 68 days after peak cases)
#   Day Zero:    2020-03-11 (-168 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-142 days, 1,101 deaths)
#
# Parameters:
#   Totals:      242,899 cases and 30,513 deaths at end of 2020-08-23
#   Smoothed:    242,899 cases and 30,512 deaths at end of 2020-08-23 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 1.6 (2020-08-23, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=2).analyse()
# Out:
# Germany data to end of 2020-08-26:
#   237,936 cases, 9,285 deaths
#   2,866 cases per million, 112 deaths per million (2019 population = 83,019,213)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-27 (-181 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-147 days, 5,583 cases)
#   End:         2020-06-07 (-79 days, 68 days after peak cases)
#   Day Zero:    2020-03-20 (-159 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-131 days, 233 deaths)
#
# Parameters:
#   Totals:      233,575 cases and 9,272 deaths at end of 2020-08-23
#   Smoothed:    233,575 cases and 9,271 deaths at end of 2020-08-23 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-08-23, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=2).analyse()
# Out:
# Belgium data to end of 2020-08-26:
#   82,936 cases, 9,879 deaths
#   7,240 cases per million, 862 deaths per million (2019 population = 11,455,519)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-02 (-177 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-08 (-140 days, 1,615 cases)
#   End:         2020-06-20 (-66 days, 74 days after peak cases)
#   Day Zero:    2020-03-17 (-162 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-10 (-138 days, 285 deaths)
#
# Parameters:
#   Totals:      82,273 cases and 9,869 deaths at end of 2020-08-23
#   Smoothed:    82,273 cases and 9,868 deaths at end of 2020-08-23 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-03-09, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-08-23, compared to 7 days earlier)
#   Growth:      37 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=2).analyse()
# Out:
# Ireland data to end of 2020-08-26:
#   28,363 cases, 1,777 deaths
#   5,783 cases per million, 362 deaths per million (2019 population = 4,904,240)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-11 (-168 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-136 days, 902 cases)
#   End:         2020-06-14 (-72 days, 64 days after peak cases)
#   Day Zero:    2020-03-30 (-149 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-126 days, 70 deaths)
#
# Parameters:
#   Totals:      27,969 cases and 1,777 deaths at end of 2020-08-23
#   Smoothed:    27,969 cases and 1,777 deaths at end of 2020-08-23 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-08-23, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...
