# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/data-national-14-day-notification-rate-covid-19">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=0, ylog=1, d_clip=2.5, dilation=1, smooth=7)
covid.data_load('x_download.json')
covid.region_name
# Out:
# {'AFG': 'Afghanistan',
#  None: 'Africa (total)',
#  'ALB': 'Albania',
#  'DZA': 'Algeria',
#  'ASM': 'American Samoa',
#  'AND': 'Andorra',
#  'AGO': 'Angola',
#  'AIA': 'Anguilla',
#  'ATG': 'Antigua And Barbuda',
#  'ARG': 'Argentina',
#  'ARM': 'Armenia',
#  'ABW': 'Aruba',
#  'AUS': 'Australia',
#  'AUT': 'Austria',
#  'AZE': 'Azerbaijan',
#  'BHS': 'Bahamas',
#  'BHR': 'Bahrain',
#  'BGD': 'Bangladesh',
#  'BRB': 'Barbados',
#  'BLR': 'Belarus',
#  'BEL': 'Belgium',
#  'BLZ': 'Belize',
#  'BEN': 'Benin',
#  'BMU': 'Bermuda',
#  'BTN': 'Bhutan',
#  'BOL': 'Bolivia',
#  'BES': 'Bonaire, Saint Eustatius And Saba',
#  'BIH': 'Bosnia And Herzegovina',
#  'BWA': 'Botswana',
#  'BRA': 'Brazil',
#  'VGB': 'British Virgin Islands',
#  'BRN': 'Brunei Darussalam',
#  'BGR': 'Bulgaria',
#  'BFA': 'Burkina Faso',
#  'BDI': 'Burundi',
#  'KHM': 'Cambodia',
#  'CMR': 'Cameroon',
#  'CAN': 'Canada',
#  'CPV': 'Cape Verde',
#  'CYM': 'Cayman Islands',
#  'CAF': 'Central African Republic',
# ...

# %%
covid.Region(geoId='GBR').analyse()
# Out:
# United Kingdom data to end of 2021-12-16:
#   11,036,338 cases, 143,303 deaths
#   162,156 cases per million, 2,106 deaths per million (2019 population = 68,059,863)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         50% through outbreak
#   Start:       2020-03-04 (-652 days, when 50 or more cases were reported)
#   Peak Cases:  2021-12-13 ( -3 days, 77,410 cases)
#   End:         2023-09-22 (646 days, 649 days after peak cases)
#   Day Zero:    2020-03-19 (-637 days, when 50 or more deaths were reported)
#   Peak Deaths: 2021-01-18 (-332 days, 1,240 deaths)
#
# Parameters:
#   Totals:      10,804,106 cases and 142,968 deaths at end of 2021-12-13
#   Smoothed:    10,804,106 cases and 142,967 deaths at end of 2021-12-13 (7 points)
#   Spread:      Peak infection rate 6.5 (2020-03-12, compared to 7 days earlier)
#                Latest infection rate 1.5 (2021-12-13, compared to 7 days earlier)
#   Growth:      649 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SWE').analyse()

# %%
covid.Region(geoId='ESP').analyse()

# %%
covid.Region(geoId='ITA').analyse()

# %%
covid.Region(geoId='FRA').analyse()

# %%
covid.Region(geoId='DEU').analyse()

# %%
covid.Region(geoId='BEL').analyse()

# %%
covid.Region(geoId='IRL').analyse()

# %%
covid.Region(geoId='CZE').analyse()

# %%
covid.Region(geoId='AUT').analyse()
