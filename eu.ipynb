# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=2.8, d_cases=3.2).analyse(ylog=1)
# Out:
# United Kingdom data to end of 2020-05-13:
#   229,705 cases, 33,186 deaths
#   3,455 cases per million, 499 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         57% through outbreak
#   Start:       2020-03-02 (-72 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-32 days, 5,528 cases)
#   End:         2020-06-29 ( 48 days, 80 days after peak cases)
#   Day Zero:    2020-03-15 (-59 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-32 days, 942 deaths)
#
# Parameters:
#   Totals:      219,183 cases and 31,855 deaths at end of 2020-05-10
#   Smoothed:    219,182 cases and 31,855 deaths at end of 2020-05-10 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-10, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=3.1, d_cases=3.5).analyse()
# note: ECDC cases data differs from Worldometer due to anti-body tests
# Out:
# Spain data to end of 2020-05-11:
#   228,030 cases, 26,920 deaths
#   4,880 cases per million, 576 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         82% through outbreak
#   Start:       2020-02-29 (-72 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-28 (-44 days, 7,806 cases)
#   End:         2020-05-22 ( 12 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-61 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-41 days, 870 deaths)
#
# Parameters:
#   Totals:      223,578 cases and 26,478 deaths at end of 2020-05-08
#   Smoothed:    223,578 cases and 26,478 deaths at end of 2020-05-08 (7 points)
#   Spread:      Peak infection rate 14.6 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-08, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=2.4, d_cases=3).analyse()
# Out:
# Italy data to end of 2020-05-12:
#   221,216 cases, 30,911 deaths
#   3,661 cases per million, 512 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         84% through outbreak
#   Start:       2020-02-21 (-81 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-50 days, 5,651 cases)
#   End:         2020-05-23 ( 12 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-71 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-43 days, 823 deaths)
#
# Parameters:
#   Totals:      218,268 cases and 30,395 deaths at end of 2020-05-09
#   Smoothed:    218,267 cases and 30,395 deaths at end of 2020-05-09 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-09, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=2.7, d_cases=3.1).analyse()
# Out:
# France data to end of 2020-05-12:
#   140,227 cases, 26,991 deaths
#   2,093 cases per million, 403 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         77% through outbreak
#   Start:       2020-02-27 (-75 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-44 days, 4,541 cases)
#   End:         2020-05-29 ( 18 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-62 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-36 days, 1,100 deaths)
#
# Parameters:
#   Totals:      138,854 cases and 26,310 deaths at end of 2020-05-09
#   Smoothed:    138,853 cases and 26,310 deaths at end of 2020-05-09 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-05-09, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1.3, d_cases=1.9).analyse()
# Out:
# Germany data to end of 2020-05-12:
#   171,306 cases, 7,634 deaths
#   2,066 cases per million, 92 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         73% through outbreak
#   Start:       2020-02-27 (-75 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-41 days, 5,605 cases)
#   End:         2020-06-03 ( 23 days, 64 days after peak cases)
#   Day Zero:    2020-03-20 (-53 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-25 days, 233 deaths)
#
# Parameters:
#   Totals:      169,218 cases and 7,395 deaths at end of 2020-05-09
#   Smoothed:    169,218 cases and 7,395 deaths at end of 2020-05-09 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-09, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=1.7, d_cases=1.2).analyse()
# Out:
# Belgium data to end of 2020-05-12:
#   53,779 cases, 8,761 deaths
#   4,708 cases per million, 767 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         78% through outbreak
#   Start:       2020-03-04 (-69 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-30 days, 1,457 cases)
#   End:         2020-05-27 ( 16 days, 46 days after peak cases)
#   Day Zero:    2020-03-21 (-52 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-29 days, 334 deaths)
#
# Parameters:
#   Totals:      52,596 cases and 8,581 deaths at end of 2020-05-09
#   Smoothed:    52,596 cases and 8,580 deaths at end of 2020-05-09 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-09, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=1.2, d_cases=1.8).analyse()
# Out:
# Ireland data to end of 2020-05-12:
#   23,242 cases, 1,488 deaths
#   4,789 cases per million, 307 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         66% through outbreak
#   Start:       2020-03-11 (-62 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-30 days, 903 cases)
#   End:         2020-06-07 ( 27 days, 57 days after peak cases)
#   Day Zero:    2020-03-30 (-43 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-20 days, 71 deaths)
#
# Parameters:
#   Totals:      22,760 cases and 1,446 deaths at end of 2020-05-09
#   Smoothed:    22,760 cases and 1,446 deaths at end of 2020-05-09 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-09, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=1, d_cases=1.2).analyse()
# Out:
# Sweden data to end of 2020-05-12:
#   27,272 cases, 3,313 deaths
#   2,678 cases per million, 325 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         62% through outbreak
#   Start:       2020-03-04 (-69 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 (-20 days, 627 cases)
#   End:         2020-06-18 ( 38 days, 58 days after peak cases)
#   Day Zero:    2020-03-25 (-48 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-21 days, 109 deaths)
#
# Parameters:
#   Totals:      25,921 cases and 3,220 deaths at end of 2020-05-09
#   Smoothed:    25,920 cases and 3,220 deaths at end of 2020-05-09 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-09, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...
