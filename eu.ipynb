# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=0, ylog=1, d_clip=2.5)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=5, d_cases=4).analyse(totals=4)
# Out:
# United Kingdom data to end of 2020-07-17:
#   293,239 cases, 45,233 deaths
#   4,400 cases per million, 679 deaths per million (2019 population = 66,647,112)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         96% through outbreak
#   Start:       2020-03-02 (-137 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-97 days, 5,524 cases)
#   End:         2020-07-19 (  3 days, 100 days after peak cases)
#   Day Zero:    2020-03-15 (-124 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-97 days, 943 deaths)
#
# Parameters:
#   Totals:      291,373 cases and 44,968 deaths at end of 2020-07-14
#   Smoothed:    291,373 cases and 44,967 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-07-14, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
#                X = 297,489, r = 6.7, L = 22,094, dilation = 4, c = 78.5% for cases
#   Lag:         0 days (Peak Cases -> Peak Deaths)
#                X = 46,106, r = 8.0, L = 3,772, dilation = 5, c = 72.0% for deaths
#
# Outcome: 293,048 total cases, 45,277 total deaths by end of 2020-07-19
#   98.6% of predicted cases and 98.1% of predicted deaths reported to date
#   98.5% of predicted cases and 98.2% of predicted deaths reported by end date
#   4,464 cases per million (0.45%), 692 deaths per million (0.069%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04      624       67     284,900   44,198    -3,761       94     289,398   44,148
# 2020-07-05      516       22     285,416   44,220    -3,790       87     285,608   44,235
# 2020-07-06      352       16     285,768   44,236       553       87     286,160   44,322
# 2020-07-07      581      155     286,349   44,391       551       74     286,712   44,396
# 2020-07-08      630      126     286,979   44,517       580       86     287,291   44,481
# 2020-07-09      642       85     287,621   44,602       599       86     287,890   44,567
# 2020-07-10      512       48     288,133   44,650       624       85     288,514   44,652
# 2020-07-11      820      148     288,953   44,798       718       82     289,233   44,734
# 2020-07-12      650       21     289,603   44,819       705       77     289,938   44,811
# 2020-07-13      530       11     290,133   44,830       705       74     290,643   44,885
# 2020-07-14    1,240      138     291,373   44,968       730       83     291,373   44,968
# 2020-07-15      538       85     291,911   45,053
# 2020-07-16      641       66     292,552   45,119
# 2020-07-17      687      114     293,239   45,233
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-07-14      378       69    291,373   44,968
# 2020-07-15      363       67    291,736   45,035
# 2020-07-16      348       64    292,084   45,099
# 2020-07-17      335       62    292,419   45,161  <-- latest raw data
# 2020-07-18      321       59    292,740   45,220
# 2020-07-19      309       57    293,048   45,277

# %%
covid.Region(geoId='SE', dilation=2, d_cases=2).analyse(totals=4)
# Out:
# Sweden data to end of 2020-07-17:
#   77,281 cases, 5,619 deaths
#   7,554 cases per million, 549 deaths per million (2019 population = 10,230,185)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         40% through outbreak
#   Start:       2020-03-04 (-135 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-23 (-24 days, 1,298 cases)
#   End:         2021-01-30 (198 days, 222 days after peak cases)
#   Day Zero:    2020-03-25 (-114 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-87 days, 107 deaths)
#
# Parameters:
#   Totals:      76,001 cases and 5,545 deaths at end of 2020-07-14
#   Smoothed:    76,001 cases and 5,545 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-07-14, compared to 7 days earlier)
#   Growth:      111 days (Start -> Peak Cases)
#                X = 163,624, r = 4.2, L = 5,193, dilation = 2, c = 57.5% for cases
#   Lag:         -63 days (Peak Cases -> Peak Deaths)
#                X = 5,910, r = 8.0, L = 428, dilation = 2, c = 52.0% for deaths
#
# Outcome: 161,214 total cases, 5,909 total deaths by end of 2021-01-30
#   47.2% of predicted cases and 95.1% of predicted deaths reported to date
#   98.5% of predicted cases and 100.0% of predicted deaths reported by end date
#   15,994 cases per million (1.60%), 578 deaths per million (0.058%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04        0        0      71,419    5,420       699       16      71,535    5,403
# 2020-07-05        0        0      71,419    5,420       595       16      72,130    5,419
# 2020-07-06    1,642       13      73,061    5,433       527       13      72,657    5,432
# 2020-07-07      283       14      73,344    5,447       497       15      73,154    5,447
# 2020-07-08      514       35      73,858    5,482       497       15      73,650    5,462
# 2020-07-09      475       18      74,333    5,500       497       15      74,147    5,477
# 2020-07-10      565       26      74,898    5,526       395       15      74,542    5,492
# 2020-07-11        0        0      74,898    5,526       379       14      74,921    5,506
# 2020-07-12        0        0      74,898    5,526       376       13      75,297    5,518
# 2020-07-13      928       10      75,826    5,536       363       13      75,661    5,532
# 2020-07-14      175        9      76,001    5,545       340       13      76,001    5,545
# 2020-07-15      491       27      76,492    5,572
# 2020-07-16      385       21      76,877    5,593
# 2020-07-17      404       26      77,281    5,619
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-07-14    1,008       13     76,001    5,545
# 2020-07-15    1,004       12     77,005    5,557
# 2020-07-16    1,000       12     78,005    5,569
# 2020-07-17      996       12     79,001    5,581  <-- latest raw data
# 2020-07-18      992       11     79,993    5,592
# 2020-07-19      987       11     80,980    5,603
# 2020-07-20      983       10     81,963    5,613
# 2020-07-21      978       10     82,941    5,624
# 2020-07-22      973       10     83,914    5,633
# 2020-07-23      968        9     84,882    5,643

# %%
covid.Region(geoId='ES', dilation=2.8, d_cases=1.9).analyse()
# Out:
# Spain data to end of 2020-07-16:
#   260,255 cases, 28,420 deaths
#   5,545 cases per million, 605 deaths per million (2019 population = 46,937,060)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-28 (-139 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-111 days, 7,899 cases)
#   End:         2020-05-18 (-58 days, 53 days after peak cases)
#   Day Zero:    2020-03-11 (-127 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-107 days, 868 deaths)
#
# Parameters:
#   Totals:      256,619 cases and 28,409 deaths at end of 2020-07-13
#   Smoothed:    256,619 cases and 28,408 deaths at end of 2020-07-13 (7 points)
#   Spread:      Peak infection rate 12.3 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.9 (2020-07-13, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
#                X = 233,813, r = 5.53, L = 31,596, dilation = 1.9, c = 89.9% for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#                X = 28,601, r = 6.25, L = 3,472, dilation = 2.8, c = 90.8% for deaths
#
# Outcome: 232,555 total cases, 27,888 total deaths at end of 2020-05-19
#   4,955 cases per million (0.50%), 594 deaths per million (0.059%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-03        0        0     250,545   28,385       408        5     250,667   28,380
# 2020-07-04        0        0     250,545   28,385       408        5     251,075   28,385
# 2020-07-05    1,244        3     251,789   28,388       422        5     251,497   28,389
# 2020-07-06      341        4     252,130   28,392       480        3     251,977   28,392
# 2020-07-07      383        4     252,513   28,396       480        3     252,457   28,394
# 2020-07-08      543        5     253,056   28,401       480        3     252,937   28,397
# 2020-07-09      852        2     253,908   28,403       595        3     253,532   28,400
# 2020-07-10        0        0     253,908   28,403       641        2     254,173   28,402
# 2020-07-11        0        0     253,908   28,403       711        2     254,884   28,404
# 2020-07-12    2,045        3     255,953   28,406       828        2     255,713   28,407
# 2020-07-13      666        3     256,619   28,409       906        2     256,619   28,409
# 2020-07-14      875        4     257,494   28,413
# 2020-07-15    1,361        3     258,855   28,416
# 2020-07-16    1,400        4     260,255   28,420
#
#   ** first wave ended **

# %%
covid.Region(geoId='IT', dilation=2.2, d_cases=3).analyse()
# Out:
# Italy data to end of 2020-07-17:
#   243,967 cases, 35,028 deaths
#   4,042 cases per million, 580 deaths per million (2019 population = 60,359,546)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-21 (-147 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-116 days, 5,643 cases)
#   End:         2020-06-07 (-39 days, 77 days after peak cases)
#   Day Zero:    2020-03-02 (-137 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-109 days, 822 deaths)
#
# Parameters:
#   Totals:      243,344 cases and 34,984 deaths at end of 2020-07-14
#   Smoothed:    243,343 cases and 34,983 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-07-14, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
#                X = 237,464, r = 5.64, L = 22,570, dilation = 3, c = 94.3% for cases
#   Lag:         7 days (Peak Cases -> Peak Deaths)
#                X = 34,312, r = 4.48, L = 3,286, dilation = 2.2, c = 87.1% for deaths
#
# Outcome: 235,278 total cases, 33,964 total deaths at end of 2020-06-08
#   3,898 cases per million (0.39%), 563 deaths per million (0.056%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04      235       21     241,419   34,854       197       19     241,350   34,845
# 2020-07-05      192        7     241,611   34,861       198       18     241,548   34,863
# 2020-07-06      208        8     241,819   34,869       200       15     241,749   34,879
# 2020-07-07      137       30     241,956   34,899       208       15     241,956   34,894
# 2020-07-08      193       15     242,149   34,914       201       13     242,157   34,907
# 2020-07-09      214       12     242,363   34,926       207       13     242,365   34,920
# 2020-07-10      276       12     242,639   34,938       202       14     242,566   34,934
# 2020-07-11      188        7     242,827   34,945       198       12     242,764   34,946
# 2020-07-12      234        9     243,061   34,954       194       12     242,958   34,958
# 2020-07-13      169       13     243,230   34,967       196       13     243,154   34,971
# 2020-07-14      114       17     243,344   34,984       190       13     243,344   34,984
# 2020-07-15      162       13     243,506   34,997
# 2020-07-16      230       20     243,736   35,017
# 2020-07-17      231       11     243,967   35,028
#
#   ** first wave ended **

# %%
covid.Region(geoId='FR', dilation=2.3, d_cases=2.3).analyse()
# Out:
# France data to end of 2020-07-17:
#   174,674 cases, 30,152 deaths
#   2,607 cases per million, 450 deaths per million (2019 population = 67,012,883)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-27 (-141 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-110 days, 4,531 cases)
#   End:         2020-06-07 (-39 days, 71 days after peak cases)
#   Day Zero:    2020-03-11 (-128 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-102 days, 1,100 deaths)
#
# Parameters:
#   Totals:      172,377 cases and 30,029 deaths at end of 2020-07-14
#   Smoothed:    172,376 cases and 30,029 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-07-14, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
#                X = 154,437, r = 6.22, L = 18,124, dilation = 2.3, c = 85.4% for cases
#   Lag:         8 days (Peak Cases -> Peak Deaths)
#                X = 29,218, r = 7.77, L = 4,398, dilation = 2.3, c = 81.3% for deaths
#
# Outcome: 154,188 total cases, 29,209 total deaths at end of 2020-06-08
#   2,301 cases per million (0.23%), 436 deaths per million (0.044%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04        0        0     166,960   29,893       572       13     166,962   29,857
# 2020-07-05        0        0     166,960   29,893       536       15     167,497   29,871
# 2020-07-06    1,375       27     168,335   29,920       530       15     168,028   29,886
# 2020-07-07      475       13     168,810   29,933       541       16     168,569   29,902
# 2020-07-08      663       32     169,473   29,965       541       16     169,110   29,918
# 2020-07-09      621       14     170,094   29,979       541       16     169,651   29,934
# 2020-07-10      658       25     170,752   30,004       577       16     170,228   29,949
# 2020-07-11        0        0     170,752   30,004       509       14     170,737   29,963
# 2020-07-12        0        0     170,752   30,004       547       22     171,283   29,985
# 2020-07-13    1,625       25     172,377   30,029       534       23     171,817   30,008
# 2020-07-14        0        0     172,377   30,029       560       21     172,377   30,029
# 2020-07-15      927       91     173,304   30,120
# 2020-07-16      534       18     173,838   30,138
# 2020-07-17      836       14     174,674   30,152
#
#   ** first wave ended **

# %%
covid.Region(geoId='DE', dilation=1.4).analyse()
# Out:
# Germany data to end of 2020-07-17:
#   201,372 cases, 9,083 deaths
#   2,426 cases per million, 109 deaths per million (2019 population = 83,019,213)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-27 (-141 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-107 days, 5,592 cases)
#   End:         2020-05-17 (-60 days, 47 days after peak cases)
#   Day Zero:    2020-03-20 (-119 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-91 days, 233 deaths)
#
# Parameters:
#   Totals:      199,726 cases and 9,071 deaths at end of 2020-07-14
#   Smoothed:    199,726 cases and 9,071 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-07-14, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
#                X = 176,600, r = 4.98, L = 22,367, dilation = 1.4, c = 85.7% for cases
#   Lag:         16 days (Peak Cases -> Peak Deaths)
#                X = 8,461, r = 4.45, L = 930, dilation = 1.4, c = 87.8% for deaths
#
# Outcome: 175,210 total cases, 8,007 total deaths at end of 2020-05-18
#   2,110 cases per million (0.21%), 96 deaths per million (0.010%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04      239        2     196,335    9,012       373        7     196,191    9,012
# 2020-07-05      219        4     196,554    9,016       365        8     196,556    9,020
# 2020-07-06      390        8     196,944    9,024       357        7     196,913    9,027
# 2020-07-07      397       12     197,341    9,036       351        7     197,265    9,035
# 2020-07-08      442       12     197,783    9,048       353        7     197,617    9,042
# 2020-07-09      395        6     198,178    9,054       344        7     197,961    9,049
# 2020-07-10      378        6     198,556    9,060       288        6     198,249    9,054
# 2020-07-11      248        3     198,804    9,063       341        5     198,590    9,059
# 2020-07-12      159        1     198,963    9,064       354        4     198,943    9,064
# 2020-07-13        0        0     198,963    9,064       380        4     199,324    9,068
# 2020-07-14      763        7     199,726    9,071       402        3     199,726    9,071
# 2020-07-15      534        7     200,260    9,078
# 2020-07-16      583        4     200,843    9,082
# 2020-07-17      529        1     201,372    9,083
#
#   ** first wave ended **

# %%
covid.Region(geoId='BE', dilation=1.5, d_cases=1).analyse()
# Out:
# Belgium data to end of 2020-07-17:
#   63,499 cases, 9,800 deaths
#   5,543 cases per million, 855 deaths per million (2019 population = 11,455,519)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-02 (-137 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-08 (-100 days, 1,601 cases)
#   End:         2020-05-14 (-63 days, 37 days after peak cases)
#   Day Zero:    2020-03-16 (-123 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-09 (-99 days, 303 deaths)
#
# Parameters:
#   Totals:      62,781 cases and 9,787 deaths at end of 2020-07-14
#   Smoothed:    62,780 cases and 9,787 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-03-09, compared to 7 days earlier)
#                Latest infection rate 1.6 (2020-07-14, compared to 7 days earlier)
#   Growth:      37 days (Start -> Peak Cases)
#                X = 56,314, r = 4.25, L = 6,405, dilation = 1, c = 87.8% for cases
#   Lag:         1 days (Peak Cases -> Peak Deaths)
#                X = 9,286, r = 5.81, L = 1,211, dilation = 1.5, c = 90.6% for deaths
#
# Outcome: 55,818 total cases, 9,079 total deaths at end of 2020-05-15
#   4,873 cases per million (0.49%), 793 deaths per million (0.079%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04       71        0      61,909    9,771        87        3      61,729    9,768
# 2020-07-05      107        0      62,016    9,771        87        2      61,816    9,770
# 2020-07-06       42        3      62,058    9,774        69        2      61,885    9,772
# 2020-07-07       65        2      62,123    9,776        90        2      61,975    9,774
# 2020-07-08       87        2      62,210    9,778        99        2      62,074    9,775
# 2020-07-09        0        3      62,210    9,781        98        2      62,173    9,777
# 2020-07-10      259        1      62,469    9,782       103        2      62,276    9,779
# 2020-07-11      137        0      62,606    9,782        94        2      62,370    9,780
# 2020-07-12      101        0      62,707    9,782       118        2      62,488    9,782
# 2020-07-13       74        5      62,781    9,787       146        2      62,634    9,784
# 2020-07-14        0        0      62,781    9,787       147        3      62,781    9,787
# 2020-07-15      258        5      63,039    9,792
# 2020-07-16      199        3      63,238    9,795
# 2020-07-17      261        5      63,499    9,800
#
#   ** first wave ended **

# %%
covid.Region(geoId='IE', dilation=1.1, d_cases=1.6).analyse()
# Out:
# Ireland data to end of 2020-07-17:
#   25,730 cases, 1,752 deaths
#   5,246 cases per million, 357 deaths per million (2019 population = 4,904,240)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-11 (-128 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-96 days, 903 cases)
#   End:         2020-06-01 (-45 days, 51 days after peak cases)
#   Day Zero:    2020-03-30 (-109 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-86 days, 70 deaths)
#
# Parameters:
#   Totals:      25,670 cases and 1,746 deaths at end of 2020-07-14
#   Smoothed:    25,670 cases and 1,746 deaths at end of 2020-07-14 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 1.5 (2020-07-14, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
#                X = 25,152, r = 5.75, L = 3,613, dilation = 1.6, c = 79.7% for cases
#   Lag:         10 days (Peak Cases -> Peak Deaths)
#                X = 1,659, r = 5.25, L = 280, dilation = 1.1, c = 72.1% for deaths
#
# Outcome: 25,066 total cases, 1,658 total deaths at end of 2020-06-02
#   5,111 cases per million (0.51%), 338 deaths per million (0.034%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-04       11        1      25,509    1,741         9        1      25,514    1,739
# 2020-07-05       18        0      25,527    1,741         9        1      25,524    1,739
# 2020-07-06        4        0      25,531    1,741        11        1      25,535    1,740
# 2020-07-07        7        2      25,538    1,743        13        1      25,548    1,741
# 2020-07-08        4        0      25,542    1,743        15        1      25,562    1,741
# 2020-07-09       23        0      25,565    1,743        14        1      25,577    1,742
# 2020-07-10       24        1      25,589    1,744        15        1      25,592    1,743
# 2020-07-11       22        2      25,611    1,746        19    < 0.5      25,611    1,743
# 2020-07-12       17        0      25,628    1,746        20        1      25,631    1,744
# 2020-07-13       10        0      25,638    1,746        19        1      25,650    1,745
# 2020-07-14       32        0      25,670    1,746        20        1      25,670    1,746
# 2020-07-15       13        2      25,683    1,748
# 2020-07-16       15        1      25,698    1,749
# 2020-07-17       32        3      25,730    1,752
#
#   ** first wave ended **
