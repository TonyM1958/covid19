# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=3.1, d_cases=3.5).analyse(ylog=1)
# Out:
# United Kingdom data to end of 2020-05-17:
#   243,695 cases, 34,636 deaths
#   3,665 cases per million, 521 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         61% through outbreak
#   Start:       2020-03-02 (-76 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-36 days, 5,516 cases)
#   End:         2020-06-29 ( 44 days, 80 days after peak cases)
#   Day Zero:    2020-03-15 (-63 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-36 days, 946 deaths)
#
# Parameters:
#   Totals:      233,151 cases and 33,614 deaths at end of 2020-05-14
#   Smoothed:    233,150 cases and 33,613 deaths at end of 2020-05-14 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-14, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=4, d_cases=3.5).analyse(ylog=1)
# note: ECDC cases data differs from Worldometer due to anti-body tests
# Out:
# Spain data to end of 2020-05-16:
#   231,350 cases, 27,650 deaths
#   4,951 cases per million, 592 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         89% through outbreak
#   Start:       2020-02-28 (-78 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-50 days, 7,903 cases)
#   End:         2020-05-21 (  6 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-66 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-46 days, 870 deaths)
#
# Parameters:
#   Totals:      229,540 cases and 27,321 deaths at end of 2020-05-13
#   Smoothed:    229,540 cases and 27,321 deaths at end of 2020-05-13 (7 points)
#   Spread:      Peak infection rate 12.3 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-13, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=3.4).analyse()
# Out:
# Italy data to end of 2020-05-17:
#   225,435 cases, 31,908 deaths
#   3,730 cases per million, 528 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         89% through outbreak
#   Start:       2020-02-21 (-86 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-55 days, 5,648 cases)
#   End:         2020-05-23 (  7 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-76 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-48 days, 822 deaths)
#
# Parameters:
#   Totals:      223,096 cases and 31,368 deaths at end of 2020-05-14
#   Smoothed:    223,095 cases and 31,368 deaths at end of 2020-05-14 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-14, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=3.5).analyse()
# Out:
# France data to end of 2020-05-17:
#   142,411 cases, 28,108 deaths
#   2,126 cases per million, 420 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         83% through outbreak
#   Start:       2020-02-27 (-80 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-49 days, 4,541 cases)
#   End:         2020-05-29 ( 13 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-67 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-41 days, 1,104 deaths)
#
# Parameters:
#   Totals:      141,356 cases and 27,425 deaths at end of 2020-05-14
#   Smoothed:    141,355 cases and 27,425 deaths at end of 2020-05-14 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.4 (2020-05-14, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1.5, d_cases=3).analyse()
# Out:
# Germany data to end of 2020-05-17:
#   174,697 cases, 7,935 deaths
#   2,107 cases per million, 96 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         75% through outbreak
#   Start:       2020-02-27 (-80 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-46 days, 5,605 cases)
#   End:         2020-06-07 ( 22 days, 68 days after peak cases)
#   Day Zero:    2020-03-20 (-58 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-30 days, 234 deaths)
#
# Parameters:
#   Totals:      173,152 cases and 7,824 deaths at end of 2020-05-14
#   Smoothed:    173,152 cases and 7,824 deaths at end of 2020-05-14 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-14, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=2.2, d_cases=1.5).analyse()
# Out:
# Belgium data to end of 2020-05-17:
#   55,280 cases, 9,052 deaths
#   4,840 cases per million, 793 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         73% through outbreak
#   Start:       2020-03-04 (-74 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-35 days, 1,451 cases)
#   End:         2020-06-08 ( 23 days, 58 days after peak cases)
#   Day Zero:    2020-03-21 (-57 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-34 days, 334 deaths)
#
# Parameters:
#   Totals:      54,288 cases and 8,903 deaths at end of 2020-05-14
#   Smoothed:    54,287 cases and 8,902 deaths at end of 2020-05-14 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-14, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=1.7, d_cases=2.7).analyse()
# Out:
# Ireland data to end of 2020-05-17:
#   24,112 cases, 1,543 deaths
#   4,968 cases per million, 318 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         67% through outbreak
#   Start:       2020-03-11 (-67 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-35 days, 909 cases)
#   End:         2020-06-14 ( 29 days, 64 days after peak cases)
#   Day Zero:    2020-03-30 (-48 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-25 days, 70 deaths)
#
# Parameters:
#   Totals:      23,827 cases and 1,506 deaths at end of 2020-05-14
#   Smoothed:    23,827 cases and 1,506 deaths at end of 2020-05-14 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-14, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=3).analyse()
# Out:
# Sweden data to end of 2020-05-17:
#   30,143 cases, 3,679 deaths
#   2,960 cases per million, 361 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         48% through outbreak
#   Start:       2020-03-04 (-74 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 (-25 days, 624 cases)
#   End:         2020-07-28 ( 73 days, 98 days after peak cases)
#   Day Zero:    2020-03-25 (-53 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-26 days, 108 deaths)
#
# Parameters:
#   Totals:      28,582 cases and 3,529 deaths at end of 2020-05-14
#   Smoothed:    28,582 cases and 3,529 deaths at end of 2020-05-14 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-14, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...
