# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://coronavirus.data.gov.uk/">coronavirus.data.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=2.4, d_cases=9).analyse()
# Out:
# United Kingdom data to end of 2020-05-03:
#   186,599 cases, 28,446 deaths
#   2,806 cases per million, 428 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         49% through outbreak
#   Start:       2020-03-02 (-62 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-22 days, 5,508 cases)
#   End:         2020-06-29 ( 58 days, 80 days after peak cases)
#   Day Zero:    2020-03-15 (-49 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-22 days, 947 deaths)
#
# Parameters:
#   Totals:      171,253 cases and 26,771 deaths at end of 2020-04-30
#   Smoothed:    171,253 cases and 26,771 deaths at end of 2020-04-30 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-04-30, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=3, d_cases=3).analyse()
# note: ECDC cases data differs from Worldometer due to anti-body tests
# Out:
# Spain data to end of 2020-05-02:
#   217,466 cases, 25,264 deaths
#   4,654 cases per million, 541 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         71% through outbreak
#   Start:       2020-02-29 (-63 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-28 (-35 days, 7,811 cases)
#   End:         2020-05-22 ( 21 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-52 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-32 days, 872 deaths)
#
# Parameters:
#   Totals:      213,435 cases and 24,543 deaths at end of 2020-04-29
#   Smoothed:    213,435 cases and 24,542 deaths at end of 2020-04-29 (7 points)
#   Spread:      Peak infection rate 14.6 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-04-29, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=2.9, d_cases=4).analyse()
# Out:
# Italy data to end of 2020-05-03:
#   210,717 cases, 28,884 deaths
#   3,487 cases per million, 478 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         74% through outbreak
#   Start:       2020-02-21 (-72 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-41 days, 5,647 cases)
#   End:         2020-05-23 ( 21 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-62 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-34 days, 822 deaths)
#
# Parameters:
#   Totals:      205,463 cases and 27,967 deaths at end of 2020-04-30
#   Smoothed:    205,462 cases and 27,967 deaths at end of 2020-04-30 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-04-30, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=2).analyse()
# Out:
# France data to end of 2020-05-03:
#   131,287 cases, 24,895 deaths
#   1,960 cases per million, 372 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         68% through outbreak
#   Start:       2020-02-27 (-66 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-35 days, 4,557 cases)
#   End:         2020-05-29 ( 27 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-53 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-27 days, 1,107 deaths)
#
# Parameters:
#   Totals:      129,581 cases and 24,376 deaths at end of 2020-04-30
#   Smoothed:    129,580 cases and 24,375 deaths at end of 2020-04-30 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-04-30, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1.2, d_cases=2.7).analyse()
# Out:
# Germany data to end of 2020-05-03:
#   163,175 cases, 6,692 deaths
#   1,968 cases per million, 81 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         62% through outbreak
#   Start:       2020-02-27 (-66 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-32 days, 5,567 cases)
#   End:         2020-06-07 ( 36 days, 68 days after peak cases)
#   Day Zero:    2020-03-20 (-44 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-16 days, 230 deaths)
#
# Parameters:
#   Totals:      159,119 cases and 6,288 deaths at end of 2020-04-30
#   Smoothed:    159,119 cases and 6,288 deaths at end of 2020-04-30 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-04-30, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=1.3, d_cases=0.9).analyse()
# Out:
# Belgium data to end of 2020-05-03:
#   49,906 cases, 7,844 deaths
#   4,369 cases per million, 687 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         73% through outbreak
#   Start:       2020-03-04 (-60 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-21 days, 1,456 cases)
#   End:         2020-05-20 ( 18 days, 39 days after peak cases)
#   Day Zero:    2020-03-21 (-43 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-20 days, 335 deaths)
#
# Parameters:
#   Totals:      48,519 cases and 7,594 deaths at end of 2020-04-30
#   Smoothed:    48,519 cases and 7,594 deaths at end of 2020-04-30 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-04-30, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=1, d_cases=2).analyse()
# Out:
# Ireland data to end of 2020-05-03:
#   21,506 cases, 1,303 deaths
#   4,431 cases per million, 268 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         52% through outbreak
#   Start:       2020-03-11 (-53 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-21 days, 906 cases)
#   End:         2020-06-14 ( 43 days, 64 days after peak cases)
#   Day Zero:    2020-03-30 (-34 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-11 days, 71 deaths)
#
# Parameters:
#   Totals:      20,612 cases and 1,232 deaths at end of 2020-04-30
#   Smoothed:    20,612 cases and 1,232 deaths at end of 2020-04-30 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-04-30, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=0.8).analyse()
# Out:
# Sweden data to end of 2020-05-03:
#   22,317 cases, 2,679 deaths
#   2,192 cases per million, 263 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         58% through outbreak
#   Start:       2020-03-04 (-60 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 (-11 days, 630 cases)
#   End:         2020-06-09 ( 38 days, 49 days after peak cases)
#   Day Zero:    2020-03-25 (-39 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-12 days, 110 deaths)
#
# Parameters:
#   Totals:      21,092 cases and 2,586 deaths at end of 2020-04-30
#   Smoothed:    21,092 cases and 2,586 deaths at end of 2020-04-30 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-04-30, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...
