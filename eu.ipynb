# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=0, ylog=1, d_clip=2.5, dilation=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK').analyse(totals=4)
# Out:
# United Kingdom data to end of 2020-11-06:
#   1,146,484 cases, 48,475 deaths
#   17,202 cases per million, 727 deaths per million (2019 population = 66,647,112)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         29% through outbreak
#   Start:       2020-03-01 (-250 days, when 50 or more cases were reported)
#   Peak Cases:  2020-10-29 ( -8 days, 22,937 cases)
#   End:         2022-06-25 (597 days, 605 days after peak cases)
#   Day Zero:    2020-03-15 (-236 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-10 (-210 days, 940 deaths)
#
# Parameters:
#   Totals:      1,073,882 cases and 47,250 deaths at end of 2020-11-03
#   Smoothed:    1,073,882 cases and 47,250 deaths at end of 2020-11-03 (7 points)
#   Spread:      Peak infection rate 6.4 (2020-03-13, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-11-03, compared to 7 days earlier)
#   Growth:      242 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=2, d_cases=4).analyse(totals=4)
# Out:
# Sweden data to end of 2020-11-06:
#   146,461 cases, 6,022 deaths
#   14,317 cases per million, 589 deaths per million (2019 population = 10,230,185)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         29% through outbreak
#   Start:       2020-03-03 (-248 days, when 50 or more cases were reported)
#   Peak Cases:  2020-11-02 ( -4 days, 3,052 cases)
#   End:         2022-07-04 (606 days, 610 days after peak cases)
#   Day Zero:    2020-03-21 (-230 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-207 days, 99 deaths)
#
# Parameters:
#   Totals:      138,523 cases and 6,016 deaths at end of 2020-11-03
#   Smoothed:    138,522 cases and 6,015 deaths at end of 2020-11-03 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-11-03, compared to 7 days earlier)
#   Growth:      244 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES').analyse()
# Out:
# Spain data to end of 2020-11-05:
#   1,328,832 cases, 38,833 deaths
#   28,311 cases per million, 827 deaths per million (2019 population = 46,937,060)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         29% through outbreak
#   Start:       2020-02-28 (-251 days, when 50 or more cases were reported)
#   Peak Cases:  2020-10-31 ( -5 days, 21,188 cases)
#   End:         2022-07-07 (610 days, 615 days after peak cases)
#   Day Zero:    2020-03-11 (-239 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-219 days, 853 deaths)
#
# Parameters:
#   Totals:      1,259,366 cases and 36,495 deaths at end of 2020-11-02
#   Smoothed:    1,259,365 cases and 36,495 deaths at end of 2020-11-02 (7 points)
#   Spread:      Peak infection rate 12.3 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-11-02, compared to 7 days earlier)
#   Growth:      246 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=2.2, d_cases=3).analyse()
# Out:
# Italy data to end of 2020-11-06:
#   862,681 cases, 40,638 deaths
#   14,292 cases per million, 673 deaths per million (2019 population = 60,359,546)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         29% through outbreak
#   Start:       2020-02-21 (-259 days, when 50 or more cases were reported)
#   Peak Cases:  2020-11-03 ( -3 days, 30,490 cases)
#   End:         2022-08-04 (637 days, 640 days after peak cases)
#   Day Zero:    2020-03-02 (-249 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-221 days, 820 deaths)
#
# Parameters:
#   Totals:      759,829 cases and 39,412 deaths at end of 2020-11-03
#   Smoothed:    759,829 cases and 39,411 deaths at end of 2020-11-03 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-11-03, compared to 7 days earlier)
#   Growth:      256 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR').analyse()
# Out:
# France data to end of 2020-11-06:
#   1,661,853 cases, 39,865 deaths
#   24,799 cases per million, 595 deaths per million (2019 population = 67,012,883)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         29% through outbreak
#   Start:       2020-02-27 (-253 days, when 50 or more cases were reported)
#   Peak Cases:  2020-11-03 ( -3 days, 46,968 cases)
#   End:         2022-07-20 (622 days, 625 days after peak cases)
#   Day Zero:    2020-03-11 (-240 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-214 days, 1,105 deaths)
#
# Parameters:
#   Totals:      1,502,763 cases and 38,289 deaths at end of 2020-11-03
#   Smoothed:    1,502,763 cases and 38,288 deaths at end of 2020-11-03 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-11-03, compared to 7 days earlier)
#   Growth:      250 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=8).analyse()
# Out:
# Germany data to end of 2020-11-06:
#   642,488 cases, 11,226 deaths
#   7,739 cases per million, 135 deaths per million (2019 population = 83,019,213)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         29% through outbreak
#   Start:       2020-02-27 (-253 days, when 50 or more cases were reported)
#   Peak Cases:  2020-11-03 ( -3 days, 17,538 cases)
#   End:         2022-07-20 (622 days, 625 days after peak cases)
#   Day Zero:    2020-03-20 (-231 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-203 days, 233 deaths)
#
# Parameters:
#   Totals:      577,593 cases and 10,812 deaths at end of 2020-11-03
#   Smoothed:    577,593 cases and 10,812 deaths at end of 2020-11-03 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-11-03, compared to 7 days earlier)
#   Growth:      250 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE').analyse()
# Out:
# Belgium data to end of 2020-11-06:
#   487,949 cases, 12,708 deaths
#   42,595 cases per million, 1,109 deaths per million (2019 population = 11,455,519)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         30% through outbreak
#   Start:       2020-03-02 (-249 days, when 50 or more cases were reported)
#   Peak Cases:  2020-10-25 (-12 days, 16,306 cases)
#   End:         2022-06-08 (580 days, 592 days after peak cases)
#   Day Zero:    2020-03-17 (-234 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-10 (-210 days, 286 deaths)
#
# Parameters:
#   Totals:      476,271 cases and 12,355 deaths at end of 2020-11-03
#   Smoothed:    476,271 cases and 12,354 deaths at end of 2020-11-03 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-03-09, compared to 7 days earlier)
#                Latest infection rate 0.4 (2020-11-03, compared to 7 days earlier)
#   Growth:      237 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE').analyse()
# Out:
# Ireland data to end of 2020-11-06:
#   64,538 cases, 1,940 deaths
#   13,160 cases per million, 396 deaths per million (2019 population = 4,904,240)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         31% through outbreak
#   Start:       2020-03-11 (-240 days, when 50 or more cases were reported)
#   Peak Cases:  2020-10-18 (-19 days, 1,168 cases)
#   End:         2022-04-22 (533 days, 552 days after peak cases)
#   Day Zero:    2020-03-30 (-221 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-198 days, 70 deaths)
#
# Parameters:
#   Totals:      63,048 cases and 1,922 deaths at end of 2020-11-03
#   Smoothed:    63,048 cases and 1,921 deaths at end of 2020-11-03 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-11-03, compared to 7 days earlier)
#   Growth:      221 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='CZ').analyse()
# Out:
# Czechia data to end of 2020-11-06:
#   403,497 cases, 4,526 deaths
#   37,888 cases per million, 425 deaths per million (2019 population = 10,649,800)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         30% through outbreak
#   Start:       2020-03-09 (-242 days, when 50 or more cases were reported)
#   Peak Cases:  2020-10-24 (-13 days, 12,750 cases)
#   End:         2022-05-18 (559 days, 572 days after peak cases)
#   Day Zero:    2020-04-03 (-217 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-11-02 ( -4 days, 211 deaths)
#
# Parameters:
#   Totals:      362,985 cases and 3,913 deaths at end of 2020-11-03
#   Smoothed:    362,984 cases and 3,912 deaths at end of 2020-11-03 (7 points)
#   Spread:      Peak infection rate 4.2 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-11-03, compared to 7 days earlier)
#   Growth:      229 days (Start -> Peak Cases)
# ...
