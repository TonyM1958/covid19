# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=2.4, d_cases=3.3).analyse(ylog=1)
# Out:
# United Kingdom data to end of 2020-05-12:
#   226,463 cases, 32,692 deaths
#   3,406 cases per million, 492 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         57% through outbreak
#   Start:       2020-03-02 (-71 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-31 days, 5,532 cases)
#   End:         2020-06-29 ( 49 days, 80 days after peak cases)
#   Day Zero:    2020-03-15 (-58 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-31 days, 947 deaths)
#
# Parameters:
#   Totals:      215,260 cases and 31,587 deaths at end of 2020-05-09
#   Smoothed:    215,259 cases and 31,586 deaths at end of 2020-05-09 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-09, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=3, d_cases=3.2).analyse()
# note: ECDC cases data differs from Worldometer due to anti-body tests
# Out:
# Spain data to end of 2020-05-10:
#   227,436 cases, 26,744 deaths
#   4,868 cases per million, 572 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         81% through outbreak
#   Start:       2020-02-29 (-71 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-28 (-43 days, 7,824 cases)
#   End:         2020-05-22 ( 13 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-60 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-40 days, 869 deaths)
#
# Parameters:
#   Totals:      222,857 cases and 26,251 deaths at end of 2020-05-07
#   Smoothed:    222,856 cases and 26,251 deaths at end of 2020-05-07 (7 points)
#   Spread:      Peak infection rate 14.6 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-07, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=2.4, d_cases=3).analyse()
# Out:
# Italy data to end of 2020-05-11:
#   219,814 cases, 30,739 deaths
#   3,637 cases per million, 509 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         83% through outbreak
#   Start:       2020-02-21 (-80 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-49 days, 5,653 cases)
#   End:         2020-05-23 ( 13 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-70 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-42 days, 824 deaths)
#
# Parameters:
#   Totals:      217,185 cases and 30,201 deaths at end of 2020-05-08
#   Smoothed:    217,184 cases and 30,200 deaths at end of 2020-05-08 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-08, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=2.6, d_cases=3).analyse()
# Out:
# France data to end of 2020-05-11:
#   139,519 cases, 26,643 deaths
#   2,083 cases per million, 398 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         76% through outbreak
#   Start:       2020-02-27 (-74 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-43 days, 4,561 cases)
#   End:         2020-05-29 ( 19 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-61 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-35 days, 1,105 deaths)
#
# Parameters:
#   Totals:      138,421 cases and 26,230 deaths at end of 2020-05-08
#   Smoothed:    138,421 cases and 26,229 deaths at end of 2020-05-08 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-05-08, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1.1, d_cases=1.7).analyse()
# Out:
# Germany data to end of 2020-05-11:
#   170,508 cases, 7,533 deaths
#   2,056 cases per million, 91 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         78% through outbreak
#   Start:       2020-02-27 (-74 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-40 days, 5,613 cases)
#   End:         2020-05-27 ( 17 days, 57 days after peak cases)
#   Day Zero:    2020-03-20 (-52 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-24 days, 235 deaths)
#
# Parameters:
#   Totals:      168,551 cases and 7,369 deaths at end of 2020-05-08
#   Smoothed:    168,551 cases and 7,369 deaths at end of 2020-05-08 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-08, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=1.7, d_cases=1.2).analyse()
# Out:
# Belgium data to end of 2020-05-11:
#   53,449 cases, 8,707 deaths
#   4,679 cases per million, 762 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         76% through outbreak
#   Start:       2020-03-04 (-68 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-29 days, 1,454 cases)
#   End:         2020-05-27 ( 17 days, 46 days after peak cases)
#   Day Zero:    2020-03-21 (-51 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-28 days, 336 deaths)
#
# Parameters:
#   Totals:      52,011 cases and 8,521 deaths at end of 2020-05-08
#   Smoothed:    52,011 cases and 8,521 deaths at end of 2020-05-08 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-08, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=1, d_cases=1.7).analyse()
# Out:
# Ireland data to end of 2020-05-11:
#   23,135 cases, 1,467 deaths
#   4,767 cases per million, 302 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         67% through outbreak
#   Start:       2020-03-11 (-61 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-29 days, 902 cases)
#   End:         2020-06-04 ( 25 days, 54 days after peak cases)
#   Day Zero:    2020-03-30 (-42 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-19 days, 71 deaths)
#
# Parameters:
#   Totals:      22,541 cases and 1,429 deaths at end of 2020-05-08
#   Smoothed:    22,541 cases and 1,429 deaths at end of 2020-05-08 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-08, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=1, d_cases=1.2).analyse()
# Out:
# Sweden data to end of 2020-05-11:
#   26,670 cases, 3,256 deaths
#   2,619 cases per million, 320 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         61% through outbreak
#   Start:       2020-03-04 (-68 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 (-19 days, 625 cases)
#   End:         2020-06-18 ( 39 days, 58 days after peak cases)
#   Day Zero:    2020-03-25 (-47 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-20 days, 110 deaths)
#
# Parameters:
#   Totals:      25,265 cases and 3,175 deaths at end of 2020-05-08
#   Smoothed:    25,265 cases and 3,175 deaths at end of 2020-05-08 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-08, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...
