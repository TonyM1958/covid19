# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=3.4, d_cases=3).analyse(ylog=1)
# Out:
# United Kingdom data to end of 2020-05-14:
#   233,151 cases, 33,614 deaths
#   3,507 cases per million, 506 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         58% through outbreak
#   Start:       2020-03-02 (-73 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-33 days, 5,530 cases)
#   End:         2020-06-29 ( 47 days, 80 days after peak cases)
#   Day Zero:    2020-03-16 (-59 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-33 days, 936 deaths)
#
# Parameters:
#   Totals:      223,060 cases and 32,065 deaths at end of 2020-05-11
#   Smoothed:    223,060 cases and 32,064 deaths at end of 2020-05-11 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-11, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=3.5, d_cases=3).analyse(ylog=0)
# note: ECDC cases data differs from Worldometer due to anti-body tests
# Out:
# Spain data to end of 2020-05-12:
#   228,691 cases, 27,104 deaths
#   4,895 cases per million, 580 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         85% through outbreak
#   Start:       2020-02-28 (-74 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-46 days, 7,954 cases)
#   End:         2020-05-21 ( 10 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-62 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-42 days, 869 deaths)
#
# Parameters:
#   Totals:      227,377 cases and 26,621 deaths at end of 2020-05-09
#   Smoothed:    227,377 cases and 26,621 deaths at end of 2020-05-09 (7 points)
#   Spread:      Peak infection rate 12.3 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-09, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=2.4, d_cases=3).analyse()
# Out:
# Italy data to end of 2020-05-13:
#   222,104 cases, 33,106 deaths
#   3,675 cases per million, 548 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         85% through outbreak
#   Start:       2020-02-21 (-82 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-51 days, 5,643 cases)
#   End:         2020-05-23 ( 11 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-72 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-44 days, 814 deaths)
#
# Parameters:
#   Totals:      219,070 cases and 30,560 deaths at end of 2020-05-10
#   Smoothed:    219,069 cases and 30,560 deaths at end of 2020-05-10 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-10, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=3, d_cases=3.3).analyse()
# Out:
# France data to end of 2020-05-13:
#   140,734 cases, 27,074 deaths
#   2,101 cases per million, 404 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         78% through outbreak
#   Start:       2020-02-27 (-76 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-45 days, 4,531 cases)
#   End:         2020-05-29 ( 17 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-63 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-37 days, 1,095 deaths)
#
# Parameters:
#   Totals:      139,063 cases and 26,380 deaths at end of 2020-05-10
#   Smoothed:    139,063 cases and 26,379 deaths at end of 2020-05-10 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.4 (2020-05-10, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1.5, d_cases=2.6).analyse()
# Out:
# Germany data to end of 2020-05-13:
#   172,239 cases, 7,723 deaths
#   2,077 cases per million, 93 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         72% through outbreak
#   Start:       2020-02-27 (-76 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-42 days, 5,587 cases)
#   End:         2020-06-07 ( 26 days, 68 days after peak cases)
#   Day Zero:    2020-03-20 (-54 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-26 days, 231 deaths)
#
# Parameters:
#   Totals:      169,575 cases and 7,417 deaths at end of 2020-05-10
#   Smoothed:    169,575 cases and 7,417 deaths at end of 2020-05-10 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-10, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=1.7, d_cases=1.2).analyse()
# Out:
# Belgium data to end of 2020-05-13:
#   53,981 cases, 8,843 deaths
#   4,726 cases per million, 774 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         79% through outbreak
#   Start:       2020-03-04 (-70 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-31 days, 1,458 cases)
#   End:         2020-05-27 ( 15 days, 46 days after peak cases)
#   Day Zero:    2020-03-21 (-53 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-30 days, 334 deaths)
#
# Parameters:
#   Totals:      53,081 cases and 8,656 deaths at end of 2020-05-10
#   Smoothed:    53,080 cases and 8,656 deaths at end of 2020-05-10 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-10, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=1.2, d_cases=1.8).analyse()
# Out:
# Ireland data to end of 2020-05-13:
#   23,401 cases, 1,497 deaths
#   4,821 cases per million, 308 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         67% through outbreak
#   Start:       2020-03-11 (-63 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-31 days, 906 cases)
#   End:         2020-06-07 ( 26 days, 57 days after peak cases)
#   Day Zero:    2020-03-30 (-44 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-21 days, 70 deaths)
#
# Parameters:
#   Totals:      22,996 cases and 1,458 deaths at end of 2020-05-10
#   Smoothed:    22,996 cases and 1,458 deaths at end of 2020-05-10 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-10, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=1.6, d_cases=1.5).analyse()
# Out:
# Sweden data to end of 2020-05-13:
#   27,909 cases, 3,460 deaths
#   2,741 cases per million, 340 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         55% through outbreak
#   Start:       2020-03-04 (-70 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 (-21 days, 623 cases)
#   End:         2020-07-03 ( 52 days, 73 days after peak cases)
#   Day Zero:    2020-03-25 (-49 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-22 days, 107 deaths)
#
# Parameters:
#   Totals:      26,322 cases and 3,225 deaths at end of 2020-05-10
#   Smoothed:    26,321 cases and 3,225 deaths at end of 2020-05-10 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-10, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...
