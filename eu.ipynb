# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=3, d_cases=3.5).analyse(ylog=1)
# Out:
# United Kingdom data to end of 2020-05-25:
#   261,184 cases, 36,914 deaths
#   3,928 cases per million, 555 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         68% through outbreak
#   Start:       2020-03-02 (-84 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-44 days, 5,516 cases)
#   End:         2020-06-29 ( 36 days, 80 days after peak cases)
#   Day Zero:    2020-03-15 (-71 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-44 days, 946 deaths)
#
# Parameters:
#   Totals:      254,195 cases and 36,393 deaths at end of 2020-05-22
#   Smoothed:    254,195 cases and 36,393 deaths at end of 2020-05-22 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-22, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=4).analyse(ylog=1)
# Out:
# Spain data to end of 2020-05-23:
#   235,772 cases, 28,752 deaths
#   5,046 cases per million, 615 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-28 (-85 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-57 days, 7,883 cases)
#   End:         2020-05-21 ( -1 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-73 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-53 days, 860 deaths)
#
# Parameters:
#   Totals:      233,037 cases and 27,940 deaths at end of 2020-05-20
#   Smoothed:    233,036 cases and 27,940 deaths at end of 2020-05-20 (7 points)
#   Spread:      Peak infection rate 12.3 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-20, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=3.3, d_cases=3).analyse()
# Out:
# Italy data to end of 2020-05-24:
#   229,858 cases, 32,785 deaths
#   3,804 cases per million, 543 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-21 (-93 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-62 days, 5,644 cases)
#   End:         2020-05-23 (  0 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-83 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-55 days, 823 deaths)
#
# Parameters:
#   Totals:      228,006 cases and 32,486 deaths at end of 2020-05-21
#   Smoothed:    228,005 cases and 32,486 deaths at end of 2020-05-21 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-21, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=3.1, d_cases=3.3).analyse()
# Out:
# France data to end of 2020-05-24:
#   144,921 cases, 28,367 deaths
#   2,163 cases per million, 423 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         90% through outbreak
#   Start:       2020-02-27 (-87 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-56 days, 4,539 cases)
#   End:         2020-05-29 (  6 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-74 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-48 days, 1,102 deaths)
#
# Parameters:
#   Totals:      144,163 cases and 28,215 deaths at end of 2020-05-21
#   Smoothed:    144,162 cases and 28,214 deaths at end of 2020-05-21 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-21, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1.8, d_cases=3.3).analyse()
# Out:
# Germany data to end of 2020-05-24:
#   178,570 cases, 8,257 deaths
#   2,153 cases per million, 100 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         82% through outbreak
#   Start:       2020-02-27 (-87 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-53 days, 5,598 cases)
#   End:         2020-06-07 ( 15 days, 68 days after peak cases)
#   Day Zero:    2020-03-20 (-65 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-37 days, 233 deaths)
#
# Parameters:
#   Totals:      177,212 cases and 8,174 deaths at end of 2020-05-21
#   Smoothed:    177,212 cases and 8,174 deaths at end of 2020-05-21 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-21, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=2.2, d_cases=1.8).analyse()
# Out:
# Belgium data to end of 2020-05-24:
#   57,092 cases, 9,280 deaths
#   4,998 cases per million, 812 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         72% through outbreak
#   Start:       2020-03-04 (-81 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-42 days, 1,452 cases)
#   End:         2020-06-20 ( 28 days, 70 days after peak cases)
#   Day Zero:    2020-03-21 (-64 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-41 days, 334 deaths)
#
# Parameters:
#   Totals:      56,235 cases and 9,186 deaths at end of 2020-05-21
#   Smoothed:    56,235 cases and 9,185 deaths at end of 2020-05-21 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-21, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=2.4, d_cases=2.6).analyse()
# Out:
# Ireland data to end of 2020-05-24:
#   24,639 cases, 1,608 deaths
#   5,077 cases per million, 331 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         74% through outbreak
#   Start:       2020-03-11 (-74 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-42 days, 903 cases)
#   End:         2020-06-14 ( 22 days, 64 days after peak cases)
#   Day Zero:    2020-03-30 (-55 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-32 days, 70 deaths)
#
# Parameters:
#   Totals:      24,391 cases and 1,583 deaths at end of 2020-05-21
#   Smoothed:    24,390 cases and 1,583 deaths at end of 2020-05-21 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-21, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=2.3).analyse()
# Out:
# Sweden data to end of 2020-05-24:
#   33,459 cases, 3,998 deaths
#   3,286 cases per million, 393 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         53% through outbreak
#   Start:       2020-03-04 (-81 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 (-32 days, 625 cases)
#   End:         2020-07-28 ( 66 days, 98 days after peak cases)
#   Day Zero:    2020-03-25 (-60 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-33 days, 108 deaths)
#
# Parameters:
#   Totals:      32,172 cases and 3,871 deaths at end of 2020-05-21
#   Smoothed:    32,171 cases and 3,871 deaths at end of 2020-05-21 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-21, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...
