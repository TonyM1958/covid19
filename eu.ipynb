# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://coronavirus.data.gov.uk/">coronavirus.data.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=2.7, d_cases=6).analyse()
# Out:
# United Kingdom data to end of 2020-05-06:
#   201,201 cases, 30,076 deaths
#   3,026 cases per million, 452 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         52% through outbreak
#   Start:       2020-03-02 (-65 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-25 days, 5,527 cases)
#   End:         2020-06-29 ( 55 days, 80 days after peak cases)
#   Day Zero:    2020-03-15 (-52 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-25 days, 943 deaths)
#
# Parameters:
#   Totals:      186,599 cases and 28,446 deaths at end of 2020-05-03
#   Smoothed:    186,599 cases and 28,446 deaths at end of 2020-05-03 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-03, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=2.7).analyse()
# note: ECDC cases data differs from Worldometer due to anti-body tests
# Out:
# Spain data to end of 2020-05-05:
#   220,325 cases, 25,857 deaths
#   4,715 cases per million, 553 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         75% through outbreak
#   Start:       2020-02-29 (-66 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-28 (-38 days, 7,830 cases)
#   End:         2020-05-22 ( 18 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-55 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-35 days, 869 deaths)
#
# Parameters:
#   Totals:      217,466 cases and 25,264 deaths at end of 2020-05-02
#   Smoothed:    217,466 cases and 25,264 deaths at end of 2020-05-02 (7 points)
#   Spread:      Peak infection rate 14.6 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-02, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=2.7).analyse()
# Out:
# Italy data to end of 2020-05-06:
#   214,457 cases, 29,684 deaths
#   3,549 cases per million, 491 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         77% through outbreak
#   Start:       2020-02-21 (-75 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-44 days, 5,654 cases)
#   End:         2020-05-23 ( 18 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-65 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-37 days, 823 deaths)
#
# Parameters:
#   Totals:      210,717 cases and 28,884 deaths at end of 2020-05-03
#   Smoothed:    210,716 cases and 28,884 deaths at end of 2020-05-03 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-03, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=2.8, d_cases=3.3).analyse()
# Out:
# France data to end of 2020-05-06:
#   137,150 cases, 25,809 deaths
#   2,047 cases per million, 385 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         71% through outbreak
#   Start:       2020-02-27 (-69 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-38 days, 4,512 cases)
#   End:         2020-05-29 ( 24 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-56 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-30 days, 1,095 deaths)
#
# Parameters:
#   Totals:      131,287 cases and 24,895 deaths at end of 2020-05-03
#   Smoothed:    131,286 cases and 24,895 deaths at end of 2020-05-03 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-03, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1.4, d_cases=2.5).analyse()
# Out:
# Germany data to end of 2020-05-06:
#   166,091 cases, 7,119 deaths
#   2,003 cases per million, 86 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         65% through outbreak
#   Start:       2020-02-27 (-69 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-35 days, 5,600 cases)
#   End:         2020-06-07 ( 33 days, 68 days after peak cases)
#   Day Zero:    2020-03-20 (-47 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-19 days, 231 deaths)
#
# Parameters:
#   Totals:      163,175 cases and 6,692 deaths at end of 2020-05-03
#   Smoothed:    163,175 cases and 6,692 deaths at end of 2020-05-03 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-03, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=1.6, d_cases=0.9).analyse()
# Out:
# Belgium data to end of 2020-05-06:
#   50,781 cases, 8,339 deaths
#   4,446 cases per million, 730 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         77% through outbreak
#   Start:       2020-03-04 (-63 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-24 days, 1,456 cases)
#   End:         2020-05-20 ( 15 days, 39 days after peak cases)
#   Day Zero:    2020-03-21 (-46 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-23 days, 332 deaths)
#
# Parameters:
#   Totals:      49,906 cases and 7,844 deaths at end of 2020-05-03
#   Smoothed:    49,906 cases and 7,844 deaths at end of 2020-05-03 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-03, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=1.1, d_cases=2.2).analyse()
# Out:
# Ireland data to end of 2020-05-06:
#   22,248 cases, 1,375 deaths
#   4,584 cases per million, 283 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         55% through outbreak
#   Start:       2020-03-11 (-56 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-24 days, 906 cases)
#   End:         2020-06-14 ( 40 days, 64 days after peak cases)
#   Day Zero:    2020-03-30 (-37 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-14 days, 70 deaths)
#
# Parameters:
#   Totals:      21,506 cases and 1,303 deaths at end of 2020-05-03
#   Smoothed:    21,506 cases and 1,303 deaths at end of 2020-05-03 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-03, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=1.2).analyse()
# Out:
# Sweden data to end of 2020-05-06:
#   23,918 cases, 2,941 deaths
#   2,349 cases per million, 289 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         56% through outbreak
#   Start:       2020-03-04 (-63 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 (-14 days, 620 cases)
#   End:         2020-06-18 ( 44 days, 58 days after peak cases)
#   Day Zero:    2020-03-25 (-42 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-15 days, 105 deaths)
#
# Parameters:
#   Totals:      22,317 cases and 2,679 deaths at end of 2020-05-03
#   Smoothed:    22,317 cases and 2,679 deaths at end of 2020-05-03 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-03, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...
