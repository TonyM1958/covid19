# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://coronavirus.data.gov.uk/">coronavirus.data.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=3.1, d_cases=5.5).analyse(ylog=1)
# Out:
# United Kingdom data to end of 2020-05-09:
#   215,260 cases, 31,587 deaths
#   3,238 cases per million, 475 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         54% through outbreak
#   Start:       2020-03-02 (-68 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-28 days, 5,525 cases)
#   End:         2020-06-29 ( 52 days, 80 days after peak cases)
#   Day Zero:    2020-03-15 (-55 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-28 days, 945 deaths)
#
# Parameters:
#   Totals:      201,201 cases and 30,076 deaths at end of 2020-05-06
#   Smoothed:    201,200 cases and 30,075 deaths at end of 2020-05-06 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-06, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=3.2).analyse()
# note: ECDC cases data differs from Worldometer due to anti-body tests
# Out:
# Spain data to end of 2020-05-07:
#   222,857 cases, 26,251 deaths
#   4,770 cases per million, 562 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         77% through outbreak
#   Start:       2020-02-29 (-68 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-28 (-40 days, 7,817 cases)
#   End:         2020-05-22 ( 16 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-57 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-37 days, 867 deaths)
#
# Parameters:
#   Totals:      219,329 cases and 25,613 deaths at end of 2020-05-04
#   Smoothed:    219,329 cases and 25,613 deaths at end of 2020-05-04 (7 points)
#   Spread:      Peak infection rate 14.6 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-04, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=3.4).analyse()
# Out:
# Italy data to end of 2020-05-08:
#   217,185 cases, 30,201 deaths
#   3,594 cases per million, 500 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         80% through outbreak
#   Start:       2020-02-21 (-77 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-46 days, 5,638 cases)
#   End:         2020-05-23 ( 16 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-67 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-39 days, 819 deaths)
#
# Parameters:
#   Totals:      213,013 cases and 29,315 deaths at end of 2020-05-05
#   Smoothed:    213,012 cases and 29,315 deaths at end of 2020-05-05 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-05, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=2.8, d_cases=3.6).analyse()
# Out:
# France data to end of 2020-05-08:
#   138,421 cases, 26,230 deaths
#   2,066 cases per million, 392 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         73% through outbreak
#   Start:       2020-02-27 (-71 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-40 days, 4,490 cases)
#   End:         2020-05-29 ( 22 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-58 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-32 days, 1,103 deaths)
#
# Parameters:
#   Totals:      132,967 cases and 25,531 deaths at end of 2020-05-05
#   Smoothed:    132,967 cases and 25,530 deaths at end of 2020-05-05 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-05, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1.5, d_cases=2.7).analyse()
# Out:
# Germany data to end of 2020-05-08:
#   168,551 cases, 7,369 deaths
#   2,032 cases per million, 89 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         67% through outbreak
#   Start:       2020-02-27 (-71 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-37 days, 5,585 cases)
#   End:         2020-06-07 ( 31 days, 68 days after peak cases)
#   Day Zero:    2020-03-20 (-49 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-21 days, 233 deaths)
#
# Parameters:
#   Totals:      164,897 cases and 6,996 deaths at end of 2020-05-05
#   Smoothed:    164,897 cases and 6,996 deaths at end of 2020-05-05 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-05, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=2, d_cases=1.1).analyse()
# Out:
# Belgium data to end of 2020-05-08:
#   52,011 cases, 8,521 deaths
#   4,554 cases per million, 746 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         77% through outbreak
#   Start:       2020-03-04 (-65 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-26 days, 1,449 cases)
#   End:         2020-05-23 ( 16 days, 42 days after peak cases)
#   Day Zero:    2020-03-21 (-48 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-25 days, 329 deaths)
#
# Parameters:
#   Totals:      50,509 cases and 8,016 deaths at end of 2020-05-05
#   Smoothed:    50,509 cases and 8,015 deaths at end of 2020-05-05 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-05, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=1.4, d_cases=2.2).analyse()
# Out:
# Ireland data to end of 2020-05-08:
#   22,541 cases, 1,429 deaths
#   4,644 cases per million, 294 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         57% through outbreak
#   Start:       2020-03-11 (-58 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-26 days, 905 cases)
#   End:         2020-06-14 ( 38 days, 64 days after peak cases)
#   Day Zero:    2020-03-30 (-39 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-16 days, 70 deaths)
#
# Parameters:
#   Totals:      21,983 cases and 1,339 deaths at end of 2020-05-05
#   Smoothed:    21,982 cases and 1,339 deaths at end of 2020-05-05 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-05, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=1.4).analyse()
# Out:
# Sweden data to end of 2020-05-08:
#   25,265 cases, 3,175 deaths
#   2,481 cases per million, 312 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         53% through outbreak
#   Start:       2020-03-04 (-65 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 (-16 days, 616 cases)
#   End:         2020-06-28 ( 52 days, 68 days after peak cases)
#   Day Zero:    2020-03-25 (-44 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-17 days, 107 deaths)
#
# Parameters:
#   Totals:      23,216 cases and 2,854 deaths at end of 2020-05-05
#   Smoothed:    23,216 cases and 2,853 deaths at end of 2020-05-05 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-05, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...
