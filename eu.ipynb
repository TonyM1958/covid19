# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://coronavirus.data.gov.uk/">coronavirus.data.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=2.3, d_cases=3.5).analyse()
# Out:
# United Kingdom data to end of 2020-05-04:
#   190,584 cases, 28,734 deaths
#   2,866 cases per million, 432 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         50% through outbreak
#   Start:       2020-03-02 (-63 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-23 days, 5,553 cases)
#   End:         2020-06-29 ( 57 days, 80 days after peak cases)
#   Day Zero:    2020-03-15 (-50 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-23 days, 951 deaths)
#
# Parameters:
#   Totals:      177,454 cases and 27,510 deaths at end of 2020-05-01
#   Smoothed:    177,454 cases and 27,510 deaths at end of 2020-05-01 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-01, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=2.5, d_cases=2).analyse()
# note: ECDC cases data differs from Worldometer due to anti-body tests
# Out:
# Spain data to end of 2020-05-04:
#   218,011 cases, 25,428 deaths
#   4,666 cases per million, 544 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         73% through outbreak
#   Start:       2020-02-29 (-64 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-28 (-36 days, 7,832 cases)
#   End:         2020-05-23 ( 20 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-53 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-33 days, 871 deaths)
#
# Parameters:
#   Totals:      215,216 cases and 24,824 deaths at end of 2020-04-30
#   Smoothed:    215,216 cases and 24,823 deaths at end of 2020-04-30 (7 points)
#   Spread:      Peak infection rate 14.6 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-04-30, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=2.9).analyse()
# Out:
# Italy data to end of 2020-05-04:
#   211,938 cases, 29,079 deaths
#   3,507 cases per million, 481 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         75% through outbreak
#   Start:       2020-02-21 (-73 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-42 days, 5,651 cases)
#   End:         2020-05-23 ( 20 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-63 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-35 days, 821 deaths)
#
# Parameters:
#   Totals:      207,428 cases and 28,236 deaths at end of 2020-05-01
#   Smoothed:    207,427 cases and 28,236 deaths at end of 2020-05-01 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-01, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=2.5, d_cases=2).analyse()
# Out:
# France data to end of 2020-05-04:
#   131,863 cases, 25,201 deaths
#   1,968 cases per million, 376 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         69% through outbreak
#   Start:       2020-02-27 (-67 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-36 days, 4,547 cases)
#   End:         2020-05-29 ( 26 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-54 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-28 days, 1,105 deaths)
#
# Parameters:
#   Totals:      130,185 cases and 24,594 deaths at end of 2020-05-01
#   Smoothed:    130,184 cases and 24,594 deaths at end of 2020-05-01 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-01, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1, d_cases=2).analyse()
# Out:
# Germany data to end of 2020-05-04:
#   163,860 cases, 6,831 deaths
#   1,976 cases per million, 82 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         63% through outbreak
#   Start:       2020-02-27 (-67 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-33 days, 5,619 cases)
#   End:         2020-06-07 ( 35 days, 68 days after peak cases)
#   Day Zero:    2020-03-20 (-45 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-17 days, 236 deaths)
#
# Parameters:
#   Totals:      161,703 cases and 6,575 deaths at end of 2020-05-01
#   Smoothed:    161,702 cases and 6,575 deaths at end of 2020-05-01 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-01, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=1.3, d_cases=0.9).analyse()
# Out:
# Belgium data to end of 2020-05-04:
#   50,267 cases, 7,924 deaths
#   4,401 cases per million, 694 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         74% through outbreak
#   Start:       2020-03-04 (-61 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-22 days, 1,456 cases)
#   End:         2020-05-20 ( 17 days, 39 days after peak cases)
#   Day Zero:    2020-03-21 (-44 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-21 days, 335 deaths)
#
# Parameters:
#   Totals:      49,032 cases and 7,703 deaths at end of 2020-05-01
#   Smoothed:    49,032 cases and 7,703 deaths at end of 2020-05-01 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-01, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=1, d_cases=2.2).analyse()
# Out:
# Ireland data to end of 2020-05-04:
#   21,722 cases, 1,319 deaths
#   4,476 cases per million, 272 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         53% through outbreak
#   Start:       2020-03-11 (-54 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-22 days, 902 cases)
#   End:         2020-06-14 ( 42 days, 64 days after peak cases)
#   Day Zero:    2020-03-30 (-35 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-12 days, 71 deaths)
#
# Parameters:
#   Totals:      20,833 cases and 1,265 deaths at end of 2020-05-01
#   Smoothed:    20,832 cases and 1,264 deaths at end of 2020-05-01 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-01, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=0.8).analyse()
# Out:
# Sweden data to end of 2020-05-04:
#   22,721 cases, 2,769 deaths
#   2,231 cases per million, 272 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         59% through outbreak
#   Start:       2020-03-04 (-61 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 (-12 days, 626 cases)
#   End:         2020-06-09 ( 37 days, 49 days after peak cases)
#   Day Zero:    2020-03-25 (-40 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-13 days, 110 deaths)
#
# Parameters:
#   Totals:      21,520 cases and 2,653 deaths at end of 2020-05-01
#   Smoothed:    21,520 cases and 2,653 deaths at end of 2020-05-01 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-01, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...
