# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=3.4, d_cases=3.1).analyse(ylog=1)
# Out:
# United Kingdom data to end of 2020-05-15:
#   236,711 cases, 33,998 deaths
#   3,560 cases per million, 511 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         59% through outbreak
#   Start:       2020-03-02 (-74 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-34 days, 5,525 cases)
#   End:         2020-06-29 ( 46 days, 80 days after peak cases)
#   Day Zero:    2020-03-15 (-61 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-34 days, 943 deaths)
#
# Parameters:
#   Totals:      226,463 cases and 32,692 deaths at end of 2020-05-12
#   Smoothed:    226,462 cases and 32,692 deaths at end of 2020-05-12 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-12, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=3.8, d_cases=3.3).analyse(ylog=1)
# note: ECDC cases data differs from Worldometer due to anti-body tests
# Out:
# Spain data to end of 2020-05-13:
#   229,540 cases, 27,321 deaths
#   4,913 cases per million, 585 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         86% through outbreak
#   Start:       2020-02-28 (-75 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-47 days, 7,930 cases)
#   End:         2020-05-21 (  9 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-63 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-43 days, 867 deaths)
#
# Parameters:
#   Totals:      227,770 cases and 26,744 deaths at end of 2020-05-10
#   Smoothed:    227,770 cases and 26,744 deaths at end of 2020-05-10 (7 points)
#   Spread:      Peak infection rate 12.3 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-10, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=2.9, d_cases=3.5).analyse()
# Out:
# Italy data to end of 2020-05-14:
#   223,096 cases, 31,368 deaths
#   3,692 cases per million, 519 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         86% through outbreak
#   Start:       2020-02-21 (-83 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-52 days, 5,636 cases)
#   End:         2020-05-23 ( 10 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-73 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-45 days, 821 deaths)
#
# Parameters:
#   Totals:      219,814 cases and 30,739 deaths at end of 2020-05-11
#   Smoothed:    219,813 cases and 30,739 deaths at end of 2020-05-11 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-11, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=3.3, d_cases=3.5).analyse()
# Out:
# France data to end of 2020-05-14:
#   141,356 cases, 27,425 deaths
#   2,110 cases per million, 409 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         80% through outbreak
#   Start:       2020-02-27 (-77 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-46 days, 4,529 cases)
#   End:         2020-05-29 ( 16 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-64 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-38 days, 1,098 deaths)
#
# Parameters:
#   Totals:      139,519 cases and 26,643 deaths at end of 2020-05-11
#   Smoothed:    139,518 cases and 26,642 deaths at end of 2020-05-11 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.4 (2020-05-11, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1.7, d_cases=3).analyse()
# Out:
# Germany data to end of 2020-05-14:
#   173,152 cases, 7,824 deaths
#   2,088 cases per million, 94 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         73% through outbreak
#   Start:       2020-02-27 (-77 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-43 days, 5,591 cases)
#   End:         2020-06-07 ( 25 days, 68 days after peak cases)
#   Day Zero:    2020-03-20 (-55 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-27 days, 232 deaths)
#
# Parameters:
#   Totals:      170,508 cases and 7,533 deaths at end of 2020-05-11
#   Smoothed:    170,508 cases and 7,533 deaths at end of 2020-05-11 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-11, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=1.9, d_cases=1.2).analyse()
# Out:
# Belgium data to end of 2020-05-14:
#   54,288 cases, 8,903 deaths
#   4,753 cases per million, 779 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         80% through outbreak
#   Start:       2020-03-04 (-71 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-32 days, 1,457 cases)
#   End:         2020-05-27 ( 14 days, 46 days after peak cases)
#   Day Zero:    2020-03-21 (-54 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-31 days, 333 deaths)
#
# Parameters:
#   Totals:      53,449 cases and 8,707 deaths at end of 2020-05-11
#   Smoothed:    53,448 cases and 8,707 deaths at end of 2020-05-11 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-11, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=1.3, d_cases=2).analyse()
# Out:
# Ireland data to end of 2020-05-14:
#   23,827 cases, 1,506 deaths
#   4,909 cases per million, 310 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         64% through outbreak
#   Start:       2020-03-11 (-64 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-32 days, 904 cases)
#   End:         2020-06-14 ( 32 days, 64 days after peak cases)
#   Day Zero:    2020-03-30 (-45 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-22 days, 70 deaths)
#
# Parameters:
#   Totals:      23,135 cases and 1,467 deaths at end of 2020-05-11
#   Smoothed:    23,135 cases and 1,467 deaths at end of 2020-05-11 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-11, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=2).analyse()
# Out:
# Sweden data to end of 2020-05-14:
#   28,582 cases, 3,529 deaths
#   2,807 cases per million, 347 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         46% through outbreak
#   Start:       2020-03-04 (-71 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 (-22 days, 618 cases)
#   End:         2020-07-28 ( 76 days, 98 days after peak cases)
#   Day Zero:    2020-03-25 (-50 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-23 days, 106 deaths)
#
# Parameters:
#   Totals:      26,670 cases and 3,256 deaths at end of 2020-05-11
#   Smoothed:    26,670 cases and 3,256 deaths at end of 2020-05-11 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-11, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...
