# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://coronavirus.data.gov.uk/">coronavirus.data.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=3, d_cases=7).analyse(ylog=1)
# Out:
# United Kingdom data to end of 2020-05-07:
#   206,715 cases, 30,615 deaths
#   3,109 cases per million, 460 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         53% through outbreak
#   Start:       2020-03-02 (-66 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-26 days, 5,495 cases)
#   End:         2020-06-29 ( 54 days, 80 days after peak cases)
#   Day Zero:    2020-03-16 (-52 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-26 days, 935 deaths)
#
# Parameters:
#   Totals:      190,584 cases and 28,734 deaths at end of 2020-05-04
#   Smoothed:    190,584 cases and 28,733 deaths at end of 2020-05-04 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-04, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=3).analyse()
# note: ECDC cases data differs from Worldometer due to anti-body tests
# Out:
# Spain data to end of 2020-05-06:
#   221,447 cases, 26,070 deaths
#   4,739 cases per million, 558 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         76% through outbreak
#   Start:       2020-02-29 (-67 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-28 (-39 days, 7,809 cases)
#   End:         2020-05-22 ( 17 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-56 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-36 days, 867 deaths)
#
# Parameters:
#   Totals:      218,011 cases and 25,428 deaths at end of 2020-05-03
#   Smoothed:    218,011 cases and 25,428 deaths at end of 2020-05-03 (7 points)
#   Spread:      Peak infection rate 14.6 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-03, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=3).analyse()
# Out:
# Italy data to end of 2020-05-07:
#   215,858 cases, 29,958 deaths
#   3,572 cases per million, 496 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         78% through outbreak
#   Start:       2020-02-21 (-76 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-45 days, 5,647 cases)
#   End:         2020-05-23 ( 17 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-66 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-38 days, 820 deaths)
#
# Parameters:
#   Totals:      211,938 cases and 29,079 deaths at end of 2020-05-04
#   Smoothed:    211,937 cases and 29,079 deaths at end of 2020-05-04 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-04, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=2.7, d_cases=3.5).analyse()
# Out:
# France data to end of 2020-05-07:
#   137,779 cases, 25,987 deaths
#   2,057 cases per million, 388 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         72% through outbreak
#   Start:       2020-02-27 (-70 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-39 days, 4,492 cases)
#   End:         2020-05-29 ( 23 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-57 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-31 days, 1,099 deaths)
#
# Parameters:
#   Totals:      131,863 cases and 25,201 deaths at end of 2020-05-04
#   Smoothed:    131,862 cases and 25,201 deaths at end of 2020-05-04 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-04, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1.5, d_cases=2.6).analyse()
# Out:
# Germany data to end of 2020-05-07:
#   167,300 cases, 7,266 deaths
#   2,017 cases per million, 88 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         66% through outbreak
#   Start:       2020-02-27 (-70 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-36 days, 5,583 cases)
#   End:         2020-06-07 ( 32 days, 68 days after peak cases)
#   Day Zero:    2020-03-20 (-48 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-20 days, 231 deaths)
#
# Parameters:
#   Totals:      163,860 cases and 6,831 deaths at end of 2020-05-04
#   Smoothed:    163,859 cases and 6,831 deaths at end of 2020-05-04 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-04, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=1.8, d_cases=1).analyse()
# Out:
# Belgium data to end of 2020-05-07:
#   51,420 cases, 8,415 deaths
#   4,502 cases per million, 737 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         78% through outbreak
#   Start:       2020-03-04 (-64 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-25 days, 1,455 cases)
#   End:         2020-05-20 ( 14 days, 39 days after peak cases)
#   Day Zero:    2020-03-21 (-47 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-24 days, 330 deaths)
#
# Parameters:
#   Totals:      50,267 cases and 7,924 deaths at end of 2020-05-04
#   Smoothed:    50,266 cases and 7,924 deaths at end of 2020-05-04 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-04, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=1.2, d_cases=2.2).analyse()
# Out:
# Ireland data to end of 2020-05-07:
#   22,385 cases, 1,403 deaths
#   4,612 cases per million, 289 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         56% through outbreak
#   Start:       2020-03-11 (-57 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-25 days, 904 cases)
#   End:         2020-06-14 ( 39 days, 64 days after peak cases)
#   Day Zero:    2020-03-30 (-38 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-15 days, 70 deaths)
#
# Parameters:
#   Totals:      21,722 cases and 1,319 deaths at end of 2020-05-04
#   Smoothed:    21,722 cases and 1,319 deaths at end of 2020-05-04 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-04, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=1.2).analyse()
# Out:
# Sweden data to end of 2020-05-07:
#   24,623 cases, 3,040 deaths
#   2,418 cases per million, 299 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         57% through outbreak
#   Start:       2020-03-04 (-64 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 (-15 days, 617 cases)
#   End:         2020-06-18 ( 43 days, 58 days after peak cases)
#   Day Zero:    2020-03-25 (-43 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-16 days, 106 deaths)
#
# Parameters:
#   Totals:      22,721 cases and 2,769 deaths at end of 2020-05-04
#   Smoothed:    22,720 cases and 2,769 deaths at end of 2020-05-04 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-04, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...
