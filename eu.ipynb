# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=0, ylog=1, d_clip=2.5)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=4).analyse(totals=4)
# Out:
# United Kingdom data to end of 2020-10-08:
#   561,815 cases, 42,592 deaths
#   8,430 cases per million, 639 deaths per million (2019 population = 66,647,112)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         29% through outbreak
#   Start:       2020-03-01 (-221 days, when 50 or more cases were reported)
#   Peak Cases:  2020-10-05 ( -3 days, 14,548 cases)
#   End:         2022-04-02 (542 days, 545 days after peak cases)
#   Day Zero:    2020-03-15 (-207 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-10 (-181 days, 942 deaths)
#
# Parameters:
#   Totals:      515,571 cases and 42,369 deaths at end of 2020-10-05
#   Smoothed:    515,571 cases and 42,369 deaths at end of 2020-10-05 (7 points)
#   Spread:      Peak infection rate 6.4 (2020-03-13, compared to 7 days earlier)
#                Latest infection rate 2.3 (2020-10-05, compared to 7 days earlier)
#   Growth:      218 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=2, d_cases=4).analyse(totals=4)
# Out:
# Sweden data to end of 2020-10-08:
#   97,532 cases, 5,892 deaths
#   9,534 cases per million, 576 deaths per million (2019 population = 10,230,185)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         59% through outbreak
#   Start:       2020-03-03 (-219 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-15 (-115 days, 1,087 cases)
#   End:         2021-03-01 (145 days, 260 days after peak cases)
#   Day Zero:    2020-03-22 (-200 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-178 days, 99 deaths)
#
# Parameters:
#   Totals:      96,177 cases and 5,891 deaths at end of 2020-10-05
#   Smoothed:    96,176 cases and 5,890 deaths at end of 2020-10-05 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-10-05, compared to 7 days earlier)
#   Growth:      104 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=4).analyse()
# Out:
# Spain data to end of 2020-10-07:
#   848,324 cases, 32,688 deaths
#   18,074 cases per million, 696 deaths per million (2019 population = 46,937,060)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         31% through outbreak
#   Start:       2020-02-28 (-222 days, when 50 or more cases were reported)
#   Peak Cases:  2020-09-19 (-18 days, 11,316 cases)
#   End:         2022-02-10 (492 days, 510 days after peak cases)
#   Day Zero:    2020-03-11 (-210 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-190 days, 866 deaths)
#
# Parameters:
#   Totals:      813,412 cases and 32,225 deaths at end of 2020-10-04
#   Smoothed:    813,412 cases and 32,225 deaths at end of 2020-10-04 (7 points)
#   Spread:      Peak infection rate 12.3 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-10-04, compared to 7 days earlier)
#   Growth:      204 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=2.2, d_cases=3).analyse()
# Out:
# Italy data to end of 2020-10-08:
#   338,398 cases, 36,083 deaths
#   5,606 cases per million, 598 deaths per million (2019 population = 60,359,546)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-21 (-230 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-199 days, 5,631 cases)
#   End:         2020-06-07 (-122 days, 77 days after peak cases)
#   Day Zero:    2020-03-02 (-220 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-192 days, 822 deaths)
#
# Parameters:
#   Totals:      327,586 cases and 36,002 deaths at end of 2020-10-05
#   Smoothed:    327,585 cases and 36,001 deaths at end of 2020-10-05 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 1.6 (2020-10-05, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=4).analyse()
# Out:
# France data to end of 2020-10-08:
#   671,638 cases, 32,521 deaths
#   10,023 cases per million, 485 deaths per million (2019 population = 67,012,883)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         29% through outbreak
#   Start:       2020-02-27 (-224 days, when 50 or more cases were reported)
#   Peak Cases:  2020-10-05 ( -3 days, 13,357 cases)
#   End:         2022-04-09 (549 days, 552 days after peak cases)
#   Day Zero:    2020-03-11 (-211 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-185 days, 1,100 deaths)
#
# Parameters:
#   Totals:      624,274 cases and 32,299 deaths at end of 2020-10-05
#   Smoothed:    624,274 cases and 32,298 deaths at end of 2020-10-05 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-10-05, compared to 7 days earlier)
#   Growth:      221 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=8).analyse()
# Out:
# Germany data to end of 2020-10-08:
#   314,660 cases, 9,589 deaths
#   3,790 cases per million, 116 deaths per million (2019 population = 83,019,213)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-27 (-224 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-190 days, 5,574 cases)
#   End:         2020-06-24 (-105 days, 85 days after peak cases)
#   Day Zero:    2020-03-20 (-202 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-174 days, 233 deaths)
#
# Parameters:
#   Totals:      303,258 cases and 9,546 deaths at end of 2020-10-05
#   Smoothed:    303,258 cases and 9,546 deaths at end of 2020-10-05 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 1.4 (2020-10-05, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=4).analyse()
# Out:
# Belgium data to end of 2020-10-08:
#   143,503 cases, 10,126 deaths
#   12,527 cases per million, 884 deaths per million (2019 population = 11,455,519)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         29% through outbreak
#   Start:       2020-03-02 (-220 days, when 50 or more cases were reported)
#   Peak Cases:  2020-10-03 ( -5 days, 2,986 cases)
#   End:         2022-03-23 (532 days, 537 days after peak cases)
#   Day Zero:    2020-03-17 (-205 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-10 (-181 days, 285 deaths)
#
# Parameters:
#   Totals:      139,773 cases and 10,091 deaths at end of 2020-10-05
#   Smoothed:    139,772 cases and 10,091 deaths at end of 2020-10-05 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-03-09, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-10-05, compared to 7 days earlier)
#   Growth:      215 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=4).analyse()
# Out:
# Ireland data to end of 2020-10-08:
#   40,086 cases, 1,817 deaths
#   8,174 cases per million, 370 deaths per million (2019 population = 4,904,240)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-11 (-211 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-179 days, 903 cases)
#   End:         2020-06-30 (-99 days, 80 days after peak cases)
#   Day Zero:    2020-03-30 (-192 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-169 days, 70 deaths)
#
# Parameters:
#   Totals:      38,551 cases and 1,810 deaths at end of 2020-10-05
#   Smoothed:    38,551 cases and 1,809 deaths at end of 2020-10-05 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-10-05, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...
