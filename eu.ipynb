# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=2.6, d_cases=4.4).analyse(ylog=1)
# Out:
# United Kingdom data to end of 2020-05-11:
#   223,060 cases, 32,065 deaths
#   3,355 cases per million, 482 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         56% through outbreak
#   Start:       2020-03-02 (-70 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-30 days, 5,548 cases)
#   End:         2020-06-29 ( 50 days, 80 days after peak cases)
#   Day Zero:    2020-03-15 (-57 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-30 days, 951 deaths)
#
# Parameters:
#   Totals:      211,364 cases and 31,241 deaths at end of 2020-05-08
#   Smoothed:    211,364 cases and 31,241 deaths at end of 2020-05-08 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-08, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=2.6, d_cases=2.5).analyse()
# note: ECDC cases data differs from Worldometer due to anti-body tests
# Out:
# Spain data to end of 2020-05-09:
#   224,390 cases, 26,621 deaths
#   4,802 cases per million, 570 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         80% through outbreak
#   Start:       2020-02-29 (-70 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-28 (-42 days, 7,822 cases)
#   End:         2020-05-22 ( 14 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-59 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-39 days, 869 deaths)
#
# Parameters:
#   Totals:      221,447 cases and 26,070 deaths at end of 2020-05-06
#   Smoothed:    221,447 cases and 26,070 deaths at end of 2020-05-06 (7 points)
#   Spread:      Peak infection rate 14.6 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-06, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=2, d_cases=3).analyse()
# Out:
# Italy data to end of 2020-05-10:
#   219,070 cases, 30,560 deaths
#   3,625 cases per million, 506 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         82% through outbreak
#   Start:       2020-02-21 (-79 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-48 days, 5,648 cases)
#   End:         2020-05-23 ( 14 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-69 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-41 days, 824 deaths)
#
# Parameters:
#   Totals:      215,858 cases and 29,958 deaths at end of 2020-05-07
#   Smoothed:    215,857 cases and 29,958 deaths at end of 2020-05-07 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-07, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=2.2, d_cases=2.8).analyse()
# Out:
# France data to end of 2020-05-10:
#   139,063 cases, 26,380 deaths
#   2,076 cases per million, 394 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         75% through outbreak
#   Start:       2020-02-27 (-73 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-42 days, 4,576 cases)
#   End:         2020-05-29 ( 20 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-60 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-34 days, 1,104 deaths)
#
# Parameters:
#   Totals:      137,779 cases and 25,987 deaths at end of 2020-05-07
#   Smoothed:    137,778 cases and 25,986 deaths at end of 2020-05-07 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-05-07, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1.1, d_cases=1.5).analyse()
# Out:
# Germany data to end of 2020-05-10:
#   169,575 cases, 7,417 deaths
#   2,045 cases per million, 89 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         82% through outbreak
#   Start:       2020-02-27 (-73 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-39 days, 5,603 cases)
#   End:         2020-05-21 ( 12 days, 51 days after peak cases)
#   Day Zero:    2020-03-20 (-51 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-23 days, 235 deaths)
#
# Parameters:
#   Totals:      167,300 cases and 7,266 deaths at end of 2020-05-07
#   Smoothed:    167,299 cases and 7,266 deaths at end of 2020-05-07 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-07, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=1.3, d_cases=0.9).analyse()
# Out:
# Belgium data to end of 2020-05-10:
#   53,081 cases, 8,656 deaths
#   4,647 cases per million, 758 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         82% through outbreak
#   Start:       2020-03-04 (-67 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-28 days, 1,450 cases)
#   End:         2020-05-20 ( 11 days, 39 days after peak cases)
#   Day Zero:    2020-03-21 (-50 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-27 days, 336 deaths)
#
# Parameters:
#   Totals:      51,420 cases and 8,415 deaths at end of 2020-05-07
#   Smoothed:    51,419 cases and 8,414 deaths at end of 2020-05-07 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-07, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=0.8, d_cases=1.5).analyse()
# Out:
# Ireland data to end of 2020-05-10:
#   22,996 cases, 1,458 deaths
#   4,738 cases per million, 300 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         71% through outbreak
#   Start:       2020-03-11 (-60 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-28 days, 904 cases)
#   End:         2020-05-29 ( 20 days, 48 days after peak cases)
#   Day Zero:    2020-03-30 (-41 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-18 days, 71 deaths)
#
# Parameters:
#   Totals:      22,385 cases and 1,403 deaths at end of 2020-05-07
#   Smoothed:    22,385 cases and 1,403 deaths at end of 2020-05-07 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-07, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=1.1, d_cases=1.3).analyse()
# Out:
# Sweden data to end of 2020-05-10:
#   26,322 cases, 3,225 deaths
#   2,585 cases per million, 317 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         57% through outbreak
#   Start:       2020-03-04 (-67 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 (-18 days, 623 cases)
#   End:         2020-06-23 ( 45 days, 63 days after peak cases)
#   Day Zero:    2020-03-25 (-46 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-19 days, 108 deaths)
#
# Parameters:
#   Totals:      24,623 cases and 3,040 deaths at end of 2020-05-07
#   Smoothed:    24,623 cases and 3,040 deaths at end of 2020-05-07 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-07, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...
