# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://coronavirus.data.gov.uk/">coronavirus.data.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=3, d_cases=5).analyse(ylog=1)
# Out:
# United Kingdom data to end of 2020-05-10:
#   219,183 cases, 31,855 deaths
#   3,297 cases per million, 479 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         55% through outbreak
#   Start:       2020-03-02 (-69 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-29 days, 5,548 cases)
#   End:         2020-06-29 ( 51 days, 80 days after peak cases)
#   Day Zero:    2020-03-15 (-56 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-29 days, 947 deaths)
#
# Parameters:
#   Totals:      206,715 cases and 30,615 deaths at end of 2020-05-07
#   Smoothed:    206,714 cases and 30,614 deaths at end of 2020-05-07 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-07, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=3.3).analyse()
# note: ECDC cases data differs from Worldometer due to anti-body tests
# Out:
# Spain data to end of 2020-05-08:
#   223,578 cases, 26,478 deaths
#   4,785 cases per million, 567 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         79% through outbreak
#   Start:       2020-02-29 (-69 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-28 (-41 days, 7,817 cases)
#   End:         2020-05-22 ( 15 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-58 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-38 days, 868 deaths)
#
# Parameters:
#   Totals:      220,325 cases and 25,857 deaths at end of 2020-05-05
#   Smoothed:    220,324 cases and 25,857 deaths at end of 2020-05-05 (7 points)
#   Spread:      Peak infection rate 14.6 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-05, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=3.4).analyse()
# Out:
# Italy data to end of 2020-05-09:
#   218,268 cases, 30,395 deaths
#   3,612 cases per million, 503 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         81% through outbreak
#   Start:       2020-02-21 (-78 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-47 days, 5,643 cases)
#   End:         2020-05-23 ( 15 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-68 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-40 days, 823 deaths)
#
# Parameters:
#   Totals:      214,457 cases and 29,684 deaths at end of 2020-05-06
#   Smoothed:    214,456 cases and 29,684 deaths at end of 2020-05-06 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-06, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=2.8, d_cases=3.4).analyse()
# Out:
# France data to end of 2020-05-09:
#   138,854 cases, 26,310 deaths
#   2,073 cases per million, 393 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         74% through outbreak
#   Start:       2020-02-27 (-72 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-41 days, 4,593 cases)
#   End:         2020-05-29 ( 21 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-59 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-33 days, 1,105 deaths)
#
# Parameters:
#   Totals:      137,150 cases and 25,809 deaths at end of 2020-05-06
#   Smoothed:    137,149 cases and 25,808 deaths at end of 2020-05-06 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-06, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1.4, d_cases=2.7).analyse()
# Out:
# Germany data to end of 2020-05-09:
#   169,218 cases, 7,395 deaths
#   2,041 cases per million, 89 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         68% through outbreak
#   Start:       2020-02-27 (-72 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-38 days, 5,593 cases)
#   End:         2020-06-07 ( 30 days, 68 days after peak cases)
#   Day Zero:    2020-03-20 (-50 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-22 days, 233 deaths)
#
# Parameters:
#   Totals:      166,091 cases and 7,119 deaths at end of 2020-05-06
#   Smoothed:    166,091 cases and 7,119 deaths at end of 2020-05-06 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-06, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=1.9, d_cases=1.2).analyse()
# Out:
# Belgium data to end of 2020-05-09:
#   52,596 cases, 8,581 deaths
#   4,605 cases per million, 751 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         74% through outbreak
#   Start:       2020-03-04 (-66 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-27 days, 1,445 cases)
#   End:         2020-05-27 ( 19 days, 46 days after peak cases)
#   Day Zero:    2020-03-21 (-49 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-26 days, 338 deaths)
#
# Parameters:
#   Totals:      50,781 cases and 8,339 deaths at end of 2020-05-06
#   Smoothed:    50,781 cases and 8,338 deaths at end of 2020-05-06 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-06, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=1.4, d_cases=2.2).analyse()
# Out:
# Ireland data to end of 2020-05-09:
#   22,760 cases, 1,446 deaths
#   4,689 cases per million, 298 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         58% through outbreak
#   Start:       2020-03-11 (-59 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-27 days, 907 cases)
#   End:         2020-06-14 ( 37 days, 64 days after peak cases)
#   Day Zero:    2020-03-30 (-40 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-17 days, 70 deaths)
#
# Parameters:
#   Totals:      22,248 cases and 1,375 deaths at end of 2020-05-06
#   Smoothed:    22,248 cases and 1,375 deaths at end of 2020-05-06 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-06, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=1.6).analyse()
# Out:
# Sweden data to end of 2020-05-09:
#   25,921 cases, 3,220 deaths
#   2,545 cases per million, 316 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         50% through outbreak
#   Start:       2020-03-04 (-66 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 (-17 days, 620 cases)
#   End:         2020-07-08 ( 61 days, 78 days after peak cases)
#   Day Zero:    2020-03-25 (-45 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-18 days, 107 deaths)
#
# Parameters:
#   Totals:      23,918 cases and 2,941 deaths at end of 2020-05-06
#   Smoothed:    23,918 cases and 2,941 deaths at end of 2020-05-06 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-06, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...
