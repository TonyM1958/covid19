# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=0, ylog=1, d_clip=2.5)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=5, d_cases=4).analyse(totals=4)
# Out:
# United Kingdom data to end of 2020-07-24:
#   297,914 cases, 45,677 deaths
#   4,470 cases per million, 685 deaths per million (2019 population = 66,647,112)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-02 (-144 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-104 days, 5,517 cases)
#   End:         2020-07-19 ( -4 days, 100 days after peak cases)
#   Day Zero:    2020-03-15 (-131 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-104 days, 943 deaths)
#
# Parameters:
#   Totals:      295,817 cases and 45,422 deaths at end of 2020-07-21
#   Smoothed:    295,816 cases and 45,421 deaths at end of 2020-07-21 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-07-21, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
#                X = 299,666, r = 6.69, L = 22,066, dilation = 4, c = 78.2% for cases
#   Lag:         0 days (Peak Cases -> Peak Deaths)
#                X = 46,189, r = 8.0, L = 3,771, dilation = 5, c = 72.1% for deaths
#
# Outcome: 295,372 total cases, 45,312 total deaths at end of 2020-07-20
#   4,432 cases per million (0.44%), 680 deaths per million (0.068%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-11      820      148     288,953   44,798       717       82     288,864   44,729
# 2020-07-12      650       21     289,603   44,819       704       77     289,568   44,805
# 2020-07-13      530       11     290,133   44,830       704       74     290,272   44,879
# 2020-07-14    1,240      138     291,373   44,968       729       83     291,002   44,962
# 2020-07-15      538       85     291,911   45,053       730       68     291,732   45,030
# 2020-07-16      641       66     292,552   45,119       741       69     292,473   45,099
# 2020-07-17      687      114     293,239   45,233       748       69     293,221   45,168
# 2020-07-18      827       40     294,066   45,273       635       65     293,856   45,232
# 2020-07-19      726       27     294,792   45,300       638       64     294,493   45,296
# 2020-07-20      580       12     295,372   45,312       656       62     295,149   45,359
# 2020-07-21      445      110     295,817   45,422       668       63     295,817   45,422
# 2020-07-22      560       79     296,377   45,501
# 2020-07-23      769       53     297,146   45,554
# 2020-07-24      768      123     297,914   45,677
#
#   ** first wave ended **

# %%
covid.Region(geoId='SE', dilation=2, d_cases=2).analyse(totals=4)
# Out:
# Sweden data to end of 2020-07-24:
#   78,997 cases, 5,697 deaths
#   7,722 cases per million, 557 deaths per million (2019 population = 10,230,185)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         42% through outbreak
#   Start:       2020-03-04 (-142 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-23 (-31 days, 1,299 cases)
#   End:         2021-01-30 (191 days, 222 days after peak cases)
#   Day Zero:    2020-03-25 (-121 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-94 days, 107 deaths)
#
# Parameters:
#   Totals:      78,166 cases and 5,646 deaths at end of 2020-07-21
#   Smoothed:    78,166 cases and 5,645 deaths at end of 2020-07-21 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-07-21, compared to 7 days earlier)
#   Growth:      111 days (Start -> Peak Cases)
#                X = 154,204, r = 4.2, L = 5,197, dilation = 2, c = 50.4% for cases
#   Lag:         -63 days (Peak Cases -> Peak Deaths)
#                X = 5,933, r = 8.0, L = 429, dilation = 2, c = 52.4% for deaths
#
# Outcome: 151,933 total cases, 5,933 total deaths by end of 2021-01-30
#   51.2% of predicted cases and 96.0% of predicted deaths reported to date
#   98.5% of predicted cases and 100.0% of predicted deaths reported by end date
#   15,073 cases per million (1.51%), 580 deaths per million (0.058%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-11        0        0      74,898    5,526       380       14      74,976    5,514
# 2020-07-12        0        0      74,898    5,526       376       13      75,352    5,527
# 2020-07-13      928       10      75,826    5,536       364       13      75,715    5,541
# 2020-07-14      175        9      76,001    5,545       341       13      76,056    5,554
# 2020-07-15      491       27      76,492    5,572       341       13      76,396    5,567
# 2020-07-16      385       21      76,877    5,593       341       13      76,737    5,580
# 2020-07-17      404       26      77,281    5,619       317       15      77,054    5,595
# 2020-07-18        0        0      77,281    5,619       309       14      77,364    5,609
# 2020-07-19        0        0      77,281    5,619       287       14      77,651    5,623
# 2020-07-20      767       20      78,048    5,639       269       12      77,921    5,635
# 2020-07-21      118        7      78,166    5,646       245       11      78,166    5,646
# 2020-07-22      338       21      78,504    5,667
# 2020-07-23      259        9      78,763    5,676
# 2020-07-24      234       21      78,997    5,697
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-07-21      922       10     78,166    5,646
# 2020-07-22      917       10     79,083    5,656
# 2020-07-23      912       10     79,995    5,665
# 2020-07-24      908        9     80,903    5,675  <-- latest raw data
# 2020-07-25      903        9     81,806    5,683
# 2020-07-26      897        9     82,703    5,692
# 2020-07-27      892        8     83,595    5,700
# 2020-07-28      887        8     84,482    5,708
# 2020-07-29      882        8     85,364    5,716
# 2020-07-30      876        8     86,240    5,724

# %%
covid.Region(geoId='ES', dilation=2.8, d_cases=1.9).analyse()
# Out:
# Spain data to end of 2020-07-23:
#   272,421 cases, 28,432 deaths
#   5,804 cases per million, 606 deaths per million (2019 population = 46,937,060)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-28 (-146 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-118 days, 7,909 cases)
#   End:         2020-05-18 (-65 days, 53 days after peak cases)
#   Day Zero:    2020-03-11 (-134 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-114 days, 868 deaths)
#
# Parameters:
#   Totals:      266,194 cases and 28,424 deaths at end of 2020-07-20
#   Smoothed:    266,194 cases and 28,424 deaths at end of 2020-07-20 (7 points)
#   Spread:      Peak infection rate 12.3 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.9 (2020-07-20, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
#                X = 234,110, r = 5.53, L = 31,636, dilation = 1.9, c = 90.3% for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#                X = 28,602, r = 6.25, L = 3,472, dilation = 2.8, c = 90.8% for deaths
#
# Outcome: 232,555 total cases, 27,888 total deaths at end of 2020-05-19
#   4,955 cases per million (0.50%), 594 deaths per million (0.059%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-10        0        0     253,908   28,403       642        2     254,496   28,402
# 2020-07-11        0        0     253,908   28,403       712        2     255,208   28,405
# 2020-07-12    2,045        3     255,953   28,406       829        2     256,037   28,407
# 2020-07-13      666        3     256,619   28,409       908        2     256,945   28,409
# 2020-07-14      875        4     257,494   28,413       908        2     257,852   28,412
# 2020-07-15    1,361        3     258,855   28,416       908        2     258,760   28,414
# 2020-07-16    1,400        4     260,255   28,420     1,270        2     260,030   28,416
# 2020-07-17        0        0     260,255   28,420     1,369        2     261,399   28,419
# 2020-07-18        0        0     260,255   28,420     1,438        2     262,837   28,420
# 2020-07-19    4,581        2     264,836   28,422     1,617        2     264,454   28,422
# 2020-07-20    1,358        2     266,194   28,424     1,740        2     266,194   28,424
# 2020-07-21    1,357        2     267,551   28,426
# 2020-07-22    2,615        3     270,166   28,429
# 2020-07-23    2,255        3     272,421   28,432
#
#   ** first wave ended **

# %%
covid.Region(geoId='IT', dilation=2.2, d_cases=3).analyse()
# Out:
# Italy data to end of 2020-07-24:
#   245,590 cases, 35,097 deaths
#   4,069 cases per million, 581 deaths per million (2019 population = 60,359,546)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-21 (-154 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-123 days, 5,641 cases)
#   End:         2020-06-07 (-46 days, 77 days after peak cases)
#   Day Zero:    2020-03-02 (-144 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-116 days, 822 deaths)
#
# Parameters:
#   Totals:      244,752 cases and 35,073 deaths at end of 2020-07-21
#   Smoothed:    244,751 cases and 35,073 deaths at end of 2020-07-21 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-07-21, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
#                X = 237,401, r = 5.64, L = 22,564, dilation = 3, c = 94.3% for cases
#   Lag:         7 days (Peak Cases -> Peak Deaths)
#                X = 34,316, r = 4.48, L = 3,287, dilation = 2.2, c = 87.1% for deaths
#
# Outcome: 235,278 total cases, 33,964 total deaths at end of 2020-06-08
#   3,898 cases per million (0.39%), 563 deaths per million (0.056%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-11      188        7     242,827   34,945       198       12     242,700   34,950
# 2020-07-12      234        9     243,061   34,954       194       12     242,893   34,962
# 2020-07-13      169       13     243,230   34,967       196       13     243,089   34,975
# 2020-07-14      114       17     243,344   34,984       190       13     243,279   34,988
# 2020-07-15      162       13     243,506   34,997       198       14     243,477   35,002
# 2020-07-16      230       20     243,736   35,017       196       13     243,673   35,015
# 2020-07-17      231       11     243,967   35,028       199       13     243,873   35,028
# 2020-07-18      249       14     244,216   35,042       201       13     244,074   35,040
# 2020-07-19      218        3     244,434   35,045       218       12     244,291   35,052
# 2020-07-20      190       13     244,624   35,058       229       11     244,520   35,063
# 2020-07-21      128       15     244,752   35,073       232       10     244,752   35,073
# 2020-07-22      280        9     245,032   35,082
# 2020-07-23      306       10     245,338   35,092
# 2020-07-24      252        5     245,590   35,097
#
#   ** first wave ended **

# %%
covid.Region(geoId='FR', dilation=2.3, d_cases=2.3).analyse()
# Out:
# France data to end of 2020-07-24:
#   180,528 cases, 30,192 deaths
#   2,694 cases per million, 451 deaths per million (2019 population = 67,012,883)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-27 (-148 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-117 days, 4,535 cases)
#   End:         2020-06-07 (-46 days, 71 days after peak cases)
#   Day Zero:    2020-03-11 (-135 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-109 days, 1,101 deaths)
#
# Parameters:
#   Totals:      177,338 cases and 30,165 deaths at end of 2020-07-21
#   Smoothed:    177,338 cases and 30,164 deaths at end of 2020-07-21 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 1.5 (2020-07-21, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
#                X = 154,579, r = 6.22, L = 18,141, dilation = 2.3, c = 85.8% for cases
#   Lag:         8 days (Peak Cases -> Peak Deaths)
#                X = 29,252, r = 7.77, L = 4,403, dilation = 2.3, c = 81.4% for deaths
#
# Outcome: 154,188 total cases, 29,209 total deaths at end of 2020-06-08
#   2,301 cases per million (0.23%), 436 deaths per million (0.044%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-11        0        0     170,752   30,004       509       14     170,893   29,998
# 2020-07-12        0        0     170,752   30,004       547       22     171,440   30,021
# 2020-07-13    1,625       25     172,377   30,029       535       23     171,975   30,043
# 2020-07-14        0        0     172,377   30,029       560       21     172,535   30,064
# 2020-07-15      927       91     173,304   30,120       560       21     173,095   30,086
# 2020-07-16      534       18     173,838   30,138       560       21     173,656   30,107
# 2020-07-17      836       14     174,674   30,152       625       19     174,281   30,126
# 2020-07-18        0        0     174,674   30,152       709       19     174,989   30,146
# 2020-07-19        0        0     174,674   30,152       719        7     175,708   30,153
# 2020-07-20    2,080       13     176,754   30,165       794        6     176,502   30,159
# 2020-07-21      584        0     177,338   30,165       836        6     177,338   30,165
# 2020-07-22      998        7     178,336   30,172
# 2020-07-23    1,062       10     179,398   30,182
# 2020-07-24    1,130       10     180,528   30,192
#
#   ** first wave ended **

# %%
covid.Region(geoId='DE', dilation=1.4).analyse()
# Out:
# Germany data to end of 2020-07-24:
#   204,964 cases, 9,118 deaths
#   2,469 cases per million, 110 deaths per million (2019 population = 83,019,213)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-27 (-148 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-114 days, 5,590 cases)
#   End:         2020-05-17 (-67 days, 47 days after peak cases)
#   Day Zero:    2020-03-20 (-126 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-98 days, 233 deaths)
#
# Parameters:
#   Totals:      202,799 cases and 9,095 deaths at end of 2020-07-21
#   Smoothed:    202,799 cases and 9,095 deaths at end of 2020-07-21 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-07-21, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
#                X = 176,525, r = 4.98, L = 22,358, dilation = 1.4, c = 85.9% for cases
#   Lag:         16 days (Peak Cases -> Peak Deaths)
#                X = 8,459, r = 4.45, L = 930, dilation = 1.4, c = 87.8% for deaths
#
# Outcome: 175,210 total cases, 8,007 total deaths at end of 2020-05-18
#   2,110 cases per million (0.21%), 96 deaths per million (0.010%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-11      248        3     198,804    9,063       340        5     198,506    9,058
# 2020-07-12      159        1     198,963    9,064       353        4     198,859    9,062
# 2020-07-13        0        0     198,963    9,064       380        4     199,240    9,066
# 2020-07-14      763        7     199,726    9,071       402        3     199,642    9,069
# 2020-07-15      534        7     200,260    9,078       395        3     200,037    9,072
# 2020-07-16      583        4     200,843    9,082       408        3     200,445    9,075
# 2020-07-17      529        1     201,372    9,083       483        4     200,928    9,079
# 2020-07-18      202        1     201,574    9,084       439        3     201,366    9,083
# 2020-07-19      249        2     201,823    9,086       444        3     201,810    9,086
# 2020-07-20      522        4     202,345    9,090       477        4     202,286    9,090
# 2020-07-21      454        5     202,799    9,095       513        5     202,799    9,095
# 2020-07-22      569        6     203,368    9,101
# 2020-07-23      815       10     204,183    9,111
# 2020-07-24      781        7     204,964    9,118
#
#   ** first wave ended **

# %%
covid.Region(geoId='BE', dilation=1.5, d_cases=1).analyse()
# Out:
# Belgium data to end of 2020-07-24:
#   65,106 cases, 9,817 deaths
#   5,683 cases per million, 857 deaths per million (2019 population = 11,455,519)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-02 (-144 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-08 (-107 days, 1,607 cases)
#   End:         2020-05-14 (-70 days, 37 days after peak cases)
#   Day Zero:    2020-03-17 (-129 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-10 (-105 days, 303 deaths)
#
# Parameters:
#   Totals:      64,719 cases and 9,810 deaths at end of 2020-07-21
#   Smoothed:    64,719 cases and 9,810 deaths at end of 2020-07-21 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-03-09, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-07-21, compared to 7 days earlier)
#   Growth:      37 days (Start -> Peak Cases)
#                X = 56,519, r = 4.25, L = 6,427, dilation = 1, c = 88.1% for cases
#   Lag:         2 days (Peak Cases -> Peak Deaths)
#                X = 9,253, r = 5.95, L = 1,210, dilation = 1.5, c = 90.7% for deaths
#
# Outcome: 55,837 total cases, 9,052 total deaths at end of 2020-05-15
#   4,874 cases per million (0.49%), 790 deaths per million (0.079%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-11       63        2      62,737    9,785       132        2      62,805    9,785
# 2020-07-12       43        4      62,780    9,789       149        2      62,954    9,787
# 2020-07-13      224        0      63,004    9,789       163        3      63,117    9,790
# 2020-07-14      206        3      63,210    9,792       184        3      63,301    9,793
# 2020-07-15      258        5      63,468    9,797       192        3      63,493    9,796
# 2020-07-16      221        5      63,689    9,802       196        3      63,689    9,799
# 2020-07-17      271        2      63,960    9,804       225        3      63,914    9,801
# 2020-07-18      121        2      64,081    9,806       216        3      64,130    9,804
# 2020-07-19       70        1      64,151    9,807       223        2      64,353    9,806
# 2020-07-20      426        2      64,577    9,809       203        2      64,555    9,808
# 2020-07-21      142        1      64,719    9,810       164        2      64,719    9,810
# 2020-07-22      308        3      65,027    9,813
# 2020-07-23       79        2      65,106    9,815
# 2020-07-24        0        2      65,106    9,817
#
#   ** first wave ended **

# %%
covid.Region(geoId='IE', dilation=1.1, d_cases=1.6).analyse()
# Out:
# Ireland data to end of 2020-07-24:
#   25,845 cases, 1,763 deaths
#   5,270 cases per million, 359 deaths per million (2019 population = 4,904,240)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-11 (-135 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-103 days, 904 cases)
#   End:         2020-06-01 (-52 days, 51 days after peak cases)
#   Day Zero:    2020-03-30 (-116 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-93 days, 70 deaths)
#
# Parameters:
#   Totals:      25,802 cases and 1,753 deaths at end of 2020-07-21
#   Smoothed:    25,802 cases and 1,752 deaths at end of 2020-07-21 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-07-21, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
#                X = 25,154, r = 5.75, L = 3,614, dilation = 1.6, c = 79.8% for cases
#   Lag:         10 days (Peak Cases -> Peak Deaths)
#                X = 1,658, r = 5.25, L = 280, dilation = 1.1, c = 72.2% for deaths
#
# Outcome: 25,066 total cases, 1,658 total deaths at end of 2020-06-02
#   5,111 cases per million (0.51%), 338 deaths per million (0.034%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-11       22        2      25,611    1,746        19    < 0.5      25,613    1,742
# 2020-07-12       17        0      25,628    1,746        20        1      25,633    1,743
# 2020-07-13       10        0      25,638    1,746        19        1      25,652    1,743
# 2020-07-14       32        0      25,670    1,746        20        1      25,672    1,745
# 2020-07-15       13        2      25,683    1,748        20        1      25,692    1,746
# 2020-07-16       15        1      25,698    1,749        19        1      25,711    1,747
# 2020-07-17       32        3      25,730    1,752        18        1      25,729    1,748
# 2020-07-18       20        1      25,750    1,753        19        1      25,748    1,749
# 2020-07-19       10        0      25,760    1,753        19        1      25,767    1,749
# 2020-07-20        6        0      25,766    1,753        18        2      25,786    1,751
# 2020-07-21       36        0      25,802    1,753        16        2      25,802    1,753
# 2020-07-22       17        1      25,819    1,754
# 2020-07-23        7        9      25,826    1,763
# 2020-07-24       19        0      25,845    1,763
#
#   ** first wave ended **
