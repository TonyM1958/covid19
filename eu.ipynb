# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4, ylog=0)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=2.9, d_cases=3.7).analyse()
# Out:
# United Kingdom data to end of 2020-05-27:
#   267,240 cases, 37,460 deaths
#   4,019 cases per million, 563 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         69% through outbreak
#   Start:       2020-03-02 (-86 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-46 days, 5,523 cases)
#   End:         2020-06-29 ( 34 days, 80 days after peak cases)
#   Day Zero:    2020-03-15 (-73 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-46 days, 944 deaths)
#
# Parameters:
#   Totals:      259,559 cases and 36,793 deaths at end of 2020-05-24
#   Smoothed:    259,558 cases and 36,792 deaths at end of 2020-05-24 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-24, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=2.8, d_cases=1.9).analyse()
# Out:
# Spain data to end of 2020-05-26:
#   236,769 cases, 27,118 deaths
#   5,067 cases per million, 580 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-28 (-88 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-60 days, 7,917 cases)
#   End:         2020-05-18 ( -7 days, 53 days after peak cases)
#   Day Zero:    2020-03-11 (-76 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-56 days, 896 deaths)
#
# Parameters:
#   Totals:      235,772 cases and 28,752 deaths at end of 2020-05-23
#   Smoothed:    235,772 cases and 28,752 deaths at end of 2020-05-23 (7 points)
#   Spread:      Peak infection rate 12.3 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-23, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=2.2, d_cases=3).analyse()
# Out:
# Italy data to end of 2020-05-27:
#   231,139 cases, 33,072 deaths
#   3,825 cases per million, 547 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-21 (-96 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-65 days, 5,648 cases)
#   End:         2020-05-23 ( -3 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-86 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-58 days, 822 deaths)
#
# Parameters:
#   Totals:      229,858 cases and 32,785 deaths at end of 2020-05-24
#   Smoothed:    229,857 cases and 32,785 deaths at end of 2020-05-24 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-24, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=2.3, d_cases=2.4).analyse()
# Out:
# France data to end of 2020-05-27:
#   145,746 cases, 28,596 deaths
#   2,176 cases per million, 427 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         94% through outbreak
#   Start:       2020-02-27 (-90 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-59 days, 4,534 cases)
#   End:         2020-05-29 (  3 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-77 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-51 days, 1,100 deaths)
#
# Parameters:
#   Totals:      144,921 cases and 28,367 deaths at end of 2020-05-24
#   Smoothed:    144,920 cases and 28,366 deaths at end of 2020-05-24 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-24, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1.3, d_cases=1.4).analyse()
# Out:
# Germany data to end of 2020-05-27:
#   179,717 cases, 8,411 deaths
#   2,167 cases per million, 101 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-27 (-90 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-56 days, 5,595 cases)
#   End:         2020-05-17 ( -9 days, 47 days after peak cases)
#   Day Zero:    2020-03-20 (-68 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-40 days, 232 deaths)
#
# Parameters:
#   Totals:      178,570 cases and 8,257 deaths at end of 2020-05-24
#   Smoothed:    178,570 cases and 8,257 deaths at end of 2020-05-24 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-24, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=1.7, d_cases=1).analyse()
# Out:
# Belgium data to end of 2020-05-27:
#   57,592 cases, 9,364 deaths
#   5,042 cases per million, 820 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-04 (-84 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-45 days, 1,455 cases)
#   End:         2020-05-20 ( -6 days, 39 days after peak cases)
#   Day Zero:    2020-03-21 (-67 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-44 days, 334 deaths)
#
# Parameters:
#   Totals:      57,092 cases and 9,280 deaths at end of 2020-05-24
#   Smoothed:    57,092 cases and 9,279 deaths at end of 2020-05-24 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-24, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=1, d_cases=1.5).analyse()
# Out:
# Ireland data to end of 2020-05-27:
#   24,803 cases, 1,631 deaths
#   5,110 cases per million, 336 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         93% through outbreak
#   Start:       2020-03-11 (-77 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-45 days, 904 cases)
#   End:         2020-05-29 (  3 days, 48 days after peak cases)
#   Day Zero:    2020-03-30 (-58 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-35 days, 70 deaths)
#
# Parameters:
#   Totals:      24,639 cases and 1,606 deaths at end of 2020-05-24
#   Smoothed:    24,639 cases and 1,606 deaths at end of 2020-05-24 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-24, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=1.8, d_cases=2.1).analyse()
# Out:
# Sweden data to end of 2020-05-27:
#   35,088 cases, 4,220 deaths
#   3,446 cases per million, 414 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         55% through outbreak
#   Start:       2020-03-04 (-84 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 (-35 days, 620 cases)
#   End:         2020-07-28 ( 63 days, 98 days after peak cases)
#   Day Zero:    2020-03-25 (-63 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-36 days, 107 deaths)
#
# Parameters:
#   Totals:      33,459 cases and 3,998 deaths at end of 2020-05-24
#   Smoothed:    33,459 cases and 3,998 deaths at end of 2020-05-24 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-05-24, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...
