# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=3, d_cases=3.3).analyse(ylog=1)
# Out:
# United Kingdom data to end of 2020-05-18:
#   246,406 cases, 34,796 deaths
#   3,706 cases per million, 523 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         62% through outbreak
#   Start:       2020-03-02 (-77 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-37 days, 5,521 cases)
#   End:         2020-06-29 ( 43 days, 80 days after peak cases)
#   Day Zero:    2020-03-15 (-64 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-37 days, 946 deaths)
#
# Parameters:
#   Totals:      236,711 cases and 33,998 deaths at end of 2020-05-15
#   Smoothed:    236,710 cases and 33,998 deaths at end of 2020-05-15 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-15, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=3.6, d_cases=3.5).analyse(ylog=1)
# note: ECDC cases data differs from Worldometer due to anti-body tests
# Out:
# Spain data to end of 2020-05-17:
#   231,606 cases, 27,709 deaths
#   4,957 cases per million, 593 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         90% through outbreak
#   Start:       2020-02-28 (-79 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-51 days, 7,907 cases)
#   End:         2020-05-21 (  5 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-67 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-47 days, 870 deaths)
#
# Parameters:
#   Totals:      230,183 cases and 27,459 deaths at end of 2020-05-14
#   Smoothed:    230,182 cases and 27,459 deaths at end of 2020-05-14 (7 points)
#   Spread:      Peak infection rate 12.3 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 0.4 (2020-05-14, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=3.3, d_cases=3).analyse()
# Out:
# Italy data to end of 2020-05-18:
#   225,886 cases, 32,007 deaths
#   3,738 cases per million, 530 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         90% through outbreak
#   Start:       2020-02-21 (-87 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-56 days, 5,646 cases)
#   End:         2020-05-23 (  6 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-77 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-49 days, 824 deaths)
#
# Parameters:
#   Totals:      223,885 cases and 31,610 deaths at end of 2020-05-15
#   Smoothed:    223,884 cases and 31,609 deaths at end of 2020-05-15 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-15, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=3.6, d_cases=3.3).analyse()
# Out:
# France data to end of 2020-05-18:
#   142,903 cases, 28,239 deaths
#   2,133 cases per million, 422 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         84% through outbreak
#   Start:       2020-02-27 (-81 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-50 days, 4,544 cases)
#   End:         2020-05-29 ( 12 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-68 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-42 days, 1,099 deaths)
#
# Parameters:
#   Totals:      141,919 cases and 27,529 deaths at end of 2020-05-15
#   Smoothed:    141,918 cases and 27,529 deaths at end of 2020-05-15 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.4 (2020-05-15, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1.4, d_cases=2.8).analyse()
# Out:
# Germany data to end of 2020-05-18:
#   175,210 cases, 8,007 deaths
#   2,113 cases per million, 97 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         76% through outbreak
#   Start:       2020-02-27 (-81 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-47 days, 5,603 cases)
#   End:         2020-06-07 ( 21 days, 68 days after peak cases)
#   Day Zero:    2020-03-20 (-59 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-31 days, 234 deaths)
#
# Parameters:
#   Totals:      173,772 cases and 7,881 deaths at end of 2020-05-15
#   Smoothed:    173,772 cases and 7,881 deaths at end of 2020-05-15 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-15, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=2.1, d_cases=1.5).analyse()
# Out:
# Belgium data to end of 2020-05-18:
#   55,559 cases, 9,080 deaths
#   4,864 cases per million, 795 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         74% through outbreak
#   Start:       2020-03-04 (-75 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-36 days, 1,453 cases)
#   End:         2020-06-08 ( 22 days, 58 days after peak cases)
#   Day Zero:    2020-03-21 (-58 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-35 days, 334 deaths)
#
# Parameters:
#   Totals:      54,644 cases and 8,959 deaths at end of 2020-05-15
#   Smoothed:    54,644 cases and 8,958 deaths at end of 2020-05-15 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-15, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=1.8, d_cases=2.6).analyse()
# Out:
# Ireland data to end of 2020-05-18:
#   24,200 cases, 1,547 deaths
#   4,986 cases per million, 319 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         68% through outbreak
#   Start:       2020-03-11 (-68 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-36 days, 908 cases)
#   End:         2020-06-14 ( 28 days, 64 days after peak cases)
#   Day Zero:    2020-03-30 (-49 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-26 days, 70 deaths)
#
# Parameters:
#   Totals:      23,956 cases and 1,518 deaths at end of 2020-05-15
#   Smoothed:    23,956 cases and 1,518 deaths at end of 2020-05-15 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-15, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=2.4).analyse()
# Out:
# Sweden data to end of 2020-05-18:
#   30,377 cases, 3,698 deaths
#   2,983 cases per million, 363 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         49% through outbreak
#   Start:       2020-03-04 (-75 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 (-26 days, 626 cases)
#   End:         2020-07-28 ( 72 days, 98 days after peak cases)
#   Day Zero:    2020-03-25 (-54 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-27 days, 110 deaths)
#
# Parameters:
#   Totals:      29,207 cases and 3,646 deaths at end of 2020-05-15
#   Smoothed:    29,207 cases and 3,646 deaths at end of 2020-05-15 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-05-15, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...
