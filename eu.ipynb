# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=0, ylog=1, d_clip=2.5)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=4.3, d_cases=4.8).analyse(totals=4)
# Out:
# United Kingdom data to end of 2020-06-23:
#   306,210 cases, 42,927 deaths
#   4,594 cases per million, 644 deaths per million (2019 population = 66,647,112)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         79% through outbreak
#   Start:       2020-03-02 (-113 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-73 days, 5,522 cases)
#   End:         2020-07-19 ( 27 days, 100 days after peak cases)
#   Day Zero:    2020-03-15 (-100 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-73 days, 944 deaths)
#
# Parameters:
#   Totals:      303,110 cases and 42,589 deaths at end of 2020-06-20
#   Smoothed:    303,110 cases and 42,589 deaths at end of 2020-06-20 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-06-20, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=2, d_cases=3).analyse(totals=4)
# Out:
# Sweden data to end of 2020-06-22:
#   58,932 cases, 5,122 deaths
#   5,761 cases per million, 501 deaths per million (2019 population = 10,230,185)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         30% through outbreak
#   Start:       2020-03-04 (-110 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-15 ( -7 days, 1,112 cases)
#   End:         2021-02-26 (250 days, 257 days after peak cases)
#   Day Zero:    2020-03-25 (-89 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-62 days, 108 deaths)
#
# Parameters:
#   Totals:      56,043 cases and 5,053 deaths at end of 2020-06-19
#   Smoothed:    56,042 cases and 5,053 deaths at end of 2020-06-19 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.9 (2020-06-19, compared to 7 days earlier)
#   Growth:      103 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=2.8, d_cases=1.9).analyse()
# Out:
# Spain data to end of 2020-06-21:
#   246,504 cases, 28,324 deaths
#   5,252 cases per million, 603 deaths per million (2019 population = 46,937,060)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-28 (-114 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-86 days, 7,904 cases)
#   End:         2020-05-18 (-33 days, 53 days after peak cases)
#   Day Zero:    2020-03-11 (-102 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-82 days, 884 deaths)
#
# Parameters:
#   Totals:      245,575 cases and 28,315 deaths at end of 2020-06-18
#   Smoothed:    245,575 cases and 28,314 deaths at end of 2020-06-18 (7 points)
#   Spread:      Peak infection rate 12.3 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-06-18, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=2.2, d_cases=3).analyse()
# Out:
# Italy data to end of 2020-06-22:
#   238,720 cases, 34,657 deaths
#   3,955 cases per million, 574 deaths per million (2019 population = 60,359,546)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-21 (-122 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-91 days, 5,640 cases)
#   End:         2020-06-07 (-14 days, 77 days after peak cases)
#   Day Zero:    2020-03-02 (-112 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-84 days, 822 deaths)
#
# Parameters:
#   Totals:      238,011 cases and 34,561 deaths at end of 2020-06-19
#   Smoothed:    238,010 cases and 34,561 deaths at end of 2020-06-19 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-06-19, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=2.3, d_cases=2.3).analyse()
# Out:
# France data to end of 2020-06-22:
#   160,750 cases, 29,663 deaths
#   2,399 cases per million, 443 deaths per million (2019 population = 67,012,883)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-27 (-116 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-85 days, 4,540 cases)
#   End:         2020-06-07 (-14 days, 71 days after peak cases)
#   Day Zero:    2020-03-11 (-103 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-77 days, 1,101 deaths)
#
# Parameters:
#   Totals:      159,452 cases and 29,617 deaths at end of 2020-06-19
#   Smoothed:    159,451 cases and 29,616 deaths at end of 2020-06-19 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-06-19, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1.4).analyse()
# Out:
# Germany data to end of 2020-06-22:
#   190,862 cases, 8,895 deaths
#   2,299 cases per million, 107 deaths per million (2019 population = 83,019,213)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-27 (-116 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-82 days, 5,596 cases)
#   End:         2020-05-17 (-35 days, 47 days after peak cases)
#   Day Zero:    2020-03-20 (-94 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-66 days, 233 deaths)
#
# Parameters:
#   Totals:      189,135 cases and 8,882 deaths at end of 2020-06-19
#   Smoothed:    189,135 cases and 8,882 deaths at end of 2020-06-19 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 1.8 (2020-06-19, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=1.5, d_cases=1).analyse()
# Out:
# Belgium data to end of 2020-06-22:
#   60,550 cases, 9,696 deaths
#   5,286 cases per million, 846 deaths per million (2019 population = 11,455,519)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-04 (-110 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-71 days, 1,454 cases)
#   End:         2020-05-20 (-32 days, 39 days after peak cases)
#   Day Zero:    2020-03-21 (-93 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-70 days, 334 deaths)
#
# Parameters:
#   Totals:      60,476 cases and 9,695 deaths at end of 2020-06-19
#   Smoothed:    60,476 cases and 9,694 deaths at end of 2020-06-19 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-06-19, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=1.1, d_cases=1.6).analyse()
# Out:
# Ireland data to end of 2020-06-22:
#   25,383 cases, 1,717 deaths
#   5,176 cases per million, 350 deaths per million (2019 population = 4,904,240)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-11 (-103 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-71 days, 903 cases)
#   End:         2020-06-01 (-20 days, 51 days after peak cases)
#   Day Zero:    2020-03-30 (-84 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-61 days, 70 deaths)
#
# Parameters:
#   Totals:      25,368 cases and 1,714 deaths at end of 2020-06-19
#   Smoothed:    25,368 cases and 1,713 deaths at end of 2020-06-19 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-06-19, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...
