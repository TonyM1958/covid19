# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://www.gov.uk/guidance/coronavirus-covid-19-information-for-the-public">www.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=0, ylog=1, d_clip=2.5)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=5, d_cases=4).analyse(totals=4)
# Out:
# United Kingdom data to end of 2020-07-28:
#   300,692 cases, 45,878 deaths
#   4,512 cases per million, 688 deaths per million (2019 population = 66,647,112)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-02 (-148 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-108 days, 5,520 cases)
#   End:         2020-07-19 ( -8 days, 100 days after peak cases)
#   Day Zero:    2020-03-15 (-135 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-108 days, 944 deaths)
#
# Parameters:
#   Totals:      298,681 cases and 45,738 deaths at end of 2020-07-25
#   Smoothed:    298,680 cases and 45,738 deaths at end of 2020-07-25 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-07-25, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
#                X = 299,837, r = 6.69, L = 22,079, dilation = 4, c = 78.4% for cases
#   Lag:         0 days (Peak Cases -> Peak Deaths)
#                X = 46,246, r = 8.0, L = 3,776, dilation = 5, c = 72.3% for deaths
#
# Outcome: 295,372 total cases, 45,312 total deaths at end of 2020-07-20
#   4,432 cases per million (0.44%), 680 deaths per million (0.068%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-15      538       85     291,911   45,053       731       68     291,898   45,085
# 2020-07-16      641       66     292,552   45,119       741       69     292,640   45,154
# 2020-07-17      687      114     293,239   45,233       749       69     293,388   45,223
# 2020-07-18      827       40     294,066   45,273       635       65     294,023   45,288
# 2020-07-19      726       27     294,792   45,300       638       64     294,661   45,352
# 2020-07-20      580       12     295,372   45,312       656       62     295,318   45,414
# 2020-07-21      445      110     295,817   45,422       668       63     295,986   45,478
# 2020-07-22      560       79     296,377   45,501       659       66     296,645   45,544
# 2020-07-23      769       53     297,146   45,554       662       65     297,307   45,609
# 2020-07-24      768      123     297,914   45,677       677       64     297,984   45,673
# 2020-07-25      767       61     298,681   45,738       697       65     298,681   45,738
# 2020-07-26      745       14     299,426   45,752
# 2020-07-27      685        7     300,111   45,759
# 2020-07-28      581      119     300,692   45,878
#
#   ** first wave ended **

# %%
covid.Region(geoId='SE', dilation=2, d_cases=1).analyse(totals=4)
# Out:
# Sweden data to end of 2020-07-28:
#   79,494 cases, 5,702 deaths
#   7,771 cases per million, 557 deaths per million (2019 population = 10,230,185)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         64% through outbreak
#   Start:       2020-03-04 (-146 days, when 50 or more cases were reported)
#   Peak Cases:  2020-06-23 (-35 days, 1,299 cases)
#   End:         2020-10-11 ( 76 days, 111 days after peak cases)
#   Day Zero:    2020-03-25 (-125 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-98 days, 108 deaths)
#
# Parameters:
#   Totals:      78,997 cases and 5,697 deaths at end of 2020-07-25
#   Smoothed:    78,997 cases and 5,697 deaths at end of 2020-07-25 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-07-25, compared to 7 days earlier)
#   Growth:      111 days (Start -> Peak Cases)
#                X = 99,903, r = 4.58, L = 5,194, dilation = 1, c = 50.4% for cases
#   Lag:         -63 days (Peak Cases -> Peak Deaths)
#                X = 5,943, r = 8.0, L = 430, dilation = 2, c = 52.4% for deaths
#
# Outcome: 98,887 total cases, 5,932 total deaths by end of 2020-10-11
#   79.6% of predicted cases and 95.9% of predicted deaths reported to date
#   99.0% of predicted cases and 99.8% of predicted deaths reported by end date
#   9,766 cases per million (0.98%), 581 deaths per million (0.058%)
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-15      491       27      76,492    5,572       340       13      76,356    5,579
# 2020-07-16      385       21      76,877    5,593       340       13      76,697    5,592
# 2020-07-17      404       26      77,281    5,619       317       15      77,014    5,607
# 2020-07-18        0        0      77,281    5,619       309       14      77,323    5,621
# 2020-07-19        0        0      77,281    5,619       287       14      77,610    5,635
# 2020-07-20      767       20      78,048    5,639       269       12      77,880    5,647
# 2020-07-21      118        7      78,166    5,646       245       11      78,125    5,658
# 2020-07-22      338       21      78,504    5,667       245       11      78,370    5,669
# 2020-07-23      259        9      78,763    5,676       245       11      78,615    5,680
# 2020-07-24      234       21      78,997    5,697       192        9      78,807    5,689
# 2020-07-25        0        0      78,997    5,697       190        8      78,997    5,697
# 2020-07-26        0        0      78,997    5,697
# 2020-07-27      398        3      79,395    5,700
# 2020-07-28       99        2      79,494    5,702
#
#               Prediction ---      Total -------
# Date          Cases   Deaths      Cases  Deaths
# 2020-07-25      693        9     78,997    5,697
# 2020-07-26      676        9     79,673    5,706
# 2020-07-27      660        8     80,333    5,714
# 2020-07-28      643        8     80,976    5,722  <-- latest raw data
# 2020-07-29      627        8     81,603    5,730
# 2020-07-30      611        8     82,214    5,737
# 2020-07-31      595        7     82,808    5,745
# 2020-08-01      579        7     83,387    5,752
# 2020-08-02      563        7     83,950    5,758
# 2020-08-03      547        7     84,497    5,765

# %%
covid.Region(geoId='ES', dilation=2.8, d_cases=1.9).analyse()
# Out:
# Spain data to end of 2020-07-27:
#   280,610 cases, 28,436 deaths
#   5,978 cases per million, 606 deaths per million (2019 population = 46,937,060)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-28 (-150 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-27 (-122 days, 7,871 cases)
#   End:         2020-05-18 (-69 days, 53 days after peak cases)
#   Day Zero:    2020-03-11 (-138 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-118 days, 868 deaths)
#
# Parameters:
#   Totals:      272,421 cases and 28,432 deaths at end of 2020-07-24
#   Smoothed:    272,421 cases and 28,431 deaths at end of 2020-07-24 (7 points)
#   Spread:      Peak infection rate 12.3 (2020-03-08, compared to 7 days earlier)
#                Latest infection rate 1.5 (2020-07-24, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
#                X = 232,991, r = 5.53, L = 31,485, dilation = 1.9, c = 90.6% for cases
#   Lag:         4 days (Peak Cases -> Peak Deaths)
#                X = 28,603, r = 6.25, L = 3,472, dilation = 2.8, c = 90.8% for deaths
#
# Outcome: 232,555 total cases, 27,888 total deaths at end of 2020-05-19
#   4,955 cases per million (0.50%), 594 deaths per million (0.059%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-14      875        4     257,494   28,413       903        2     256,621   28,413
# 2020-07-15    1,361        3     258,855   28,416       903        2     257,524   28,415
# 2020-07-16    1,400        4     260,255   28,420     1,264        2     258,788   28,418
# 2020-07-17        0        0     260,255   28,420     1,363        2     260,150   28,420
# 2020-07-18        0        0     260,255   28,420     1,431        2     261,582   28,422
# 2020-07-19    4,581        2     264,836   28,422     1,610        2     263,191   28,423
# 2020-07-20    1,358        2     266,194   28,424     1,731        2     264,922   28,425
# 2020-07-21    1,357        2     267,551   28,426     1,731        2     266,654   28,427
# 2020-07-22    2,615        3     270,166   28,429     1,731        2     268,385   28,429
# 2020-07-23    2,255        3     272,421   28,432     1,985        2     270,370   28,430
# 2020-07-24        0        0     272,421   28,432     2,051        2     272,421   28,432
# 2020-07-25        0        0     272,421   28,432
# 2020-07-26    6,361        2     278,782   28,434
# 2020-07-27    1,828        2     280,610   28,436
#
#   ** first wave ended **

# %%
covid.Region(geoId='IT', dilation=2.2, d_cases=3).analyse()
# Out:
# Italy data to end of 2020-07-28:
#   246,488 cases, 35,123 deaths
#   4,084 cases per million, 582 deaths per million (2019 population = 60,359,546)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-21 (-158 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-127 days, 5,645 cases)
#   End:         2020-06-07 (-50 days, 77 days after peak cases)
#   Day Zero:    2020-03-02 (-148 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-120 days, 822 deaths)
#
# Parameters:
#   Totals:      245,864 cases and 35,102 deaths at end of 2020-07-25
#   Smoothed:    245,863 cases and 35,102 deaths at end of 2020-07-25 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-07-25, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
#                X = 237,546, r = 5.64, L = 22,578, dilation = 3, c = 94.4% for cases
#   Lag:         7 days (Peak Cases -> Peak Deaths)
#                X = 34,312, r = 4.48, L = 3,286, dilation = 2.2, c = 87.1% for deaths
#
# Outcome: 235,278 total cases, 33,964 total deaths at end of 2020-06-08
#   3,898 cases per million (0.39%), 563 deaths per million (0.056%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-15      162       13     243,506   34,997       198       14     243,627   34,998
# 2020-07-16      230       20     243,736   35,017       196       13     243,823   35,011
# 2020-07-17      231       11     243,967   35,028       199       13     244,022   35,024
# 2020-07-18      249       14     244,216   35,042       201       13     244,224   35,037
# 2020-07-19      218        3     244,434   35,045       218       12     244,442   35,049
# 2020-07-20      190       13     244,624   35,058       229       11     244,670   35,060
# 2020-07-21      128       15     244,752   35,073       232       10     244,902   35,070
# 2020-07-22      280        9     245,032   35,082       235        9     245,138   35,078
# 2020-07-23      306       10     245,338   35,092       241        9     245,378   35,087
# 2020-07-24      252        5     245,590   35,097       237        8     245,616   35,095
# 2020-07-25      274        5     245,864   35,102       248        7     245,864   35,102
# 2020-07-26      254        5     246,118   35,107
# 2020-07-27      168        5     246,286   35,112
# 2020-07-28      202       11     246,488   35,123
#
#   ** first wave ended **

# %%
covid.Region(geoId='FR', dilation=2.3, d_cases=2.3).analyse()
# Out:
# France data to end of 2020-07-28:
#   183,804 cases, 30,223 deaths
#   2,743 cases per million, 451 deaths per million (2019 population = 67,012,883)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-27 (-152 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-121 days, 4,528 cases)
#   End:         2020-06-07 (-50 days, 71 days after peak cases)
#   Day Zero:    2020-03-11 (-139 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-113 days, 1,101 deaths)
#
# Parameters:
#   Totals:      180,528 cases and 30,192 deaths at end of 2020-07-25
#   Smoothed:    180,527 cases and 30,191 deaths at end of 2020-07-25 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-07-25, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
#                X = 154,315, r = 6.22, L = 18,110, dilation = 2.3, c = 86.1% for cases
#   Lag:         8 days (Peak Cases -> Peak Deaths)
#                X = 29,253, r = 7.77, L = 4,403, dilation = 2.3, c = 81.4% for deaths
#
# Outcome: 154,188 total cases, 29,209 total deaths at end of 2020-06-08
#   2,301 cases per million (0.23%), 436 deaths per million (0.044%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-15      927       91     173,304   30,120       559       21     172,800   30,087
# 2020-07-16      534       18     173,838   30,138       559       21     173,359   30,108
# 2020-07-17      836       14     174,674   30,152       624       19     173,983   30,127
# 2020-07-18        0        0     174,674   30,152       707       19     174,690   30,147
# 2020-07-19        0        0     174,674   30,152       717        7     175,408   30,154
# 2020-07-20    2,080       13     176,754   30,165       793        6     176,200   30,160
# 2020-07-21      584        0     177,338   30,165       835        6     177,035   30,166
# 2020-07-22      998        7     178,336   30,172       835        6     177,870   30,172
# 2020-07-23    1,062       10     179,398   30,182       835        6     178,704   30,177
# 2020-07-24    1,130       10     180,528   30,192       902        6     179,606   30,184
# 2020-07-25        0        0     180,528   30,192       922        8     180,528   30,192
# 2020-07-26        0        0     180,528   30,192
# 2020-07-27    2,551       17     183,079   30,209
# 2020-07-28      725       14     183,804   30,223
#
#   ** first wave ended **

# %%
covid.Region(geoId='DE', dilation=1.4).analyse()
# Out:
# Germany data to end of 2020-07-28:
#   206,926 cases, 9,128 deaths
#   2,493 cases per million, 110 deaths per million (2019 population = 83,019,213)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-02-27 (-152 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-118 days, 5,597 cases)
#   End:         2020-05-17 (-71 days, 47 days after peak cases)
#   Day Zero:    2020-03-20 (-130 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-102 days, 233 deaths)
#
# Parameters:
#   Totals:      205,269 cases and 9,118 deaths at end of 2020-07-25
#   Smoothed:    205,269 cases and 9,118 deaths at end of 2020-07-25 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 1.3 (2020-07-25, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
#                X = 176,747, r = 4.98, L = 22,386, dilation = 1.4, c = 86.1% for cases
#   Lag:         16 days (Peak Cases -> Peak Deaths)
#                X = 8,463, r = 4.45, L = 931, dilation = 1.4, c = 87.8% for deaths
#
# Outcome: 175,210 total cases, 8,007 total deaths at end of 2020-05-18
#   2,110 cases per million (0.21%), 96 deaths per million (0.010%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-15      534        7     200,260    9,078       396        3     200,288    9,077
# 2020-07-16      583        4     200,843    9,082       409        3     200,697    9,080
# 2020-07-17      529        1     201,372    9,083       483        4     201,180    9,083
# 2020-07-18      202        1     201,574    9,084       439        3     201,619    9,087
# 2020-07-19      249        2     201,823    9,086       444        3     202,063    9,090
# 2020-07-20      522        4     202,345    9,090       477        4     202,540    9,094
# 2020-07-21      454        5     202,799    9,095       513        5     203,054    9,099
# 2020-07-22      569        6     203,368    9,101       528        5     203,581    9,104
# 2020-07-23      815       10     204,183    9,111       541        5     204,122    9,109
# 2020-07-24      781        7     204,964    9,118       557        5     204,679    9,113
# 2020-07-25      305        0     205,269    9,118       590        5     205,269    9,118
# 2020-07-26      340        0     205,609    9,118
# 2020-07-27      633        4     206,242    9,122
# 2020-07-28      684        6     206,926    9,128
#
#   ** first wave ended **

# %%
covid.Region(geoId='BE', dilation=1.5, d_cases=1).analyse()
# Out:
# Belgium data to end of 2020-07-28:
#   66,569 cases, 9,833 deaths
#   5,811 cases per million, 858 deaths per million (2019 population = 11,455,519)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-02 (-148 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-08 (-111 days, 1,611 cases)
#   End:         2020-05-14 (-74 days, 37 days after peak cases)
#   Day Zero:    2020-03-17 (-133 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-10 (-109 days, 303 deaths)
#
# Parameters:
#   Totals:      66,380 cases and 9,828 deaths at end of 2020-07-25
#   Smoothed:    66,379 cases and 9,827 deaths at end of 2020-07-25 (7 points)
#   Spread:      Peak infection rate 4.0 (2020-03-09, compared to 7 days earlier)
#                Latest infection rate 1.2 (2020-07-25, compared to 7 days earlier)
#   Growth:      37 days (Start -> Peak Cases)
#                X = 56,667, r = 4.25, L = 6,444, dilation = 1, c = 88.4% for cases
#   Lag:         2 days (Peak Cases -> Peak Deaths)
#                X = 9,258, r = 5.95, L = 1,210, dilation = 1.5, c = 90.7% for deaths
#
# Outcome: 55,837 total cases, 9,056 total deaths at end of 2020-05-15
#   4,874 cases per million (0.49%), 791 deaths per million (0.079%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-15      259        5      63,471    9,804       193        3      63,663    9,805
# 2020-07-16      221        5      63,692    9,809       197        3      63,860    9,807
# 2020-07-17      272        2      63,964    9,811       226        3      64,086    9,810
# 2020-07-18      122        2      64,086    9,813       217        3      64,304    9,813
# 2020-07-19       70        1      64,156    9,814       258        2      64,562    9,815
# 2020-07-20      428        2      64,584    9,816       287        2      64,850    9,817
# 2020-07-21      145        1      64,729    9,817       317        2      65,167    9,819
# 2020-07-22      545        3      65,274    9,820       329        2      65,495    9,821
# 2020-07-23      423        2      65,697    9,822       337        2      65,832    9,823
# 2020-07-24      479        5      66,176    9,827       284        2      66,116    9,826
# 2020-07-25      204        1      66,380    9,828       264        2      66,380    9,828
# 2020-07-26      124        2      66,504    9,830
# 2020-07-27       65        2      66,569    9,832
# 2020-07-28        0        1      66,569    9,833
#
#   ** first wave ended **

# %%
covid.Region(geoId='IE', dilation=1.1, d_cases=1.6).analyse()
# Out:
# Ireland data to end of 2020-07-28:
#   25,929 cases, 1,764 deaths
#   5,287 cases per million, 360 deaths per million (2019 population = 4,904,240)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         past end of first outbreak
#   Start:       2020-03-11 (-139 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-107 days, 903 cases)
#   End:         2020-06-01 (-56 days, 51 days after peak cases)
#   Day Zero:    2020-03-30 (-120 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-97 days, 70 deaths)
#
# Parameters:
#   Totals:      25,869 cases and 1,764 deaths at end of 2020-07-25
#   Smoothed:    25,869 cases and 1,763 deaths at end of 2020-07-25 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 1.0 (2020-07-25, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
#                X = 25,150, r = 5.75, L = 3,613, dilation = 1.6, c = 79.8% for cases
#   Lag:         10 days (Peak Cases -> Peak Deaths)
#                X = 1,662, r = 5.25, L = 281, dilation = 1.1, c = 72.3% for deaths
#
# Outcome: 25,066 total cases, 1,658 total deaths at end of 2020-06-02
#   5,111 cases per million (0.51%), 338 deaths per million (0.034%)
#   ** first wave ended **
#               Raw ----------       Total --------     Smoothed ------      Total ---------
# Date          Cases   Deaths       Cases   Deaths     Cases   Deaths       Cases   Deaths
# 2020-07-15       13        2      25,683    1,748        20        1      25,688    1,750
# 2020-07-16       15        1      25,698    1,749        19        1      25,707    1,751
# 2020-07-17       32        3      25,730    1,752        18        1      25,726    1,752
# 2020-07-18       20        1      25,750    1,753        19        1      25,744    1,753
# 2020-07-19       10        0      25,760    1,753        19        1      25,764    1,754
# 2020-07-20        6        0      25,766    1,753        18        2      25,782    1,756
# 2020-07-21       36        0      25,802    1,753        16        2      25,799    1,758
# 2020-07-22       17        1      25,819    1,754        17        2      25,816    1,759
# 2020-07-23        7        9      25,826    1,763        17        2      25,833    1,761
# 2020-07-24       19        0      25,845    1,763        18        2      25,851    1,762
# 2020-07-25       24        1      25,869    1,764        18        2      25,869    1,764
# 2020-07-26       12        0      25,881    1,764
# 2020-07-27       11        0      25,892    1,764
# 2020-07-28       37        0      25,929    1,764
#
#   ** first wave ended **
