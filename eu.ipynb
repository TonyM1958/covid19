# %% [markdown]
# <h3>COVID-19 Data Analysis</h3>
# Latest UK data is from <a target="_blank" href="https://coronavirus.data.gov.uk/">coronavirus.data.gov.uk</a>
# <br>Latest world-wide data is from <a target="_blank" href="https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide">www.ecdc.europa.eu</a>
# <br>Cross check data with <a target="_blank" href="https://www.worldometers.info/coronavirus/">www.worldometers.info</a>
# <br>Github: <a target="_blank" href="https://github.com/TonyM1958/covid19">repository / readme</a>

# %%
import covid
# plot total deaths, linear Y axis
covid.setting(totals=4)
covid.data_load('download.json')

# %%
covid.Region(geoId='UK', dilation=2.2, d_cases=3.3).analyse()
# Out:
# United Kingdom data to end of 2020-05-05:
#   194,990 cases, 29,427 deaths
#   2,933 cases per million, 443 deaths per million (2018 population = 66,488,991)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         51% through outbreak
#   Start:       2020-03-02 (-64 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-11 (-24 days, 5,551 cases)
#   End:         2020-06-29 ( 56 days, 80 days after peak cases)
#   Day Zero:    2020-03-15 (-51 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-11 (-24 days, 952 deaths)
#
# Parameters:
#   Totals:      182,260 cases and 28,131 deaths at end of 2020-05-02
#   Smoothed:    182,260 cases and 28,131 deaths at end of 2020-05-02 (7 points)
#   Spread:      Peak infection rate 6.0 (2020-03-17, compared to 7 days earlier)
#                Latest infection rate 1.1 (2020-05-02, compared to 7 days earlier)
#   Growth:      40 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='ES', dilation=2.5).analyse()
# note: ECDC cases data differs from Worldometer due to anti-body tests
# Out:
# Spain data to end of 2020-05-05:
#   219,329 cases, 25,613 deaths
#   4,694 cases per million, 548 deaths per million (2018 population = 46,723,749)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         74% through outbreak
#   Start:       2020-02-29 (-65 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-28 (-37 days, 7,837 cases)
#   End:         2020-05-23 ( 19 days, 56 days after peak cases)
#   Day Zero:    2020-03-11 (-54 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-31 (-34 days, 871 deaths)
#
# Parameters:
#   Totals:      216,582 cases and 25,100 deaths at end of 2020-05-01
#   Smoothed:    216,582 cases and 25,100 deaths at end of 2020-05-01 (7 points)
#   Spread:      Peak infection rate 14.6 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-01, compared to 7 days earlier)
#   Growth:      28 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IT', dilation=2.7).analyse()
# Out:
# Italy data to end of 2020-05-05:
#   213,013 cases, 29,315 deaths
#   3,525 cases per million, 485 deaths per million (2018 population = 60,431,283)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         76% through outbreak
#   Start:       2020-02-21 (-74 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-23 (-43 days, 5,658 cases)
#   End:         2020-05-23 ( 19 days, 62 days after peak cases)
#   Day Zero:    2020-03-02 (-64 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-03-30 (-36 days, 826 deaths)
#
# Parameters:
#   Totals:      209,328 cases and 28,710 deaths at end of 2020-05-02
#   Smoothed:    209,327 cases and 28,710 deaths at end of 2020-05-02 (7 points)
#   Spread:      Peak infection rate 13.8 (2020-02-26, compared to 7 days earlier)
#                Latest infection rate 0.7 (2020-05-02, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='FR', dilation=2.6).analyse()
# Out:
# France data to end of 2020-05-05:
#   132,967 cases, 25,531 deaths
#   1,985 cases per million, 381 deaths per million (2018 population = 66,987,244)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         70% through outbreak
#   Start:       2020-02-27 (-68 days, when 50 or more cases were reported)
#   Peak Cases:  2020-03-29 (-37 days, 4,544 cases)
#   End:         2020-05-29 ( 25 days, 62 days after peak cases)
#   Day Zero:    2020-03-11 (-55 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-06 (-29 days, 1,100 deaths)
#
# Parameters:
#   Totals:      130,979 cases and 24,760 deaths at end of 2020-05-02
#   Smoothed:    130,978 cases and 24,760 deaths at end of 2020-05-02 (7 points)
#   Spread:      Peak infection rate 8.4 (2020-03-05, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-02, compared to 7 days earlier)
#   Growth:      31 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='DE', dilation=1.2, d_cases=2).analyse()
# Out:
# Germany data to end of 2020-05-05:
#   164,897 cases, 6,996 deaths
#   1,988 cases per million, 84 deaths per million (2018 population = 82,927,922)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         64% through outbreak
#   Start:       2020-02-27 (-68 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-01 (-34 days, 5,611 cases)
#   End:         2020-06-07 ( 34 days, 68 days after peak cases)
#   Day Zero:    2020-03-20 (-46 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-17 (-18 days, 234 deaths)
#
# Parameters:
#   Totals:      162,496 cases and 6,649 deaths at end of 2020-05-02
#   Smoothed:    162,496 cases and 6,649 deaths at end of 2020-05-02 (7 points)
#   Spread:      Peak infection rate 6.9 (2020-03-06, compared to 7 days earlier)
#                Latest infection rate 0.6 (2020-05-02, compared to 7 days earlier)
#   Growth:      34 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='BE', dilation=1.5, d_cases=0.9).analyse()
# Out:
# Belgium data to end of 2020-05-05:
#   50,509 cases, 8,016 deaths
#   4,422 cases per million, 702 deaths per million (2018 population = 11,422,068)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         76% through outbreak
#   Start:       2020-03-04 (-62 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-23 days, 1,457 cases)
#   End:         2020-05-20 ( 16 days, 39 days after peak cases)
#   Day Zero:    2020-03-21 (-45 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-13 (-22 days, 333 deaths)
#
# Parameters:
#   Totals:      49,517 cases and 7,765 deaths at end of 2020-05-02
#   Smoothed:    49,517 cases and 7,765 deaths at end of 2020-05-02 (7 points)
#   Spread:      Peak infection rate 4.1 (2020-03-18, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-02, compared to 7 days earlier)
#   Growth:      39 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='IE', dilation=1, d_cases=2.2).analyse()
# Out:
# Ireland data to end of 2020-05-05:
#   21,983 cases, 1,339 deaths
#   4,529 cases per million, 276 deaths per million (2018 population = 4,853,506)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         54% through outbreak
#   Start:       2020-03-11 (-55 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-12 (-23 days, 904 cases)
#   End:         2020-06-14 ( 41 days, 64 days after peak cases)
#   Day Zero:    2020-03-30 (-36 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-22 (-13 days, 70 deaths)
#
# Parameters:
#   Totals:      21,176 cases and 1,265 deaths at end of 2020-05-02
#   Smoothed:    21,175 cases and 1,264 deaths at end of 2020-05-02 (7 points)
#   Spread:      Peak infection rate 4.9 (2020-03-19, compared to 7 days earlier)
#                Latest infection rate 0.5 (2020-05-02, compared to 7 days earlier)
#   Growth:      32 days (Start -> Peak Cases)
# ...

# %%
covid.Region(geoId='SE', dilation=0.9).analyse()
# Out:
# Sweden data to end of 2020-05-05:
#   23,216 cases, 2,854 deaths
#   2,280 cases per million, 280 deaths per million (2018 population = 10,183,175)
#
# Timeline: (-ve days are past, +ve days are predicted)
#   Now:         60% through outbreak
#   Start:       2020-03-04 (-62 days, when 50 or more cases were reported)
#   Peak Cases:  2020-04-22 (-13 days, 628 cases)
#   End:         2020-06-09 ( 36 days, 49 days after peak cases)
#   Day Zero:    2020-03-25 (-41 days, when 50 or more deaths were reported)
#   Peak Deaths: 2020-04-21 (-14 days, 107 deaths)
#
# Parameters:
#   Totals:      22,082 cases and 2,669 deaths at end of 2020-05-02
#   Smoothed:    22,082 cases and 2,669 deaths at end of 2020-05-02 (7 points)
#   Spread:      Peak infection rate 5.2 (2020-03-11, compared to 7 days earlier)
#                Latest infection rate 0.8 (2020-05-02, compared to 7 days earlier)
#   Growth:      49 days (Start -> Peak Cases)
# ...
